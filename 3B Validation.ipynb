# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from random import seed
from scipy import stats
import seaborn as sns
import pingouin as pg
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, Lasso
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm
from statsmodels.formula.api import ols
from statsmodels.regression import linear_model
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from statsmodels.stats.mediation import Mediation
from sklearn.svm import SVR
from pingouin import ancova
import matplotlib.cm as cm
# %matplotlib inline

seed(888)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1 Load validation set

# %%
# load data from pickle and convert to dataframe
brain_test = pd.read_pickle("brain_test_validate.pkl")
main_test = pd.read_pickle("main_test_validate.pkl")
brain_train = pd.read_pickle("1_brain_train.pkl")
brain_test = pd.DataFrame(brain_test)
main_test = pd.DataFrame(main_test)
brain_train = pd.DataFrame(brain_train)

# %% [markdown]
# # 2 Preprocessing of validation set

# %% [markdown]
# ### 2.1 BrainAGE prediction for A2009

# %%
X_train = brain_train.iloc[:,1657:2544:2]
Y_train = brain_train.iloc[:,-1]
X_test = brain_test.iloc[:,1657:2544:2]
Y_test = brain_test.iloc[:,-1]

# standardize x-data
X_train = stats.zscore(X_train)
X_test = stats.zscore(X_test)

# set of alphas to try (=penalization)
alpha_parameters = np.power(10,np.linspace(start=-3, stop=5, num=100))

# %% [markdown]
# ### 2.1.1 Cross-validation

# %%
X_CV = X_train
Y_CV = Y_train

# randomly split data (only training no PA) into training and testing set
X_train_cv, X_test_cv, Y_train_cv, Y_test_cv = train_test_split(X_CV,Y_CV)

#define the model
model = RidgeCV(alphas = alpha_parameters)
#perform 10-fold cross validation
scores = cross_val_score(model, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')
#calculate the mean-absolute error
mae = -1 * scores.mean()
print("The MAE for cross-validation (Ridge):", mae)

# for correction
model.fit(X_train_cv,Y_train_cv)
y_pred_cv = model.predict(X_test_cv)
# Out:
# The MAE for cross-validation (Ridge): 4.192981026915527

# %% [markdown]
# ### 2.1.2 Prediction

# %%
model_Lasso = LassoCV(alphas = alpha_parameters, max_iter=100000)
model_Ridge = RidgeCV(alphas = alpha_parameters)
model_SVR = SVR(kernel = 'rbf')

# train model 
model_Lasso.fit(X_train,Y_train)
model_Ridge.fit(X_train,Y_train)
model_SVR.fit(X_train,Y_train)

# get predicted values for test set
y_pred_Lasso = model_Lasso.predict(X_test)
y_pred_Ridge = model_Ridge.predict(X_test)
y_pred_SVR = model_SVR.predict(X_test)

# calculate brain age gap
brain_age_delta_Lasso = y_pred_Lasso-Y_test
brain_age_delta_Ridge = y_pred_Ridge-Y_test
brain_age_delta_SVR = y_pred_SVR-Y_test

# get mean absolute error (MAE)
print("The MAE for testing set using Lasso:", mean_absolute_error(Y_test,y_pred_Lasso))
print("The MAE for testing set using Ridge:", mean_absolute_error(Y_test,y_pred_Ridge))
print("The MAE for testing set using SVR:", mean_absolute_error(Y_test,y_pred_SVR))

# Spearman rank order correlations
print("The Spearman r for Ridge vs Lasso:", stats.spearmanr(brain_age_delta_Ridge, brain_age_delta_Lasso))
print("The Spearman r for Ridge vs SVR:", stats.spearmanr(brain_age_delta_Ridge, brain_age_delta_SVR))
print("The Spearman r for SVR vs Lasso:", stats.spearmanr(brain_age_delta_SVR, brain_age_delta_Lasso))

# top x coefficients and their names
coeff = np.asarray(model_Ridge.coef_)
coeffabs = np.asarray(abs(model_Ridge.coef_))
top_10_coefficients = np.argsort(coeffabs)[-20:]
print(X_train.iloc[:,top_10_coefficients].columns)
print(coeff[top_10_coefficients])

# plot figure with x: actual age Y: predicted age, and a line with slope 1 for reference
plt.figure()
plt.scatter(Y_test, y_pred_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((60,60), slope=1, color='r')
plt.xticks(range(40,90,5))
plt.yticks(range(40,90,5))
plt.ylabel('Predicted Age', fontsize = 16)
plt.xlabel('Age', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()

plt.figure()
plt.scatter(Y_test,brain_age_delta_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((65,0), slope=-0.69, color="r")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# The MAE for testing set using Lasso: 4.265579543071238
# The MAE for testing set using Ridge: 4.262589702409484
# The MAE for testing set using SVR: 4.538391428456859
# The Spearman r for Ridge vs Lasso: SpearmanrResult(correlation=0.9997394384429193, pvalue=0.0)
# The Spearman r for Ridge vs SVR: SpearmanrResult(correlation=0.917699544760441, pvalue=0.0)
# The Spearman r for SVR vs Lasso: SpearmanrResult(correlation=0.9183795135363797, pvalue=0.0)
# Index(['volume_of_gtemporalinf_left_hemisphere_f27513_2_0',
#        'volume_of_scentral_right_hemisphere_f27743_2_0',
#        'volume_of_gpostcentral_right_hemisphere_f27726_2_0',
#        'area_of_gtemporalinf_left_hemisphere_f27365_2_0',
#        'mean_thickness_of_gfrontsup_left_hemisphere_f27418_2_0',
#        'area_of_latfispost_right_hemisphere_f27591_2_0',
#        'volume_of_stemporalsup_left_hemisphere_f27549_2_0',
#        'area_of_stemporalsup_left_hemisphere_f27401_2_0',
#        'area_of_sparietooccipital_right_hemisphere_f27615_2_0',
#        'area_of_gscingulant_right_hemisphere_f27556_2_0',
#        'area_of_scalcarine_left_hemisphere_f27372_2_0',
#        'volume_of_scalcarine_left_hemisphere_f27520_2_0',
#        'volume_of_gfrontsup_left_hemisphere_f27492_2_0',
#        'volume_of_gscingulant_right_hemisphere_f27704_2_0',
#        'area_of_gfrontsup_left_hemisphere_f27344_2_0',
#        'volume_of_sparietooccipital_right_hemisphere_f27763_2_0',
#        'volume_of_scentral_left_hemisphere_f27521_2_0',
#        'volume_of_latfispost_right_hemisphere_f27739_2_0',
#        'area_of_scalcarine_right_hemisphere_f27594_2_0',
#        'volume_of_scalcarine_right_hemisphere_f27742_2_0'],
#       dtype='object')
# [ 1.33500311  1.35589929 -1.40956036 -1.41335742 -1.4290742  -1.49188128
#  -1.49429486  1.5138274  -1.53084042  1.55013063 -1.58490537  1.58906398
#   1.60619697 -1.67635603 -1.749753    1.75977046  1.86033162  2.16152389
#  -2.37541509  2.37603676]

# %% [markdown]
# ### 2.1.3 Correction

# %%
# reformat cross validation data for regression model
y_pred_cv = np.asarray(y_pred_cv)
y_pred_cv = np.reshape(y_pred_cv, (-1,1))
Y_test_cv = np.asarray(Y_test_cv)
Y_test_cv = np.reshape(Y_test_cv, (-1,1))

# now using correction from the R code that's online from Cole
reg = LinearRegression().fit(Y_test_cv, y_pred_cv)
coef = float(reg.coef_)
intercept = float(reg.intercept_)
print("Coefficient and Intercept:", coef, intercept)

# correction by cole
function = lambda t: (t-intercept)/coef
vfunc = np.vectorize(function)
corr_brainage_1 = vfunc(y_pred_Ridge)
corr_brainage_delta_1 = corr_brainage_1-Y_test

# plots corrected
# plots corrected
plt.figure()
plt.scatter(Y_test, corr_brainage_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((65,65), slope=coef, color="g")
plt.ylabel("Brain Age Corrected", fontsize = 15)
plt.axline((60,60), slope=1, color='r')
plt.xlabel("Age", fontsize = 15)
plt.xticks(range(40,90,5))
plt.yticks(range(25,110,5))
plt.show()

plt.figure()
plt.scatter(Y_test, corr_brainage_delta_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE Corrected", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# Coefficient and Intercept: 0.5423528685097959 29.55261252813179

# %% [markdown]
# ### 2.1.4 Add BrainAge Deltas to Dataframe

# %%
main_test["BA"] = corr_brainage_delta_1

# %% [markdown]
# ## 2.2 Recoding

# %%
# 1 = Cheadle;  2 = Reading;  3 = Newcastle;  4 = Bristol
main_test['IS'] = main_test['IS'].map({'11025': 1, '11026': 2,'11027': 3, '11028': 4})
main_test["Gender"] = main_test["Gender"].map({"Female":0, "Male":1})
main_test["Gender"] = main_test["Gender"].astype("int")

del main_test["ID"]
del main_test["MVPA"]
del main_test["TPA"]

# %% [markdown]
# ## 2.3 Exclusions of missing SRPA

# %%
before = main_test.shape[0]
outlier = np.mean(main_test["SRLPA"]) + np.std(main_test["SRLPA"])*3
main_test = main_test[main_test["SRLPA"]<outlier]
outlier = np.mean(main_test["SRMPA"]) + np.std(main_test["SRMPA"])*3
main_test = main_test[main_test["SRMPA"]<outlier]
outlier = np.mean(main_test["SRVPA"]) + np.std(main_test["SRVPA"])*3
main_test = main_test[main_test["SRVPA"]<outlier]
after = main_test.shape[0]
print("Outliers on self-reported PA:", before-after)
print(after)
# Out:
# Outliers on self-reported PA: 532
# 5452

# %% [markdown]
# # 3 Basic distributions of validation set

# %% [markdown]
# ## 3.1 Data and Descriptives

# %%
main_test.head()
# Out:
#         Age  Gender  IS      VPA       MPA        LPA   SRLPA   SRMPA   SRVPA  \
# 4723   73.0       0   1  59.2704  661.8528  2400.4512  1039.5   360.0     0.0
# 25494  55.0       1   1  70.0560  970.7760  1991.5920   396.0   120.0     0.0
# 34463  65.0       0   2  48.6720  506.1888  2813.2416  1386.0  3360.0  1280.0
# 26337  67.0       0   3   0.0000   60.4800  1653.1200   132.0   240.0     0.0
# 29224  70.0       0   2   9.2736  361.6704  1873.2672    99.0     0.0   360.0
#
#          HG    HR      BMI   DBP    SBP         BA
# 4723   20.0  52.0  25.1338  74.0  137.0   3.414835
# 25494  26.0  55.0  22.9630  80.0  148.0   2.356011
# 34463  22.0  45.0  23.8325  63.0  108.0  -6.996363
# 26337  38.0  68.0  33.6473  84.0  139.0  15.439077
# 29224  24.0  69.0  32.8906  87.0  132.0   2.780876

# %%
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("Number of females:", female.shape[0])
print("NUmber of males:",male.shape[0])

print("Age")
mean = female["Age"].mean()
print("Female", mean)
std = female["Age"].std()
print("Female",std)
mean = male["Age"].mean()
print("Male",mean)
std = male["Age"].std()
print("Male",std)

print("LPA")
mean = female["LPA"].mean()
print("Female", mean)
std = female["LPA"].std()
print("Female",std)
mean = male["LPA"].mean()
print("Male",mean)
std = male["LPA"].std()
print("Male",std)

print("MPA")
mean = female["MPA"].mean()
print("Female", mean)
std = female["MPA"].std()
print("Female",std)
mean = male["MPA"].mean()
print("Male",mean)
std = male["MPA"].std()
print("Male",std)

print("VPA")
mean = female["VPA"].mean()
print("Female", mean)
std = female["VPA"].std()
print("Female",std)
mean = male["VPA"].mean()
print("Male",mean)
std = male["VPA"].std()
print("Male",std)

print("SRLPA")
mean = female["SRLPA"].mean()
print("Female", mean)
std = female["SRLPA"].std()
print("Female",std)
mean = male["SRLPA"].mean()
print("Male",mean)
std = male["SRLPA"].std()
print("Male",std)

print("SRMPA")
mean = female["SRMPA"].mean()
print("Female", mean)
std = female["SRMPA"].std()
print("Female",std)
mean = male["SRMPA"].mean()
print("Male",mean)
std = male["SRMPA"].std()
print("Male",std)

print("SRVPA")
mean = female["SRVPA"].mean()
print("Female", mean)
std = female["SRVPA"].std()
print("Female",std)
mean = male["SRVPA"].mean()
print("Male",mean)
std = male["SRVPA"].std()
print("Male",std)

print("BMI")
mean = female["BMI"].mean()
print("Female", mean)
std = female["BMI"].std()
print("Female",std)
mean = male["BMI"].mean()
print("Male",mean)
std = male["BMI"].std()
print("Male",std)

print("HG")
mean = female["HG"].mean()
print("Female", mean)
std = female["HG"].std()
print("Female",std)
mean = male["HG"].mean()
print("Male",mean)
std = male["HG"].std()
print("Male",std)

print("HR")
mean = female["HR"].mean()
print("Female", mean)
std = female["HR"].std()
print("Female",std)
mean = male["HR"].mean()
print("Male",mean)
std = male["HR"].std()
print("Male",std)

print("DBP")
mean = female["DBP"].mean()
print("Female", mean)
std = female["DBP"].std()
print("Female",std)
mean = male["DBP"].mean()
print("Male",mean)
std = male["DBP"].std()
print("Male",std)

print("SBP")
mean = female["SBP"].mean()
print("Female", mean)
std = female["SBP"].std()
print("Female",std)
mean = male["SBP"].mean()
print("Male",mean)
std = male["SBP"].std()
print("Male",std)

print("IS")
print("Female")
female["IS"].value_counts()
print("Male")
male["IS"].value_counts()
# Out:
# Number of females: 2970
# NUmber of males: 2482
# Age
# Female 63.365656565656565
# Female 7.671358834590245
# Male 65.17808219178082
# Male 7.870456794472667
# LPA
# Female 2061.0672872727273
# Female 406.33606702437504
# Male 1885.3467519742142
# Male 409.6249987343925
# MPA
# Female 493.00463030303035
# Female 219.37278852675698
# Male 470.0986926672039
# Male 213.1870127069337
# VPA
# Female 31.059233939393966
# Female 39.8729402584149
# Male 38.12592618855765
# Male 46.701593415163025
# SRLPA
# Female 782.4266666666666
# Female 706.1642469143237
# Male 769.0568896051572
# Male 742.7437996329985
# SRMPA
# Female 642.7501683501683
# Female 762.365502137756
# Male 630.0080580177276
# Male 776.9453699945714
# SRVPA
# Female 476.6222222222222
# Female 627.6737299431975
# Male 597.453666398066
# Male 713.3294572774662
# BMI
# Female 25.948532020202023
# Female 4.526024283563611
# Male 26.8570723207091
# Male 3.747773618911473
# HG
# Female 26.25690235690236
# Female 6.234093493954997
# Male 42.15592264302982
# Male 8.508682952449652
# HR
# Female 68.92861952861954
# Female 10.21306969707317
# Male 66.81103948428687
# Male 11.861867502725236
# DBP
# Female 79.24410774410775
# Female 10.12791250037231
# Male 83.36059629331184
# Male 10.193142187231949
# SBP
# Female 132.9090909090909
# Female 18.395686947322144
# Male 140.41821112006446
# Male 17.186624075161365
# IS
# Female
# Male
# 1    1586
# 3     490
# 2     403
# 4       3
# Name: IS, dtype: int64

# %% [markdown]
# ## 3.2 Age and BrainAge

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'Gender', fill=True, palette = "crest")
plt.title("Age x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'Gender', fill=True, palette = "crest")
plt.title("BrainAge x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'IS', fill=True, palette = "crest")
plt.title("BrainAge x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'IS', fill=True, palette = "crest")
plt.title("Age x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'MPA', hue = 'IS', fill=True, palette = "crest")
plt.title("Moderate PA x Imaging site")
plt.show()


plt.figure()
sns.kdeplot(data = main_test, x= 'BA', fill=True, label="A2009")
plt.title("BrainAge Segmentations")
plt.legend()
plt.show()

# %% [markdown]
# ## 3.3 Physical activity

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA")
#sns.kdeplot(data = main_test, x= 'TPA', fill=True, label = "Total PA")
plt.xlabel("Min/week of physical activity")
plt.legend()
plt.xticks(range(0,5000,1000))
plt.ylim(0,0.01)
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA")
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA")
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA")
plt.xlabel("Min/week of physical activity")
#plt.title("Self Report PA distributions")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA", color="#6baed6")
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA", color="#08519c")
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Light PA")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA", color="#fd8d3c")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA", color="#a63603")
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Moderate PA")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA", color="#74c476")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA", color="#006d2c")
plt.ylim(0,0.01)
plt.xticks(range(0,3500,1000))
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Vigorous PA")
plt.legend()
plt.show()

# %% [markdown]
# ## 3.4 Health and Fitness

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'HG', hue = 'Gender', fill=True, palette = "crest")
plt.title("Hand grip")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'HR', hue = 'Gender', fill=True, palette = "crest")
plt.title("Heart rate")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Systolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'DBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Distolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BMI', hue = 'Gender', fill=True, palette = "crest")
plt.title("BMI")
plt.show()

# %%
main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI"]] = stats.zscore(main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI"]], nan_policy='omit')

# %%
main_test["CR"] = main_test["MPA"]*-1 + main_test["HG"]*-1 + main_test["DBP"] + main_test["SBP"] + main_test["HR"] + main_test["BMI"]
main_test["SRCR"] = main_test["SRMPA"]*-1 + main_test["HG"]*-1 + main_test["DBP"] + main_test["SBP"] + main_test["HR"] + main_test["BMI"]

# %%
model = ols("LPA ~ Age", data = main_test).fit()
main_test["LPA"] = model.resid

model = ols("MPA ~ Age", data = main_test).fit()
main_test["MPA"] = model.resid

model = ols("VPA ~ Age", data = main_test).fit()
main_test["VPA"] = model.resid

model = ols("SRLPA ~ Age", data = main_test).fit()
main_test["SRLPA"] = model.resid

model = ols("SRMPA ~ Age", data = main_test).fit()
main_test["SRMPA"] = model.resid

model = ols("SRVPA ~ Age", data = main_test).fit()
main_test["SRVPA"] = model.resid

model = ols("CR ~ Age", data = main_test).fit()
main_test["CR"] = model.resid

model = ols("SRCR ~ Age", data = main_test).fit()
main_test["SRCR"] = model.resid

model = ols("HR ~ Age", data = main_test).fit()
main_test["HR"] = model.resid

model = ols("DBP ~ Age", data = main_test).fit()
main_test["DBP"] = model.resid

model = ols("SBP ~ Age", data = main_test).fit()
main_test["SBP"] = model.resid

model = ols("BMI ~ Age", data = main_test).fit()
main_test["BMI"] = model.resid

model = ols("HG ~ Age", data = main_test).fit()
main_test["HG"] = model.resid

##

# model = ols("TPA ~ Age", data = main_test).fit()
# main_test["TPA"] = model.resid

# model = ols("MVPA ~ Age", data = main_test).fit()
# main_test["MVPA"] = model.resid

# model = ols("SRTPA ~ Age", data = main_test).fit()
# main_test["SRTPA"] = model.resid

# model = ols("SRMVPA ~ Age", data = main_test).fit()
# main_test["SRMVPA"] = model.resid

# %%
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("CR")
mean = female["CR"].mean()
print("Female", mean)
std = female["CR"].std()
print("Female",std)
mean = male["CR"].mean()
print("Male",mean)
std = male["CR"].std()
print("Male",std)

print("SRCR")
mean = female["SRCR"].mean()
print("Female", mean)
std = female["SRCR"].std()
print("Female",std)
mean = male["SRCR"].mean()
print("Male",mean)
std = male["SRCR"].std()
print("Male",std)
# Out:
# CR
# Female 0.3172916449635202
# Female 3.0887835991196364
# Male -0.3796761424422374
# Male 3.0192486917163497
# SRCR
# Female 0.3218057675469012
# Female 2.969016608057288
# Male -0.3850778120927849
# Male 2.9785580603962707

# %% [markdown]
# # 4 Simple Correlation Heatmap

# %%
corr = main_test.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'Gender'),
#   Text(0, 2.5, 'IS'),
#   Text(0, 3.5, 'VPA'),
#   Text(0, 4.5, 'MPA'),
#   Text(0, 5.5, 'LPA'),
#   Text(0, 6.5, 'SRLPA'),
#   Text(0, 7.5, 'SRMPA'),
#   Text(0, 8.5, 'SRVPA'),
#   Text(0, 9.5, 'HG'),
#   Text(0, 10.5, 'HR'),
#   Text(0, 11.5, 'BMI'),
#   Text(0, 12.5, 'DBP'),
#   Text(0, 13.5, 'SBP'),
#   Text(0, 14.5, 'BA'),
#   Text(0, 15.5, 'CR'),
#   Text(0, 16.5, 'SRCR')])

# %%
female = main_test[main_test["Gender"] == 0]
del female["Gender"]
corr = female.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'IS'),
#   Text(0, 2.5, 'VPA'),
#   Text(0, 3.5, 'MPA'),
#   Text(0, 4.5, 'LPA'),
#   Text(0, 5.5, 'SRLPA'),
#   Text(0, 6.5, 'SRMPA'),
#   Text(0, 7.5, 'SRVPA'),
#   Text(0, 8.5, 'HG'),
#   Text(0, 9.5, 'HR'),
#   Text(0, 10.5, 'BMI'),
#   Text(0, 11.5, 'DBP'),
#   Text(0, 12.5, 'SBP'),
#   Text(0, 13.5, 'BA'),
#   Text(0, 14.5, 'CR'),
#   Text(0, 15.5, 'SRCR')])

# %%
male = main_test[main_test["Gender"] == 1]
del male["Gender"]
corr = male.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'IS'),
#   Text(0, 2.5, 'VPA'),
#   Text(0, 3.5, 'MPA'),
#   Text(0, 4.5, 'LPA'),
#   Text(0, 5.5, 'SRLPA'),
#   Text(0, 6.5, 'SRMPA'),
#   Text(0, 7.5, 'SRVPA'),
#   Text(0, 8.5, 'HG'),
#   Text(0, 9.5, 'HR'),
#   Text(0, 10.5, 'BMI'),
#   Text(0, 11.5, 'DBP'),
#   Text(0, 12.5, 'SBP'),
#   Text(0, 13.5, 'BA'),
#   Text(0, 14.5, 'CR'),
#   Text(0, 15.5, 'SRCR')])

# %% [markdown]
# # 6 Models with OLS

# %% [markdown]
# ## 6.1 Single Predictor Models

# %% [markdown]
# ### 6.1.1 Accelerometer PA

# %%
lpa = ols('BA ~ LPA + Gender + IS + Gender:LPA', missing='drop', data = main_test).fit()
print(lpa.summary())

#calculate effect size
results = lpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.544
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):             0.0377
# Time:                        21:01:13   Log-Likelihood:                -18432.
# No. Observations:                5452   AIC:                         3.687e+04
# Df Residuals:                    5447   BIC:                         3.691e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4645      0.231     -2.008      0.045      -0.918      -0.011
# LPA           -0.0579      0.134     -0.432      0.666      -0.321       0.205
# Gender         0.5539      0.198      2.795      0.005       0.165       0.942
# IS             0.0682      0.118      0.575      0.565      -0.164       0.300
# Gender:LPA    -0.0419      0.198     -0.212      0.832      -0.430       0.346
# ==============================================================================
# Omnibus:                       57.406   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.574
# Skew:                           0.199   Prob(JB):                     5.77e-15
# Kurtosis:                       3.360   Cond. No.                         5.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.027195
# LPA          -0.005849
# Gender        0.037858
# IS            0.007794
# Gender:LPA   -0.002865
# dtype: float64

# %%
mpa = ols('BA ~ MPA + Gender + IS + Gender:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     6.651
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           2.46e-05
# Time:                        21:01:16   Log-Likelihood:                -18424.
# No. Observations:                5452   AIC:                         3.686e+04
# Df Residuals:                    5447   BIC:                         3.689e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5095      0.229     -2.221      0.026      -0.959      -0.060
# MPA           -0.4029      0.132     -3.062      0.002      -0.661      -0.145
# Gender         0.5649      0.193      2.921      0.004       0.186       0.944
# IS             0.0962      0.118      0.813      0.416      -0.136       0.328
# Gender:MPA    -0.0077      0.198     -0.039      0.969      -0.396       0.380
# ==============================================================================
# Omnibus:                       56.984   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.949
# Skew:                           0.199   Prob(JB):                     7.88e-15
# Kurtosis:                       3.357   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.030075
# MPA          -0.041473
# Gender        0.039563
# IS            0.011006
# Gender:MPA   -0.000524
# dtype: float64

# %%
vpa = ols('BA ~ VPA + Gender +  IS + Gender:VPA', missing='drop', data = main_test).fit()
print(vpa.summary())

#calculate effect size
results = vpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.991
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):             0.0177
# Time:                        21:01:19   Log-Likelihood:                -18431.
# No. Observations:                5452   AIC:                         3.687e+04
# Df Residuals:                    5447   BIC:                         3.691e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5093      0.230     -2.210      0.027      -0.961      -0.058
# VPA           -0.1698      0.146     -1.167      0.243      -0.455       0.116
# Gender         0.6214      0.195      3.191      0.001       0.240       1.003
# IS             0.0790      0.119      0.666      0.505      -0.153       0.311
# Gender:VPA     0.0283      0.199      0.142      0.887      -0.362       0.419
# ==============================================================================
# Omnibus:                       57.367   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.517
# Skew:                           0.199   Prob(JB):                     5.93e-15
# Kurtosis:                       3.360   Cond. No.                         5.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.029935
# VPA          -0.015802
# Gender        0.043218
# IS            0.009022
# Gender:VPA    0.001925
# dtype: float64

# %% [markdown]
# ### 6.1.2 Self-report PA

# %%
srlpa = ols('BA ~ SRLPA + Gender + IS + Gender:SRLPA', missing='drop', data = main_test).fit()
print(srlpa.summary())

#calculate effect size
results = srlpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.389
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):             0.0488
# Time:                        21:01:22   Log-Likelihood:                -18433.
# No. Observations:                5452   AIC:                         3.688e+04
# Df Residuals:                    5447   BIC:                         3.691e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.4798      0.230     -2.089      0.037      -0.930      -0.030
# SRLPA           -0.0220      0.134     -0.165      0.869      -0.284       0.240
# Gender           0.5881      0.194      3.038      0.002       0.209       0.968
# IS               0.0710      0.118      0.599      0.549      -0.161       0.303
# Gender:SRLPA     0.0366      0.193      0.189      0.850      -0.342       0.415
# ==============================================================================
# Omnibus:                       57.419   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.666
# Skew:                           0.199   Prob(JB):                     5.51e-15
# Kurtosis:                       3.362   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      -0.028292
# SRLPA          -0.002230
# Gender          0.041139
# IS              0.008117
# Gender:SRLPA    0.002565
# dtype: float64

# %%
srmpa = ols('BA ~ SRMPA + Gender + IS + Gender:SRMPA', missing='drop', data = main_test).fit()
print(srmpa.summary())

#calculate effect size
results = srmpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.702
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):             0.0289
# Time:                        21:01:25   Log-Likelihood:                -18432.
# No. Observations:                5452   AIC:                         3.687e+04
# Df Residuals:                    5447   BIC:                         3.691e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.4774      0.230     -2.077      0.038      -0.928      -0.027
# SRMPA            0.0437      0.133      0.328      0.743      -0.217       0.305
# Gender           0.5849      0.194      3.021      0.003       0.205       0.964
# IS               0.0687      0.118      0.580      0.562      -0.164       0.301
# Gender:SRMPA    -0.1991      0.195     -1.020      0.308      -0.582       0.184
# ==============================================================================
# Omnibus:                       57.367   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.718
# Skew:                           0.198   Prob(JB):                     5.37e-15
# Kurtosis:                       3.364   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      -0.028136
# SRMPA           0.004445
# Gender          0.040909
# IS              0.007852
# Gender:SRMPA   -0.013807
# dtype: float64

# %%
srvpa = ols('BA ~ SRVPA + Gender + IS + Gender:SRVPA', missing='drop', data = main_test).fit()
print(srvpa.summary())

#calculate effect size
results = srvpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.475
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):             0.0423
# Time:                        21:01:28   Log-Likelihood:                -18432.
# No. Observations:                5452   AIC:                         3.687e+04
# Df Residuals:                    5447   BIC:                         3.691e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.4859      0.230     -2.113      0.035      -0.937      -0.035
# SRVPA           -0.0726      0.140     -0.520      0.603      -0.346       0.201
# Gender           0.5991      0.194      3.081      0.002       0.218       0.980
# IS               0.0707      0.118      0.597      0.551      -0.161       0.303
# Gender:SRVPA     0.0272      0.194      0.140      0.888      -0.353       0.407
# ==============================================================================
# Omnibus:                       57.381   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.642
# Skew:                           0.199   Prob(JB):                     5.57e-15
# Kurtosis:                       3.362   Cond. No.                         5.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      -0.028621
# SRVPA          -0.007036
# Gender          0.041728
# IS              0.008085
# Gender:SRVPA    0.001903
# dtype: float64

# %% [markdown]
# ### 6.1.3 Combined risk scores (Acc)

# %%
cr = ols('BA ~ CR + Gender + IS + Gender:CR', missing='drop', data = main_test).fit()
print(cr.summary())

#calculate effect size
results = cr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     16.70
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           1.30e-13
# Time:                        21:01:31   Log-Likelihood:                -18404.
# No. Observations:                5452   AIC:                         3.682e+04
# Df Residuals:                    5447   BIC:                         3.685e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5667      0.229     -2.476      0.013      -1.015      -0.118
# CR             0.2178      0.042      5.178      0.000       0.135       0.300
# Gender         0.7561      0.194      3.900      0.000       0.376       1.136
# IS             0.0820      0.118      0.696      0.487      -0.149       0.313
# Gender:CR      0.0417      0.063      0.660      0.509      -0.082       0.165
# ==============================================================================
# Omnibus:                       63.138   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.526
# Skew:                           0.206   Prob(JB):                     1.08e-16
# Kurtosis:                       3.393   Cond. No.                         9.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.033536
# CR           0.070123
# Gender       0.052824
# IS           0.009424
# Gender:CR    0.008944
# dtype: float64

# %% [markdown]
# #### 6.1.3.1 Males

# %%
male = main_test[main_test["Gender"] == 1]

crm = ols('BA ~ CR + IS', missing='drop', data = male).fit()
print(crm.summary())

#calculate effect size
results = crm
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     18.12
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           1.55e-08
# Time:                        21:01:34   Log-Likelihood:                -8384.7
# No. Observations:                2482   AIC:                         1.678e+04
# Df Residuals:                    2479   BIC:                         1.679e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3665      0.311     -1.179      0.239      -0.976       0.243
# CR             0.2620      0.047      5.548      0.000       0.169       0.355
# IS             0.4388      0.177      2.479      0.013       0.092       0.786
# ==============================================================================
# Omnibus:                       10.620   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.111
# Skew:                           0.126   Prob(JB):                      0.00387
# Kurtosis:                       3.209   Cond. No.                         7.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.015963
# CR           0.075144
# IS           0.033570
# dtype: float64

# %% [markdown]
# #### 6.1.3.2 Females

# %%
female = main_test[main_test["Gender"] == 0]

crf = ols('BA ~ CR + IS', missing='drop', data = female).fit()
print(crf.summary())

#calculate effect size
results = crf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     14.34
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           6.35e-07
# Time:                        21:01:37   Log-Likelihood:                -10016.
# No. Observations:                2970   AIC:                         2.004e+04
# Df Residuals:                    2967   BIC:                         2.006e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1095      0.283     -0.386      0.699      -0.665       0.446
# CR             0.2178      0.042      5.196      0.000       0.136       0.300
# IS            -0.2047      0.158     -1.298      0.194      -0.514       0.105
# ==============================================================================
# Omnibus:                       59.631   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.745
# Skew:                           0.272   Prob(JB):                     9.69e-17
# Kurtosis:                       3.549   Cond. No.                         7.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.005233
# CR           0.070373
# IS          -0.017576
# dtype: float64

# %% [markdown]
# ### 6.1.4 Combined risk score (SR)

# %%
srcr = ols('BA ~ SRCR + Gender + IS + Gender:SRCR', missing='drop', data = main_test).fit()
print(srcr.summary())

#calculate effect size
results = srcr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     13.28
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           9.15e-11
# Time:                        21:01:41   Log-Likelihood:                -18411.
# No. Observations:                5452   AIC:                         3.683e+04
# Df Residuals:                    5447   BIC:                         3.686e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.5219      0.229     -2.279      0.023      -0.971      -0.073
# SRCR            0.1862      0.044      4.248      0.000       0.100       0.272
# Gender          0.7405      0.194      3.813      0.000       0.360       1.121
# IS              0.0596      0.118      0.505      0.613      -0.172       0.291
# Gender:SRCR     0.0549      0.065      0.847      0.397      -0.072       0.182
# ==============================================================================
# Omnibus:                       60.618   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.424
# Skew:                           0.201   Prob(JB):                     5.10e-16
# Kurtosis:                       3.385   Cond. No.                         9.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept     -0.030868
# SRCR           0.057537
# Gender         0.051643
# IS             0.006843
# Gender:SRCR    0.011465
# dtype: float64

# %% [markdown]
# ### 6.1.5 Health & Fitness

# %%
hg = ols('BA ~ HG + Gender + IS + Gender:HG', missing='drop', data = main_test).fit()
print(hg.summary())

#calculate effect size
results = hg
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.798
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):             0.0246
# Time:                        21:01:43   Log-Likelihood:                -18432.
# No. Observations:                5452   AIC:                         3.687e+04
# Df Residuals:                    5447   BIC:                         3.691e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6466      0.279     -2.314      0.021      -1.194      -0.099
# HG            -0.2460      0.234     -1.053      0.292      -0.704       0.212
# Gender         0.8668      0.291      2.977      0.003       0.296       1.438
# IS             0.0709      0.118      0.599      0.549      -0.161       0.303
# Gender:HG      0.1079      0.297      0.363      0.717      -0.475       0.691
# ==============================================================================
# Omnibus:                       58.855   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.579
# Skew:                           0.201   Prob(JB):                     2.12e-15
# Kurtosis:                       3.369   Cond. No.                         9.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.031343
# HG          -0.014261
# Gender       0.040325
# IS           0.008107
# Gender:HG    0.004916
# dtype: float64

# %%
hr = ols('BA ~ HR + Gender + IS + Gender:HR', missing='drop', data = main_test).fit()
print(hr.summary())

#calculate effect size
results = hr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     7.264
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           7.87e-06
# Time:                        21:01:45   Log-Likelihood:                -18423.
# No. Observations:                5452   AIC:                         3.686e+04
# Df Residuals:                    5447   BIC:                         3.689e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5082      0.229     -2.216      0.027      -0.958      -0.059
# HR             0.3973      0.141      2.817      0.005       0.121       0.674
# Gender         0.6712      0.194      3.457      0.001       0.291       1.052
# IS             0.0665      0.118      0.562      0.574      -0.165       0.298
# Gender:HR      0.0543      0.194      0.280      0.779      -0.326       0.434
# ==============================================================================
# Omnibus:                       60.668   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.993
# Skew:                           0.203   Prob(JB):                     6.33e-16
# Kurtosis:                       3.378   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.030006
# HR           0.038146
# Gender       0.046823
# IS           0.007614
# Gender:HR    0.003798
# dtype: float64

# %%
bmi = ols('BA ~ BMI + Gender + IS + Gender:BMI', missing='drop', data = main_test).fit()
print(bmi.summary())

#calculate effect size
results = bmi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     8.382
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           9.74e-07
# Time:                        21:01:46   Log-Likelihood:                -18421.
# No. Observations:                5452   AIC:                         3.685e+04
# Df Residuals:                    5447   BIC:                         3.688e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4705      0.229     -2.052      0.040      -0.920      -0.021
# BMI            0.3194      0.121      2.632      0.009       0.081       0.557
# Gender         0.4823      0.194      2.481      0.013       0.101       0.863
# IS             0.0841      0.118      0.712      0.477      -0.148       0.316
# Gender:BMI     0.3422      0.201      1.703      0.089      -0.052       0.736
# ==============================================================================
# Omnibus:                       58.514   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.703
# Skew:                           0.198   Prob(JB):                     1.99e-15
# Kurtosis:                       3.377   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.027788
# BMI           0.035641
# Gender        0.033605
# IS            0.009642
# Gender:BMI    0.023063
# dtype: float64

# %%
dbp = ols('BA ~ DBP + Gender + IS + Gender:DBP', missing='drop', data = main_test).fit()
print(dbp.summary())

#calculate effect size
results = dbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     9.199
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           2.10e-07
# Time:                        21:01:48   Log-Likelihood:                -18419.
# No. Observations:                5452   AIC:                         3.685e+04
# Df Residuals:                    5447   BIC:                         3.688e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3588      0.231     -1.553      0.120      -0.812       0.094
# DBP            0.5386      0.134      4.025      0.000       0.276       0.801
# Gender         0.3956      0.197      2.010      0.044       0.010       0.781
# IS             0.0531      0.118      0.449      0.653      -0.179       0.285
# Gender:DBP    -0.0578      0.197     -0.293      0.769      -0.444       0.329
# ==============================================================================
# Omnibus:                       58.226   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.718
# Skew:                           0.200   Prob(JB):                     3.25e-15
# Kurtosis:                       3.365   Cond. No.                         5.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.021034
# DBP           0.054514
# Gender        0.027226
# IS            0.006086
# Gender:DBP   -0.003974
# dtype: float64

# %%
sbp = ols('BA ~ SBP + Gender + IS + Gender:SBP', missing='drop', data = main_test).fit()
print(sbp.summary())

#calculate effect size
results = sbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     7.064
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           1.14e-05
# Time:                        21:01:48   Log-Likelihood:                -18423.
# No. Observations:                5452   AIC:                         3.686e+04
# Df Residuals:                    5447   BIC:                         3.689e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4125      0.230     -1.791      0.073      -0.864       0.039
# SBP            0.4305      0.137      3.133      0.002       0.161       0.700
# Gender         0.4362      0.197      2.219      0.026       0.051       0.821
# IS             0.0702      0.118      0.594      0.552      -0.162       0.302
# Gender:SBP     0.0337      0.208      0.162      0.871      -0.373       0.441
# ==============================================================================
# Omnibus:                       60.434   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.621
# Skew:                           0.203   Prob(JB):                     7.62e-16
# Kurtosis:                       3.376   Cond. No.                         5.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.024257
# SBP           0.042433
# Gender        0.030059
# IS            0.008046
# Gender:SBP    0.002196
# dtype: float64

# %% [markdown]
# ## 6.2 Multiple Predictor & COmparison Models

# %% [markdown]
# ### 6.2.1 Covariates

# %%
cov_model = ols('BA ~ Gender + Age + IS ', missing='drop', data = main_test).fit()
print(cov_model.summary())

#calculate effect size
results = cov_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     5.745
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           0.000640
# Time:                        21:01:48   Log-Likelihood:                -18429.
# No. Observations:                5452   AIC:                         3.687e+04
# Df Residuals:                    5448   BIC:                         3.689e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6543      0.803      2.061      0.039       0.081       3.228
# Gender         0.6524      0.195      3.349      0.001       0.271       1.034
# Age           -0.0347      0.013     -2.775      0.006      -0.059      -0.010
# IS             0.1111      0.119      0.932      0.351      -0.123       0.345
# ==============================================================================
# Omnibus:                       60.694   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.316
# Skew:                           0.207   Prob(JB):                     8.87e-16
# Kurtosis:                       3.366   Cond. No.                         539.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.027917
# Gender       0.045356
# Age         -0.037586
# IS           0.012621
# dtype: float64

# %% [markdown]
# ### 6.2.2 Accelerometer + Self-report PA

# %%
sr_pa_model = ols('BA ~ SRMPA + MPA + Gender + IS', missing='drop', data = main_test).fit()
print(sr_pa_model.summary())

#calculate effect size
results = sr_pa_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     6.651
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           2.46e-05
# Time:                        21:01:48   Log-Likelihood:                -18424.
# No. Observations:                5452   AIC:                         3.686e+04
# Df Residuals:                    5447   BIC:                         3.689e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5090      0.230     -2.217      0.027      -0.959      -0.059
# SRMPA         -0.0038      0.098     -0.039      0.969      -0.196       0.188
# MPA           -0.4059      0.099     -4.099      0.000      -0.600      -0.212
# Gender         0.5647      0.193      2.920      0.004       0.186       0.944
# IS             0.0961      0.118      0.811      0.418      -0.136       0.328
# ==============================================================================
# Omnibus:                       56.920   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.869
# Skew:                           0.199   Prob(JB):                     8.20e-15
# Kurtosis:                       3.357   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.030025
# SRMPA       -0.000531
# MPA         -0.055520
# Gender       0.039545
# IS           0.010979
# dtype: float64

# %% [markdown]
# ### 6.2.3 PA + Fitness

# %%
pa_fitness = ols('BA ~ HG + MPA + IS + Gender', missing='drop', data = main_test).fit()
print(pa_fitness.summary())

#calculate effect size
results = pa_fitness
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     7.005
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           1.28e-05
# Time:                        21:01:48   Log-Likelihood:                -18423.
# No. Observations:                5452   AIC:                         3.686e+04
# Df Residuals:                    5447   BIC:                         3.689e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6249      0.249     -2.508      0.012      -1.113      -0.136
# HG            -0.1713      0.144     -1.187      0.235      -0.454       0.112
# MPA           -0.4047      0.098     -4.114      0.000      -0.598      -0.212
# IS             0.0959      0.118      0.810      0.418      -0.136       0.328
# Gender         0.8200      0.289      2.837      0.005       0.253       1.387
# ==============================================================================
# Omnibus:                       58.014   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.330
# Skew:                           0.200   Prob(JB):                     3.95e-15
# Kurtosis:                       3.363   Cond. No.                         7.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.033968
# HG          -0.016082
# MPA         -0.055714
# IS           0.010965
# Gender       0.038425
# dtype: float64

# %% [markdown]
# ### 6.2.4 Health

# %%
health = ols('BA ~ SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(health.summary())

#calculate effect size
results = health
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     9.354
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           3.11e-10
# Time:                        21:01:48   Log-Likelihood:                -18409.
# No. Observations:                5452   AIC:                         3.683e+04
# Df Residuals:                    5445   BIC:                         3.688e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4057      0.230     -1.763      0.078      -0.857       0.046
# SBP            0.1823      0.146      1.250      0.212      -0.104       0.468
# HR             0.2841      0.102      2.795      0.005       0.085       0.483
# DBP            0.2264      0.146      1.551      0.121      -0.060       0.513
# BMI            0.2896      0.102      2.845      0.004       0.090       0.489
# Gender         0.4351      0.199      2.183      0.029       0.044       0.826
# IS             0.0680      0.118      0.576      0.565      -0.164       0.300
# ==============================================================================
# Omnibus:                       61.397   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.408
# Skew:                           0.202   Prob(JB):                     3.12e-16
# Kurtosis:                       3.388   Cond. No.                         5.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.023870
# SBP          0.016922
# HR           0.037848
# DBP          0.021002
# BMI          0.038530
# Gender       0.029559
# IS           0.007796
# dtype: float64

# %% [markdown]
# ### 6.2.5 Health and Fitness

# %%
he_fi = ols('BA ~ HG + SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(he_fi.summary())

#calculate effect size
results = he_fi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     8.314
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           3.93e-10
# Time:                        21:01:48   Log-Likelihood:                -18408.
# No. Observations:                5452   AIC:                         3.683e+04
# Df Residuals:                    5444   BIC:                         3.689e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5429      0.249     -2.179      0.029      -1.031      -0.054
# HG            -0.2073      0.144     -1.437      0.151      -0.490       0.076
# SBP            0.1861      0.146      1.275      0.202      -0.100       0.472
# HR             0.2774      0.102      2.726      0.006       0.078       0.477
# DBP            0.2337      0.146      1.600      0.110      -0.053       0.520
# BMI            0.2902      0.102      2.851      0.004       0.091       0.490
# Gender         0.7383      0.290      2.543      0.011       0.169       1.307
# IS             0.0675      0.118      0.571      0.568      -0.164       0.299
# ==============================================================================
# Omnibus:                       62.741   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.231
# Skew:                           0.204   Prob(JB):                     1.25e-16
# Kurtosis:                       3.395   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.029507
# HG          -0.019455
# SBP          0.017274
# HR           0.036918
# DBP          0.021664
# BMI          0.038617
# Gender       0.034443
# IS           0.007739
# dtype: float64

# %% [markdown]
# ### 6.2.6 PA & Health

# %%
pa_he = ols('BA ~ MPA + SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(pa_he.summary())

#calculate effect size
results = pa_he
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     9.291
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           1.74e-11
# Time:                        21:01:49   Log-Likelihood:                -18405.
# No. Observations:                5452   AIC:                         3.683e+04
# Df Residuals:                    5444   BIC:                         3.688e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4279      0.230     -1.859      0.063      -0.879       0.023
# MPA           -0.3029      0.102     -2.972      0.003      -0.503      -0.103
# SBP            0.1880      0.146      1.289      0.197      -0.098       0.474
# HR             0.2659      0.102      2.613      0.009       0.066       0.465
# DBP            0.2329      0.146      1.596      0.110      -0.053       0.519
# BMI            0.2117      0.105      2.015      0.044       0.006       0.418
# Gender         0.4262      0.199      2.139      0.032       0.036       0.817
# IS             0.0846      0.118      0.716      0.474      -0.147       0.316
# ==============================================================================
# Omnibus:                       60.826   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.391
# Skew:                           0.203   Prob(JB):                     5.19e-16
# Kurtosis:                       3.381   Cond. No.                         5.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.025180
# MPA         -0.040252
# SBP          0.017459
# HR           0.035385
# DBP          0.021620
# BMI          0.027296
# Gender       0.028968
# IS           0.009698
# dtype: float64

# %% [markdown]
# ### 6.2.7 PA & Health & Fitness

# %%
pa_he_fi = ols('BA ~ MPA + HG + SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(pa_he_fi.summary())

#calculate effect size
results = pa_he_fi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     8.375
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           2.29e-11
# Time:                        21:01:49   Log-Likelihood:                -18404.
# No. Observations:                5452   AIC:                         3.683e+04
# Df Residuals:                    5443   BIC:                         3.689e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5611      0.249     -2.253      0.024      -1.049      -0.073
# MPA           -0.3009      0.102     -2.953      0.003      -0.501      -0.101
# HG            -0.2015      0.144     -1.397      0.162      -0.484       0.081
# SBP            0.1916      0.146      1.314      0.189      -0.094       0.477
# HR             0.2595      0.102      2.547      0.011       0.060       0.459
# DBP            0.2399      0.146      1.644      0.100      -0.046       0.526
# BMI            0.2128      0.105      2.026      0.043       0.007       0.419
# Gender         0.7209      0.290      2.485      0.013       0.152       1.290
# IS             0.0840      0.118      0.711      0.477      -0.148       0.316
# ==============================================================================
# Omnibus:                       62.143   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.172
# Skew:                           0.204   Prob(JB):                     2.13e-16
# Kurtosis:                       3.388   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.030508
# MPA         -0.039994
# HG          -0.018922
# SBP          0.017798
# HR           0.034500
# DBP          0.022259
# BMI          0.027440
# Gender       0.033649
# IS           0.009631
# dtype: float64

# %%
sr_pa_he_fi = ols('BA ~ SRMPA + HG + SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(sr_pa_he_fi.summary())

#calculate effect size
results = sr_pa_he_fi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     7.274
# Date:                Sun, 12 Feb 2023   Prob (F-statistic):           1.19e-09
# Time:                        21:01:49   Log-Likelihood:                -18408.
# No. Observations:                5452   AIC:                         3.683e+04
# Df Residuals:                    5443   BIC:                         3.689e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5429      0.249     -2.176      0.030      -1.032      -0.054
# SRMPA         -0.0005      0.097     -0.005      0.996      -0.191       0.190
# HG            -0.2073      0.144     -1.436      0.151      -0.490       0.076
# SBP            0.1861      0.146      1.275      0.202      -0.100       0.472
# HR             0.2774      0.102      2.723      0.006       0.078       0.477
# DBP            0.2336      0.146      1.599      0.110      -0.053       0.520
# BMI            0.2902      0.102      2.849      0.004       0.091       0.490
# Gender         0.7383      0.291      2.541      0.011       0.169       1.308
# IS             0.0675      0.118      0.571      0.568      -0.164       0.299
# ==============================================================================
# Omnibus:                       62.736   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.224
# Skew:                           0.204   Prob(JB):                     1.26e-16
# Kurtosis:                       3.395   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.029474
# SRMPA       -0.000067
# HG          -0.019445
# SBP          0.017269
# HR           0.036876
# DBP          0.021649
# BMI          0.038588
# Gender       0.034416
# IS           0.007732
# dtype: float64

# %% [markdown]
# # 7 Model comparisons

# %% [markdown]
# ## 7.1 Cov x PA

# %%
model_comparison = anova_lm(cov_model, mpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F   Pr(>F)
# 0    5448.0  275463.940194      0.0         NaN       NaN      NaN
# 1    5447.0  274992.276555      1.0  471.663639  9.342633  0.00225

# %%
model_comparison = anova_lm(cov_model, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F  Pr(>F)
# 0    5448.0  275463.940194      0.0         NaN       NaN     NaN
# 1    5447.0  275788.090429      1.0 -324.150235 -6.402185     1.0

# %% [markdown]
# ## 7.2 Cov x PA x SR

# %%
model_comparison = anova_lm(mpa, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff    F  Pr(>F)
# 0    5447.0  274992.276555      0.0         NaN  NaN     NaN
# 1    5447.0  275788.090429     -0.0 -795.813874  inf     NaN

# %%
model_comparison = anova_lm(mpa, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff    F  Pr(>F)
# 0    5447.0  274992.276555      0.0         NaN  NaN     NaN
# 1    5447.0  275788.090429     -0.0 -795.813874  inf     NaN

# %% [markdown]
# ## 7.3 Health x Fitness x PA

# %%
model_comparison = anova_lm(mpa, pa_fitness)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff    F  Pr(>F)
# 0    5447.0  274992.276555      0.0        NaN  NaN     NaN
# 1    5447.0  274921.183349     -0.0  71.093206 -inf     NaN

# %%
model_comparison = anova_lm(mpa, pa_he)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff      ss_diff          F        Pr(>F)
# 0    5447.0  274992.276555      0.0          NaN        NaN           NaN
# 1    5444.0  273072.873046      3.0  1919.403509  12.755121  2.646434e-08

# %%
model_comparison = anova_lm(mpa, pa_he_fi)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff      ss_diff          F        Pr(>F)
# 0    5447.0  274992.276555      0.0          NaN        NaN           NaN
# 1    5443.0  272974.978814      4.0  2017.297741  10.056006  4.159726e-08

# %% [markdown]
# # 8 Mediation analysis

# %% [markdown]
# ## 8.1 PA x Health / Fitness

# %% [markdown]
# ### 8.1.1 BMI

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + LPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.083047       -0.126039       -0.044227    0.000
# ACME (treated)           -0.083047       -0.126039       -0.044227    0.000
# ADE (control)            -0.055435       -0.246146        0.117212    0.568
# ADE (treated)            -0.055435       -0.246146        0.117212    0.568
# Total effect             -0.138483       -0.323444        0.036156    0.152
# Prop. mediated (control)  0.531663       -3.972702        5.176582    0.152
# Prop. mediated (treated)  0.531663       -3.972702        5.176582    0.152
# ACME (average)           -0.083047       -0.126039       -0.044227    0.000
# ADE (average)            -0.055435       -0.246146        0.117212    0.568
# Prop. mediated (average)  0.531663       -3.972702        5.176582    0.152

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + MPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.107467       -0.165479       -0.050254    0.000
# ACME (treated)           -0.107467       -0.165479       -0.050254    0.000
# ADE (control)            -0.308989       -0.497286       -0.108184    0.002
# ADE (treated)            -0.308989       -0.497286       -0.108184    0.002
# Total effect             -0.416456       -0.600067       -0.230718    0.000
# Prop. mediated (control)  0.254889        0.116040        0.555525    0.000
# Prop. mediated (treated)  0.254889        0.116040        0.555525    0.000
# ACME (average)           -0.107467       -0.165479       -0.050254    0.000
# ADE (average)            -0.308989       -0.497286       -0.108184    0.002
# Prop. mediated (average)  0.254889        0.116040        0.555525    0.000

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + VPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.089118       -0.131702       -0.047642    0.000
# ACME (treated)           -0.089118       -0.131702       -0.047642    0.000
# ADE (control)            -0.026589       -0.220330        0.164956    0.784
# ADE (treated)            -0.026589       -0.220330        0.164956    0.784
# Total effect             -0.115708       -0.310921        0.081452    0.254
# Prop. mediated (control)  0.593666       -7.615643        8.976906    0.254
# Prop. mediated (treated)  0.593666       -7.615643        8.976906    0.254
# ACME (average)           -0.089118       -0.131702       -0.047642    0.000
# ADE (average)            -0.026589       -0.220330        0.164956    0.784
# Prop. mediated (average)  0.593666       -7.615643        8.976906    0.254

# %% [markdown]
# ### 8.1.2 DBP

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + LPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.059468       -0.092712       -0.030229     0.00
# ACME (treated)           -0.059468       -0.092712       -0.030229     0.00
# ADE (control)            -0.077420       -0.263610        0.108697     0.40
# ADE (treated)            -0.077420       -0.263610        0.108697     0.40
# Total effect             -0.136888       -0.319866        0.050307     0.14
# Prop. mediated (control)  0.383555       -1.937227        3.889613     0.14
# Prop. mediated (treated)  0.383555       -1.937227        3.889613     0.14
# ACME (average)           -0.059468       -0.092712       -0.030229     0.00
# ADE (average)            -0.077420       -0.263610        0.108697     0.40
# Prop. mediated (average)  0.383555       -1.937227        3.889613     0.14

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + MPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.032586       -0.061586       -0.008281    0.010
# ACME (treated)           -0.032586       -0.061586       -0.008281    0.010
# ADE (control)            -0.377095       -0.574648       -0.181861    0.002
# ADE (treated)            -0.377095       -0.574648       -0.181861    0.002
# Total effect             -0.409681       -0.607133       -0.212459    0.000
# Prop. mediated (control)  0.078533        0.019490        0.179770    0.010
# Prop. mediated (treated)  0.078533        0.019490        0.179770    0.010
# ACME (average)           -0.032586       -0.061586       -0.008281    0.010
# ADE (average)            -0.377095       -0.574648       -0.181861    0.002
# Prop. mediated (average)  0.078533        0.019490        0.179770    0.010

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + VPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.032820       -0.063741       -0.007305    0.008
# ACME (treated)           -0.032820       -0.063741       -0.007305    0.008
# ADE (control)            -0.088946       -0.281122        0.096633    0.382
# ADE (treated)            -0.088946       -0.281122        0.096633    0.382
# Total effect             -0.121766       -0.318032        0.071226    0.232
# Prop. mediated (control)  0.208875       -2.068455        2.631611    0.228
# Prop. mediated (treated)  0.208875       -2.068455        2.631611    0.228
# ACME (average)           -0.032820       -0.063741       -0.007305    0.008
# ADE (average)            -0.088946       -0.281122        0.096633    0.382
# Prop. mediated (average)  0.208875       -2.068455        2.631611    0.228

# %% [markdown]
# ### 8.1.3 Heart rate

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + LPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.016123       -0.037189        0.001019    0.074
# ACME (treated)           -0.016123       -0.037189        0.001019    0.074
# ADE (control)            -0.118833       -0.315523        0.078127    0.220
# ADE (treated)            -0.118833       -0.315523        0.078127    0.220
# Total effect             -0.134956       -0.329021        0.063273    0.172
# Prop. mediated (control)  0.093648       -0.854759        1.007265    0.230
# Prop. mediated (treated)  0.093648       -0.854759        1.007265    0.230
# ACME (average)           -0.016123       -0.037189        0.001019    0.074
# ADE (average)            -0.118833       -0.315523        0.078127    0.220
# Prop. mediated (average)  0.093648       -0.854759        1.007265    0.230

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + MPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.036817       -0.064209       -0.013456    0.002
# ACME (treated)           -0.036817       -0.064209       -0.013456    0.002
# ADE (control)            -0.366060       -0.565704       -0.164978    0.000
# ADE (treated)            -0.366060       -0.565704       -0.164978    0.000
# Total effect             -0.402876       -0.598138       -0.204644    0.000
# Prop. mediated (control)  0.089947        0.032618        0.209212    0.002
# Prop. mediated (treated)  0.089947        0.032618        0.209212    0.002
# ACME (average)           -0.036817       -0.064209       -0.013456    0.002
# ADE (average)            -0.366060       -0.565704       -0.164978    0.000
# Prop. mediated (average)  0.089947        0.032618        0.209212    0.002

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + VPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.070330       -0.111573       -0.034785    0.000
# ACME (treated)           -0.070330       -0.111573       -0.034785    0.000
# ADE (control)            -0.044136       -0.233005        0.144271    0.642
# ADE (treated)            -0.044136       -0.233005        0.144271    0.642
# Total effect             -0.114466       -0.303483        0.073158    0.252
# Prop. mediated (control)  0.466266       -3.833246        6.021922    0.252
# Prop. mediated (treated)  0.466266       -3.833246        6.021922    0.252
# ACME (average)           -0.070330       -0.111573       -0.034785    0.000
# ADE (average)            -0.044136       -0.233005        0.144271    0.642
# Prop. mediated (average)  0.466266       -3.833246        6.021922    0.252

# %% [markdown]
# ### 8.1.4 Hand grip

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + LPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.020005       -0.053590        0.013183    0.268
# ACME (treated)           -0.020005       -0.053590        0.013183    0.268
# ADE (control)            -0.112250       -0.290072        0.071582    0.250
# ADE (treated)            -0.112250       -0.290072        0.071582    0.250
# Total effect             -0.132255       -0.312145        0.050587    0.180
# Prop. mediated (control)  0.121652       -1.348351        1.336722    0.404
# Prop. mediated (treated)  0.121652       -1.348351        1.336722    0.404
# ACME (average)           -0.020005       -0.053590        0.013183    0.268
# ADE (average)            -0.112250       -0.290072        0.071582    0.250
# Prop. mediated (average)  0.121652       -1.348351        1.336722    0.404

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + MPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.001891       -0.011621        0.005567    0.602
# ACME (treated)           -0.001891       -0.011621        0.005567    0.602
# ADE (control)            -0.410813       -0.603552       -0.225629    0.000
# ADE (treated)            -0.410813       -0.603552       -0.225629    0.000
# Total effect             -0.412704       -0.602652       -0.226367    0.000
# Prop. mediated (control)  0.002762       -0.013566        0.032177    0.602
# Prop. mediated (treated)  0.002762       -0.013566        0.032177    0.602
# ACME (average)           -0.001891       -0.011621        0.005567    0.602
# ADE (average)            -0.410813       -0.603552       -0.225629    0.000
# Prop. mediated (average)  0.002762       -0.013566        0.032177    0.602

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + VPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.016436       -0.004167        0.040662    0.106
# ACME (treated)            0.016436       -0.004167        0.040662    0.106
# ADE (control)            -0.132574       -0.319055        0.051389    0.146
# ADE (treated)            -0.132574       -0.319055        0.051389    0.146
# Total effect             -0.116138       -0.303937        0.065921    0.222
# Prop. mediated (control) -0.108805       -1.434250        1.749519    0.300
# Prop. mediated (treated) -0.108805       -1.434250        1.749519    0.300
# ACME (average)            0.016436       -0.004167        0.040662    0.106
# ADE (average)            -0.132574       -0.319055        0.051389    0.146
# Prop. mediated (average) -0.108805       -1.434250        1.749519    0.300

# %% [markdown]
# # 9 LASSO Regression

# %% [markdown]
# ## 9.1 Accelerometer PA

# %%
df = main_test[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# ### 9.1.1 Females only

# %%
female = main_test[main_test["Gender"]==0]
df = female[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# ### 9.1.2 Males only

# %%
male = main_test[main_test["Gender"]==1]
df = female[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# ## 9.2 Self-report PA

# %%
df = main_test[["Age", "Gender", "IS", "LPA", "MPA", "VPA",  "SRLPA", "SRMPA", "SRVPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# # Figures

# %%
plt.figure()
plt.scatter("CR", "BA", data = female, label = "Female", alpha=0.5, s=10, color = "darkcyan")
plt.scatter("CR", "BA", data = male, label = "Male", alpha=0.5, s=10, color = "mediumvioletred")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Combined risk score", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(loc="best")
plt.axline((0,-0.55), slope=0.17, color="teal")
plt.axline((0,0.25), slope=0.37, color="purple")
plt.show()

# %%
x = main_test
del x["IS"]
del x["LPA"]
del x["VPA"]
del x["SRLPA"]
del x["SRVPA"]

corr = x.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(12,9)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'Gender'),
#   Text(0, 2.5, 'MPA'),
#   Text(0, 3.5, 'SRMPA'),
#   Text(0, 4.5, 'HG'),
#   Text(0, 5.5, 'HR'),
#   Text(0, 6.5, 'BMI'),
#   Text(0, 7.5, 'DBP'),
#   Text(0, 8.5, 'SBP'),
#   Text(0, 9.5, 'BA'),
#   Text(0, 10.5, 'CR'),
#   Text(0, 11.5, 'SRCR')])

# %% [markdown]
# # 10 Pickle for comparison to exploration set

# %%
main_test.to_pickle("3_validate.pkl")
