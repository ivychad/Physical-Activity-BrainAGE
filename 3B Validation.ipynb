# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from random import seed
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, Lasso
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm
from statsmodels.formula.api import ols
from statsmodels.regression import linear_model
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from statsmodels.stats.mediation import Mediation
from sklearn.svm import SVR
from pingouin import ancova
import matplotlib.cm as cm
# %matplotlib inline

seed(888)
pd.set_option('display.max_columns', None)
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %% [markdown]
# # 1 Load validation set

# %%
# load data from pickle and convert to dataframe
brain_test = pd.read_pickle("brain_test_validate.pkl")
main_test = pd.read_pickle("main_test_validate.pkl")
brain_train = pd.read_pickle("1_brain_train.pkl")
brain_test = pd.DataFrame(brain_test)
main_test = pd.DataFrame(main_test)
brain_train = pd.DataFrame(brain_train)

# %% [markdown]
# # 2 Preprocessing of validation set

# %% [markdown]
# ### 2.1 BrainAGE prediction for A2009

# %%
# select variables belonging to A2009s segmentation
X_train = brain_train.iloc[:,1657:2544:2]
Y_train = brain_train.iloc[:,-1]
X_test = brain_test.iloc[:,1657:2544:2]
Y_test = brain_test.iloc[:,-1]

# standardize x-data
X_train = stats.zscore(X_train)
X_test = stats.zscore(X_test)

# set of alphas to try (=penalization)
alpha_parameters = np.power(10,np.linspace(start=-3, stop=5, num=100))

# %% [markdown]
# ### 2.1.1 Cross-validation

# %%
X_CV = X_train
Y_CV = Y_train

# randomly split data (only training no PA) into training and testing set
X_train_cv, X_test_cv, Y_train_cv, Y_test_cv = train_test_split(X_CV,Y_CV)

#define the model
model_ridge = RidgeCV(alphas = alpha_parameters)
model_lasso = LassoCV(alphas = alpha_parameters, max_iter=100000)
model_SVR = SVR(kernel = "rbf")
#perform 10-fold cross validation
scores_ridge = cross_val_score(model_ridge, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')
scores_lasso = cross_val_score(model_lasso, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')
scores_SVR = cross_val_score(model_SVR, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')
#calculate the mean-absolute error
mae_ridge = -1 * scores_ridge.mean()
mae_lasso = -1 * scores_lasso.mean()
mae_SVR = -1 * scores_SVR.mean()
print("The MAE for cross-validation (Ridge):", mae_ridge)
print("The MAE for cross-validation (Lasso):", mae_lasso)
print("The MAE for cross-validation (SVR):", mae_SVR)

# for correction
model_ridge.fit(X_train_cv,Y_train_cv)
y_pred_cv = model_ridge.predict(X_test_cv)
# Out:
# The MAE for cross-validation (Ridge): 4.192981026915527
# The MAE for cross-validation (Lasso): 4.1922802059335185
# The MAE for cross-validation (SVR): 4.4481956143214845

# %% [markdown]
# ### 2.1.2 Prediction

# %%
# initialize models
model_Lasso = LassoCV(alphas = alpha_parameters, max_iter=100000)
model_Ridge = RidgeCV(alphas = alpha_parameters)
model_SVR = SVR(kernel = 'rbf')

# train model 
model_Lasso.fit(X_train,Y_train)
model_Ridge.fit(X_train,Y_train)
model_SVR.fit(X_train,Y_train)

# get predicted values for test set
y_pred_Lasso = model_Lasso.predict(X_test)
y_pred_Ridge = model_Ridge.predict(X_test)
y_pred_SVR = model_SVR.predict(X_test)

# calculate brain age gap
brain_age_delta_Lasso = y_pred_Lasso-Y_test
brain_age_delta_Ridge = y_pred_Ridge-Y_test
brain_age_delta_SVR = y_pred_SVR-Y_test

# get mean absolute error (MAE)
print("The MAE for testing set using Lasso:", mean_absolute_error(Y_test,y_pred_Lasso))
print("The MAE for testing set using Ridge:", mean_absolute_error(Y_test,y_pred_Ridge))
print("The MAE for testing set using SVR:", mean_absolute_error(Y_test,y_pred_SVR))

# Spearman rank order correlations
print("The Spearman r for Ridge vs Lasso:", stats.spearmanr(brain_age_delta_Ridge, brain_age_delta_Lasso))
print("The Spearman r for Ridge vs SVR:", stats.spearmanr(brain_age_delta_Ridge, brain_age_delta_SVR))
print("The Spearman r for SVR vs Lasso:", stats.spearmanr(brain_age_delta_SVR, brain_age_delta_Lasso))

# top x coefficients and their names
coeff = np.asarray(model_Ridge.coef_)
coeffabs = np.asarray(abs(model_Ridge.coef_))
top_coefficients = np.argsort(coeffabs)[-20:]
print(X_train.iloc[:,top_coefficients].columns)
print(coeff[top_coefficients])

# plot figure with x: actual age Y: predicted age, and a line with slope 1 for reference
plt.figure()
plt.scatter(Y_test, y_pred_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((60,60), slope=1, color='r')
plt.xticks(range(40,90,5))
plt.yticks(range(40,90,5))
plt.ylabel('Predicted Age', fontsize = 16)
plt.xlabel('Age', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()

plt.figure()
plt.scatter(Y_test,brain_age_delta_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((65,0), slope=-0.69, color="blue")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# The MAE for testing set using Lasso: 4.265579543071238
# The MAE for testing set using Ridge: 4.262589702409484
# The MAE for testing set using SVR: 4.538391428456859
# The Spearman r for Ridge vs Lasso: SpearmanrResult(correlation=0.9997394384429193, pvalue=0.0)
# The Spearman r for Ridge vs SVR: SpearmanrResult(correlation=0.917699544760441, pvalue=0.0)
# The Spearman r for SVR vs Lasso: SpearmanrResult(correlation=0.9183795135363797, pvalue=0.0)
# Index(['volume_of_gtemporalinf_left_hemisphere_f27513_2_0',
#        'volume_of_scentral_right_hemisphere_f27743_2_0',
#        'volume_of_gpostcentral_right_hemisphere_f27726_2_0',
#        'area_of_gtemporalinf_left_hemisphere_f27365_2_0',
#        'mean_thickness_of_gfrontsup_left_hemisphere_f27418_2_0',
#        'area_of_latfispost_right_hemisphere_f27591_2_0',
#        'volume_of_stemporalsup_left_hemisphere_f27549_2_0',
#        'area_of_stemporalsup_left_hemisphere_f27401_2_0',
#        'area_of_sparietooccipital_right_hemisphere_f27615_2_0',
#        'area_of_gscingulant_right_hemisphere_f27556_2_0',
#        'area_of_scalcarine_left_hemisphere_f27372_2_0',
#        'volume_of_scalcarine_left_hemisphere_f27520_2_0',
#        'volume_of_gfrontsup_left_hemisphere_f27492_2_0',
#        'volume_of_gscingulant_right_hemisphere_f27704_2_0',
#        'area_of_gfrontsup_left_hemisphere_f27344_2_0',
#        'volume_of_sparietooccipital_right_hemisphere_f27763_2_0',
#        'volume_of_scentral_left_hemisphere_f27521_2_0',
#        'volume_of_latfispost_right_hemisphere_f27739_2_0',
#        'area_of_scalcarine_right_hemisphere_f27594_2_0',
#        'volume_of_scalcarine_right_hemisphere_f27742_2_0'],
#       dtype='object')
# [ 1.33500311  1.35589929 -1.40956036 -1.41335742 -1.4290742  -1.49188128
#  -1.49429486  1.5138274  -1.53084042  1.55013063 -1.58490537  1.58906398
#   1.60619697 -1.67635603 -1.749753    1.75977046  1.86033162  2.16152389
#  -2.37541509  2.37603676]

# %% [markdown]
# ### 2.1.3 Correction

# %%
# reformat cross validation data for regression model
y_pred_cv = np.asarray(y_pred_cv)
y_pred_cv = np.reshape(y_pred_cv, (-1,1))
Y_test_cv = np.asarray(Y_test_cv)
Y_test_cv = np.reshape(Y_test_cv, (-1,1))

# now using correction from the R code that's online from Cole
reg = LinearRegression().fit(Y_test_cv, y_pred_cv)
coef = float(reg.coef_)
intercept = float(reg.intercept_)
print("Coefficient and Intercept:", coef, intercept)

# correction by cole
function = lambda t: (t-intercept)/coef
vfunc = np.vectorize(function)
corr_brainage_1 = vfunc(y_pred_Ridge)
corr_brainage_delta_1 = corr_brainage_1-Y_test

# plots corrected
plt.figure()
plt.scatter(Y_test, corr_brainage_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((65,65), slope=coef, color="blue")
plt.ylabel("Predicted Age Corrected", fontsize = 16)
plt.axline((60,60), slope=1, color='r')
plt.xlabel("Age", fontsize = 16)
plt.xticks(range(40,90,5))
plt.yticks(range(30,115,10))
plt.show()

plt.figure()
plt.scatter(Y_test, corr_brainage_delta_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE Corrected", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# Coefficient and Intercept: 0.5322558436639405 30.15139043103926

# %% [markdown]
# ### 2.1.4 Add BrainAge Delta to Dataframe

# %%
main_test["BA"] = corr_brainage_delta_1

# %% [markdown]
# ## 2.2 Recoding

# %%
# recoding imaging site and gender
# 1 = Cheadle;  2 = Reading;  3 = Newcastle;  4 = Bristol
main_test['IS'] = main_test['IS'].map({'11025': 1, '11026': 2,'11027': 3, '11028': 4})
main_test["Gender"] = main_test["Gender"].map({"Female":0, "Male":1})
main_test["Gender"] = main_test["Gender"].astype("int")

# delete unnecessary variables
del main_test["ID"]
del main_test["MVPA"]
del main_test["TPA"]

# %% [markdown]
# ## 2.3 Remove outliers on SRPA

# %%
# remove outliers on self-reported physical activity data for each intensity seperately
before = main_test.shape[0]
outlier = np.mean(main_test["SRLPA"]) + np.std(main_test["SRLPA"])*3
main_test = main_test[main_test["SRLPA"]<outlier]
outlier = np.mean(main_test["SRMPA"]) + np.std(main_test["SRMPA"])*3
main_test = main_test[main_test["SRMPA"]<outlier]
outlier = np.mean(main_test["SRVPA"]) + np.std(main_test["SRVPA"])*3
main_test = main_test[main_test["SRVPA"]<outlier]
after = main_test.shape[0]
print("Outliers on self-reported PA:", before-after)
print(after)
# Out:
# Outliers on self-reported PA: 532
# 5452

# %% [markdown]
# ## 2.4 Remove people with Gender other than Male or Female

# %%
before = main_test.shape[0]
main_test = main_test[(main_test["Gender"] == 0) | (main_test["Gender"] == 1)]
after = main_test.shape[0]
print("Gender not Male or Female:", before-after)
print(after)
# Out:
# Gender not Male or Female: 0
# 5452

# %% [markdown]
# # 3 Basic distributions of validation set

# %% [markdown]
# ## 3.1 Data and Descriptives

# %%
main_test.head()
# Out:
#         Age  Gender  IS      VPA       MPA        LPA   SRLPA   SRMPA   SRVPA  \
# 4723   73.0       0   1  59.2704  661.8528  2400.4512  1039.5   360.0     0.0
# 25494  55.0       1   1  70.0560  970.7760  1991.5920   396.0   120.0     0.0
# 34463  65.0       0   2  48.6720  506.1888  2813.2416  1386.0  3360.0  1280.0
# 26337  67.0       0   3   0.0000   60.4800  1653.1200   132.0   240.0     0.0
# 29224  70.0       0   2   9.2736  361.6704  1873.2672    99.0     0.0   360.0
#
#          HG    HR      BMI   DBP    SBP         BA
# 4723   20.0  52.0  25.1338  74.0  137.0   3.739462
# 25494  26.0  55.0  22.9630  80.0  148.0   2.319087
# 34463  22.0  45.0  23.8325  63.0  108.0  -7.021001
# 26337  38.0  68.0  33.6473  84.0  139.0  15.877985
# 29224  24.0  69.0  32.8906  87.0  132.0   3.036566

# %%
# mean and std of all variables for males and females seperately
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("Number of females:", female.shape[0])
print("NUmber of males:",male.shape[0])

print("Age")
mean = female["Age"].mean()
print("Female", mean)
std = female["Age"].std()
print("Female",std)
mean = male["Age"].mean()
print("Male",mean)
std = male["Age"].std()
print("Male",std)

print("LPA")
mean = female["LPA"].mean()
print("Female", mean)
std = female["LPA"].std()
print("Female",std)
mean = male["LPA"].mean()
print("Male",mean)
std = male["LPA"].std()
print("Male",std)

print("MPA")
mean = female["MPA"].mean()
print("Female", mean)
std = female["MPA"].std()
print("Female",std)
mean = male["MPA"].mean()
print("Male",mean)
std = male["MPA"].std()
print("Male",std)

print("VPA")
mean = female["VPA"].mean()
print("Female", mean)
std = female["VPA"].std()
print("Female",std)
mean = male["VPA"].mean()
print("Male",mean)
std = male["VPA"].std()
print("Male",std)

print("SRLPA")
mean = female["SRLPA"].mean()
print("Female", mean)
std = female["SRLPA"].std()
print("Female",std)
mean = male["SRLPA"].mean()
print("Male",mean)
std = male["SRLPA"].std()
print("Male",std)

print("SRMPA")
mean = female["SRMPA"].mean()
print("Female", mean)
std = female["SRMPA"].std()
print("Female",std)
mean = male["SRMPA"].mean()
print("Male",mean)
std = male["SRMPA"].std()
print("Male",std)

print("SRVPA")
mean = female["SRVPA"].mean()
print("Female", mean)
std = female["SRVPA"].std()
print("Female",std)
mean = male["SRVPA"].mean()
print("Male",mean)
std = male["SRVPA"].std()
print("Male",std)

print("BMI")
mean = female["BMI"].mean()
print("Female", mean)
std = female["BMI"].std()
print("Female",std)
mean = male["BMI"].mean()
print("Male",mean)
std = male["BMI"].std()
print("Male",std)

print("HG")
mean = female["HG"].mean()
print("Female", mean)
std = female["HG"].std()
print("Female",std)
mean = male["HG"].mean()
print("Male",mean)
std = male["HG"].std()
print("Male",std)

print("HR")
mean = female["HR"].mean()
print("Female", mean)
std = female["HR"].std()
print("Female",std)
mean = male["HR"].mean()
print("Male",mean)
std = male["HR"].std()
print("Male",std)

print("DBP")
mean = female["DBP"].mean()
print("Female", mean)
std = female["DBP"].std()
print("Female",std)
mean = male["DBP"].mean()
print("Male",mean)
std = male["DBP"].std()
print("Male",std)

print("SBP")
mean = female["SBP"].mean()
print("Female", mean)
std = female["SBP"].std()
print("Female",std)
mean = male["SBP"].mean()
print("Male",mean)
std = male["SBP"].std()
print("Male",std)

print("IS")
print("Female")
print(female["IS"].value_counts())
print("Male")
print(male["IS"].value_counts())
# Out:
# Number of females: 2970
# NUmber of males: 2482
# Age
# Female 63.365656565656565
# Female 7.671358834590245
# Male 65.17808219178082
# Male 7.870456794472667
# LPA
# Female 2061.0672872727273
# Female 406.33606702437504
# Male 1885.3467519742142
# Male 409.6249987343925
# MPA
# Female 493.00463030303035
# Female 219.37278852675698
# Male 470.0986926672039
# Male 213.1870127069337
# VPA
# Female 31.059233939393966
# Female 39.8729402584149
# Male 38.12592618855765
# Male 46.701593415163025
# SRLPA
# Female 782.4266666666666
# Female 706.1642469143237
# Male 769.0568896051572
# Male 742.7437996329985
# SRMPA
# Female 642.7501683501683
# Female 762.365502137756
# Male 630.0080580177276
# Male 776.9453699945714
# SRVPA
# Female 476.6222222222222
# Female 627.6737299431975
# Male 597.453666398066
# Male 713.3294572774662
# BMI
# Female 25.948532020202023
# Female 4.526024283563611
# Male 26.8570723207091
# Male 3.747773618911473
# HG
# Female 26.25690235690236
# Female 6.234093493954997
# Male 42.15592264302982
# Male 8.508682952449652
# HR
# Female 68.92861952861954
# Female 10.21306969707317
# Male 66.81103948428687
# Male 11.861867502725236
# DBP
# Female 79.24410774410775
# Female 10.12791250037231
# Male 83.36059629331184
# Male 10.193142187231949
# SBP
# Female 132.9090909090909
# Female 18.395686947322144
# Male 140.41821112006446
# Male 17.186624075161365
# IS
# Female
# 1    1837
# 3     619
# 2     506
# 4       8
# Name: IS, dtype: int64
# Male
# 1    1586
# 3     490
# 2     403
# 4       3
# Name: IS, dtype: int64

# %% [markdown]
# ## 3.2 Age and BrainAge

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'Gender', fill=True, palette = "crest")
plt.title("Age x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'Gender', fill=True, palette = "crest")
plt.title("BrainAge x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'IS', fill=True, palette = "crest")
plt.title("BrainAge x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'IS', fill=True, palette = "crest")
plt.title("Age x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'MPA', hue = 'IS', fill=True, palette = "crest")
plt.title("Moderate PA x Imaging site")
plt.show()


plt.figure()
sns.kdeplot(data = main_test, x= 'BA', fill=True, label="A2009")
plt.title("BrainAge Segmentations")
plt.legend()
plt.show()

# %% [markdown]
# ## 3.3 Physical activity

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA")
#sns.kdeplot(data = main_test, x= 'TPA', fill=True, label = "Total PA")
plt.xlabel("Min/week of physical activity")
plt.legend()
plt.xticks(range(0,5000,1000))
plt.ylim(0,0.01)
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA")
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA")
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA")
plt.xlabel("Min/week of physical activity")
#plt.title("Self Report PA distributions")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA", color="#6baed6")
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA", color="#08519c")
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Light PA")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA", color="#fd8d3c")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA", color="#a63603")
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Moderate PA")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA", color="#74c476")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA", color="#006d2c")
plt.ylim(0,0.01)
plt.xticks(range(0,3500,1000))
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Vigorous PA")
plt.legend()
plt.show()

# %% [markdown]
# ## 3.4 Health and Fitness

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'HG', hue = 'Gender', fill=True, palette = "crest")
plt.title("Hand grip")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'HR', hue = 'Gender', fill=True, palette = "crest")
plt.title("Heart rate")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Systolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'DBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Distolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BMI', hue = 'Gender', fill=True, palette = "crest")
plt.title("BMI")
plt.show()

# %% [markdown]
# ## 3.5 MPA model for quantification

# %%
mpa = ols('BA ~ MPA + Gender + IS + Gender:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     6.453
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           3.54e-05
# Time:                        19:59:04   Log-Likelihood:                -18525.
# No. Observations:                5452   AIC:                         3.706e+04
# Df Residuals:                    5447   BIC:                         3.709e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2430      0.376      0.647      0.518      -0.493       0.979
# MPA           -0.0014      0.001     -2.374      0.018      -0.003      -0.000
# Gender         0.9023      0.480      1.879      0.060      -0.039       1.843
# IS             0.1060      0.120      0.880      0.379      -0.130       0.342
# Gender:MPA    -0.0006      0.001     -0.701      0.483      -0.002       0.001
# ==============================================================================
# Omnibus:                       58.247   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.428
# Skew:                           0.202   Prob(JB):                     3.76e-15
# Kurtosis:                       3.360   Cond. No.                     3.30e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.3e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.008788
# MPA          -0.032245
# Gender        0.025522
# IS            0.011953
# Gender:MPA   -0.009518
# dtype: float64

# %% [markdown]
# ## 3.6 Standardize all variables (except Gender, Age, BA, IS)

# %%
# standardize
main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI"]] = stats.zscore(main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI"]], nan_policy='omit')

# %% [markdown]
# ## 3.7 Compute combined risk score

# %%
main_test["CR"] = main_test["MPA"]*-1 + main_test["HG"]*-1 + main_test["DBP"] + main_test["HR"] + main_test["BMI"]
main_test["SRCR"] = main_test["SRMPA"]*-1 + main_test["HG"]*-1 + main_test["DBP"] + main_test["HR"] + main_test["BMI"]

# %% [markdown]
# ## 3.8 Remove effect of Age on all predictor variables (regression -> residuals)

# %%
model = ols("LPA ~ Age", data = main_test).fit()
main_test["LPA"] = model.resid

model = ols("MPA ~ Age", data = main_test).fit()
main_test["MPA"] = model.resid

model = ols("VPA ~ Age", data = main_test).fit()
main_test["VPA"] = model.resid

model = ols("SRLPA ~ Age", data = main_test).fit()
main_test["SRLPA"] = model.resid

model = ols("SRMPA ~ Age", data = main_test).fit()
main_test["SRMPA"] = model.resid

model = ols("SRVPA ~ Age", data = main_test).fit()
main_test["SRVPA"] = model.resid

model = ols("CR ~ Age", data = main_test).fit()
main_test["CR"] = model.resid

model = ols("SRCR ~ Age", data = main_test).fit()
main_test["SRCR"] = model.resid

model = ols("HR ~ Age", data = main_test).fit()
main_test["HR"] = model.resid

model = ols("DBP ~ Age", data = main_test).fit()
main_test["DBP"] = model.resid

model = ols("SBP ~ Age", data = main_test).fit()
main_test["SBP"] = model.resid

model = ols("BMI ~ Age", data = main_test).fit()
main_test["BMI"] = model.resid

model = ols("HG ~ Age", data = main_test).fit()
main_test["HG"] = model.resid

# %% [markdown]
# ## 3.9 Descriptives for combined risk score

# %%
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("CR")
mean = female["CR"].mean()
print("Female", mean)
std = female["CR"].std()
print("Female",std)
mean = male["CR"].mean()
print("Male",mean)
std = male["CR"].std()
print("Male",std)

print("SRCR")
mean = female["SRCR"].mean()
print("Female", mean)
std = female["SRCR"].std()
print("Female",std)
mean = male["SRCR"].mean()
print("Male",mean)
std = male["SRCR"].std()
print("Male",std)
# Out:
# CR
# Female 0.47140451693110796
# Female 2.5950672470538887
# Male -0.5640900142165179
# Male 2.551569436488242
# SRCR
# Female 0.47591863951449354
# Female 2.4631969530145295
# Male -0.5694916838670608
# Male 2.499766586323754

# %% [markdown]
# ## 3.10 Reorder Dataframe

# %%
# reorder dataframe
main_test = main_test[['Age', 'Gender', 'IS' , 'LPA', 'MPA', 'VPA', 'SRLPA', 'SRMPA', 'SRVPA', 'HG', 'HR', 'BMI', 'DBP', 'SBP', 'CR', 'SRCR', 'BA']]

# %% [markdown]
# # 4 Simple Correlation Heatmap

# %%
corr = main_test.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'Gender'),
#   Text(0, 2.5, 'IS'),
#   Text(0, 3.5, 'LPA'),
#   Text(0, 4.5, 'MPA'),
#   Text(0, 5.5, 'VPA'),
#   Text(0, 6.5, 'SRLPA'),
#   Text(0, 7.5, 'SRMPA'),
#   Text(0, 8.5, 'SRVPA'),
#   Text(0, 9.5, 'HG'),
#   Text(0, 10.5, 'HR'),
#   Text(0, 11.5, 'BMI'),
#   Text(0, 12.5, 'DBP'),
#   Text(0, 13.5, 'SBP'),
#   Text(0, 14.5, 'CR'),
#   Text(0, 15.5, 'SRCR'),
#   Text(0, 16.5, 'BA')])

# %% [markdown]
# ## 4.1 Female

# %%
female = main_test[main_test["Gender"] == 0]
del female["Gender"]
corr = female.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'IS'),
#   Text(0, 2.5, 'LPA'),
#   Text(0, 3.5, 'MPA'),
#   Text(0, 4.5, 'VPA'),
#   Text(0, 5.5, 'SRLPA'),
#   Text(0, 6.5, 'SRMPA'),
#   Text(0, 7.5, 'SRVPA'),
#   Text(0, 8.5, 'HG'),
#   Text(0, 9.5, 'HR'),
#   Text(0, 10.5, 'BMI'),
#   Text(0, 11.5, 'DBP'),
#   Text(0, 12.5, 'SBP'),
#   Text(0, 13.5, 'CR'),
#   Text(0, 14.5, 'SRCR'),
#   Text(0, 15.5, 'BA')])

# %% [markdown]
# ## 4.2 Male

# %%
male = main_test[main_test["Gender"] == 1]
del male["Gender"]
corr = male.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'IS'),
#   Text(0, 2.5, 'LPA'),
#   Text(0, 3.5, 'MPA'),
#   Text(0, 4.5, 'VPA'),
#   Text(0, 5.5, 'SRLPA'),
#   Text(0, 6.5, 'SRMPA'),
#   Text(0, 7.5, 'SRVPA'),
#   Text(0, 8.5, 'HG'),
#   Text(0, 9.5, 'HR'),
#   Text(0, 10.5, 'BMI'),
#   Text(0, 11.5, 'DBP'),
#   Text(0, 12.5, 'SBP'),
#   Text(0, 13.5, 'CR'),
#   Text(0, 14.5, 'SRCR'),
#   Text(0, 15.5, 'BA')])

# %% [markdown]
# # 6 Models with OLS

# %% [markdown]
# ## 6.1 Single Predictor Models

# %% [markdown]
# ### 6.1.1 Accelerometer PA

# %%
mpa = ols('BA ~ MPA + Gender + IS + Gender:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     7.002
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           1.28e-05
# Time:                        19:59:11   Log-Likelihood:                -18523.
# No. Observations:                5452   AIC:                         3.706e+04
# Df Residuals:                    5447   BIC:                         3.709e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4771      0.234     -2.042      0.041      -0.935      -0.019
# MPA           -0.4120      0.134     -3.075      0.002      -0.675      -0.149
# Gender         0.6107      0.197      3.101      0.002       0.225       0.997
# IS             0.1201      0.121      0.996      0.319      -0.116       0.356
# Gender:MPA    -0.0055      0.202     -0.027      0.978      -0.400       0.390
# ==============================================================================
# Omnibus:                       58.535   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.647
# Skew:                           0.203   Prob(JB):                     3.37e-15
# Kurtosis:                       3.359   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.027658
# MPA          -0.041643
# Gender        0.042001
# IS            0.013486
# Gender:MPA   -0.000367
# dtype: float64

# %% [markdown]
# ### 6.1.2 Self-report PA

# %%
srmpa = ols('BA ~ SRMPA + Gender + IS + Gender:SRMPA', missing='drop', data = main_test).fit()
print(srmpa.summary())

#calculate effect size
results = srmpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     3.034
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):             0.0164
# Time:                        19:59:12   Log-Likelihood:                -18531.
# No. Observations:                5452   AIC:                         3.707e+04
# Df Residuals:                    5447   BIC:                         3.711e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.4445      0.234     -1.900      0.058      -0.903       0.014
# SRMPA            0.0450      0.135      0.332      0.740      -0.221       0.311
# Gender           0.6312      0.197      3.201      0.001       0.245       1.018
# IS               0.0920      0.121      0.763      0.446      -0.145       0.329
# Gender:SRMPA    -0.2017      0.199     -1.014      0.311      -0.592       0.188
# ==============================================================================
# Omnibus:                       59.065   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.613
# Skew:                           0.202   Prob(JB):                     2.08e-15
# Kurtosis:                       3.366   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      -0.025726
# SRMPA           0.004497
# Gender          0.043350
# IS              0.010330
# Gender:SRMPA   -0.013735
# dtype: float64

# %% [markdown]
# ### 6.1.3 Combined risk scores (Acc)

# %%
cr = ols('BA ~ CR + Gender + IS + Gender:CR', missing='drop', data = main_test).fit()
print(cr.summary())

#calculate effect size
results = cr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     16.59
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           1.62e-13
# Time:                        19:59:12   Log-Likelihood:                -18504.
# No. Observations:                5452   AIC:                         3.702e+04
# Df Residuals:                    5447   BIC:                         3.705e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5904      0.234     -2.523      0.012      -1.049      -0.132
# CR             0.2583      0.051      5.064      0.000       0.158       0.358
# Gender         0.9312      0.200      4.651      0.000       0.539       1.324
# IS             0.1078      0.120      0.898      0.369      -0.128       0.343
# Gender:CR      0.0511      0.076      0.670      0.503      -0.098       0.201
# ==============================================================================
# Omnibus:                       63.972   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.284
# Skew:                           0.209   Prob(JB):                     7.40e-17
# Kurtosis:                       3.391   Cond. No.                         8.23
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.034170
# CR           0.068589
# Gender       0.062990
# IS           0.012161
# Gender:CR    0.009069
# dtype: float64

# %% [markdown]
# #### 6.1.3.1 Males

# %%
male = main_test[main_test["Gender"] == 1]

crm = ols('BA ~ CR + IS', missing='drop', data = male).fit()
print(crm.summary())

#calculate effect size
results = crm
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     18.08
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           1.60e-08
# Time:                        19:59:14   Log-Likelihood:                -8432.6
# No. Observations:                2482   AIC:                         1.687e+04
# Df Residuals:                    2479   BIC:                         1.689e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2257      0.318     -0.710      0.478      -0.849       0.397
# CR             0.3127      0.057      5.490      0.000       0.201       0.424
# IS             0.4719      0.180      2.615      0.009       0.118       0.826
# ==============================================================================
# Omnibus:                       11.318   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.867
# Skew:                           0.131   Prob(JB):                      0.00265
# Kurtosis:                       3.215   Cond. No.                         6.60
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.009619
# CR           0.074352
# IS           0.035412
# dtype: float64

# %% [markdown]
# #### 6.1.3.2 Females

# %%
female = main_test[main_test["Gender"] == 0]

crf = ols('BA ~ CR + IS', missing='drop', data = female).fit()
print(crf.summary())

#calculate effect size
results = crf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     13.59
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           1.34e-06
# Time:                        19:59:14   Log-Likelihood:                -10068.
# No. Observations:                2970   AIC:                         2.014e+04
# Df Residuals:                    2967   BIC:                         2.016e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1237      0.289     -0.428      0.669      -0.690       0.443
# CR             0.2581      0.051      5.082      0.000       0.159       0.358
# IS            -0.1847      0.161     -1.151      0.250      -0.499       0.130
# ==============================================================================
# Omnibus:                       59.503   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.159
# Skew:                           0.273   Prob(JB):                     1.30e-16
# Kurtosis:                       3.541   Cond. No.                         6.60
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.005796
# CR           0.068833
# IS          -0.015586
# dtype: float64

# %% [markdown]
# ### 6.1.4 Combined risk score (SR)

# %%
srcr = ols('BA ~ SRCR + Gender + IS + Gender:SRCR', missing='drop', data = main_test).fit()
print(srcr.summary())

#calculate effect size
results = srcr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     12.70
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           2.75e-10
# Time:                        19:59:15   Log-Likelihood:                -18512.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5447   BIC:                         3.707e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.5281      0.234     -2.257      0.024      -0.987      -0.069
# SRCR            0.2130      0.054      3.958      0.000       0.108       0.319
# Gender          0.8978      0.201      4.471      0.000       0.504       1.291
# IS              0.0815      0.120      0.678      0.498      -0.154       0.317
# Gender:SRCR     0.0722      0.079      0.912      0.362      -0.083       0.227
# ==============================================================================
# Omnibus:                       61.212   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.912
# Skew:                           0.203   Prob(JB):                     4.00e-16
# Kurtosis:                       3.383   Cond. No.                         7.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept     -0.030570
# SRCR           0.053605
# Gender         0.060551
# IS             0.009183
# Gender:SRCR    0.012357
# dtype: float64

# %% [markdown]
# ## 6.2 Multiple Predictor & COmparison Models

# %% [markdown]
# ### 6.2.1 Covariates

# %%
cov_model = ols('BA ~ Gender + Age + IS ', missing='drop', data = main_test).fit()
print(cov_model.summary())

#calculate effect size
results = cov_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     4.175
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):            0.00582
# Time:                        19:59:15   Log-Likelihood:                -18531.
# No. Observations:                5452   AIC:                         3.707e+04
# Df Residuals:                    5448   BIC:                         3.710e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5607      0.818      0.686      0.493      -1.042       2.164
# Gender         0.6648      0.199      3.349      0.001       0.276       1.054
# Age           -0.0164      0.013     -1.286      0.199      -0.041       0.009
# IS             0.1132      0.121      0.932      0.351      -0.125       0.351
# ==============================================================================
# Omnibus:                       60.694   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.316
# Skew:                           0.207   Prob(JB):                     8.87e-16
# Kurtosis:                       3.366   Cond. No.                         539.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.009286
# Gender       0.045356
# Age         -0.017416
# IS           0.012621
# dtype: float64

# %% [markdown]
# ### 6.2.2 CR / MPA

# %%
no_mpa = ols('BA ~ HG + DBP + HR + BMI + Gender + IS + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_mpa.summary())

#calculate effect size
results = no_mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     6.177
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           1.91e-09
# Time:                        19:59:16   Log-Likelihood:                -18507.
# No. Observations:                5452   AIC:                         3.704e+04
# Df Residuals:                    5441   BIC:                         3.711e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5770      0.285     -2.025      0.043      -1.135      -0.018
# HG            -0.3119      0.237     -1.315      0.189      -0.777       0.153
# DBP            0.4404      0.147      3.001      0.003       0.153       0.728
# HR             0.2474      0.150      1.650      0.099      -0.047       0.541
# BMI            0.1501      0.132      1.141      0.254      -0.108       0.408
# Gender         0.8489      0.298      2.853      0.004       0.266       1.432
# IS             0.0860      0.120      0.715      0.475      -0.150       0.322
# HG:Gender      0.1136      0.303      0.375      0.707      -0.480       0.707
# DBP:Gender    -0.1524      0.215     -0.708      0.479      -0.574       0.269
# HR:Gender      0.0425      0.207      0.205      0.838      -0.364       0.448
# BMI:Gender     0.3787      0.215      1.763      0.078      -0.042       0.800
# ==============================================================================
# Omnibus:                       64.159   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.613
# Skew:                           0.208   Prob(JB):                     6.28e-17
# Kurtosis:                       3.393   Cond. No.                         9.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.027428
# HG           -0.017808
# DBP           0.040650
# HR            0.022346
# BMI           0.015458
# Gender        0.038635
# IS            0.009677
# HG:Gender     0.005085
# DBP:Gender   -0.009595
# HR:Gender     0.002777
# BMI:Gender    0.023880
# dtype: float64

# %% [markdown]
# ### 6.2.3 CR / HG

# %%
no_hg = ols('BA ~ MPA + DBP + HR + BMI + Gender + IS + MPA:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hg.summary())

#calculate effect size
results = no_hg
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     6.789
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           1.33e-10
# Time:                        19:59:16   Log-Likelihood:                -18504.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5441   BIC:                         3.710e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3899      0.235     -1.656      0.098      -0.851       0.072
# MPA           -0.3455      0.139     -2.483      0.013      -0.618      -0.073
# DBP            0.4449      0.147      3.035      0.002       0.158       0.732
# HR             0.2359      0.150      1.573      0.116      -0.058       0.530
# BMI            0.0658      0.136      0.483      0.629      -0.201       0.333
# Gender         0.4748      0.203      2.338      0.019       0.077       0.873
# IS             0.1031      0.120      0.857      0.392      -0.133       0.339
# MPA:Gender     0.0877      0.209      0.420      0.674      -0.321       0.497
# DBP:Gender    -0.1633      0.215     -0.761      0.447      -0.584       0.257
# HR:Gender      0.0455      0.207      0.219      0.826      -0.361       0.451
# BMI:Gender     0.3889      0.221      1.757      0.079      -0.045       0.823
# ==============================================================================
# Omnibus:                       61.444   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.727
# Skew:                           0.206   Prob(JB):                     4.38e-16
# Kurtosis:                       3.377   Cond. No.                         6.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.022432
# MPA          -0.033628
# DBP           0.041105
# HR            0.021309
# BMI           0.006545
# Gender        0.031667
# IS            0.011604
# MPA:Gender    0.005692
# DBP:Gender   -0.010305
# HR:Gender     0.002973
# BMI:Gender    0.023799
# dtype: float64

# %% [markdown]
# ### 6.2.4 CR / HR

# %%
no_hr = ols('BA ~ HG + DBP + MPA + BMI + Gender + IS + HG:Gender + DBP:Gender + MPA:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hr.summary())

#calculate effect size
results = no_hr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     6.450
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           5.85e-10
# Time:                        19:59:17   Log-Likelihood:                -18505.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5441   BIC:                         3.711e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5555      0.285     -1.952      0.051      -1.113       0.002
# HG            -0.2879      0.237     -1.212      0.225      -0.753       0.178
# DBP            0.4988      0.144      3.473      0.001       0.217       0.780
# MPA           -0.3451      0.139     -2.478      0.013      -0.618      -0.072
# BMI            0.0912      0.135      0.675      0.500      -0.174       0.356
# Gender         0.7702      0.297      2.595      0.009       0.188       1.352
# IS             0.1051      0.120      0.873      0.383      -0.131       0.341
# HG:Gender      0.0562      0.302      0.186      0.853      -0.537       0.649
# DBP:Gender    -0.1258      0.209     -0.601      0.548      -0.536       0.284
# MPA:Gender     0.0585      0.208      0.281      0.779      -0.350       0.467
# BMI:Gender     0.4103      0.220      1.868      0.062      -0.020       0.841
# ==============================================================================
# Omnibus:                       61.417   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.756
# Skew:                           0.206   Prob(JB):                     4.32e-16
# Kurtosis:                       3.378   Cond. No.                         9.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.026436
# HG           -0.016420
# DBP           0.047037
# MPA          -0.033562
# BMI           0.009145
# Gender        0.035148
# IS            0.011827
# HG:Gender     0.002516
# DBP:Gender   -0.008144
# MPA:Gender    0.003804
# BMI:Gender    0.025294
# dtype: float64

# %% [markdown]
# ### 6.2.5 CR / DBP

# %%
no_dbp = ols('BA ~ HG + MPA + HR + BMI + Gender + IS + HG:Gender + MPA:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_dbp.summary())

#calculate effect size
results = no_dbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     5.734
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           1.29e-08
# Time:                        19:59:17   Log-Likelihood:                -18509.
# No. Observations:                5452   AIC:                         3.704e+04
# Df Residuals:                    5441   BIC:                         3.711e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6602      0.284     -2.325      0.020      -1.217      -0.104
# HG            -0.2548      0.237     -1.073      0.283      -0.720       0.211
# MPA           -0.3231      0.139     -2.318      0.020      -0.596      -0.050
# HR             0.3283      0.147      2.235      0.025       0.040       0.616
# BMI            0.1804      0.131      1.377      0.168      -0.076       0.437
# Gender         0.9183      0.297      3.095      0.002       0.337       1.500
# IS             0.1177      0.120      0.977      0.328      -0.118       0.354
# HG:Gender      0.0826      0.302      0.273      0.785      -0.510       0.675
# MPA:Gender     0.0720      0.209      0.345      0.730      -0.338       0.482
# HR:Gender      0.0105      0.202      0.052      0.958      -0.385       0.406
# BMI:Gender     0.3451      0.216      1.600      0.110      -0.078       0.768
# ==============================================================================
# Omnibus:                       63.094   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.139
# Skew:                           0.207   Prob(JB):                     1.31e-16
# Kurtosis:                       3.388   Cond. No.                         9.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.031491
# HG           -0.014531
# MPA          -0.031398
# HR            0.030274
# BMI           0.018653
# Gender        0.041921
# IS            0.013235
# HG:Gender     0.003702
# MPA:Gender    0.004670
# HR:Gender     0.000705
# BMI:Gender    0.021671
# dtype: float64

# %% [markdown]
# ### 6.2.6 CR / BMI

# %%
no_bmi = ols('BA ~ HG + DBP + HR + MPA + Gender + IS + HG:Gender + DBP:Gender + HR:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(no_bmi.summary())

#calculate effect size
results = no_bmi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     6.324
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           1.01e-09
# Time:                        19:59:17   Log-Likelihood:                -18506.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5441   BIC:                         3.711e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5777      0.285     -2.028      0.043      -1.136      -0.019
# HG            -0.2844      0.237     -1.198      0.231      -0.750       0.181
# DBP            0.4709      0.141      3.340      0.001       0.195       0.747
# HR             0.2428      0.149      1.632      0.103      -0.049       0.534
# MPA           -0.3541      0.134     -2.633      0.008      -0.618      -0.090
# Gender         0.8539      0.297      2.871      0.004       0.271       1.437
# IS             0.0987      0.120      0.820      0.412      -0.137       0.335
# HG:Gender      0.0973      0.303      0.321      0.748      -0.496       0.691
# DBP:Gender    -0.0928      0.209     -0.444      0.657      -0.503       0.317
# HR:Gender      0.0729      0.206      0.354      0.723      -0.331       0.476
# MPA:Gender    -0.0023      0.203     -0.012      0.991      -0.399       0.395
# ==============================================================================
# Omnibus:                       63.182   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.779
# Skew:                           0.210   Prob(JB):                     1.57e-16
# Kurtosis:                       3.381   Cond. No.                         9.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.027465
# HG           -0.016219
# DBP           0.045236
# HR            0.022103
# MPA          -0.035657
# Gender        0.038881
# IS            0.011101
# HG:Gender     0.004354
# DBP:Gender   -0.006012
# HR:Gender     0.004796
# MPA:Gender   -0.000156
# dtype: float64

# %% [markdown]
# ### 6.2.7 CR

# %%
cr2 = ols('BA ~ MPA +HG + DBP + HR + BMI + Gender + IS + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(cr2.summary())

#calculate effect size
results = cr2
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     5.875
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           3.05e-10
# Time:                        19:59:17   Log-Likelihood:                -18502.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5439   BIC:                         3.712e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5796      0.285     -2.035      0.042      -1.138      -0.021
# MPA           -0.3371      0.139     -2.420      0.016      -0.610      -0.064
# HG            -0.2830      0.237     -1.192      0.233      -0.748       0.182
# DBP            0.4518      0.147      3.079      0.002       0.164       0.739
# HR             0.2336      0.150      1.558      0.119      -0.060       0.528
# BMI            0.0638      0.136      0.469      0.639      -0.203       0.331
# Gender         0.8258      0.298      2.775      0.006       0.242       1.409
# IS             0.1024      0.120      0.851      0.395      -0.134       0.338
# HG:Gender      0.0789      0.303      0.261      0.794      -0.514       0.672
# DBP:Gender    -0.1547      0.215     -0.719      0.472      -0.576       0.267
# HR:Gender      0.0356      0.207      0.171      0.864      -0.371       0.442
# BMI:Gender     0.3974      0.221      1.795      0.073      -0.037       0.831
# MPA:Gender     0.0761      0.209      0.365      0.715      -0.333       0.486
# ==============================================================================
# Omnibus:                       63.079   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.911
# Skew:                           0.208   Prob(JB):                     1.47e-16
# Kurtosis:                       3.384   Cond. No.                         9.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.027566
# MPA          -0.032770
# HG           -0.016149
# DBP           0.041705
# HR            0.021100
# BMI           0.006345
# Gender        0.037586
# IS            0.011525
# HG:Gender     0.003533
# DBP:Gender   -0.009740
# HR:Gender     0.002322
# BMI:Gender    0.024313
# MPA:Gender    0.004937
# dtype: float64

# %% [markdown]
# ### 6.2.8 SRCR

# %%
srcr2 = ols('BA ~ SRMPA + HG + DBP + HR + BMI + Gender + IS + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + SRMPA:Gender', missing='drop', data = main_test).fit()
print(srcr2.summary())

#calculate effect size
results = srcr2
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     5.209
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           8.91e-09
# Time:                        19:59:18   Log-Likelihood:                -18506.
# No. Observations:                5452   AIC:                         3.704e+04
# Df Residuals:                    5439   BIC:                         3.712e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.5787      0.285     -2.030      0.042      -1.137      -0.020
# SRMPA            0.0810      0.135      0.598      0.550      -0.184       0.346
# HG              -0.3123      0.237     -1.317      0.188      -0.777       0.153
# DBP              0.4406      0.147      3.003      0.003       0.153       0.728
# HR               0.2511      0.150      1.673      0.094      -0.043       0.545
# BMI              0.1537      0.132      1.167      0.243      -0.104       0.412
# Gender           0.8445      0.298      2.835      0.005       0.261       1.428
# IS               0.0858      0.120      0.712      0.476      -0.150       0.322
# HG:Gender        0.1198      0.303      0.396      0.692      -0.474       0.713
# DBP:Gender      -0.1568      0.215     -0.729      0.466      -0.579       0.265
# HR:Gender        0.0343      0.207      0.165      0.869      -0.372       0.441
# BMI:Gender       0.3729      0.215      1.735      0.083      -0.048       0.794
# SRMPA:Gender    -0.1721      0.199     -0.865      0.387      -0.562       0.218
# ==============================================================================
# Omnibus:                       64.388   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.052
# Skew:                           0.208   Prob(JB):                     5.04e-17
# Kurtosis:                       3.396   Cond. No.                         9.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      -0.027492
# SRMPA           0.008103
# HG             -0.017830
# DBP             0.040666
# HR              0.022658
# BMI             0.015810
# Gender          0.038402
# IS              0.009646
# HG:Gender       0.005358
# DBP:Gender     -0.009867
# HR:Gender       0.002240
# BMI:Gender      0.023498
# SRMPA:Gender   -0.011720
# dtype: float64

# %% [markdown]
# # 7 Model comparisons

# %% [markdown]
# ## 7.1 Cov vs. PA

# %%
model_comparison = anova_lm(cov_model, mpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff          F    Pr(>F)
# 0    5448.0  286014.309472      0.0         NaN        NaN       NaN
# 1    5447.0  285205.273328      1.0  809.036144  15.451397  0.000086

# %% [markdown]
# ## 7.2 Cov vs. SRPA

# %%
model_comparison = anova_lm(cov_model, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F  Pr(>F)
# 0    5448.0  286014.309472      0.0        NaN       NaN     NaN
# 1    5447.0  286034.521079      1.0 -20.211607 -0.384893     1.0

# %% [markdown]
# ## 7.3 CR / MPA

# %%
model_comparison = anova_lm(no_mpa, cr2)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5441.0  283453.729068      0.0         NaN       NaN       NaN
# 1    5439.0  283003.444458      2.0  450.284611  4.326976  0.013253

# %% [markdown]
# ## 7.4 SRCR / SRMPA

# %%
model_comparison = anova_lm(no_mpa, srcr2)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5441.0  283453.729068      0.0        NaN       NaN       NaN
# 1    5439.0  283414.697522      2.0  39.031546  0.374526  0.687633

# %% [markdown]
# ## 7.5 CR / HG

# %%
model_comparison = anova_lm(no_hg, cr2)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5441.0  283138.957428      0.0        NaN       NaN       NaN
# 1    5439.0  283003.444458      2.0  135.51297  1.302202  0.272017

# %% [markdown]
# ## 7.6 CR / DBP

# %%
model_comparison = anova_lm(no_dbp, cr2)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5441.0  283682.118187      0.0        NaN       NaN       NaN
# 1    5439.0  283003.444458      2.0  678.67373  6.521663  0.001483

# %% [markdown]
# ## 7.7 CR / HR

# %%
model_comparison = anova_lm(no_hr, cr2)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F   Pr(>F)
# 0    5441.0  283313.465321      0.0         NaN       NaN      NaN
# 1    5439.0  283003.444458      2.0  310.020863  2.979122  0.05092

# %% [markdown]
# ## 7.8 CR / BMI

# %%
model_comparison = anova_lm(no_bmi, cr2)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5441.0  283378.357299      0.0         NaN       NaN       NaN
# 1    5439.0  283003.444458      2.0  374.912841  3.602696  0.027315

# %% [markdown]
# ## 7.9 CR Female vs. Male

# %%
model_comparison = anova_lm(crf, crm)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff       ss_diff         F    Pr(>F)
# 0    2967.0  153010.880013      0.0           NaN       NaN       NaN
# 1    2479.0  129827.031692    488.0  23183.848321  0.907146  0.913135

# %% [markdown]
# # 8 Mediation analysis

# %% [markdown]
# ## 8.1 PA x Health / Fitness

# %% [markdown]
# ### 8.1.1 BMI

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + LPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.083418       -0.128419       -0.046498    0.000
# ACME (treated)           -0.083418       -0.128419       -0.046498    0.000
# ADE (control)            -0.059500       -0.240443        0.141662    0.502
# ADE (treated)            -0.059500       -0.240443        0.141662    0.502
# Total effect             -0.142917       -0.326589        0.051923    0.152
# Prop. mediated (control)  0.507122       -3.959728        4.590576    0.152
# Prop. mediated (treated)  0.507122       -3.959728        4.590576    0.152
# ACME (average)           -0.083418       -0.128419       -0.046498    0.000
# ADE (average)            -0.059500       -0.240443        0.141662    0.502
# Prop. mediated (average)  0.507122       -3.959728        4.590576    0.152

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + MPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.107360       -0.167877       -0.052357    0.000
# ACME (treated)           -0.107360       -0.167877       -0.052357    0.000
# ADE (control)            -0.311505       -0.513799       -0.105301    0.002
# ADE (treated)            -0.311505       -0.513799       -0.105301    0.002
# Total effect             -0.418865       -0.612080       -0.219545    0.000
# Prop. mediated (control)  0.258529        0.112468        0.554012    0.000
# Prop. mediated (treated)  0.258529        0.112468        0.554012    0.000
# ACME (average)           -0.107360       -0.167877       -0.052357    0.000
# ADE (average)            -0.311505       -0.513799       -0.105301    0.002
# Prop. mediated (average)  0.258529        0.112468        0.554012    0.000

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + VPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.091114       -0.138304       -0.050049    0.000
# ACME (treated)           -0.091114       -0.138304       -0.050049    0.000
# ADE (control)            -0.026503       -0.221323        0.177386    0.830
# ADE (treated)            -0.026503       -0.221323        0.177386    0.830
# Total effect             -0.117617       -0.318978        0.081583    0.276
# Prop. mediated (control)  0.564727       -8.321459        6.440192    0.276
# Prop. mediated (treated)  0.564727       -8.321459        6.440192    0.276
# ACME (average)           -0.091114       -0.138304       -0.050049    0.000
# ADE (average)            -0.026503       -0.221323        0.177386    0.830
# Prop. mediated (average)  0.564727       -8.321459        6.440192    0.276

# %% [markdown]
# ### 8.1.2 DBP

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + LPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.059598       -0.093127       -0.029636    0.000
# ACME (treated)           -0.059598       -0.093127       -0.029636    0.000
# ADE (control)            -0.083110       -0.274006        0.108139    0.430
# ADE (treated)            -0.083110       -0.274006        0.108139    0.430
# Total effect             -0.142708       -0.335164        0.051188    0.148
# Prop. mediated (control)  0.364182       -2.905981        3.480615    0.148
# Prop. mediated (treated)  0.364182       -2.905981        3.480615    0.148
# ACME (average)           -0.059598       -0.093127       -0.029636    0.000
# ADE (average)            -0.083110       -0.274006        0.108139    0.430
# Prop. mediated (average)  0.364182       -2.905981        3.480615    0.148

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + MPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.033274       -0.064984       -0.007736     0.01
# ACME (treated)           -0.033274       -0.064984       -0.007736     0.01
# ADE (control)            -0.389659       -0.599952       -0.209073     0.00
# ADE (treated)            -0.389659       -0.599952       -0.209073     0.00
# Total effect             -0.422932       -0.623688       -0.242706     0.00
# Prop. mediated (control)  0.076797        0.019806        0.182672     0.01
# Prop. mediated (treated)  0.076797        0.019806        0.182672     0.01
# ACME (average)           -0.033274       -0.064984       -0.007736     0.01
# ADE (average)            -0.389659       -0.599952       -0.209073     0.00
# Prop. mediated (average)  0.076797        0.019806        0.182672     0.01

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + VPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.033635       -0.065174       -0.008595    0.010
# ACME (treated)           -0.033635       -0.065174       -0.008595    0.010
# ADE (control)            -0.090012       -0.278045        0.096886    0.354
# ADE (treated)            -0.090012       -0.278045        0.096886    0.354
# Total effect             -0.123647       -0.312339        0.072715    0.204
# Prop. mediated (control)  0.216133       -2.205555        2.584582    0.210
# Prop. mediated (treated)  0.216133       -2.205555        2.584582    0.210
# ACME (average)           -0.033635       -0.065174       -0.008595    0.010
# ADE (average)            -0.090012       -0.278045        0.096886    0.354
# Prop. mediated (average)  0.216133       -2.205555        2.584582    0.210

# %% [markdown]
# ### 8.1.3 Heart rate

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + LPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.016696       -0.038644        0.000296    0.056
# ACME (treated)           -0.016696       -0.038644        0.000296    0.056
# ADE (control)            -0.128309       -0.310927        0.057942    0.196
# ADE (treated)            -0.128309       -0.310927        0.057942    0.196
# Total effect             -0.145005       -0.327714        0.040095    0.138
# Prop. mediated (control)  0.097679       -0.765853        1.158310    0.190
# Prop. mediated (treated)  0.097679       -0.765853        1.158310    0.190
# ACME (average)           -0.016696       -0.038644        0.000296    0.056
# ADE (average)            -0.128309       -0.310927        0.057942    0.196
# Prop. mediated (average)  0.097679       -0.765853        1.158310    0.190

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + MPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.037837       -0.066718       -0.015388      0.0
# ACME (treated)           -0.037837       -0.066718       -0.015388      0.0
# ADE (control)            -0.379892       -0.573995       -0.188427      0.0
# ADE (treated)            -0.379892       -0.573995       -0.188427      0.0
# Total effect             -0.417729       -0.611539       -0.223819      0.0
# Prop. mediated (control)  0.089087        0.034438        0.216284      0.0
# Prop. mediated (treated)  0.089087        0.034438        0.216284      0.0
# ACME (average)           -0.037837       -0.066718       -0.015388      0.0
# ADE (average)            -0.379892       -0.573995       -0.188427      0.0
# Prop. mediated (average)  0.089087        0.034438        0.216284      0.0

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + VPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.071212       -0.113462       -0.034376    0.000
# ACME (treated)           -0.071212       -0.113462       -0.034376    0.000
# ADE (control)            -0.050889       -0.251818        0.149133    0.614
# ADE (treated)            -0.050889       -0.251818        0.149133    0.614
# Total effect             -0.122102       -0.315305        0.083228    0.226
# Prop. mediated (control)  0.469147       -7.566670        4.518475    0.226
# Prop. mediated (treated)  0.469147       -7.566670        4.518475    0.226
# ACME (average)           -0.071212       -0.113462       -0.034376    0.000
# ADE (average)            -0.050889       -0.251818        0.149133    0.614
# Prop. mediated (average)  0.469147       -7.566670        4.518475    0.226

# %% [markdown]
# ### 8.1.4 Hand grip

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + LPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.020437       -0.055048        0.012442    0.230
# ACME (treated)           -0.020437       -0.055048        0.012442    0.230
# ADE (control)            -0.125017       -0.318217        0.073543    0.246
# ADE (treated)            -0.125017       -0.318217        0.073543    0.246
# Total effect             -0.145454       -0.336670        0.047654    0.170
# Prop. mediated (control)  0.111952       -1.025134        1.693511    0.356
# Prop. mediated (treated)  0.111952       -1.025134        1.693511    0.356
# ACME (average)           -0.020437       -0.055048        0.012442    0.230
# ADE (average)            -0.125017       -0.318217        0.073543    0.246
# Prop. mediated (average)  0.111952       -1.025134        1.693511    0.356

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + MPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.001693       -0.011690        0.006557     0.67
# ACME (treated)           -0.001693       -0.011690        0.006557     0.67
# ADE (control)            -0.415957       -0.600752       -0.221896     0.00
# ADE (treated)            -0.415957       -0.600752       -0.221896     0.00
# Total effect             -0.417650       -0.600186       -0.222940     0.00
# Prop. mediated (control)  0.002544       -0.017516        0.030605     0.67
# Prop. mediated (treated)  0.002544       -0.017516        0.030605     0.67
# ACME (average)           -0.001693       -0.011690        0.006557     0.67
# ADE (average)            -0.415957       -0.600752       -0.221896     0.00
# Prop. mediated (average)  0.002544       -0.017516        0.030605     0.67

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + VPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.016874       -0.002454        0.042142    0.092
# ACME (treated)            0.016874       -0.002454        0.042142    0.092
# ADE (control)            -0.138551       -0.331602        0.060890    0.174
# ADE (treated)            -0.138551       -0.331602        0.060890    0.174
# Total effect             -0.121677       -0.310083        0.079059    0.226
# Prop. mediated (control) -0.098830       -1.633782        1.014410    0.298
# Prop. mediated (treated) -0.098830       -1.633782        1.014410    0.298
# ACME (average)            0.016874       -0.002454        0.042142    0.092
# ADE (average)            -0.138551       -0.331602        0.060890    0.174
# Prop. mediated (average) -0.098830       -1.633782        1.014410    0.298

# %% [markdown]
# # 9 LASSO Regression

# %% [markdown]
# ## 9.1 Accelerometer PA

# %%
df = main_test[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# lasso with cross validated alpha

lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_

# Print the coefficients
print(coefficients)
# Out:
# Optimal alpha: 0.0023101297000831605
# [-0.01791937  0.86656619  0.12061852 -0.30373892  0.25370348  0.37276985
#  -0.24361822  0.21355017]

# %% [markdown]
# ### 9.1.1 Females only

# %%
female = main_test[main_test["Gender"]==0]
df = female[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# ### 9.1.2 Males only

# %%
male = main_test[main_test["Gender"]==1]
df = female[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# ## 9.2 Self-report PA

# %%
df = main_test[["Age", "Gender", "IS", "LPA", "MPA", "VPA",  "SRLPA", "SRMPA", "SRVPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# lasso with cross validated alpha

lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_

# Print the coefficients
print(coefficients)
# Out:
# Optimal alpha: 0.016297508346206444
# [-0.01599478  0.70389108  0.0802131   0.          0.26012892  0.35688144
#  -0.16839811  0.28358135]

# %% [markdown]
# # 10 Figures

# %% [markdown]
# ## 10.1 Scatterplot BrainAGE x Combined risk score

# %%
plt.figure()
plt.scatter("CR", "BA", data = female, label = "Female", alpha=0.5, s=10, color = "darkcyan")
plt.scatter("CR", "BA", data = male, label = "Male", alpha=0.5, s=10, color = "mediumvioletred")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Combined risk score", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(loc="best")
plt.axline((0,-0.14), slope=0.31, color="teal")
plt.axline((0,-0.03), slope=0.26, color="purple")
plt.show()

# %% [markdown]
# ## 10.2 Smaller Correlation Heatmap

# %%
x = main_test
del x["IS"]
del x["LPA"]
del x["VPA"]
del x["SRLPA"]
del x["SRVPA"]
del x["SBP"]

corr = x.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(12,9)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'Gender'),
#   Text(0, 2.5, 'MPA'),
#   Text(0, 3.5, 'SRMPA'),
#   Text(0, 4.5, 'HG'),
#   Text(0, 5.5, 'HR'),
#   Text(0, 6.5, 'BMI'),
#   Text(0, 7.5, 'DBP'),
#   Text(0, 8.5, 'CR'),
#   Text(0, 9.5, 'SRCR'),
#   Text(0, 10.5, 'BA')])

# %% [markdown]
# ### 10.2.1 Females only

# %%
female = x[x["Gender"] == 0]
del female["Gender"]
corr = female.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(12,9)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'MPA'),
#   Text(0, 2.5, 'SRMPA'),
#   Text(0, 3.5, 'HG'),
#   Text(0, 4.5, 'HR'),
#   Text(0, 5.5, 'BMI'),
#   Text(0, 6.5, 'DBP'),
#   Text(0, 7.5, 'CR'),
#   Text(0, 8.5, 'SRCR'),
#   Text(0, 9.5, 'BA')])

# %% [markdown]
# ### 10.2.2 Males only

# %%
male = x[x["Gender"] == 1]
del male["Gender"]
corr = male.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(12,9)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'MPA'),
#   Text(0, 2.5, 'SRMPA'),
#   Text(0, 3.5, 'HG'),
#   Text(0, 4.5, 'HR'),
#   Text(0, 5.5, 'BMI'),
#   Text(0, 6.5, 'DBP'),
#   Text(0, 7.5, 'CR'),
#   Text(0, 8.5, 'SRCR'),
#   Text(0, 9.5, 'BA')])

# %% [markdown]
# # 11 Pickle for comparison to exploration set

# %%
main_test.to_pickle("3_validate.pkl")
