# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from random import seed
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, Lasso
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm
from statsmodels.formula.api import ols
from statsmodels.regression import linear_model
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from statsmodels.stats.mediation import Mediation
from sklearn.svm import SVR
from pingouin import ancova
import matplotlib.cm as cm
from scipy.stats import pearsonr
# %matplotlib inline

seed(888)
pd.set_option('display.max_columns', None)
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.5.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %% [markdown]
# # 1 Load validation set

# %%
# load data from pickle and convert to dataframe
brain_test = pd.read_pickle("brain_test_validate.pkl")
main_test = pd.read_pickle("main_test_validate.pkl")
brain_train = pd.read_pickle("1_brain_train.pkl")
brain_test = pd.DataFrame(brain_test)
main_test = pd.DataFrame(main_test)
brain_train = pd.DataFrame(brain_train)

# %% [markdown]
# # 2 BrainAGE prediction Destrieux

# %%
# select Freesurfer ASEG for training data
whole_brain = brain_train.iloc[:,27:70:2]
left_hemi = brain_train.iloc[:,103:134:2]
right_hemi = brain_train.iloc[:,165:196:2]
age = brain_train["Age"]
ASEG_train = pd.DataFrame(pd.concat([whole_brain,left_hemi, right_hemi,age],axis = 1))

# select Freesurfer ASEG for testing data
whole_brain = brain_test.iloc[:,27:70:2]
left_hemi = brain_test.iloc[:,103:134:2]
right_hemi = brain_test.iloc[:,165:196:2]
age = brain_test["Age"]
ASEG_test = pd.DataFrame(pd.concat([whole_brain,left_hemi, right_hemi,age],axis = 1))

ASEG_X_train = ASEG_train.iloc[:,:-1]
ASEG_X_test = ASEG_test.iloc[:,:-1]


# select variables belonging to the A2009s segmentation
Des_X_train = brain_train.iloc[:,1657:2544:2]
Des_X_test = brain_test.iloc[:,1657:2544:2]


# select age
Y_train = brain_train.iloc[:,-1]
Y_test = brain_test.iloc[:,-1]

# Combine ASEG and A2009s for training data
X_train = pd.concat([ASEG_X_train, Des_X_train], axis=1)
Y_train = Y_train

# Combine ASEG and A2009s for testing data
X_test = pd.concat([ASEG_X_test, Des_X_test], axis=1)
Y_test = Y_test

# standardize x-data
X_train = stats.zscore(X_train)
X_test = stats.zscore(X_test)

# set of alphas to try (=penalization)
alpha_parameters = np.power(10,np.linspace(start=-3, stop=5, num=100))

# %%
X_CV = X_train
Y_CV = Y_train

# randomly split data (only training no PA) into training and testing set
X_train_cv, X_test_cv, Y_train_cv, Y_test_cv = train_test_split(X_CV,Y_CV)

# define the model
model_ridge = RidgeCV(alphas = alpha_parameters)

# perform 10-fold cross validation
scores_ridge = cross_val_score(model_ridge, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')

# calculate the mean-absolute error
mae_ridge = -1 * scores_ridge.mean()

print("The MAE for cross-validation (Ridge):", mae_ridge)

# for correction
model_ridge.fit(X_train_cv,Y_train_cv)
y_pred_cv = model_ridge.predict(X_test_cv)
# Out:
# The MAE for cross-validation (Ridge): 3.73656425547509

# %%
model_Ridge = RidgeCV(alphas = alpha_parameters)

# train model 
model_Ridge.fit(X_train,Y_train)

# get predicted values for test set
y_pred_Ridge = model_Ridge.predict(X_test)

# calculate brain age gap
brain_age_delta_Ridge = y_pred_Ridge-Y_test

# get mean absolute error (MAE)
print("The MAE for testing set using Ridge:", mean_absolute_error(Y_test,y_pred_Ridge))

# top x coefficients and their names
coeff = np.asarray(model_Ridge.coef_)
coeffabs = np.asarray(abs(model_Ridge.coef_))
top_coefficients = np.argsort(coeffabs)[-20:]
print(X_train.iloc[:,top_coefficients].columns)
print(coeff[top_coefficients])

# plot figure with x: actual age Y: predicted age, and a line with slope 1 for reference
plt.figure()
plt.scatter(Y_test, y_pred_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((60,60), slope=1, color='r')
plt.xticks(range(40,90,5))
plt.yticks(range(40,95,5))
plt.ylabel('Predicted Age', fontsize = 16)
plt.xlabel('Age', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()

# plot the brainAGE and a line with the correlation between brainAGE and age 
plt.figure()
plt.scatter(Y_test,brain_age_delta_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((65,0), slope=-0.69, color="blue")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# The MAE for testing set using Ridge: 3.8495727593131943
# Index(['volume_of_putamen_left_hemisphere_f26560_2_0',
#        'volume_of_brainstem_whole_brain_f26526_2_0',
#        'volume_of_putamen_right_hemisphere_f26591_2_0',
#        'volume_of_ventraldc_right_hemisphere_f26596_2_0',
#        'volume_of_supratentorialnotvent_whole_brain_f26520_2_0',
#        'volume_of_thalamusproper_left_hemisphere_f26558_2_0',
#        'volume_of_thalamusproper_right_hemisphere_f26589_2_0',
#        'volume_of_supratentorial_whole_brain_f26519_2_0',
#        'volume_of_cortex_right_hemisphere_f26583_2_0',
#        'volume_of_cortex_left_hemisphere_f26552_2_0',
#        'volume_of_totalgray_whole_brain_f26518_2_0',
#        'volume_of_brainsegnotvent_whole_brain_f26515_2_0',
#        'volume_of_cerebralwhitematter_left_hemisphere_f26553_2_0',
#        'volume_of_brainseg_whole_brain_f26514_2_0',
#        'volume_of_cerebralwhitematter_right_hemisphere_f26584_2_0',
#        'volume_of_subcortgray_whole_brain_f26517_2_0',
#        'volume_of_lateralventricle_right_hemisphere_f26585_2_0',
#        'volume_of_lateralventricle_left_hemisphere_f26554_2_0',
#        'volume_of_ventriclechoroid_whole_brain_f26522_2_0',
#        'volume_of_brainsegnotventsurf_whole_brain_f26516_2_0'],
#       dtype='object')
# [ -2.26860126   2.39696434  -2.50775638  -2.73702095  -2.79581218
#   -3.18768567  -3.46072034   4.47572726   5.88380517  -7.24909472
#   -9.94656768 -10.80662041 -11.75101437  12.15655364 -13.17155378
#   17.63982205 -19.89223201 -23.21030878  42.26283551  48.04208732]

# %%
# reformat cross validation data for regression model
y_pred_cv = np.asarray(y_pred_cv)
y_pred_cv = np.reshape(y_pred_cv, (-1,1))
Y_test_cv = np.asarray(Y_test_cv)
Y_test_cv = np.reshape(Y_test_cv, (-1,1))

# now using correction from the R code that's online from Cole
reg = LinearRegression().fit(Y_test_cv, y_pred_cv)
coef = float(reg.coef_)
intercept = float(reg.intercept_)
print("Coefficient and Intercept:", coef, intercept)

# correction by cole
function = lambda t: (t-intercept)/coef
vfunc = np.vectorize(function)
corr_brainage_4 = vfunc(y_pred_Ridge)
corr_brainage_delta_4 = corr_brainage_4-Y_test

# plots corrected
plt.figure()
plt.scatter(Y_test, corr_brainage_4, alpha=0.5, s=10, color="darkcyan")
plt.axline((65,65), slope=coef, color="blue")
plt.ylabel("Predicted Age Corrected", fontsize = 16)
plt.axline((60,60), slope=1, color='r')
plt.xlabel("Age", fontsize = 16)
plt.xticks(range(40,90,5), fontsize = 14)
plt.yticks(range(30,115,10), fontsize = 14)
plt.show()

plt.figure()
plt.scatter(Y_test, corr_brainage_delta_4, alpha=0.5, s=10, color="darkcyan")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE Corrected", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# Coefficient and Intercept: 0.6439980118128842 22.894452295909254

# %%
main_test["BA"] = corr_brainage_delta_4

# %% [markdown]
# # 3 Preprocessing

# %% [markdown]
# ## 3.1 Recoding

# %%
# recoding imaging site and gender
# 1 = Cheadle;  2 = Reading;  3 = Newcastle;  4 = Bristol
main_test['IS'] = main_test['IS'].map({'11025': 0, '11026': 1,'11027': 2, '11028': 3})
main_test["Sex"] = main_test["Sex"].map({"Female":0, "Male":1})
main_test["Sex"] = main_test["Sex"].astype("int")

# delete unnecessary variables
del main_test["ID"]
del main_test["MVPA"]
del main_test["TPA"]

# %% [markdown]
# ## 3.2 Remove outliers on SRPA

# %%
# remove outliers on self-reported physical activity data for each intensity seperately
before = main_test.shape[0]
outlier = np.mean(main_test["SRLPA"]) + np.std(main_test["SRLPA"])*3
main_test = main_test[main_test["SRLPA"]<outlier]
outlier = np.mean(main_test["SRMPA"]) + np.std(main_test["SRMPA"])*3
main_test = main_test[main_test["SRMPA"]<outlier]
outlier = np.mean(main_test["SRVPA"]) + np.std(main_test["SRVPA"])*3
main_test = main_test[main_test["SRVPA"]<outlier]
after = main_test.shape[0]
print("Outliers on self-reported PA:", before-after)
print(after)
# Out:
# Outliers on self-reported PA: 532
# 5452

# %% [markdown]
# ## 3.3 Convert SRPA from MET min/week to min/week

# %%
main_test["SRLPA"] = main_test["SRLPA"]/3.3
main_test["SRMPA"] = main_test["SRMPA"]/4
main_test["SRVPA"] = main_test["SRVPA"]/8

# %% [markdown]
# ## 3.4 Remove people with Gender other than Male or Female

# %%
before = main_test.shape[0]
main_test = main_test[(main_test["Sex"] == 0) | (main_test["Sex"] == 1)]
after = main_test.shape[0]
print("Sex not Male or Female:", before-after)
print(after)
# Out:
# Sex not Male or Female: 0
# 5452

# %% [markdown]
# # 4 Basic distributions of validation set

# %% [markdown]
# ## 4.1 Data and Descriptives

# %%
main_test.head()
# Out:
#         Age  Sex  IS      VPA       MPA        LPA  SRLPA  SRMPA  SRVPA    HG  \
# 4723   73.0    0   0  59.2704  661.8528  2400.4512  315.0   90.0    0.0  20.0
# 25494  55.0    1   0  70.0560  970.7760  1991.5920  120.0   30.0    0.0  26.0
# 34463  65.0    0   1  48.6720  506.1888  2813.2416  420.0  840.0  160.0  22.0
# 26337  67.0    0   2   0.0000   60.4800  1653.1200   40.0   60.0    0.0  38.0
# 29224  70.0    0   1   9.2736  361.6704  1873.2672   30.0    0.0   45.0  24.0
#
#          HR      BMI   DBP    SBP        BA
# 4723   52.0  25.1338  74.0  137.0  0.220685
# 25494  55.0  22.9630  80.0  148.0 -0.870378
# 34463  45.0  23.8325  63.0  108.0 -7.358534
# 26337  68.0  33.6473  84.0  139.0  7.023851
# 29224  69.0  32.8906  87.0  132.0  3.464389

# %%
# get mean and std for all variables for males and females seperately for the test set
female = main_test[main_test["Sex"] == 0]
male = main_test[main_test["Sex"]== 1]

print("Number of females:", female.shape[0])
print("NUmber of males:", male.shape[0])

print("Age")
mean = main_test["Age"].mean()
print("Mean", mean)
std = main_test["Age"].std()
print("Std",std)

print("LPA")
mean = main_test["LPA"].mean()
print("Mean", mean)
std = main_test["LPA"].std()
print("Std",std)

print("MPA")
mean = main_test["MPA"].mean()
print("Mean", mean)
std = main_test["MPA"].std()
print("Std",std)

print("VPA")
mean = main_test["VPA"].mean()
print("Mean", mean)
std = main_test["VPA"].std()
print("Std",std)

print("SRLPA")
mean = main_test["SRLPA"].mean()
print("Mean", mean)
std = main_test["SRLPA"].std()
print("Std",std)

print("SRMPA")
mean = main_test["SRMPA"].mean()
print("Mean", mean)
std = main_test["SRMPA"].std()
print("Std",std)

print("SRVPA")
mean = main_test["SRVPA"].mean()
print("Mean", mean)
std = main_test["SRVPA"].std()
print("Std",std)

print("DBP")
mean = main_test["DBP"].mean()
print("Mean", mean)
std = main_test["DBP"].std()
print("Std",std)

print("SBP")
mean = main_test["SBP"].mean()
print("Mean", mean)
std = main_test["SBP"].std()
print("Std",std)

print("BMI")
mean = main_test["BMI"].mean()
print("Mean", mean)
std = main_test["BMI"].std()
print("Std",std)

print("HG")
mean = main_test["HG"].mean()
print("Mean", mean)
std = main_test["HG"].std()
print("Std",std)

print("HR")
mean = main_test["HR"].mean()
print("Mean", mean)
std = main_test["HR"].std()
print("Std",std)

print("IS")
print(main_test["IS"].value_counts())
# Out:
# Number of females: 2970
# NUmber of males: 2482
# Age
# Mean 64.1907556859868
# Std 7.814225465582799
# LPA
# Mean 1981.0712548789434
# Std 417.08409539087546
# MPA
# Mean 482.57679882611893
# Std 216.85915554816543
# VPA
# Mean 34.27631577402791
# Std 43.2553234105916
# SRLPA
# Mean 235.25458547322083
# Std 219.09399284018272
# SRMPA
# Mean 159.23734409391048
# Std 192.24815076490748
# SRVPA
# Mean 66.45377842993398
# Std 83.83425453246974
# DBP
# Mean 81.11812179016874
# Std 10.361578350786544
# SBP
# Mean 136.32758620689654
# Std 18.24128891718472
# BMI
# Mean 26.36214115920763
# Std 4.213687095706291
# HG
# Mean 33.49486426999266
# Std 10.80830496808681
# HR
# Mean 67.96460014673514
# Std 11.043817664608612
# IS
# 0    3423
# 2    1109
# 1     909
# 3      11
# Name: IS, dtype: int64

# %% [markdown]
# ## 4.3 Physical activity

# %%
# plot physical activity intensity categories for self-report and accelerometer together and seperately

plt.figure()
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,5000,1000),fontsize = 14)
plt.ylim(0,0.01)
plt.ylabel("Density",fontsize = 16)
plt.yticks(fontsize = 14)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA")
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA")
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2000,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

# plt.figure()
# sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA", color="#6baed6")
# sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA", color="#08519c")
# plt.xlabel("Min/week of physical activity", fontsize = 16)
# plt.xticks(range(0,4500,1000),fontsize = 14)
# plt.yticks(fontsize = 14)
# plt.ylabel("Density",fontsize = 16)
# plt.legend()
# plt.show()

# plt.figure()
# sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA", color="#fd8d3c")
# sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA", color="#a63603")
# plt.xlabel("Min/week of physical activity", fontsize = 16)
# plt.xticks(range(0,2500,500),fontsize = 14)
# plt.yticks(fontsize = 14)
# plt.ylabel("Density",fontsize = 16)
# plt.legend()
# plt.show()

# plt.figure()
# sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA", color="#74c476")
# sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA", color="#006d2c")
# plt.ylim(0,0.01)
# plt.xticks(range(0,1500,500),fontsize = 14)
# plt.yticks(fontsize = 14)
# plt.ylabel("Density",fontsize = 16)
# plt.xlabel("Min/week of physical activity", fontsize = 16)
# plt.legend()
# plt.show()

plt.figure()
plt.scatter("MPA", "SRMPA", data = main_test, label = "Moderate PA", alpha=0.3, s=10, color = "darkcyan")
plt.scatter("VPA", "SRVPA", data = main_test, label = "Vigorous PA", alpha=0.3, s=10, color = "mediumvioletred")
plt.ylabel("Self-reported (min/week)", fontsize = 16)
plt.xlabel("Accelerometer (min/week)", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # 5 Reorder Dataframe

# %%
# reorder dataframe
main_test = main_test[['Age', 'Sex', 'IS' , 'LPA', 'MPA', 'VPA', 'SRLPA', 'SRMPA', 'SRVPA', 'HG', 'HR', 'BMI', 'DBP', 'SBP', 'BA']]

# %% [markdown]
# # 6 Correlation Heatmap

# %%
def calculate_pvalues(df):
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            tmp = df[df[r].notnull() & df[c].notnull()]
            pvalues[r][c] = round(pearsonr(tmp[r], tmp[c])[1], 4)
    return pvalues

# %%
corr_test = main_test
corr_test = corr_test[:]
del corr_test["BA"]
del corr_test["SBP"]
del corr_test["IS"]
corr = corr_test.corr()
corr = round(corr,3)

fig, ax = plt.subplots(figsize=(13,10)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)


p_values = np.asarray(calculate_pvalues(corr_test))

threshold = 0.0007575  # Define your significance threshold

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if i != j:
            correlation = corr.iloc[i, j]
            p_value = p_values[i,j]  # Calculate or provide the p-value for the correlation

            if p_value < threshold:
                ax.text(j + 0.9, i + 0.2, "*", ha='right', va='top', color='black', fontsize=12)

# %% [markdown]
# # 7 Models with OLS

# %% [markdown]
# ### 7.1 Baseline Covariates

# %%
cov_model = ols('BA ~ Sex + Age + IS', missing='drop', data = main_test).fit()
print(cov_model.summary())

#calculate effect size
results = cov_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     16.75
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           7.90e-11
# Time:                        21:01:17   Log-Likelihood:                -17433.
# No. Observations:                5452   AIC:                         3.487e+04
# Df Residuals:                    5448   BIC:                         3.490e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0027      0.664      3.015      0.003       0.700       3.305
# Sex            1.0471      0.162      6.453      0.000       0.729       1.365
# Age           -0.0379      0.010     -3.637      0.000      -0.058      -0.017
# IS             0.1062      0.099      1.069      0.285      -0.089       0.301
# ==============================================================================
# Omnibus:                       74.328   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.215
# Skew:                           0.231   Prob(JB):                     1.90e-19
# Kurtosis:                       3.408   Cond. No.                         536.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.040831
# Sex          0.087391
# Age         -0.049259
# IS           0.014481
# dtype: float64

# %% [markdown]
# ### 7.2 Accelerometer PA

# %%
lpa = ols('BA ~ LPA + Age + Sex + IS + Sex:LPA', missing='drop', data = main_test).fit()
print(lpa.summary())

#calculate effect size
results = lpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     10.23
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           8.99e-10
# Time:                        21:01:17   Log-Likelihood:                -17432.
# No. Observations:                5452   AIC:                         3.488e+04
# Df Residuals:                    5446   BIC:                         3.492e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6083      0.848      1.897      0.058      -0.053       3.270
# LPA            0.0002      0.000      0.753      0.452      -0.000       0.001
# Age           -0.0382      0.010     -3.668      0.000      -0.059      -0.018
# Sex            1.1446      0.794      1.441      0.150      -0.413       2.702
# IS             0.1087      0.099      1.094      0.274      -0.086       0.303
# Sex:LPA    -3.252e-05      0.000     -0.082      0.934      -0.001       0.001
# ==============================================================================
# Omnibus:                       74.440   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.402
# Skew:                           0.231   Prob(JB):                     1.73e-19
# Kurtosis:                       3.409   Cond. No.                     2.74e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    0.025696
# LPA          0.010195
# Age         -0.049678
# Sex          0.019512
# IS           0.014813
# Sex:LPA     -0.001115
# dtype: float64

# %%
mpa = ols('BA ~ MPA + Sex + Age + IS + Sex:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     13.20
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           8.36e-13
# Time:                        21:01:18   Log-Likelihood:                -17425.
# No. Observations:                5452   AIC:                         3.486e+04
# Df Residuals:                    5446   BIC:                         3.490e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.5464      0.753      3.383      0.001       1.071       4.022
# MPA           -0.0003      0.001     -0.579      0.563      -0.001       0.001
# Sex            1.9531      0.393      4.971      0.000       1.183       2.723
# Age           -0.0443      0.011     -4.177      0.000      -0.065      -0.024
# IS             0.1205      0.099      1.214      0.225      -0.074       0.315
# Sex:MPA       -0.0019      0.001     -2.570      0.010      -0.003      -0.000
# ==============================================================================
# Omnibus:                       74.888   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.993
# Skew:                           0.232   Prob(JB):                     1.29e-19
# Kurtosis:                       3.410   Cond. No.                     5.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    0.045820
# MPA         -0.007844
# Sex          0.067319
# Age         -0.056567
# IS           0.016436
# Sex:MPA     -0.034807
# dtype: float64

# %%
vpa = ols('BA ~ VPA + Age + Sex + IS + Sex:VPA', missing='drop', data = main_test).fit()
print(vpa.summary())

#calculate effect size
results = vpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     11.38
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           6.06e-11
# Time:                        21:01:18   Log-Likelihood:                -17429.
# No. Observations:                5452   AIC:                         3.487e+04
# Df Residuals:                    5446   BIC:                         3.491e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0427      0.701      2.913      0.004       0.668       3.417
# VPA            0.0028      0.003      1.017      0.309      -0.003       0.008
# Age           -0.0400      0.011     -3.737      0.000      -0.061      -0.019
# Sex            1.3681      0.207      6.597      0.000       0.962       1.775
# IS             0.1164      0.099      1.171      0.242      -0.078       0.311
# Sex:VPA       -0.0088      0.004     -2.367      0.018      -0.016      -0.002
# ==============================================================================
# Omnibus:                       75.287   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.339
# Skew:                           0.233   Prob(JB):                     1.08e-19
# Kurtosis:                       3.409   Cond. No.                         708.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.039454
# VPA          0.013773
# Age         -0.050609
# Sex          0.089351
# IS           0.015864
# Sex:VPA     -0.032059
# dtype: float64

# %% [markdown]
# ### 7.1.3 Self-report PA

# %%
srlpa = ols('BA ~ SRLPA + Age + Sex + IS + Sex:SRLPA', missing='drop', data = main_test).fit()
print(srlpa.summary())

#calculate effect size
results = srlpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     10.19
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           9.80e-10
# Time:                        21:01:18   Log-Likelihood:                -17432.
# No. Observations:                5452   AIC:                         3.488e+04
# Df Residuals:                    5446   BIC:                         3.492e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0936      0.674      3.106      0.002       0.772       3.415
# SRLPA         -0.0003      0.001     -0.683      0.494      -0.001       0.001
# Age           -0.0380      0.010     -3.645      0.000      -0.058      -0.018
# Sex            0.9030      0.236      3.820      0.000       0.440       1.366
# IS             0.1068      0.099      1.075      0.282      -0.088       0.302
# Sex:SRLPA      0.0006      0.001      0.837      0.403      -0.001       0.002
# ==============================================================================
# Omnibus:                       74.404   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.292
# Skew:                           0.231   Prob(JB):                     1.83e-19
# Kurtosis:                       3.408   Cond. No.                     3.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    0.042071
# SRLPA       -0.009256
# Age         -0.049370
# Sex          0.051736
# IS           0.014559
# Sex:SRLPA    0.011335
# dtype: float64

# %%
srmpa = ols('BA ~ SRMPA + Sex + Age + IS + Sex:SRMPA', missing='drop', data = main_test).fit()
print(srmpa.summary())

#calculate effect size
results = srmpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     10.20
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           9.69e-10
# Time:                        21:01:18   Log-Likelihood:                -17432.
# No. Observations:                5452   AIC:                         3.488e+04
# Df Residuals:                    5446   BIC:                         3.492e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0372      0.668      3.049      0.002       0.727       3.347
# SRMPA          0.0003      0.001      0.512      0.609      -0.001       0.001
# Sex            1.0288      0.210      4.903      0.000       0.617       1.440
# Age           -0.0392      0.011     -3.723      0.000      -0.060      -0.019
# IS             0.1091      0.099      1.098      0.272      -0.086       0.304
# Sex:SRMPA      0.0001      0.001      0.165      0.869      -0.002       0.002
# ==============================================================================
# Omnibus:                       74.923   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.083
# Skew:                           0.232   Prob(JB):                     1.23e-19
# Kurtosis:                       3.411   Cond. No.                     2.36e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.36e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    0.041294
# SRMPA        0.006932
# Sex          0.066398
# Age         -0.050415
# IS           0.014866
# Sex:SRMPA    0.002240
# dtype: float64

# %%
srvpa = ols('BA ~ SRVPA + Age + Sex + IS + Sex:SRVPA', missing='drop', data = main_test).fit()
print(srvpa.summary())

#calculate effect size
results = srvpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     10.16
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           1.06e-09
# Time:                        21:01:18   Log-Likelihood:                -17432.
# No. Observations:                5452   AIC:                         3.488e+04
# Df Residuals:                    5446   BIC:                         3.492e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9379      0.673      2.880      0.004       0.619       3.257
# SRVPA          0.0010      0.001      0.707      0.480      -0.002       0.004
# Age           -0.0378      0.010     -3.622      0.000      -0.058      -0.017
# Sex            1.1283      0.208      5.430      0.000       0.721       1.536
# IS             0.1066      0.099      1.074      0.283      -0.088       0.301
# Sex:SRVPA     -0.0013      0.002     -0.670      0.503      -0.005       0.002
# ==============================================================================
# Omnibus:                       74.303   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.061
# Skew:                           0.231   Prob(JB):                     2.05e-19
# Kurtosis:                       3.406   Cond. No.                     1.10e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    0.039003
# SRVPA        0.009573
# Age         -0.049048
# Sex          0.073535
# IS           0.014539
# Sex:SRVPA   -0.009068
# dtype: float64

# %% [markdown]
# # 8 Model comparisons

# %% [markdown]
# ## 8.1 Cov vs. PA

# %%
model_comparison = anova_lm(cov_model, lpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  191150.225212      0.0        NaN       NaN       NaN
# 1    5446.0  191118.464685      2.0  31.760528  0.452515  0.636051

# %%
model_comparison = anova_lm(cov_model, mpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F   Pr(>F)
# 0    5448.0  191150.225212      0.0         NaN       NaN      NaN
# 1    5446.0  190603.542093      2.0  546.683119  7.810023  0.00041

# %%
model_comparison = anova_lm(cov_model, vpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5448.0  191150.225212      0.0         NaN       NaN       NaN
# 1    5446.0  190918.544530      2.0  231.680683  3.304375  0.036796

# %% [markdown]
# ## 8.2 Cov vs. SRPA

# %%
model_comparison = anova_lm(cov_model, srlpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  191150.225212      0.0        NaN       NaN       NaN
# 1    5446.0  191124.913183      2.0  25.312029  0.360626  0.697256

# %%
model_comparison = anova_lm(cov_model, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  191150.225212      0.0        NaN       NaN       NaN
# 1    5446.0  191124.030021      2.0  26.195191  0.373211  0.688538

# %%
model_comparison = anova_lm(cov_model, srvpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  191150.225212      0.0        NaN       NaN       NaN
# 1    5446.0  191130.808040      2.0  19.417172  0.276632  0.758344

# %% [markdown]
# # 10 Standardization of all variables

# %%
main_test = pd.DataFrame(main_test)
main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Sex","IS"]] = stats.zscore(main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Sex","IS"]], nan_policy='omit')

# %% [markdown]
# # 11 Mediation analysis

# %% [markdown]
# ## 11.1 BMI

# %%
# outcome_model = sm.OLS.from_formula("BA ~ BMI + LPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("BMI ~ LPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + MPA + Age + Sex + IS", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ MPA + Age + Sex + IS", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "MPA").fit()
print(res.summary())

modelm = ols("BMI ~ MPA + Age + Sex + IS", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ BMI + Age + Sex + IS", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.074351       -0.121694       -0.033409    0.002
# ACME (treated)           -0.074351       -0.121694       -0.033409    0.002
# ADE (control)            -0.170945       -0.328236       -0.002871    0.048
# ADE (treated)            -0.170945       -0.328236       -0.002871    0.048
# Total effect             -0.245296       -0.399969       -0.081120    0.006
# Prop. mediated (control)  0.300491        0.111129        0.909240    0.008
# Prop. mediated (treated)  0.300491        0.111129        0.909240    0.008
# ACME (average)           -0.074351       -0.121694       -0.033409    0.002
# ADE (average)            -0.170945       -0.328236       -0.002871    0.048
# Prop. mediated (average)  0.300491        0.111129        0.909240    0.008
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BMI   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     120.5
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           1.08e-98
# Time:                        21:02:55   Log-Likelihood:                -7504.9
# No. Observations:                5452   AIC:                         1.502e+04
# Df Residuals:                    5447   BIC:                         1.505e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.711e-16      0.013  -2.09e-14      1.000      -0.025       0.025
# MPA           -0.2688      0.013    -20.247      0.000      -0.295      -0.243
# Age           -0.0405      0.013     -3.011      0.003      -0.067      -0.014
# Sex            0.0977      0.013      7.467      0.000       0.072       0.123
# IS            -0.0091      0.013     -0.695      0.487      -0.035       0.017
# ==============================================================================
# Omnibus:                      983.245   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2199.039
# Skew:                           1.037   Prob(JB):                         0.00
# Kurtosis:                       5.319   Cond. No.                         1.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     16.56
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           1.71e-13
# Time:                        21:02:55   Log-Likelihood:                -17425.
# No. Observations:                5452   AIC:                         3.486e+04
# Df Residuals:                    5447   BIC:                         3.489e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1097      0.080      1.369      0.171      -0.047       0.267
# BMI            0.3209      0.081      3.981      0.000       0.163       0.479
# Age           -0.3004      0.081     -3.697      0.000      -0.460      -0.141
# Sex            0.4877      0.081      6.010      0.000       0.329       0.647
# IS             0.0938      0.081      1.161      0.246      -0.065       0.252
# ==============================================================================
# Omnibus:                       74.786   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.626
# Skew:                           0.229   Prob(JB):                     9.38e-20
# Kurtosis:                       3.421   Cond. No.                         1.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ BMI + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("BMI ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.2 DBP

# %%
# outcome_model = sm.OLS.from_formula("BA ~ DBP + LPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("DBP ~ LPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + MPA + Age + Sex + IS", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ MPA + Age + Sex + IS", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "MPA").fit()
print(res.summary())

modelm = ols("DBP ~ MPA + Age + Sex + IS", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ DBP + Age + Sex + IS", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.028508       -0.053788       -0.005703    0.016
# ACME (treated)           -0.028508       -0.053788       -0.005703    0.016
# ADE (control)            -0.214734       -0.366647       -0.063498    0.006
# ADE (treated)            -0.214734       -0.366647       -0.063498    0.006
# Total effect             -0.243242       -0.390510       -0.088797    0.002
# Prop. mediated (control)  0.116868        0.023618        0.316421    0.018
# Prop. mediated (treated)  0.116868        0.023618        0.316421    0.018
# ACME (average)           -0.028508       -0.053788       -0.005703    0.016
# ADE (average)            -0.214734       -0.366647       -0.063498    0.006
# Prop. mediated (average)  0.116868        0.023618        0.316421    0.018
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DBP   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     66.58
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           4.42e-55
# Time:                        21:04:37   Log-Likelihood:                -7605.9
# No. Observations:                5452   AIC:                         1.522e+04
# Df Residuals:                    5447   BIC:                         1.525e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.108e-16      0.013   1.59e-14      1.000      -0.026       0.026
# MPA           -0.0573      0.014     -4.237      0.000      -0.084      -0.031
# Age            0.0436      0.014      3.185      0.001       0.017       0.070
# Sex            0.1905      0.013     14.289      0.000       0.164       0.217
# IS             0.0331      0.013      2.480      0.013       0.007       0.059
# ==============================================================================
# Omnibus:                       87.285   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.466
# Skew:                           0.280   Prob(JB):                     1.86e-21
# Kurtosis:                       3.328   Cond. No.                         1.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     22.71
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           1.24e-18
# Time:                        21:04:37   Log-Likelihood:                -17413.
# No. Observations:                5452   AIC:                         3.484e+04
# Df Residuals:                    5447   BIC:                         3.487e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1097      0.080      1.372      0.170      -0.047       0.266
# DBP            0.5185      0.082      6.344      0.000       0.358       0.679
# Age           -0.3246      0.081     -3.997      0.000      -0.484      -0.165
# Sex            0.4219      0.082      5.142      0.000       0.261       0.583
# IS             0.0708      0.081      0.878      0.380      -0.087       0.229
# ==============================================================================
# Omnibus:                       73.194   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.279
# Skew:                           0.227   Prob(JB):                     3.03e-19
# Kurtosis:                       3.411   Cond. No.                         1.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ DBP + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("DBP ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.3 Heart rate

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HR + LPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("HR ~ LPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + MPA + Age + Sex + IS", main_test)
mediator_model = sm.OLS.from_formula("HR ~ MPA + Age + Sex + IS", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "MPA").fit()
print(res.summary())

modelm = ols("HR ~ MPA + Age + Sex + IS", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ HR + Age + Sex + IS", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.032716       -0.056723       -0.012071    0.000
# ACME (treated)           -0.032716       -0.056723       -0.012071    0.000
# ADE (control)            -0.213634       -0.373466       -0.052873    0.020
# ADE (treated)            -0.213634       -0.373466       -0.052873    0.020
# Total effect             -0.246351       -0.406176       -0.083492    0.002
# Prop. mediated (control)  0.129317        0.041197        0.383897    0.002
# Prop. mediated (treated)  0.129317        0.041197        0.383897    0.002
# ACME (average)           -0.032716       -0.056723       -0.012071    0.000
# ADE (average)            -0.213634       -0.373466       -0.052873    0.020
# Prop. mediated (average)  0.129317        0.041197        0.383897    0.002
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     HR   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     29.49
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           2.66e-24
# Time:                        21:06:28   Log-Likelihood:                -7677.6
# No. Observations:                5452   AIC:                         1.537e+04
# Df Residuals:                    5447   BIC:                         1.540e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.621e-16      0.013   4.19e-14      1.000      -0.026       0.026
# MPA           -0.1090      0.014     -7.954      0.000      -0.136      -0.082
# Age            0.0021      0.014      0.150      0.881      -0.025       0.029
# Sex           -0.1012      0.014     -7.488      0.000      -0.128      -0.075
# IS             0.0147      0.014      1.085      0.278      -0.012       0.041
# ==============================================================================
# Omnibus:                      530.633   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              847.876
# Skew:                           0.713   Prob(JB):                    7.69e-185
# Kurtosis:                       4.304   Cond. No.                         1.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     16.58
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           1.64e-13
# Time:                        21:06:28   Log-Likelihood:                -17425.
# No. Observations:                5452   AIC:                         3.486e+04
# Df Residuals:                    5447   BIC:                         3.489e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1097      0.080      1.369      0.171      -0.047       0.267
# HR             0.3213      0.081      3.991      0.000       0.164       0.479
# Age           -0.3037      0.081     -3.737      0.000      -0.463      -0.144
# Sex            0.5530      0.081      6.820      0.000       0.394       0.712
# IS             0.0835      0.081      1.034      0.301      -0.075       0.242
# ==============================================================================
# Omnibus:                       77.231   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.656
# Skew:                           0.233   Prob(JB):                     2.06e-20
# Kurtosis:                       3.427   Cond. No.                         1.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HR + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("HR ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.4 Hand grip

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HG + LPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("HG ~ LPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + MPA + Sex + IS + Age", main_test)
mediator_model = sm.OLS.from_formula("HG ~ MPA + Sex + IS + Age", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "MPA").fit()
print(res.summary())

modelm = ols("HG ~ MPA + Age + Sex + IS", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ HG + Age + Sex + IS", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.002367       -0.012598        0.004812    0.568
# ACME (treated)           -0.002367       -0.012598        0.004812    0.568
# ADE (control)            -0.241471       -0.404134       -0.078178    0.004
# ADE (treated)            -0.241471       -0.404134       -0.078178    0.004
# Total effect             -0.243839       -0.405584       -0.079608    0.004
# Prop. mediated (control)  0.007324       -0.029080        0.061987    0.572
# Prop. mediated (treated)  0.007324       -0.029080        0.061987    0.572
# ACME (average)           -0.002367       -0.012598        0.004812    0.568
# ADE (average)            -0.241471       -0.404134       -0.078178    0.004
# Prop. mediated (average)  0.007324       -0.029080        0.061987    0.572
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     HG   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     1753.
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):               0.00
# Time:                        21:08:17   Log-Likelihood:                -5480.8
# No. Observations:                5452   AIC:                         1.097e+04
# Df Residuals:                    5447   BIC:                         1.100e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.056e-16      0.009   2.29e-14      1.000      -0.018       0.018
# MPA            0.0090      0.009      0.982      0.326      -0.009       0.027
# Age           -0.1613      0.009    -17.392      0.000      -0.179      -0.143
# Sex            0.7519      0.009     83.277      0.000       0.734       0.770
# IS             0.0088      0.009      0.970      0.332      -0.009       0.026
# ==============================================================================
# Omnibus:                       83.253   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              157.444
# Skew:                          -0.038   Prob(JB):                     6.48e-35
# Kurtosis:                       3.829   Cond. No.                         1.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     13.65
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):           4.44e-11
# Time:                        21:08:17   Log-Likelihood:                -17430.
# No. Observations:                5452   AIC:                         3.487e+04
# Df Residuals:                    5447   BIC:                         3.490e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1097      0.080      1.367      0.172      -0.048       0.267
# HG            -0.2525      0.121     -2.082      0.037      -0.490      -0.015
# Age           -0.3371      0.084     -4.027      0.000      -0.501      -0.173
# Sex            0.7113      0.122      5.840      0.000       0.472       0.950
# IS             0.0888      0.081      1.098      0.272      -0.070       0.247
# ==============================================================================
# Omnibus:                       76.133   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.574
# Skew:                           0.234   Prob(JB):                     5.84e-20
# Kurtosis:                       3.414   Cond. No.                         2.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HG + VPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("HG ~ VPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# # 12 LASSO Regression

# %% [markdown]
# ## 12.1 Accelerometer PA

# %%
df = main_test[["Age", "Sex", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Sex", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Sex", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=0, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('turbo')
plt.figure(figsize=(7,5))
for i, column in enumerate(columns):
    plt.plot(alphas, coefs[column], label=column, color=cmap(i / (len(columns) - 1)))

# lasso with cross validated alpha
lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

for i, column in enumerate(columns):
    y_pos = coefficients[i]
    color = cmap(i / 7.0)
    if i == 0:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, -7),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 1:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, 4),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 4:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 6:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, -10),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 2:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 3:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, -5),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 7:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(40, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 5:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, 0),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white',edgecolor="white", pad=0))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.xlim(0.001, 1)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend().set_visible(False)
plt.show()

# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.0093260334688322
# [-0.38439288  0.60439084  0.07407823 -0.15855197  0.1486614   0.43415179
#  -0.23920018  0.11980226]
# 0.01976668774356738

# %% [markdown]
# ## 12.2 Self-report PA

# %%
df = main_test[["Age", "Sex", "IS", "LPA", "MPA", "VPA",  "SRLPA", "SRMPA", "SRVPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Sex", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Sex", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=0, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('turbo')
plt.figure(figsize=(7,5))
for i, column in enumerate(columns):
    plt.plot(alphas, coefs[column], label=column, color=cmap(i / (len(columns) - 1)))


# lasso with cross validated alpha
lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)


# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

for i, column in enumerate(columns):
    y_pos = coefficients[i]
    color = cmap(i / 7.0)
    if i == 0:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, -5),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 1:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, 4),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 2:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(40, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 3:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, 0),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 4:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(40, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 5:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 6:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(40, -7),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 7:
        plt.annotate(column, (0.0025, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.xlim(0.001, 1)
plt.ylabel('Coefficients', fontsize = 16)
plt.legend().set_visible(False)
plt.show()

# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.008111308307896872
# [-0.37178794  0.61969016  0.07188584  0.10091176  0.16405348  0.43176804
#  -0.25192067  0.16503608]
# 0.01941401861477121
