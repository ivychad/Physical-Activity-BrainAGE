# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from random import seed
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, Lasso
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm
from statsmodels.formula.api import ols
from statsmodels.regression import linear_model
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from statsmodels.stats.mediation import Mediation
from sklearn.svm import SVR
from pingouin import ancova
import matplotlib.cm as cm
# %matplotlib inline

seed(888)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1 Load validation set

# %%
# load data from pickle and convert to dataframe
brain_test = pd.read_pickle("brain_test_validate.pkl")
main_test = pd.read_pickle("main_test_validate.pkl")
brain_train = pd.read_pickle("1_brain_train.pkl")
brain_test = pd.DataFrame(brain_test)
main_test = pd.DataFrame(main_test)
brain_train = pd.DataFrame(brain_train)

# %% [markdown]
# # 2 Preprocessing of validation set

# %% [markdown]
# ### 2.1 BrainAGE prediction for A2009

# %%
# select variables belonging to A2009s segmentation
X_train = brain_train.iloc[:,1657:2544:2]
Y_train = brain_train.iloc[:,-1]
X_test = brain_test.iloc[:,1657:2544:2]
Y_test = brain_test.iloc[:,-1]

# standardize x-data
X_train = stats.zscore(X_train)
X_test = stats.zscore(X_test)

# set of alphas to try (=penalization)
alpha_parameters = np.power(10,np.linspace(start=-3, stop=5, num=100))

# %% [markdown]
# ### 2.1.1 Cross-validation

# %%
X_CV = X_train
Y_CV = Y_train

# randomly split data (only training no PA) into training and testing set
X_train_cv, X_test_cv, Y_train_cv, Y_test_cv = train_test_split(X_CV,Y_CV)

#define the model
model = RidgeCV(alphas = alpha_parameters)
#perform 10-fold cross validation
scores = cross_val_score(model, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')
#calculate the mean-absolute error
mae = -1 * scores.mean()
print("The MAE for cross-validation (Ridge):", mae)

# for correction
model.fit(X_train_cv,Y_train_cv)
y_pred_cv = model.predict(X_test_cv)
# Out:
# The MAE for cross-validation (Ridge): 4.192981026915527

# %% [markdown]
# ### 2.1.2 Prediction

# %%
# initialize models
model_Lasso = LassoCV(alphas = alpha_parameters, max_iter=100000)
model_Ridge = RidgeCV(alphas = alpha_parameters)
model_SVR = SVR(kernel = 'rbf')

# train model 
model_Lasso.fit(X_train,Y_train)
model_Ridge.fit(X_train,Y_train)
model_SVR.fit(X_train,Y_train)

# get predicted values for test set
y_pred_Lasso = model_Lasso.predict(X_test)
y_pred_Ridge = model_Ridge.predict(X_test)
y_pred_SVR = model_SVR.predict(X_test)

# calculate brain age gap
brain_age_delta_Lasso = y_pred_Lasso-Y_test
brain_age_delta_Ridge = y_pred_Ridge-Y_test
brain_age_delta_SVR = y_pred_SVR-Y_test

# get mean absolute error (MAE)
print("The MAE for testing set using Lasso:", mean_absolute_error(Y_test,y_pred_Lasso))
print("The MAE for testing set using Ridge:", mean_absolute_error(Y_test,y_pred_Ridge))
print("The MAE for testing set using SVR:", mean_absolute_error(Y_test,y_pred_SVR))

# Spearman rank order correlations
print("The Spearman r for Ridge vs Lasso:", stats.spearmanr(brain_age_delta_Ridge, brain_age_delta_Lasso))
print("The Spearman r for Ridge vs SVR:", stats.spearmanr(brain_age_delta_Ridge, brain_age_delta_SVR))
print("The Spearman r for SVR vs Lasso:", stats.spearmanr(brain_age_delta_SVR, brain_age_delta_Lasso))

# top x coefficients and their names
coeff = np.asarray(model_Ridge.coef_)
coeffabs = np.asarray(abs(model_Ridge.coef_))
top_coefficients = np.argsort(coeffabs)[-20:]
print(X_train.iloc[:,top_coefficients].columns)
print(coeff[top_coefficients])

# plot figure with x: actual age Y: predicted age, and a line with slope 1 for reference
plt.figure()
plt.scatter(Y_test, y_pred_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((60,60), slope=1, color='r')
plt.xticks(range(40,90,5))
plt.yticks(range(40,90,5))
plt.ylabel('Predicted Age', fontsize = 16)
plt.xlabel('Age', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()

plt.figure()
plt.scatter(Y_test,brain_age_delta_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((65,0), slope=-0.69, color="blue")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# The MAE for testing set using Lasso: 4.265579543071238
# The MAE for testing set using Ridge: 4.262589702409484
# The MAE for testing set using SVR: 4.538391428456859
# The Spearman r for Ridge vs Lasso: SpearmanrResult(correlation=0.9997394384429193, pvalue=0.0)
# The Spearman r for Ridge vs SVR: SpearmanrResult(correlation=0.917699544760441, pvalue=0.0)
# The Spearman r for SVR vs Lasso: SpearmanrResult(correlation=0.9183795135363797, pvalue=0.0)
# Index(['volume_of_gtemporalinf_left_hemisphere_f27513_2_0',
#        'volume_of_scentral_right_hemisphere_f27743_2_0',
#        'volume_of_gpostcentral_right_hemisphere_f27726_2_0',
#        'area_of_gtemporalinf_left_hemisphere_f27365_2_0',
#        'mean_thickness_of_gfrontsup_left_hemisphere_f27418_2_0',
#        'area_of_latfispost_right_hemisphere_f27591_2_0',
#        'volume_of_stemporalsup_left_hemisphere_f27549_2_0',
#        'area_of_stemporalsup_left_hemisphere_f27401_2_0',
#        'area_of_sparietooccipital_right_hemisphere_f27615_2_0',
#        'area_of_gscingulant_right_hemisphere_f27556_2_0',
#        'area_of_scalcarine_left_hemisphere_f27372_2_0',
#        'volume_of_scalcarine_left_hemisphere_f27520_2_0',
#        'volume_of_gfrontsup_left_hemisphere_f27492_2_0',
#        'volume_of_gscingulant_right_hemisphere_f27704_2_0',
#        'area_of_gfrontsup_left_hemisphere_f27344_2_0',
#        'volume_of_sparietooccipital_right_hemisphere_f27763_2_0',
#        'volume_of_scentral_left_hemisphere_f27521_2_0',
#        'volume_of_latfispost_right_hemisphere_f27739_2_0',
#        'area_of_scalcarine_right_hemisphere_f27594_2_0',
#        'volume_of_scalcarine_right_hemisphere_f27742_2_0'],
#       dtype='object')
# [ 1.33500311  1.35589929 -1.40956036 -1.41335742 -1.4290742  -1.49188128
#  -1.49429486  1.5138274  -1.53084042  1.55013063 -1.58490537  1.58906398
#   1.60619697 -1.67635603 -1.749753    1.75977046  1.86033162  2.16152389
#  -2.37541509  2.37603676]

# %% [markdown]
# ### 2.1.3 Correction

# %%
# reformat cross validation data for regression model
y_pred_cv = np.asarray(y_pred_cv)
y_pred_cv = np.reshape(y_pred_cv, (-1,1))
Y_test_cv = np.asarray(Y_test_cv)
Y_test_cv = np.reshape(Y_test_cv, (-1,1))

# now using correction from the R code that's online from Cole
reg = LinearRegression().fit(Y_test_cv, y_pred_cv)
coef = float(reg.coef_)
intercept = float(reg.intercept_)
print("Coefficient and Intercept:", coef, intercept)

# correction by cole
function = lambda t: (t-intercept)/coef
vfunc = np.vectorize(function)
corr_brainage_1 = vfunc(y_pred_Ridge)
corr_brainage_delta_1 = corr_brainage_1-Y_test

# plots corrected
plt.figure()
plt.scatter(Y_test, corr_brainage_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((65,65), slope=coef, color="blue")
plt.ylabel("Predicted Age Corrected", fontsize = 16)
plt.axline((60,60), slope=1, color='r')
plt.xlabel("Age", fontsize = 16)
plt.xticks(range(40,90,5))
plt.yticks(range(30,115,10))
plt.show()

plt.figure()
plt.scatter(Y_test, corr_brainage_delta_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE Corrected", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# Coefficient and Intercept: 0.5342980116479878 29.980604037577542

# %% [markdown]
# ### 2.1.4 Add BrainAge Delta to Dataframe

# %%
main_test["BA"] = corr_brainage_delta_1

# %% [markdown]
# ## 2.2 Recoding

# %%
# recoding imaging site and gender
# 1 = Cheadle;  2 = Reading;  3 = Newcastle;  4 = Bristol
main_test['IS'] = main_test['IS'].map({'11025': 1, '11026': 2,'11027': 3, '11028': 4})
main_test["Gender"] = main_test["Gender"].map({"Female":0, "Male":1})
main_test["Gender"] = main_test["Gender"].astype("int")

# delete unnecessary variables
del main_test["ID"]
del main_test["MVPA"]
del main_test["TPA"]

# %% [markdown]
# ## 2.3 Remove outliers on SRPA

# %%
# remove outliers on self-reported physical activity data for each intensity seperately
before = main_test.shape[0]
outlier = np.mean(main_test["SRLPA"]) + np.std(main_test["SRLPA"])*3
main_test = main_test[main_test["SRLPA"]<outlier]
outlier = np.mean(main_test["SRMPA"]) + np.std(main_test["SRMPA"])*3
main_test = main_test[main_test["SRMPA"]<outlier]
outlier = np.mean(main_test["SRVPA"]) + np.std(main_test["SRVPA"])*3
main_test = main_test[main_test["SRVPA"]<outlier]
after = main_test.shape[0]
print("Outliers on self-reported PA:", before-after)
print(after)
# Out:
# Outliers on self-reported PA: 532
# 5452

# %% [markdown]
# ## 2.4 Remove people with Gender other than Male or Female

# %%
before = main_test.shape[0]
main_test = main_test[(main_test["Gender"] == 0) | (main_test["Gender"] == 1)]
after = main_test.shape[0]
print("Gender not Male or Female:", before-after)
print(after)
# Out:
# Gender not Male or Female: 0
# 5452

# %% [markdown]
# # 3 Basic distributions of validation set

# %% [markdown]
# ## 3.1 Data and Descriptives

# %%
main_test.head()
# Out:
#         Age  Gender  IS      VPA       MPA        LPA   SRLPA   SRMPA   SRVPA  \
# 4723   73.0       0   1  59.2704  661.8528  2400.4512  1039.5   360.0     0.0
# 25494  55.0       1   1  70.0560  970.7760  1991.5920   396.0   120.0     0.0
# 34463  65.0       0   2  48.6720  506.1888  2813.2416  1386.0  3360.0  1280.0
# 26337  67.0       0   3   0.0000   60.4800  1653.1200   132.0   240.0     0.0
# 29224  70.0       0   2   9.2736  361.6704  1873.2672    99.0     0.0   360.0
#
#          HG    HR      BMI   DBP    SBP         BA
# 4723   20.0  52.0  25.1338  74.0  137.0   3.765799
# 25494  26.0  55.0  22.9630  80.0  148.0   2.419652
# 34463  22.0  45.0  23.8325  63.0  108.0  -6.922959
# 26337  38.0  68.0  33.6473  84.0  139.0  15.880859
# 29224  24.0  69.0  32.8906  87.0  132.0   3.077056

# %%
# mean and std of all variables for males and females seperately
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("Number of females:", female.shape[0])
print("NUmber of males:",male.shape[0])

print("Age")
mean = female["Age"].mean()
print("Female", mean)
std = female["Age"].std()
print("Female",std)
mean = male["Age"].mean()
print("Male",mean)
std = male["Age"].std()
print("Male",std)

print("LPA")
mean = female["LPA"].mean()
print("Female", mean)
std = female["LPA"].std()
print("Female",std)
mean = male["LPA"].mean()
print("Male",mean)
std = male["LPA"].std()
print("Male",std)

print("MPA")
mean = female["MPA"].mean()
print("Female", mean)
std = female["MPA"].std()
print("Female",std)
mean = male["MPA"].mean()
print("Male",mean)
std = male["MPA"].std()
print("Male",std)

print("VPA")
mean = female["VPA"].mean()
print("Female", mean)
std = female["VPA"].std()
print("Female",std)
mean = male["VPA"].mean()
print("Male",mean)
std = male["VPA"].std()
print("Male",std)

print("SRLPA")
mean = female["SRLPA"].mean()
print("Female", mean)
std = female["SRLPA"].std()
print("Female",std)
mean = male["SRLPA"].mean()
print("Male",mean)
std = male["SRLPA"].std()
print("Male",std)

print("SRMPA")
mean = female["SRMPA"].mean()
print("Female", mean)
std = female["SRMPA"].std()
print("Female",std)
mean = male["SRMPA"].mean()
print("Male",mean)
std = male["SRMPA"].std()
print("Male",std)

print("SRVPA")
mean = female["SRVPA"].mean()
print("Female", mean)
std = female["SRVPA"].std()
print("Female",std)
mean = male["SRVPA"].mean()
print("Male",mean)
std = male["SRVPA"].std()
print("Male",std)

print("BMI")
mean = female["BMI"].mean()
print("Female", mean)
std = female["BMI"].std()
print("Female",std)
mean = male["BMI"].mean()
print("Male",mean)
std = male["BMI"].std()
print("Male",std)

print("HG")
mean = female["HG"].mean()
print("Female", mean)
std = female["HG"].std()
print("Female",std)
mean = male["HG"].mean()
print("Male",mean)
std = male["HG"].std()
print("Male",std)

print("HR")
mean = female["HR"].mean()
print("Female", mean)
std = female["HR"].std()
print("Female",std)
mean = male["HR"].mean()
print("Male",mean)
std = male["HR"].std()
print("Male",std)

print("DBP")
mean = female["DBP"].mean()
print("Female", mean)
std = female["DBP"].std()
print("Female",std)
mean = male["DBP"].mean()
print("Male",mean)
std = male["DBP"].std()
print("Male",std)

print("SBP")
mean = female["SBP"].mean()
print("Female", mean)
std = female["SBP"].std()
print("Female",std)
mean = male["SBP"].mean()
print("Male",mean)
std = male["SBP"].std()
print("Male",std)

print("IS")
print("Female")
print(female["IS"].value_counts())
print("Male")
print(male["IS"].value_counts())
# Out:
# Number of females: 2970
# NUmber of males: 2482
# Age
# Female 63.365656565656565
# Female 7.671358834590245
# Male 65.17808219178082
# Male 7.870456794472667
# LPA
# Female 2061.0672872727273
# Female 406.33606702437504
# Male 1885.3467519742142
# Male 409.6249987343925
# MPA
# Female 493.00463030303035
# Female 219.37278852675698
# Male 470.0986926672039
# Male 213.1870127069337
# VPA
# Female 31.059233939393966
# Female 39.8729402584149
# Male 38.12592618855765
# Male 46.701593415163025
# SRLPA
# Female 782.4266666666666
# Female 706.1642469143237
# Male 769.0568896051572
# Male 742.7437996329985
# SRMPA
# Female 642.7501683501683
# Female 762.365502137756
# Male 630.0080580177276
# Male 776.9453699945714
# SRVPA
# Female 476.6222222222222
# Female 627.6737299431975
# Male 597.453666398066
# Male 713.3294572774662
# BMI
# Female 25.948532020202023
# Female 4.526024283563611
# Male 26.8570723207091
# Male 3.747773618911473
# HG
# Female 26.25690235690236
# Female 6.234093493954997
# Male 42.15592264302982
# Male 8.508682952449652
# HR
# Female 68.92861952861954
# Female 10.21306969707317
# Male 66.81103948428687
# Male 11.861867502725236
# DBP
# Female 79.24410774410775
# Female 10.12791250037231
# Male 83.36059629331184
# Male 10.193142187231949
# SBP
# Female 132.9090909090909
# Female 18.395686947322144
# Male 140.41821112006446
# Male 17.186624075161365
# IS
# Female
# 1    1837
# 3     619
# 2     506
# 4       8
# Name: IS, dtype: int64
# Male
# 1    1586
# 3     490
# 2     403
# 4       3
# Name: IS, dtype: int64

# %% [markdown]
# ## 3.2 Age and BrainAge

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'Gender', fill=True, palette = "crest")
plt.title("Age x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'Gender', fill=True, palette = "crest")
plt.title("BrainAge x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'IS', fill=True, palette = "crest")
plt.title("BrainAge x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'IS', fill=True, palette = "crest")
plt.title("Age x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'MPA', hue = 'IS', fill=True, palette = "crest")
plt.title("Moderate PA x Imaging site")
plt.show()


plt.figure()
sns.kdeplot(data = main_test, x= 'BA', fill=True, label="A2009")
plt.title("BrainAge Segmentations")
plt.legend()
plt.show()

# %% [markdown]
# ## 3.3 Physical activity

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA")
#sns.kdeplot(data = main_test, x= 'TPA', fill=True, label = "Total PA")
plt.xlabel("Min/week of physical activity")
plt.legend()
plt.xticks(range(0,5000,1000))
plt.ylim(0,0.01)
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA")
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA")
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA")
plt.xlabel("Min/week of physical activity")
#plt.title("Self Report PA distributions")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA", color="#6baed6")
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA", color="#08519c")
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Light PA")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA", color="#fd8d3c")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA", color="#a63603")
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Moderate PA")
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA", color="#74c476")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA", color="#006d2c")
plt.ylim(0,0.01)
plt.xticks(range(0,3500,1000))
plt.xlabel("Min/week of physical activity")
#plt.title("SR vs. Accelerometry Vigorous PA")
plt.legend()
plt.show()

# %% [markdown]
# ## 3.4 Health and Fitness

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'HG', hue = 'Gender', fill=True, palette = "crest")
plt.title("Hand grip")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'HR', hue = 'Gender', fill=True, palette = "crest")
plt.title("Heart rate")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Systolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'DBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Distolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BMI', hue = 'Gender', fill=True, palette = "crest")
plt.title("BMI")
plt.show()

# %% [markdown]
# ## 3.5 Standardize all variables (except Gender, Age, BA, IS)

# %%
# standardize
main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI"]] = stats.zscore(main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI"]], nan_policy='omit')

# %% [markdown]
# ## 3.6 Compute combined risk score

# %%
main_test["CR"] = main_test["MPA"]*-1 + main_test["HG"]*-1 + main_test["DBP"] + main_test["SBP"] + main_test["HR"] + main_test["BMI"]
main_test["SRCR"] = main_test["SRMPA"]*-1 + main_test["HG"]*-1 + main_test["DBP"] + main_test["SBP"] + main_test["HR"] + main_test["BMI"]

# %% [markdown]
# ## 3.7 Copy BrainAGE to end of dataframe

# %%
brainage = main_test["BA"]
del main_test["BA"]
main_test["BA"] = brainage

# %% [markdown]
# ## 3.8 Remove effect of Age on all predictor variables (regression -> residuals)

# %%
model = ols("LPA ~ Age", data = main_test).fit()
main_test["LPA"] = model.resid

model = ols("MPA ~ Age", data = main_test).fit()
main_test["MPA"] = model.resid

model = ols("VPA ~ Age", data = main_test).fit()
main_test["VPA"] = model.resid

model = ols("SRLPA ~ Age", data = main_test).fit()
main_test["SRLPA"] = model.resid

model = ols("SRMPA ~ Age", data = main_test).fit()
main_test["SRMPA"] = model.resid

model = ols("SRVPA ~ Age", data = main_test).fit()
main_test["SRVPA"] = model.resid

model = ols("CR ~ Age", data = main_test).fit()
main_test["CR"] = model.resid

model = ols("SRCR ~ Age", data = main_test).fit()
main_test["SRCR"] = model.resid

model = ols("HR ~ Age", data = main_test).fit()
main_test["HR"] = model.resid

model = ols("DBP ~ Age", data = main_test).fit()
main_test["DBP"] = model.resid

model = ols("SBP ~ Age", data = main_test).fit()
main_test["SBP"] = model.resid

model = ols("BMI ~ Age", data = main_test).fit()
main_test["BMI"] = model.resid

model = ols("HG ~ Age", data = main_test).fit()
main_test["HG"] = model.resid

# %% [markdown]
# ## 3.9 Descriptives for combined risk score

# %%
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("CR")
mean = female["CR"].mean()
print("Female", mean)
std = female["CR"].std()
print("Female",std)
mean = male["CR"].mean()
print("Male",mean)
std = male["CR"].std()
print("Male",std)

print("SRCR")
mean = female["SRCR"].mean()
print("Female", mean)
std = female["SRCR"].std()
print("Female",std)
mean = male["SRCR"].mean()
print("Male",mean)
std = male["SRCR"].std()
print("Male",std)
# Out:
# CR
# Female 0.3172916449635202
# Female 3.0887835991196364
# Male -0.3796761424422374
# Male 3.0192486917163497
# SRCR
# Female 0.3218057675469012
# Female 2.969016608057288
# Male -0.3850778120927849
# Male 2.9785580603962707

# %% [markdown]
# # 4 Simple Correlation Heatmap

# %%
corr = main_test.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'Gender'),
#   Text(0, 2.5, 'IS'),
#   Text(0, 3.5, 'VPA'),
#   Text(0, 4.5, 'MPA'),
#   Text(0, 5.5, 'LPA'),
#   Text(0, 6.5, 'SRLPA'),
#   Text(0, 7.5, 'SRMPA'),
#   Text(0, 8.5, 'SRVPA'),
#   Text(0, 9.5, 'HG'),
#   Text(0, 10.5, 'HR'),
#   Text(0, 11.5, 'BMI'),
#   Text(0, 12.5, 'DBP'),
#   Text(0, 13.5, 'SBP'),
#   Text(0, 14.5, 'CR'),
#   Text(0, 15.5, 'SRCR'),
#   Text(0, 16.5, 'BA')])

# %% [markdown]
# ## 4.1 Female

# %%
female = main_test[main_test["Gender"] == 0]
del female["Gender"]
corr = female.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'IS'),
#   Text(0, 2.5, 'VPA'),
#   Text(0, 3.5, 'MPA'),
#   Text(0, 4.5, 'LPA'),
#   Text(0, 5.5, 'SRLPA'),
#   Text(0, 6.5, 'SRMPA'),
#   Text(0, 7.5, 'SRVPA'),
#   Text(0, 8.5, 'HG'),
#   Text(0, 9.5, 'HR'),
#   Text(0, 10.5, 'BMI'),
#   Text(0, 11.5, 'DBP'),
#   Text(0, 12.5, 'SBP'),
#   Text(0, 13.5, 'CR'),
#   Text(0, 14.5, 'SRCR'),
#   Text(0, 15.5, 'BA')])

# %% [markdown]
# ## 4.2 Male

# %%
male = main_test[main_test["Gender"] == 1]
del male["Gender"]
corr = male.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(15,12)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'IS'),
#   Text(0, 2.5, 'VPA'),
#   Text(0, 3.5, 'MPA'),
#   Text(0, 4.5, 'LPA'),
#   Text(0, 5.5, 'SRLPA'),
#   Text(0, 6.5, 'SRMPA'),
#   Text(0, 7.5, 'SRVPA'),
#   Text(0, 8.5, 'HG'),
#   Text(0, 9.5, 'HR'),
#   Text(0, 10.5, 'BMI'),
#   Text(0, 11.5, 'DBP'),
#   Text(0, 12.5, 'SBP'),
#   Text(0, 13.5, 'CR'),
#   Text(0, 14.5, 'SRCR'),
#   Text(0, 15.5, 'BA')])

# %% [markdown]
# # 6 Models with OLS

# %% [markdown]
# ## 6.1 Single Predictor Models

# %% [markdown]
# ### 6.1.1 Accelerometer PA

# %%
lpa = ols('BA ~ LPA + Gender + IS + Gender:LPA', missing='drop', data = main_test).fit()
print(lpa.summary())

#calculate effect size
results = lpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.800
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):             0.0245
# Time:                        18:39:02   Log-Likelihood:                -18511.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5447   BIC:                         3.707e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3463      0.235     -1.476      0.140      -0.806       0.114
# LPA           -0.0531      0.136     -0.391      0.696      -0.320       0.214
# Gender         0.5914      0.201      2.942      0.003       0.197       0.986
# IS             0.0867      0.120      0.722      0.471      -0.149       0.322
# Gender:LPA    -0.0475      0.201     -0.237      0.813      -0.441       0.346
# ==============================================================================
# Omnibus:                       58.782   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.116
# Skew:                           0.203   Prob(JB):                     2.67e-15
# Kurtosis:                       3.362   Cond. No.                         5.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.019983
# LPA          -0.005289
# Gender        0.039841
# IS            0.009773
# Gender:LPA   -0.003204
# dtype: float64

# %%
mpa = ols('BA ~ MPA + Gender + IS + Gender:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     6.929
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.47e-05
# Time:                        18:39:03   Log-Likelihood:                -18503.
# No. Observations:                5452   AIC:                         3.702e+04
# Df Residuals:                    5447   BIC:                         3.705e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3908      0.233     -1.679      0.093      -0.847       0.066
# MPA           -0.4101      0.133     -3.072      0.002      -0.672      -0.148
# Gender         0.6013      0.196      3.065      0.002       0.217       0.986
# IS             0.1152      0.120      0.959      0.338      -0.120       0.351
# Gender:MPA    -0.0059      0.201     -0.029      0.976      -0.399       0.388
# ==============================================================================
# Omnibus:                       58.224   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.308
# Skew:                           0.202   Prob(JB):                     3.99e-15
# Kurtosis:                       3.358   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.022738
# MPA          -0.041610
# Gender        0.041509
# IS            0.012985
# Gender:MPA   -0.000399
# dtype: float64

# %%
vpa = ols('BA ~ VPA + Gender +  IS + Gender:VPA', missing='drop', data = main_test).fit()
print(vpa.summary())

#calculate effect size
results = vpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.275
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):             0.0109
# Time:                        18:39:03   Log-Likelihood:                -18510.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5447   BIC:                         3.706e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3909      0.234     -1.672      0.095      -0.849       0.067
# VPA           -0.1728      0.148     -1.170      0.242      -0.462       0.117
# Gender         0.6591      0.198      3.336      0.001       0.272       1.046
# IS             0.0978      0.120      0.813      0.416      -0.138       0.334
# Gender:VPA     0.0253      0.202      0.125      0.900      -0.371       0.421
# ==============================================================================
# Omnibus:                       58.708   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.012
# Skew:                           0.203   Prob(JB):                     2.81e-15
# Kurtosis:                       3.362   Cond. No.                         5.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.022647
# VPA          -0.015846
# Gender        0.045187
# IS            0.011013
# Gender:VPA    0.001699
# dtype: float64

# %% [markdown]
# ### 6.1.2 Self-report PA

# %%
srlpa = ols('BA ~ SRLPA + Gender + IS + Gender:SRLPA', missing='drop', data = main_test).fit()
print(srlpa.summary())

#calculate effect size
results = srlpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.658
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):             0.0311
# Time:                        18:39:04   Log-Likelihood:                -18512.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5447   BIC:                         3.707e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.3606      0.233     -1.548      0.122      -0.817       0.096
# SRLPA           -0.0253      0.136     -0.186      0.852      -0.291       0.241
# Gender           0.6249      0.196      3.181      0.001       0.240       1.010
# IS               0.0895      0.120      0.745      0.456      -0.146       0.325
# Gender:SRLPA     0.0430      0.196      0.220      0.826      -0.341       0.427
# ==============================================================================
# Omnibus:                       58.769   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.171
# Skew:                           0.202   Prob(JB):                     2.59e-15
# Kurtosis:                       3.364   Cond. No.                         5.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      -0.020960
# SRLPA          -0.002521
# Gender          0.043085
# IS              0.010091
# Gender:SRLPA    0.002975
# dtype: float64

# %%
srmpa = ols('BA ~ SRMPA + Gender + IS + Gender:SRMPA', missing='drop', data = main_test).fit()
print(srmpa.summary())

#calculate effect size
results = srmpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.965
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):             0.0185
# Time:                        18:39:04   Log-Likelihood:                -18511.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5447   BIC:                         3.706e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.3583      0.233     -1.537      0.124      -0.815       0.099
# SRMPA            0.0447      0.135      0.331      0.740      -0.220       0.309
# Gender           0.6216      0.196      3.164      0.002       0.237       1.007
# IS               0.0872      0.120      0.726      0.468      -0.148       0.323
# Gender:SRMPA    -0.2011      0.198     -1.015      0.310      -0.590       0.187
# ==============================================================================
# Omnibus:                       58.724   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.234
# Skew:                           0.202   Prob(JB):                     2.51e-15
# Kurtosis:                       3.365   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      -0.020813
# SRMPA           0.004486
# Gender          0.042857
# IS              0.009829
# Gender:SRMPA   -0.013750
# dtype: float64

# %%
srvpa = ols('BA ~ SRVPA + Gender + IS + Gender:SRVPA', missing='drop', data = main_test).fit()
print(srvpa.summary())

#calculate effect size
results = srvpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.744
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):             0.0269
# Time:                        18:39:05   Log-Likelihood:                -18511.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5447   BIC:                         3.707e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.3668      0.233     -1.572      0.116      -0.824       0.091
# SRVPA           -0.0728      0.142     -0.514      0.607      -0.351       0.205
# Gender           0.6363      0.197      3.225      0.001       0.250       1.023
# IS               0.0893      0.120      0.743      0.458      -0.146       0.325
# Gender:SRVPA     0.0236      0.197      0.120      0.904      -0.362       0.409
# ==============================================================================
# Omnibus:                       58.742   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.164
# Skew:                           0.202   Prob(JB):                     2.60e-15
# Kurtosis:                       3.364   Cond. No.                         5.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept      -0.021296
# SRVPA          -0.006962
# Gender          0.043683
# IS              0.010060
# Gender:SRVPA    0.001625
# dtype: float64

# %% [markdown]
# ### 6.1.3 Combined risk scores (Acc)

# %%
cr = ols('BA ~ CR + Gender + IS + Gender:CR', missing='drop', data = main_test).fit()
print(cr.summary())

#calculate effect size
results = cr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     17.04
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           6.83e-14
# Time:                        18:39:07   Log-Likelihood:                -18483.
# No. Observations:                5452   AIC:                         3.698e+04
# Df Residuals:                    5447   BIC:                         3.701e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4494      0.232     -1.935      0.053      -0.905       0.006
# CR             0.2229      0.043      5.223      0.000       0.139       0.307
# Gender         0.7957      0.197      4.045      0.000       0.410       1.181
# IS             0.1007      0.120      0.842      0.400      -0.134       0.335
# Gender:CR      0.0395      0.064      0.617      0.537      -0.086       0.165
# ==============================================================================
# Omnibus:                       64.520   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.097
# Skew:                           0.209   Prob(JB):                     4.93e-17
# Kurtosis:                       3.395   Cond. No.                         9.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.026212
# CR           0.070732
# Gender       0.054786
# IS           0.011404
# Gender:CR    0.008352
# dtype: float64

# %% [markdown]
# #### 6.1.3.1 Males

# %%
male = main_test[main_test["Gender"] == 1]

crm = ols('BA ~ CR + IS', missing='drop', data = male).fit()
print(crm.summary())

#calculate effect size
results = crm
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     18.22
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.40e-08
# Time:                        18:39:08   Log-Likelihood:                -8422.6
# No. Observations:                2482   AIC:                         1.685e+04
# Df Residuals:                    2479   BIC:                         1.687e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2179      0.316     -0.690      0.490      -0.837       0.401
# CR             0.2649      0.048      5.526      0.000       0.171       0.359
# IS             0.4627      0.180      2.575      0.010       0.110       0.815
# ==============================================================================
# Omnibus:                       11.248   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.799
# Skew:                           0.130   Prob(JB):                      0.00274
# Kurtosis:                       3.215   Cond. No.                         7.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.009348
# CR           0.074835
# IS           0.034867
# dtype: float64

# %% [markdown]
# #### 6.1.3.2 Females

# %%
female = main_test[main_test["Gender"] == 0]

crf = ols('BA ~ CR + IS', missing='drop', data = female).fit()
print(crf.summary())

#calculate effect size
results = crf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     14.46
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           5.64e-07
# Time:                        18:39:08   Log-Likelihood:                -10057.
# No. Observations:                2970   AIC:                         2.012e+04
# Df Residuals:                    2967   BIC:                         2.014e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0147      0.287      0.051      0.959      -0.548       0.578
# CR             0.2229      0.043      5.245      0.000       0.140       0.306
# IS            -0.1903      0.160     -1.190      0.234      -0.504       0.123
# ==============================================================================
# Omnibus:                       60.313   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.444
# Skew:                           0.274   Prob(JB):                     6.84e-17
# Kurtosis:                       3.548   Cond. No.                         7.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.000691
# CR           0.071033
# IS          -0.016115
# dtype: float64

# %% [markdown]
# ### 6.1.4 Combined risk score (SR)

# %%
srcr = ols('BA ~ SRCR + Gender + IS + Gender:SRCR', missing='drop', data = main_test).fit()
print(srcr.summary())

#calculate effect size
results = srcr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     13.58
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           5.08e-11
# Time:                        18:39:09   Log-Likelihood:                -18490.
# No. Observations:                5452   AIC:                         3.699e+04
# Df Residuals:                    5447   BIC:                         3.702e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.4038      0.232     -1.738      0.082      -0.859       0.052
# SRCR            0.1908      0.044      4.291      0.000       0.104       0.278
# Gender          0.7797      0.197      3.958      0.000       0.393       1.166
# IS              0.0779      0.120      0.651      0.515      -0.157       0.313
# Gender:SRCR     0.0528      0.066      0.803      0.422      -0.076       0.182
# ==============================================================================
# Omnibus:                       62.033   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.032
# Skew:                           0.204   Prob(JB):                     2.28e-16
# Kurtosis:                       3.388   Cond. No.                         9.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept     -0.023540
# SRCR           0.058109
# Gender         0.053598
# IS             0.008812
# Gender:SRCR    0.010874
# dtype: float64

# %% [markdown]
# ### 6.1.5 Health & Fitness

# %%
hg = ols('BA ~ HG + Gender + IS + Gender:HG', missing='drop', data = main_test).fit()
print(hg.summary())

#calculate effect size
results = hg
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.183
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):             0.0127
# Time:                        18:39:11   Log-Likelihood:                -18510.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5447   BIC:                         3.706e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5554      0.283     -1.959      0.050      -1.111       0.000
# HG            -0.2871      0.237     -1.211      0.226      -0.752       0.178
# Gender         0.9441      0.295      3.196      0.001       0.365       1.523
# IS             0.0895      0.120      0.745      0.456      -0.146       0.325
# Gender:HG      0.1335      0.302      0.442      0.658      -0.458       0.725
# ==============================================================================
# Omnibus:                       60.427   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.381
# Skew:                           0.204   Prob(JB):                     8.59e-16
# Kurtosis:                       3.372   Cond. No.                         9.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.026536
# HG          -0.016406
# Gender       0.043290
# IS           0.010086
# Gender:HG    0.005993
# dtype: float64

# %%
hr = ols('BA ~ HR + Gender + IS + Gender:HR', missing='drop', data = main_test).fit()
print(hr.summary())

#calculate effect size
results = hr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     7.564
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           4.51e-06
# Time:                        18:39:14   Log-Likelihood:                -18502.
# No. Observations:                5452   AIC:                         3.701e+04
# Df Residuals:                    5447   BIC:                         3.705e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3896      0.233     -1.674      0.094      -0.846       0.067
# HR             0.4043      0.143      2.825      0.005       0.124       0.685
# Gender         0.7095      0.197      3.602      0.000       0.323       1.096
# IS             0.0850      0.120      0.708      0.479      -0.150       0.320
# Gender:HR      0.0555      0.197      0.282      0.778      -0.330       0.441
# ==============================================================================
# Omnibus:                       62.032   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.525
# Skew:                           0.207   Prob(JB):                     2.94e-16
# Kurtosis:                       3.380   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.022671
# HR           0.038260
# Gender       0.048782
# IS           0.009589
# Gender:HR    0.003822
# dtype: float64

# %%
bmi = ols('BA ~ BMI + Gender + IS + Gender:BMI', missing='drop', data = main_test).fit()
print(bmi.summary())

#calculate effect size
results = bmi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     8.616
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           6.29e-07
# Time:                        18:39:15   Log-Likelihood:                -18500.
# No. Observations:                5452   AIC:                         3.701e+04
# Df Residuals:                    5447   BIC:                         3.704e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3512      0.233     -1.509      0.131      -0.807       0.105
# BMI            0.3243      0.123      2.634      0.008       0.083       0.566
# Gender         0.5178      0.197      2.626      0.009       0.131       0.904
# IS             0.1029      0.120      0.858      0.391      -0.132       0.338
# Gender:BMI     0.3440      0.204      1.687      0.092      -0.056       0.744
# ==============================================================================
# Omnibus:                       59.865   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.216
# Skew:                           0.201   Prob(JB):                     9.33e-16
# Kurtosis:                       3.379   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.020442
# BMI           0.035673
# Gender        0.035563
# IS            0.011616
# Gender:BMI    0.022849
# dtype: float64

# %%
dbp = ols('BA ~ DBP + Gender + IS + Gender:DBP', missing='drop', data = main_test).fit()
print(dbp.summary())

#calculate effect size
results = dbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     9.397
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.44e-07
# Time:                        18:39:15   Log-Likelihood:                -18498.
# No. Observations:                5452   AIC:                         3.701e+04
# Df Residuals:                    5447   BIC:                         3.704e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2379      0.234     -1.015      0.310      -0.697       0.222
# DBP            0.5463      0.136      4.024      0.000       0.280       0.812
# Gender         0.4308      0.200      2.158      0.031       0.039       0.822
# IS             0.0714      0.120      0.596      0.551      -0.164       0.307
# Gender:DBP    -0.0644      0.200     -0.322      0.747      -0.456       0.328
# ==============================================================================
# Omnibus:                       59.660   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.345
# Skew:                           0.203   Prob(JB):                     1.44e-15
# Kurtosis:                       3.368   Cond. No.                         5.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.013749
# DBP           0.054493
# Gender        0.029224
# IS            0.008066
# Gender:DBP   -0.004361
# dtype: float64

# %%
sbp = ols('BA ~ SBP + Gender + IS + Gender:SBP', missing='drop', data = main_test).fit()
print(sbp.summary())

#calculate effect size
results = sbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     7.276
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           7.70e-06
# Time:                        18:39:16   Log-Likelihood:                -18502.
# No. Observations:                5452   AIC:                         3.701e+04
# Df Residuals:                    5447   BIC:                         3.705e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2917      0.234     -1.248      0.212      -0.750       0.166
# SBP            0.4413      0.139      3.165      0.002       0.168       0.715
# Gender         0.4721      0.199      2.368      0.018       0.081       0.863
# IS             0.0887      0.120      0.740      0.459      -0.146       0.324
# Gender:SBP     0.0184      0.211      0.087      0.931      -0.395       0.431
# ==============================================================================
# Omnibus:                       61.888   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.275
# Skew:                           0.207   Prob(JB):                     3.33e-16
# Kurtosis:                       3.378   Cond. No.                         5.73
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    -0.016903
# SBP           0.042867
# Gender        0.032069
# IS            0.010018
# Gender:SBP    0.001180
# dtype: float64

# %% [markdown]
# ## 6.2 Multiple Predictor & COmparison Models

# %% [markdown]
# ### 6.2.1 Covariates

# %%
cov_model = ols('BA ~ Gender + Age + IS ', missing='drop', data = main_test).fit()
print(cov_model.summary())

#calculate effect size
results = cov_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     4.370
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):            0.00444
# Time:                        18:39:16   Log-Likelihood:                -18510.
# No. Observations:                5452   AIC:                         3.703e+04
# Df Residuals:                    5448   BIC:                         3.706e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8782      0.815      1.078      0.281      -0.719       2.475
# Gender         0.6622      0.198      3.349      0.001       0.275       1.050
# Age           -0.0201      0.013     -1.587      0.113      -0.045       0.005
# IS             0.1128      0.121      0.932      0.351      -0.124       0.350
# ==============================================================================
# Omnibus:                       60.694   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.316
# Skew:                           0.207   Prob(JB):                     8.87e-16
# Kurtosis:                       3.366   Cond. No.                         539.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.014600
# Gender       0.045356
# Age         -0.021496
# IS           0.012621
# dtype: float64

# %% [markdown]
# ### 6.2.2 Accelerometer + Self-report PA

# %%
sr_pa_model = ols('BA ~ SRMPA + MPA + Gender + IS', missing='drop', data = main_test).fit()
print(sr_pa_model.summary())

#calculate effect size
results = sr_pa_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     6.929
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.47e-05
# Time:                        18:39:16   Log-Likelihood:                -18503.
# No. Observations:                5452   AIC:                         3.702e+04
# Df Residuals:                    5447   BIC:                         3.705e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3905      0.233     -1.676      0.094      -0.847       0.066
# SRMPA         -0.0030      0.099     -0.030      0.976      -0.198       0.192
# MPA           -0.4124      0.100     -4.106      0.000      -0.609      -0.215
# Gender         0.6012      0.196      3.064      0.002       0.217       0.986
# IS             0.1151      0.120      0.957      0.339      -0.121       0.351
# ==============================================================================
# Omnibus:                       58.174   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               66.246
# Skew:                           0.202   Prob(JB):                     4.12e-15
# Kurtosis:                       3.358   Cond. No.                         5.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.022700
# SRMPA       -0.000413
# MPA         -0.055605
# Gender       0.041493
# IS           0.012961
# dtype: float64

# %% [markdown]
# ### 6.2.3 PA + Fitness

# %%
pa_fitness = ols('BA ~ HG + MPA + IS + Gender', missing='drop', data = main_test).fit()
print(pa_fitness.summary())

#calculate effect size
results = pa_fitness
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     7.382
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           6.32e-06
# Time:                        18:39:17   Log-Likelihood:                -18502.
# No. Observations:                5452   AIC:                         3.701e+04
# Df Residuals:                    5447   BIC:                         3.705e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5233      0.253     -2.070      0.038      -1.019      -0.028
# HG            -0.1965      0.146     -1.343      0.179      -0.483       0.090
# MPA           -0.4109      0.100     -4.117      0.000      -0.607      -0.215
# IS             0.1147      0.120      0.955      0.339      -0.121       0.350
# Gender         0.8940      0.293      3.049      0.002       0.319       1.469
# ==============================================================================
# Omnibus:                       59.422   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.912
# Skew:                           0.204   Prob(JB):                     1.79e-15
# Kurtosis:                       3.365   Cond. No.                         7.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.028034
# HG          -0.018184
# MPA         -0.055760
# IS           0.012938
# Gender       0.041290
# dtype: float64

# %% [markdown]
# ### 6.2.4 Health

# %%
health = ols('BA ~ SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(health.summary())

#calculate effect size
results = health
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     9.503
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           2.06e-10
# Time:                        18:39:17   Log-Likelihood:                -18488.
# No. Observations:                5452   AIC:                         3.699e+04
# Df Residuals:                    5445   BIC:                         3.704e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2864      0.234     -1.226      0.220      -0.744       0.171
# SBP            0.1846      0.148      1.247      0.212      -0.106       0.475
# HR             0.2906      0.103      2.817      0.005       0.088       0.493
# DBP            0.2266      0.148      1.530      0.126      -0.064       0.517
# BMI            0.2934      0.103      2.841      0.005       0.091       0.496
# Gender         0.4716      0.202      2.331      0.020       0.075       0.868
# IS             0.0865      0.120      0.722      0.470      -0.148       0.321
# ==============================================================================
# Omnibus:                       62.818   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.028
# Skew:                           0.206   Prob(JB):                     1.39e-16
# Kurtosis:                       3.390   Cond. No.                         5.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.016610
# SBP          0.016889
# HR           0.038157
# DBP          0.020717
# BMI          0.038473
# Gender       0.031572
# IS           0.009782
# dtype: float64

# %% [markdown]
# ### 6.2.5 Health and Fitness

# %%
he_fi = ols('BA ~ HG + SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(he_fi.summary())

#calculate effect size
results = he_fi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     8.509
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           2.12e-10
# Time:                        18:39:17   Log-Likelihood:                -18487.
# No. Observations:                5452   AIC:                         3.699e+04
# Df Residuals:                    5444   BIC:                         3.704e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4405      0.253     -1.742      0.081      -0.936       0.055
# HG            -0.2328      0.146     -1.590      0.112      -0.520       0.054
# SBP            0.1889      0.148      1.276      0.202      -0.101       0.479
# HR             0.2831      0.103      2.742      0.006       0.081       0.486
# DBP            0.2347      0.148      1.584      0.113      -0.056       0.525
# BMI            0.2941      0.103      2.848      0.004       0.092       0.497
# Gender         0.8120      0.295      2.757      0.006       0.235       1.389
# IS             0.0860      0.120      0.718      0.473      -0.149       0.321
# ==============================================================================
# Omnibus:                       64.339   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.090
# Skew:                           0.208   Prob(JB):                     4.95e-17
# Kurtosis:                       3.398   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.023598
# HG          -0.021532
# SBP          0.017279
# HR           0.037133
# DBP          0.021451
# BMI          0.038570
# Gender       0.037335
# IS           0.009720
# dtype: float64

# %% [markdown]
# ### 6.2.6 PA & Health

# %%
pa_he = ols('BA ~ MPA + SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(pa_he.summary())

#calculate effect size
results = pa_he
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     9.424
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.14e-11
# Time:                        18:39:18   Log-Likelihood:                -18484.
# No. Observations:                5452   AIC:                         3.698e+04
# Df Residuals:                    5444   BIC:                         3.704e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.3090      0.233     -1.323      0.186      -0.767       0.149
# MPA           -0.3079      0.103     -2.978      0.003      -0.511      -0.105
# SBP            0.1903      0.148      1.287      0.198      -0.100       0.480
# HR             0.2721      0.103      2.635      0.008       0.070       0.475
# DBP            0.2332      0.148      1.575      0.115      -0.057       0.523
# BMI            0.2142      0.107      2.010      0.044       0.005       0.423
# Gender         0.4625      0.202      2.288      0.022       0.066       0.859
# IS             0.1034      0.120      0.863      0.388      -0.132       0.338
# ==============================================================================
# Omnibus:                       62.164   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.895
# Skew:                           0.206   Prob(JB):                     2.44e-16
# Kurtosis:                       3.383   Cond. No.                         5.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.017921
# MPA         -0.040333
# SBP          0.017427
# HR           0.035689
# DBP          0.021336
# BMI          0.027221
# Gender       0.030981
# IS           0.011687
# dtype: float64

# %% [markdown]
# ### 6.2.7 PA & Health & Fitness

# %%
pa_he_fi = ols('BA ~ MPA + HG + SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(pa_he_fi.summary())

#calculate effect size
results = pa_he_fi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     8.549
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           1.23e-11
# Time:                        18:39:18   Log-Likelihood:                -18483.
# No. Observations:                5452   AIC:                         3.698e+04
# Df Residuals:                    5443   BIC:                         3.704e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4590      0.253     -1.816      0.069      -0.954       0.036
# MPA           -0.3057      0.103     -2.957      0.003      -0.508      -0.103
# HG            -0.2269      0.146     -1.550      0.121      -0.514       0.060
# SBP            0.1945      0.148      1.315      0.189      -0.096       0.484
# HR             0.2649      0.103      2.563      0.010       0.062       0.468
# DBP            0.2411      0.148      1.628      0.104      -0.049       0.531
# BMI            0.2155      0.107      2.022      0.043       0.007       0.424
# Gender         0.7943      0.294      2.698      0.007       0.217       1.371
# IS             0.1028      0.120      0.858      0.391      -0.132       0.338
# ==============================================================================
# Omnibus:                       63.657   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.913
# Skew:                           0.208   Prob(JB):                     8.91e-17
# Kurtosis:                       3.391   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.024598
# MPA         -0.040048
# HG          -0.020998
# SBP          0.017803
# HR           0.034711
# DBP          0.022047
# BMI          0.027382
# Gender       0.036541
# IS           0.011614
# dtype: float64

# %% [markdown]
# ### 6.2.8 SR PA + Health + Fitness

# %%
sr_pa_he_fi = ols('BA ~ SRMPA + HG + SBP + HR + DBP + BMI + Gender + IS', missing='drop', data = main_test).fit()
print(sr_pa_he_fi.summary())

#calculate effect size
results = sr_pa_he_fi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     7.444
# Date:                Mon, 13 Feb 2023   Prob (F-statistic):           6.52e-10
# Time:                        18:39:18   Log-Likelihood:                -18487.
# No. Observations:                5452   AIC:                         3.699e+04
# Df Residuals:                    5443   BIC:                         3.705e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4406      0.253     -1.741      0.082      -0.937       0.056
# SRMPA          0.0007      0.099      0.007      0.994      -0.193       0.194
# HG            -0.2328      0.147     -1.589      0.112      -0.520       0.054
# SBP            0.1888      0.148      1.275      0.202      -0.101       0.479
# HR             0.2831      0.103      2.739      0.006       0.081       0.486
# DBP            0.2348      0.148      1.583      0.113      -0.056       0.525
# BMI            0.2941      0.103      2.846      0.004       0.092       0.497
# Gender         0.8120      0.295      2.755      0.006       0.234       1.390
# IS             0.0860      0.120      0.717      0.473      -0.149       0.321
# ==============================================================================
# Omnibus:                       64.346   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.100
# Skew:                           0.208   Prob(JB):                     4.92e-17
# Kurtosis:                       3.398   Cond. No.                         7.56
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept   -0.023578
# SRMPA        0.000097
# HG          -0.021525
# SBP          0.017270
# HR           0.037097
# DBP          0.021442
# BMI          0.038547
# Gender       0.037312
# IS           0.009717
# dtype: float64

# %% [markdown]
# # 7 Model comparisons

# %% [markdown]
# ## 7.1 Cov x PA

# %%
model_comparison = anova_lm(cov_model, mpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff          F    Pr(>F)
# 0    5448.0  283832.107726      0.0         NaN        NaN       NaN
# 1    5447.0  283074.690639      1.0  757.417087  14.574425  0.000136

# %%
model_comparison = anova_lm(cov_model, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F  Pr(>F)
# 0    5448.0  283832.107726      0.0        NaN       NaN     NaN
# 1    5447.0  283897.018524      1.0 -64.910798 -1.245413     1.0

# %% [markdown]
# ## 7.2 Cov x PA x SR

# %%
model_comparison = anova_lm(mpa, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff    F  Pr(>F)
# 0    5447.0  283074.690639      0.0         NaN  NaN     NaN
# 1    5447.0  283897.018524     -0.0 -822.327885  inf     NaN

# %% [markdown]
# ## 7.3 Health x Fitness x PA

# %%
model_comparison = anova_lm(mpa, pa_fitness)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff    F  Pr(>F)
# 0    5447.0  283074.690639      0.0        NaN  NaN     NaN
# 1    5447.0  282981.079124     -0.0  93.611515 -inf     NaN

# %%
model_comparison = anova_lm(mpa, pa_he)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff          F        Pr(>F)
# 0    5447.0  283074.690639      0.0         NaN        NaN           NaN
# 1    5444.0  281108.735889      3.0  1965.95475  12.691006  2.904720e-08

# %%
model_comparison = anova_lm(mpa, pa_he_fi)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff      ss_diff          F        Pr(>F)
# 0    5447.0  283074.690639      0.0          NaN        NaN           NaN
# 1    5443.0  280984.634981      4.0  2090.055658  10.121704  3.673616e-08

# %% [markdown]
# ## 7.4 CR vs. Individual

# %%
model_comparison = anova_lm(cr, pa_he_fi)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5447.0  280999.632389      0.0        NaN       NaN       NaN
# 1    5443.0  280984.634981      4.0  14.997408  0.072629  0.990415

# %%
model_comparison = anova_lm(srcr, sr_pa_he_fi)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5447.0  281705.196498      0.0         NaN       NaN       NaN
# 1    5443.0  281436.033552      4.0  269.162946  1.301409  0.266989

# %% [markdown]
# ## 7.5 Genders

# %%
model_comparison = anova_lm(crf, crm)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff       ss_diff         F    Pr(>F)
# 0    2967.0  151830.802309      0.0           NaN       NaN       NaN
# 1    2479.0  128788.611894    488.0  23042.190415  0.908873  0.908857

# %% [markdown]
# # 8 Mediation analysis

# %% [markdown]
# ## 8.1 PA x Health / Fitness

# %% [markdown]
# ### 8.1.1 BMI

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + LPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.084815       -0.128753       -0.042490    0.000
# ACME (treated)           -0.084815       -0.128753       -0.042490    0.000
# ADE (control)            -0.055684       -0.267289        0.127160    0.580
# ADE (treated)            -0.055684       -0.267289        0.127160    0.580
# Total effect             -0.140499       -0.349301        0.045831    0.156
# Prop. mediated (control)  0.538971       -4.938838        5.968368    0.156
# Prop. mediated (treated)  0.538971       -4.938838        5.968368    0.156
# ACME (average)           -0.084815       -0.128753       -0.042490    0.000
# ADE (average)            -0.055684       -0.267289        0.127160    0.580
# Prop. mediated (average)  0.538971       -4.938838        5.968368    0.156

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + MPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.105603       -0.160271       -0.050136    0.000
# ACME (treated)           -0.105603       -0.160271       -0.050136    0.000
# ADE (control)            -0.314531       -0.516227       -0.109701    0.006
# ADE (treated)            -0.314531       -0.516227       -0.109701    0.006
# Total effect             -0.420133       -0.614560       -0.223546    0.000
# Prop. mediated (control)  0.250694        0.105669        0.536504    0.000
# Prop. mediated (treated)  0.250694        0.105669        0.536504    0.000
# ACME (average)           -0.105603       -0.160271       -0.050136    0.000
# ADE (average)            -0.314531       -0.516227       -0.109701    0.006
# Prop. mediated (average)  0.250694        0.105669        0.536504    0.000

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + VPA", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.089918       -0.135465       -0.046666    0.000
# ACME (treated)           -0.089918       -0.135465       -0.046666    0.000
# ADE (control)            -0.026922       -0.237526        0.175447    0.814
# ADE (treated)            -0.026922       -0.237526        0.175447    0.814
# Total effect             -0.116840       -0.326852        0.081286    0.272
# Prop. mediated (control)  0.593074       -7.023061        7.722492    0.272
# Prop. mediated (treated)  0.593074       -7.023061        7.722492    0.272
# ACME (average)           -0.089918       -0.135465       -0.046666    0.000
# ADE (average)            -0.026922       -0.237526        0.175447    0.814
# Prop. mediated (average)  0.593074       -7.023061        7.722492    0.272

# %% [markdown]
# ### 8.1.2 DBP

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + LPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.059665       -0.095134       -0.031170    0.000
# ACME (treated)           -0.059665       -0.095134       -0.031170    0.000
# ADE (control)            -0.075253       -0.264887        0.127960    0.452
# ADE (treated)            -0.075253       -0.264887        0.127960    0.452
# Total effect             -0.134918       -0.335888        0.068619    0.176
# Prop. mediated (control)  0.374564       -2.286323        3.612710    0.176
# Prop. mediated (treated)  0.374564       -2.286323        3.612710    0.176
# ACME (average)           -0.059665       -0.095134       -0.031170    0.000
# ADE (average)            -0.075253       -0.264887        0.127960    0.452
# Prop. mediated (average)  0.374564       -2.286323        3.612710    0.176

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + MPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.032466       -0.063968       -0.007596    0.008
# ACME (treated)           -0.032466       -0.063968       -0.007596    0.008
# ADE (control)            -0.384086       -0.593853       -0.192833    0.000
# ADE (treated)            -0.384086       -0.593853       -0.192833    0.000
# Total effect             -0.416553       -0.623021       -0.225343    0.000
# Prop. mediated (control)  0.077072        0.017942        0.176208    0.008
# Prop. mediated (treated)  0.077072        0.017942        0.176208    0.008
# ACME (average)           -0.032466       -0.063968       -0.007596    0.008
# ADE (average)            -0.384086       -0.593853       -0.192833    0.000
# Prop. mediated (average)  0.077072        0.017942        0.176208    0.008

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + VPA", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.032243       -0.062777       -0.004784    0.024
# ACME (treated)           -0.032243       -0.062777       -0.004784    0.024
# ADE (control)            -0.077207       -0.271301        0.113166    0.446
# ADE (treated)            -0.077207       -0.271301        0.113166    0.446
# Total effect             -0.109451       -0.303959        0.073168    0.290
# Prop. mediated (control)  0.215397       -2.671096        2.943208    0.294
# Prop. mediated (treated)  0.215397       -2.671096        2.943208    0.294
# ACME (average)           -0.032243       -0.062777       -0.004784    0.024
# ADE (average)            -0.077207       -0.271301        0.113166    0.446
# Prop. mediated (average)  0.215397       -2.671096        2.943208    0.294

# %% [markdown]
# ### 8.1.3 Heart rate

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + LPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.016957       -0.040528        0.002802    0.082
# ACME (treated)           -0.016957       -0.040528        0.002802    0.082
# ADE (control)            -0.120289       -0.312010        0.065016    0.220
# ADE (treated)            -0.120289       -0.312010        0.065016    0.220
# Total effect             -0.137246       -0.330195        0.048921    0.140
# Prop. mediated (control)  0.103772       -0.595629        1.484942    0.206
# Prop. mediated (treated)  0.103772       -0.595629        1.484942    0.206
# ACME (average)           -0.016957       -0.040528        0.002802    0.082
# ADE (average)            -0.120289       -0.312010        0.065016    0.220
# Prop. mediated (average)  0.103772       -0.595629        1.484942    0.206

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + MPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.038427       -0.066446       -0.014876      0.0
# ACME (treated)           -0.038427       -0.066446       -0.014876      0.0
# ADE (control)            -0.382674       -0.572877       -0.189011      0.0
# ADE (treated)            -0.382674       -0.572877       -0.189011      0.0
# Total effect             -0.421101       -0.607677       -0.227419      0.0
# Prop. mediated (control)  0.089166        0.033058        0.202803      0.0
# Prop. mediated (treated)  0.089166        0.033058        0.202803      0.0
# ACME (average)           -0.038427       -0.066446       -0.014876      0.0
# ADE (average)            -0.382674       -0.572877       -0.189011      0.0
# Prop. mediated (average)  0.089166        0.033058        0.202803      0.0

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + VPA", main_test)
mediator_model = sm.OLS.from_formula("HR ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.071743       -0.113549       -0.032236    0.000
# ACME (treated)           -0.071743       -0.113549       -0.032236    0.000
# ADE (control)            -0.046009       -0.251667        0.156305    0.694
# ADE (treated)            -0.046009       -0.251667        0.156305    0.694
# Total effect             -0.117752       -0.320381        0.079135    0.252
# Prop. mediated (control)  0.477123       -5.138030        5.107650    0.252
# Prop. mediated (treated)  0.477123       -5.138030        5.107650    0.252
# ACME (average)           -0.071743       -0.113549       -0.032236    0.000
# ADE (average)            -0.046009       -0.251667        0.156305    0.694
# Prop. mediated (average)  0.477123       -5.138030        5.107650    0.252

# %% [markdown]
# ### 8.1.4 Hand grip

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + LPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ LPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.020594       -0.058888        0.013202    0.250
# ACME (treated)           -0.020594       -0.058888        0.013202    0.250
# ADE (control)            -0.114130       -0.297485        0.068103    0.258
# ADE (treated)            -0.114130       -0.297485        0.068103    0.258
# Total effect             -0.134724       -0.312681        0.045607    0.178
# Prop. mediated (control)  0.119516       -1.291732        1.725737    0.368
# Prop. mediated (treated)  0.119516       -1.291732        1.725737    0.368
# ACME (average)           -0.020594       -0.058888        0.013202    0.250
# ADE (average)            -0.114130       -0.297485        0.068103    0.258
# Prop. mediated (average)  0.119516       -1.291732        1.725737    0.368

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + MPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ MPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.001761       -0.011955        0.005401    0.668
# ACME (treated)           -0.001761       -0.011955        0.005401    0.668
# ADE (control)            -0.414750       -0.620090       -0.213900    0.000
# ADE (treated)            -0.414750       -0.620090       -0.213900    0.000
# Total effect             -0.416511       -0.621121       -0.216222    0.000
# Prop. mediated (control)  0.002456       -0.015142        0.030871    0.668
# Prop. mediated (treated)  0.002456       -0.015142        0.030871    0.668
# ACME (average)           -0.001761       -0.011955        0.005401    0.668
# ADE (average)            -0.414750       -0.620090       -0.213900    0.000
# Prop. mediated (average)  0.002456       -0.015142        0.030871    0.668

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + VPA", main_test)
mediator_model = sm.OLS.from_formula("HG ~ VPA", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.016237       -0.003993        0.040463    0.126
# ACME (treated)            0.016237       -0.003993        0.040463    0.126
# ADE (control)            -0.131849       -0.335689        0.057790    0.178
# ADE (treated)            -0.131849       -0.335689        0.057790    0.178
# Total effect             -0.115612       -0.306725        0.070030    0.252
# Prop. mediated (control) -0.099986       -1.633354        1.427816    0.350
# Prop. mediated (treated) -0.099986       -1.633354        1.427816    0.350
# ACME (average)            0.016237       -0.003993        0.040463    0.126
# ADE (average)            -0.131849       -0.335689        0.057790    0.178
# Prop. mediated (average) -0.099986       -1.633354        1.427816    0.350

# %% [markdown]
# # 9 LASSO Regression

# %% [markdown]
# ## 9.1 Accelerometer PA

# %%
df = main_test[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# ### 9.1.1 Females only

# %%
female = main_test[main_test["Gender"]==0]
df = female[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# ### 9.1.2 Males only

# %%
male = main_test[main_test["Gender"]==1]
df = female[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# ## 9.2 Self-report PA

# %%
df = main_test[["Age", "Gender", "IS", "LPA", "MPA", "VPA",  "SRLPA", "SRMPA", "SRVPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Alpha', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# %% [markdown]
# # 10 Figures

# %% [markdown]
# ## 10.1 Scatterplot BrainAGE x Combined risk score

# %%
plt.figure()
plt.scatter("CR", "BA", data = female, label = "Female", alpha=0.5, s=10, color = "darkcyan")
plt.scatter("CR", "BA", data = male, label = "Male", alpha=0.5, s=10, color = "mediumvioletred")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Combined risk score", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(loc="best")
plt.axline((0,-0.55), slope=0.17, color="teal")
plt.axline((0,0.25), slope=0.37, color="purple")
plt.show()

# %% [markdown]
# ## 10.2 Smaller Correlation Heatmap

# %%
x = main_test
del x["IS"]
del x["LPA"]
del x["VPA"]
del x["SRLPA"]
del x["SRVPA"]

corr = x.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(12,9)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'Gender'),
#   Text(0, 2.5, 'MPA'),
#   Text(0, 3.5, 'SRMPA'),
#   Text(0, 4.5, 'HG'),
#   Text(0, 5.5, 'HR'),
#   Text(0, 6.5, 'BMI'),
#   Text(0, 7.5, 'DBP'),
#   Text(0, 8.5, 'SBP'),
#   Text(0, 9.5, 'CR'),
#   Text(0, 10.5, 'SRCR'),
#   Text(0, 11.5, 'BA')])

# %% [markdown]
# ### 10.2.1 Females only

# %%
female = x[x["Gender"] == 0]
del female["Gender"]
corr = female.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(12,9)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'MPA'),
#   Text(0, 2.5, 'SRMPA'),
#   Text(0, 3.5, 'HG'),
#   Text(0, 4.5, 'HR'),
#   Text(0, 5.5, 'BMI'),
#   Text(0, 6.5, 'DBP'),
#   Text(0, 7.5, 'SBP'),
#   Text(0, 8.5, 'CR'),
#   Text(0, 9.5, 'SRCR'),
#   Text(0, 10.5, 'BA')])

# %% [markdown]
# ### 10.2.2 Males only

# %%
male = x[x["Gender"] == 1]
del male["Gender"]
corr = male.corr()
corr = round(corr,3)
fig, ax = plt.subplots(figsize=(12,9)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5]),
#  [Text(0, 0.5, 'Age'),
#   Text(0, 1.5, 'MPA'),
#   Text(0, 2.5, 'SRMPA'),
#   Text(0, 3.5, 'HG'),
#   Text(0, 4.5, 'HR'),
#   Text(0, 5.5, 'BMI'),
#   Text(0, 6.5, 'DBP'),
#   Text(0, 7.5, 'SBP'),
#   Text(0, 8.5, 'CR'),
#   Text(0, 9.5, 'SRCR'),
#   Text(0, 10.5, 'BA')])

# %% [markdown]
# # 11 Pickle for comparison to exploration set

# %%
main_test.to_pickle("3_validate.pkl")
