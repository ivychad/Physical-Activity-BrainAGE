# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from random import seed
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, Lasso
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm
from statsmodels.formula.api import ols
from statsmodels.regression import linear_model
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from statsmodels.stats.mediation import Mediation
from sklearn.svm import SVR
from pingouin import ancova
import matplotlib.cm as cm
from scipy.stats import pearsonr
# %matplotlib inline

seed(888)
pd.set_option('display.max_columns', None)
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %% [markdown]
# # 1 Load validation set

# %%
# load data from pickle and convert to dataframe
brain_test = pd.read_pickle("brain_test_validate.pkl")
main_test = pd.read_pickle("main_test_validate.pkl")
brain_train = pd.read_pickle("1_brain_train.pkl")
brain_test = pd.DataFrame(brain_test)
main_test = pd.DataFrame(main_test)
brain_train = pd.DataFrame(brain_train)

# %% [markdown]
# # 2 BrainAGE prediction Destrieux

# %%
# select variables belonging to A2009s segmentation
X_train = brain_train.iloc[:,1657:2544:2]
Y_train = brain_train.iloc[:,-1]
X_test = brain_test.iloc[:,1657:2544:2]
Y_test = brain_test.iloc[:,-1]

# standardize x-data
X_train = stats.zscore(X_train)
X_test = stats.zscore(X_test)

# set of alphas to try (=penalization)
alpha_parameters = np.power(10,np.linspace(start=-3, stop=5, num=100))

# %% [markdown]
# ## 2.1 Cross-validation

# %%
X_CV = X_train
Y_CV = Y_train

# randomly split data (only training no PA) into training and testing set
X_train_cv, X_test_cv, Y_train_cv, Y_test_cv = train_test_split(X_CV,Y_CV)

#define the model
model_ridge = RidgeCV(alphas = alpha_parameters)

#perform 10-fold cross validation
scores_ridge = cross_val_score(model_ridge, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')

#calculate the mean-absolute error
mae_ridge = -1 * scores_ridge.mean()

print("The MAE for cross-validation (Ridge):", mae_ridge)

# for correction
model_ridge.fit(X_train_cv,Y_train_cv)
y_pred_cv = model_ridge.predict(X_test_cv)
# Out:
# The MAE for cross-validation (Ridge): 4.192981026915527

# %% [markdown]
# ## 2.2 Prediction

# %%
# initialize models
model_Ridge = RidgeCV(alphas = alpha_parameters)

# train model 
model_Ridge.fit(X_train,Y_train)

# get predicted values for test set
y_pred_Ridge = model_Ridge.predict(X_test)

# calculate brain age gap
brain_age_delta_Ridge = y_pred_Ridge-Y_test

# get mean absolute error (MAE)
print("The MAE for testing set using Ridge:", mean_absolute_error(Y_test,y_pred_Ridge))

# top x coefficients and their names
coeff = np.asarray(model_Ridge.coef_)
coeffabs = np.asarray(abs(model_Ridge.coef_))
top_coefficients = np.argsort(coeffabs)[-20:]
print(X_train.iloc[:,top_coefficients].columns)
print(coeff[top_coefficients])

# plot figure with x: actual age Y: predicted age, and a line with slope 1 for reference
plt.figure()
plt.scatter(Y_test, y_pred_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((60,60), slope=1, color='r')
plt.xticks(range(40,90,5))
plt.yticks(range(40,90,5))
plt.ylabel('Predicted Age', fontsize = 16)
plt.xlabel('Age', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()

plt.figure()
plt.scatter(Y_test,brain_age_delta_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((65,0), slope=-0.69, color="blue")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# The MAE for testing set using Ridge: 4.262589702409484
# Index(['volume_of_gtemporalinf_left_hemisphere_f27513_2_0',
#        'volume_of_scentral_right_hemisphere_f27743_2_0',
#        'volume_of_gpostcentral_right_hemisphere_f27726_2_0',
#        'area_of_gtemporalinf_left_hemisphere_f27365_2_0',
#        'mean_thickness_of_gfrontsup_left_hemisphere_f27418_2_0',
#        'area_of_latfispost_right_hemisphere_f27591_2_0',
#        'volume_of_stemporalsup_left_hemisphere_f27549_2_0',
#        'area_of_stemporalsup_left_hemisphere_f27401_2_0',
#        'area_of_sparietooccipital_right_hemisphere_f27615_2_0',
#        'area_of_gscingulant_right_hemisphere_f27556_2_0',
#        'area_of_scalcarine_left_hemisphere_f27372_2_0',
#        'volume_of_scalcarine_left_hemisphere_f27520_2_0',
#        'volume_of_gfrontsup_left_hemisphere_f27492_2_0',
#        'volume_of_gscingulant_right_hemisphere_f27704_2_0',
#        'area_of_gfrontsup_left_hemisphere_f27344_2_0',
#        'volume_of_sparietooccipital_right_hemisphere_f27763_2_0',
#        'volume_of_scentral_left_hemisphere_f27521_2_0',
#        'volume_of_latfispost_right_hemisphere_f27739_2_0',
#        'area_of_scalcarine_right_hemisphere_f27594_2_0',
#        'volume_of_scalcarine_right_hemisphere_f27742_2_0'],
#       dtype='object')
# [ 1.33500311  1.35589929 -1.40956036 -1.41335742 -1.4290742  -1.49188128
#  -1.49429486  1.5138274  -1.53084042  1.55013063 -1.58490537  1.58906398
#   1.60619697 -1.67635603 -1.749753    1.75977046  1.86033162  2.16152389
#  -2.37541509  2.37603676]

# %% [markdown]
# ## 2.3 Correction

# %%
# reformat cross validation data for regression model
y_pred_cv = np.asarray(y_pred_cv)
y_pred_cv = np.reshape(y_pred_cv, (-1,1))
Y_test_cv = np.asarray(Y_test_cv)
Y_test_cv = np.reshape(Y_test_cv, (-1,1))

# now using correction from the R code that's online from Cole
reg = LinearRegression().fit(Y_test_cv, y_pred_cv)
coef = float(reg.coef_)
intercept = float(reg.intercept_)
print("Coefficient and Intercept:", coef, intercept)

# correction by cole
function = lambda t: (t-intercept)/coef
vfunc = np.vectorize(function)
corr_brainage_1 = vfunc(y_pred_Ridge)
corr_brainage_delta_1 = corr_brainage_1-Y_test

# plots corrected
plt.figure()
plt.scatter(Y_test, corr_brainage_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((65,65), slope=coef, color="blue")
plt.ylabel("Predicted Age Corrected", fontsize = 16)
plt.axline((60,60), slope=1, color='r')
plt.xlabel("Age", fontsize = 16)
plt.xticks(range(40,90,5))
plt.yticks(range(30,115,10))
plt.show()

plt.figure()
plt.scatter(Y_test, corr_brainage_delta_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE Corrected", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# Coefficient and Intercept: 0.5419205750944074 29.47846775422658

# %% [markdown]
# ## 2.4 Add BrainAge Delta to Dataframe

# %%
main_test["BA"] = corr_brainage_delta_1

# %% [markdown]
# # 3 Preprocessing

# %% [markdown]
# ## 3.1 Recoding

# %%
# recoding imaging site and gender
# 1 = Cheadle;  2 = Reading;  3 = Newcastle;  4 = Bristol
main_test['IS'] = main_test['IS'].map({'11025': 0, '11026': 1,'11027': 2, '11028': 3})
main_test["Gender"] = main_test["Gender"].map({"Female":0, "Male":1})
main_test["Gender"] = main_test["Gender"].astype("int")

# delete unnecessary variables
del main_test["ID"]
del main_test["MVPA"]
del main_test["TPA"]

# %% [markdown]
# ## 3.2 Remove outliers on SRPA

# %%
# remove outliers on self-reported physical activity data for each intensity seperately
before = main_test.shape[0]
outlier = np.mean(main_test["SRLPA"]) + np.std(main_test["SRLPA"])*3
main_test = main_test[main_test["SRLPA"]<outlier]
outlier = np.mean(main_test["SRMPA"]) + np.std(main_test["SRMPA"])*3
main_test = main_test[main_test["SRMPA"]<outlier]
outlier = np.mean(main_test["SRVPA"]) + np.std(main_test["SRVPA"])*3
main_test = main_test[main_test["SRVPA"]<outlier]
after = main_test.shape[0]
print("Outliers on self-reported PA:", before-after)
print(after)
# Out:
# Outliers on self-reported PA: 532
# 5452

# %% [markdown]
# ## 3.3 Convert SRPA from MET min/week to min/week

# %%
main_test["SRLPA"] = main_test["SRLPA"]/3.3
main_test["SRMPA"] = main_test["SRMPA"]/4
main_test["SRVPA"] = main_test["SRVPA"]/8

# %% [markdown]
# ## 3.4 Remove people with Gender other than Male or Female

# %%
before = main_test.shape[0]
main_test = main_test[(main_test["Gender"] == 0) | (main_test["Gender"] == 1)]
after = main_test.shape[0]
print("Gender not Male or Female:", before-after)
print(after)
# Out:
# Gender not Male or Female: 0
# 5452

# %% [markdown]
# # 4 Basic distributions of validation set

# %% [markdown]
# ## 4.1 Data and Descriptives

# %%
main_test.head()
# Out:
#         Age  Gender  IS      VPA       MPA        LPA  SRLPA  SRMPA  SRVPA  \
# 4723   73.0       0   0  59.2704  661.8528  2400.4512  315.0   90.0    0.0
# 25494  55.0       1   0  70.0560  970.7760  1991.5920  120.0   30.0    0.0
# 34463  65.0       0   1  48.6720  506.1888  2813.2416  420.0  840.0  160.0
# 26337  67.0       0   2   0.0000   60.4800  1653.1200   40.0   60.0    0.0
# 29224  70.0       0   1   9.2736  361.6704  1873.2672   30.0    0.0   45.0
#
#          HG    HR      BMI   DBP    SBP         BA
# 4723   20.0  52.0  25.1338  74.0  137.0   3.612610
# 25494  26.0  55.0  22.9630  80.0  148.0   2.538583
# 34463  22.0  45.0  23.8325  63.0  108.0  -6.813275
# 26337  38.0  68.0  33.6473  84.0  139.0  15.641657
# 29224  24.0  69.0  32.8906  87.0  132.0   2.975753

# %%
# get mean and std for all variables for males and females seperately for the test set
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("Number of females:", female.shape[0])
print("NUmber of males:", male.shape[0])

print("Age")
mean = main_test["Age"].mean()
print("Mean", mean)
std = main_test["Age"].std()
print("Std",std)

print("LPA")
mean = main_test["LPA"].mean()
print("Mean", mean)
std = main_test["LPA"].std()
print("Std",std)

print("MPA")
mean = main_test["MPA"].mean()
print("Mean", mean)
std = main_test["MPA"].std()
print("Std",std)

print("VPA")
mean = main_test["VPA"].mean()
print("Mean", mean)
std = main_test["VPA"].std()
print("Std",std)

print("SRLPA")
mean = main_test["SRLPA"].mean()
print("Mean", mean)
std = main_test["SRLPA"].std()
print("Std",std)

print("SRMPA")
mean = main_test["SRMPA"].mean()
print("Mean", mean)
std = main_test["SRMPA"].std()
print("Std",std)

print("SRVPA")
mean = main_test["SRVPA"].mean()
print("Mean", mean)
std = main_test["SRVPA"].std()
print("Std",std)

print("DBP")
mean = main_test["DBP"].mean()
print("Mean", mean)
std = main_test["DBP"].std()
print("Std",std)

print("SBP")
mean = main_test["SBP"].mean()
print("Mean", mean)
std = main_test["SBP"].std()
print("Std",std)

print("BMI")
mean = main_test["BMI"].mean()
print("Mean", mean)
std = main_test["BMI"].std()
print("Std",std)

print("HG")
mean = main_test["HG"].mean()
print("Mean", mean)
std = main_test["HG"].std()
print("Std",std)

print("HR")
mean = main_test["HR"].mean()
print("Mean", mean)
std = main_test["HR"].std()
print("Std",std)

print("IS")
print(main_test["IS"].value_counts())
# Out:
# Number of females: 2970
# NUmber of males: 2482
# Age
# Mean 64.1907556859868
# Std 7.814225465582799
# LPA
# Mean 1981.0712548789434
# Std 417.08409539087546
# MPA
# Mean 482.57679882611893
# Std 216.85915554816543
# VPA
# Mean 34.27631577402791
# Std 43.2553234105916
# SRLPA
# Mean 235.25458547322083
# Std 219.09399284018272
# SRMPA
# Mean 159.23734409391048
# Std 192.24815076490748
# SRVPA
# Mean 66.45377842993398
# Std 83.83425453246974
# DBP
# Mean 81.11812179016874
# Std 10.361578350786544
# SBP
# Mean 136.32758620689654
# Std 18.24128891718472
# BMI
# Mean 26.36214115920763
# Std 4.213687095706291
# HG
# Mean 33.49486426999266
# Std 10.80830496808681
# HR
# Mean 67.96460014673514
# Std 11.043817664608612
# IS
# 0    3423
# 2    1109
# 1     909
# 3      11
# Name: IS, dtype: int64

# %% [markdown]
# ## 4.2 Age and BrainAge

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'Gender', fill=True, palette = "crest")
plt.title("Age x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'Gender', fill=True, palette = "crest")
plt.title("BrainAge x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'IS', fill=True, palette = "crest")
plt.title("BrainAge x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'IS', fill=True, palette = "crest")
plt.title("Age x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'MPA', hue = 'IS', fill=True, palette = "crest")
plt.title("Moderate PA x Imaging site")
plt.show()


plt.figure()
sns.kdeplot(data = main_test, x= 'BA', fill=True, label="A2009")
plt.title("BrainAge Segmentations")
plt.legend()
plt.show()

# %% [markdown]
# ## 4.3 Physical activity

# %%
# plot physical activity intensity categories for self-report and accelerometer together and seperately

plt.figure()
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,5000,1000),fontsize = 14)
plt.ylim(0,0.01)
plt.ylabel("Density",fontsize = 16)
plt.yticks(fontsize = 14)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA")
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA")
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2000,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA", color="#6baed6")
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA", color="#08519c")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,4500,1000),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA", color="#fd8d3c")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA", color="#a63603")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2500,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA", color="#74c476")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA", color="#006d2c")
plt.ylim(0,0.01)
plt.xticks(range(0,1500,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.legend()
plt.show()

plt.figure()
plt.scatter("MPA", "SRMPA", data = main_test, label = "Moderate PA", alpha=0.3, s=10, color = "darkcyan")
plt.scatter("VPA", "SRVPA", data = main_test, label = "Vigorous PA", alpha=0.3, s=10, color = "mediumvioletred")
plt.ylabel("Self-reported (min/week)", fontsize = 16)
plt.xlabel("Accelerometer (min/week)", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## 4.4 Health and Fitness

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'HG', hue = 'Gender', fill=True, palette = "crest")
plt.title("Hand grip")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'HR', hue = 'Gender', fill=True, palette = "crest")
plt.title("Heart rate")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Systolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'DBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Distolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BMI', hue = 'Gender', fill=True, palette = "crest")
plt.title("BMI")
plt.show()

# %% [markdown]
# # 5 Reorder Dataframe

# %%
# reorder dataframe
main_test = main_test[['Age', 'Gender', 'IS' , 'LPA', 'MPA', 'VPA', 'SRLPA', 'SRMPA', 'SRVPA', 'HG', 'HR', 'BMI', 'DBP', 'SBP', 'BA']]

# %% [markdown]
# # 6 Correlation Heatmap

# %%
def calculate_pvalues(df):
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            tmp = df[df[r].notnull() & df[c].notnull()]
            pvalues[r][c] = round(pearsonr(tmp[r], tmp[c])[1], 4)
    return pvalues

# %%
corr_test = main_test
corr_test = corr_test[:]
del corr_test["BA"]
del corr_test["SBP"]
del corr_test["IS"]
corr = corr_test.corr()
corr = round(corr,3)

fig, ax = plt.subplots(figsize=(13,10)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)


p_values = np.asarray(calculate_pvalues(corr_test))

threshold = 0.0007575  # Define your significance threshold

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if i != j:
            correlation = corr.iloc[i, j]
            p_value = p_values[i,j]  # Calculate or provide the p-value for the correlation

            if p_value < threshold:
                ax.text(j + 0.9, i + 0.2, "*", ha='right', va='top', color='black', fontsize=12)

# %% [markdown]
# # 7 Models with OLS

# %% [markdown]
# ## 7.1 PA BrainAGE Regression

# %% [markdown]
# ### 7.1.1 Baseline Covariates

# %%
cov_model = ols('BA ~ Gender + Age + IS', missing='drop', data = main_test).fit()
print(cov_model.summary())

#calculate effect size
results = cov_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     5.646
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           0.000736
# Time:                        09:43:10   Log-Likelihood:                -18433.
# No. Observations:                5452   AIC:                         3.687e+04
# Df Residuals:                    5448   BIC:                         3.690e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9036      0.798      2.385      0.017       0.339       3.468
# Gender         0.6529      0.195      3.349      0.001       0.271       1.035
# Age           -0.0339      0.013     -2.711      0.007      -0.058      -0.009
# IS             0.1112      0.119      0.932      0.351      -0.123       0.345
# ==============================================================================
# Omnibus:                       60.694   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.316
# Skew:                           0.207   Prob(JB):                     8.87e-16
# Kurtosis:                       3.366   Cond. No.                         536.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.032305
# Gender       0.045356
# Age         -0.036722
# IS           0.012621
# dtype: float64

# %% [markdown]
# ### 7.1.2 Accelerometer PA

# %%
lpa = ols('BA ~ LPA + Age + Gender + IS + Gender:LPA', missing='drop', data = main_test).fit()
print(lpa.summary())

#calculate effect size
results = lpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.498
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):            0.00369
# Time:                        09:43:11   Log-Likelihood:                -18433.
# No. Observations:                5452   AIC:                         3.688e+04
# Df Residuals:                    5446   BIC:                         3.692e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.1220      1.018      2.084      0.037       0.125       4.119
# LPA           -0.0001      0.000     -0.350      0.727      -0.001       0.001
# Age           -0.0337      0.013     -2.690      0.007      -0.058      -0.009
# Gender         0.8551      0.954      0.896      0.370      -1.016       2.726
# IS             0.1084      0.119      0.908      0.364      -0.126       0.342
# Gender:LPA    -0.0001      0.000     -0.249      0.804      -0.001       0.001
# ==============================================================================
# Omnibus:                       60.568   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.090
# Skew:                           0.207   Prob(JB):                     9.94e-16
# Kurtosis:                       3.364   Cond. No.                     2.74e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.028218
# LPA          -0.004735
# Age          -0.036430
# Gender        0.012133
# IS            0.012300
# Gender:LPA   -0.003367
# dtype: float64

# %%
mpa = ols('BA ~ MPA + Gender + Age + IS + Gender:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     6.926
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           1.87e-06
# Time:                        09:43:11   Log-Likelihood:                -18424.
# No. Observations:                5452   AIC:                         3.686e+04
# Df Residuals:                    5446   BIC:                         3.690e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3478      0.904      3.703      0.000       1.575       5.120
# MPA           -0.0016      0.001     -2.660      0.008      -0.003      -0.000
# Gender         0.9342      0.472      1.979      0.048       0.009       1.859
# Age           -0.0445      0.013     -3.491      0.000      -0.070      -0.020
# IS             0.1364      0.119      1.144      0.253      -0.097       0.370
# Gender:MPA    -0.0006      0.001     -0.708      0.479      -0.002       0.001
# ==============================================================================
# Omnibus:                       60.270   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.585
# Skew:                           0.207   Prob(JB):                     1.28e-15
# Kurtosis:                       3.361   Cond. No.                     5.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.050150
# MPA          -0.036023
# Gender        0.026807
# Age          -0.047275
# IS            0.015487
# Gender:MPA   -0.009586
# dtype: float64

# %%
vpa = ols('BA ~ VPA + Age + Gender + IS + Gender:VPA', missing='drop', data = main_test).fit()
print(vpa.summary())

#calculate effect size
results = vpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     3.986
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):            0.00130
# Time:                        09:43:11   Log-Likelihood:                -18432.
# No. Observations:                5452   AIC:                         3.688e+04
# Df Residuals:                    5446   BIC:                         3.691e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.2602      0.843      2.682      0.007       0.608       3.912
# VPA           -0.0022      0.003     -0.656      0.512      -0.009       0.004
# Age           -0.0386      0.013     -3.001      0.003      -0.064      -0.013
# Gender         0.7852      0.249      3.151      0.002       0.297       1.274
# IS             0.1221      0.119      1.022      0.307      -0.112       0.356
# Gender:VPA    -0.0028      0.004     -0.632      0.527      -0.012       0.006
# ==============================================================================
# Omnibus:                       60.770   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.283
# Skew:                           0.208   Prob(JB):                     9.02e-16
# Kurtosis:                       3.364   Cond. No.                         708.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept     0.036324
# VPA          -0.008888
# Age          -0.040638
# Gender        0.042669
# IS            0.013845
# Gender:VPA   -0.008558
# dtype: float64

# %% [markdown]
# ### 7.1.3 Self-report PA

# %%
srlpa = ols('BA ~ SRLPA + Age + Gender + IS + Gender:SRLPA', missing='drop', data = main_test).fit()
print(srlpa.summary())

#calculate effect size
results = srlpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.423
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):            0.00433
# Time:                        09:43:11   Log-Likelihood:                -18433.
# No. Observations:                5452   AIC:                         3.688e+04
# Df Residuals:                    5446   BIC:                         3.692e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.9571      0.810      2.417      0.016       0.370       3.544
# SRLPA           -0.0002      0.001     -0.327      0.744      -0.001       0.001
# Age             -0.0340      0.013     -2.715      0.007      -0.059      -0.009
# Gender           0.5657      0.284      1.992      0.046       0.009       1.122
# IS               0.1115      0.119      0.934      0.350      -0.122       0.345
# Gender:SRLPA     0.0004      0.001      0.422      0.673      -0.001       0.002
# ==============================================================================
# Omnibus:                       60.465   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.015
# Skew:                           0.207   Prob(JB):                     1.03e-15
# Kurtosis:                       3.365   Cond. No.                     3.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.032732
# SRLPA          -0.004425
# Age            -0.036774
# Gender          0.026978
# IS              0.012652
# Gender:SRLPA    0.005711
# dtype: float64

# %%
srmpa = ols('BA ~ SRMPA + Gender + Age + IS + Gender:SRMPA', missing='drop', data = main_test).fit()
print(srmpa.summary())

#calculate effect size
results = srmpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.486
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):            0.00379
# Time:                        09:43:11   Log-Likelihood:                -18433.
# No. Observations:                5452   AIC:                         3.688e+04
# Df Residuals:                    5446   BIC:                         3.692e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.8468      0.803      2.301      0.021       0.273       3.420
# SRMPA        -2.838e-06      0.001     -0.004      0.997      -0.001       0.001
# Gender           0.7329      0.252      2.907      0.004       0.239       1.227
# Age             -0.0330      0.013     -2.609      0.009      -0.058      -0.008
# IS               0.1091      0.119      0.913      0.361      -0.125       0.343
# Gender:SRMPA    -0.0005      0.001     -0.516      0.606      -0.002       0.001
# ==============================================================================
# Omnibus:                       60.402   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.012
# Skew:                           0.206   Prob(JB):                     1.03e-15
# Kurtosis:                       3.366   Cond. No.                     2.36e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.36e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.031158
# SRMPA          -0.000056
# Gender          0.039371
# Age            -0.035331
# IS              0.012370
# Gender:SRMPA   -0.006989
# dtype: float64

# %%
srvpa = ols('BA ~ SRVPA + Age + Gender + IS + Gender:SRVPA', missing='drop', data = main_test).fit()
print(srvpa.summary())

#calculate effect size
results = srvpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.468
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):            0.00394
# Time:                        09:43:11   Log-Likelihood:                -18433.
# No. Observations:                5452   AIC:                         3.688e+04
# Df Residuals:                    5446   BIC:                         3.692e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.9713      0.808      2.438      0.015       0.386       3.556
# SRVPA           -0.0007      0.002     -0.397      0.691      -0.004       0.003
# Age             -0.0344      0.013     -2.742      0.006      -0.059      -0.010
# Gender           0.6740      0.250      2.699      0.007       0.185       1.163
# IS               0.1112      0.119      0.932      0.351      -0.123       0.345
# Gender:SRVPA    -0.0001      0.002     -0.059      0.953      -0.005       0.004
# ==============================================================================
# Omnibus:                       60.578   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.193
# Skew:                           0.207   Prob(JB):                     9.44e-16
# Kurtosis:                       3.366   Cond. No.                     1.10e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.033025
# SRVPA          -0.005380
# Age            -0.037141
# Gender          0.036560
# IS              0.012623
# Gender:SRVPA   -0.000805
# dtype: float64

# %% [markdown]
# ## 7.2 PA+Fitness models

# %% [markdown]
# ### 7.2.1 PAF

# %%
paf = ols('BA ~ MPA + HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(paf.summary())

#calculate effect size
results = paf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     5.915
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           5.13e-11
# Time:                        09:43:11   Log-Likelihood:                -18403.
# No. Observations:                5452   AIC:                         3.683e+04
# Df Residuals:                    5438   BIC:                         3.693e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9385      1.744     -0.538      0.590      -4.357       2.480
# MPA           -0.0012      0.001     -1.959      0.050      -0.002    9.19e-07
# HG            -0.0235      0.021     -1.093      0.275      -0.066       0.019
# DBP            0.0398      0.014      2.867      0.004       0.013       0.067
# HR             0.0214      0.013      1.602      0.109      -0.005       0.048
# BMI            0.0193      0.032      0.608      0.543      -0.043       0.081
# Gender        -0.5377      2.232     -0.241      0.810      -4.914       3.838
# IS             0.1213      0.119      1.018      0.309      -0.112       0.355
# Age           -0.0508      0.013     -3.861      0.000      -0.077      -0.025
# HG:Gender     -0.0012      0.027     -0.045      0.964      -0.054       0.052
# DBP:Gender    -0.0085      0.020     -0.419      0.675      -0.048       0.031
# HR:Gender      0.0016      0.018      0.085      0.932      -0.035       0.038
# BMI:Gender     0.0838      0.052      1.627      0.104      -0.017       0.185
# MPA:Gender    -0.0003      0.001     -0.372      0.710      -0.002       0.001
# ==============================================================================
# Omnibus:                       65.241   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.437
# Skew:                           0.213   Prob(JB):                     4.16e-17
# Kurtosis:                       3.389   Cond. No.                     1.58e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.007289
# MPA          -0.026530
# HG           -0.014799
# DBP           0.038825
# HR            0.021696
# BMI           0.008234
# Gender       -0.003263
# IS            0.013786
# Age          -0.052294
# HG:Gender    -0.000616
# DBP:Gender   -0.005674
# HR:Gender     0.001149
# BMI:Gender    0.022029
# MPA:Gender   -0.005034
# dtype: float64

# %% [markdown]
# ### 7.2.2 SRPAF

# %%
srpaf = ols('BA ~ SRMPA + HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + SRMPA:Gender', missing='drop', data = main_test).fit()
print(srpaf.summary())

#calculate effect size
results = srpaf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.242
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           2.04e-09
# Time:                        09:43:12   Log-Likelihood:                -18408.
# No. Observations:                5452   AIC:                         3.684e+04
# Df Residuals:                    5438   BIC:                         3.694e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -2.4227      1.643     -1.475      0.140      -5.643       0.798
# SRMPA            0.0002      0.001      0.241      0.809      -0.001       0.002
# HG              -0.0250      0.021     -1.167      0.243      -0.067       0.017
# DBP              0.0388      0.014      2.797      0.005       0.012       0.066
# HR               0.0225      0.013      1.684      0.092      -0.004       0.049
# BMI              0.0358      0.031      1.166      0.244      -0.024       0.096
# Gender          -0.8828      2.119     -0.417      0.677      -5.036       3.271
# IS               0.1054      0.119      0.885      0.376      -0.128       0.339
# Age             -0.0433      0.013     -3.317      0.001      -0.069      -0.018
# HG:Gender        0.0009      0.027      0.033      0.974      -0.052       0.054
# DBP:Gender      -0.0088      0.020     -0.432      0.666      -0.049       0.031
# HR:Gender        0.0028      0.018      0.150      0.880      -0.033       0.039
# BMI:Gender       0.0881      0.050      1.758      0.079      -0.010       0.186
# SRMPA:Gender    -0.0003      0.001     -0.314      0.754      -0.002       0.002
# ==============================================================================
# Omnibus:                       66.000   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.781
# Skew:                           0.212   Prob(JB):                     2.12e-17
# Kurtosis:                       3.397   Cond. No.                     7.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept      -0.019971
# SRMPA           0.003265
# HG             -0.015799
# DBP             0.037876
# HR              0.022813
# BMI             0.015796
# Gender         -0.005643
# IS              0.011982
# Age            -0.044919
# HG:Gender       0.000443
# DBP:Gender     -0.005848
# HR:Gender       0.002037
# BMI:Gender      0.023816
# SRMPA:Gender   -0.004250
# dtype: float64

# %% [markdown]
# ### 7.2.3 PAF / MPA

# %%
no_mpa = ols('BA ~ HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_mpa.summary())

#calculate effect size
results = no_mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     6.188
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           3.33e-10
# Time:                        09:43:12   Log-Likelihood:                -18408.
# No. Observations:                5452   AIC:                         3.684e+04
# Df Residuals:                    5440   BIC:                         3.692e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.3762      1.636     -1.452      0.146      -5.584       0.831
# HG            -0.0252      0.021     -1.176      0.239      -0.067       0.017
# DBP            0.0389      0.014      2.799      0.005       0.012       0.066
# HR             0.0224      0.013      1.676      0.094      -0.004       0.048
# BMI            0.0355      0.031      1.156      0.248      -0.025       0.096
# Gender        -0.9730      2.099     -0.464      0.643      -5.088       3.142
# IS             0.1054      0.119      0.885      0.376      -0.128       0.339
# Age           -0.0433      0.013     -3.354      0.001      -0.069      -0.018
# HG:Gender      0.0010      0.027      0.038      0.970      -0.052       0.054
# DBP:Gender    -0.0087      0.020     -0.428      0.668      -0.049       0.031
# HR:Gender      0.0030      0.018      0.165      0.869      -0.033       0.039
# BMI:Gender     0.0886      0.050      1.770      0.077      -0.010       0.187
# ==============================================================================
# Omnibus:                       65.863   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.548
# Skew:                           0.212   Prob(JB):                     2.39e-17
# Kurtosis:                       3.396   Cond. No.                     3.57e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.019671
# HG           -0.015933
# DBP           0.037913
# HR            0.022703
# BMI           0.015660
# Gender       -0.006278
# IS            0.011991
# Age          -0.045421
# HG:Gender     0.000509
# DBP:Gender   -0.005801
# HR:Gender     0.002230
# BMI:Gender    0.023974
# dtype: float64

# %% [markdown]
# ### 7.2.4 PAF / HG

# %%
no_hg = ols('BA ~ MPA + DBP + HR + BMI + Gender + IS + Age + MPA:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hg.summary())

#calculate effect size
results = no_hg
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     6.696
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           2.97e-11
# Time:                        09:43:12   Log-Likelihood:                -18405.
# No. Observations:                5452   AIC:                         3.683e+04
# Df Residuals:                    5440   BIC:                         3.691e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.8550      1.593     -1.164      0.244      -4.978       1.268
# MPA           -0.0013      0.001     -2.022      0.043      -0.002   -3.85e-05
# DBP            0.0392      0.014      2.827      0.005       0.012       0.066
# HR             0.0215      0.013      1.614      0.107      -0.005       0.048
# BMI            0.0197      0.032      0.621      0.535      -0.043       0.082
# Gender        -0.9104      2.083     -0.437      0.662      -4.995       3.174
# IS             0.1190      0.119      0.999      0.318      -0.115       0.352
# Age           -0.0454      0.013     -3.561      0.000      -0.070      -0.020
# MPA:Gender    -0.0003      0.001     -0.311      0.756      -0.002       0.002
# DBP:Gender    -0.0098      0.020     -0.483      0.629      -0.050       0.030
# HR:Gender      0.0028      0.018      0.152      0.879      -0.033       0.039
# BMI:Gender     0.0815      0.051      1.582      0.114      -0.019       0.182
# ==============================================================================
# Omnibus:                       63.310   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.901
# Skew:                           0.210   Prob(JB):                     1.48e-16
# Kurtosis:                       3.380   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.015770
# MPA          -0.027386
# DBP           0.038290
# HR            0.021858
# BMI           0.008408
# Gender       -0.005918
# IS            0.013525
# Age          -0.048229
# MPA:Gender   -0.004213
# DBP:Gender   -0.006546
# HR:Gender     0.002061
# BMI:Gender    0.021430
# dtype: float64

# %% [markdown]
# ### 7.2.5 PAF / HR

# %%
no_hr = ols('BA ~ HG + DBP + MPA + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + MPA:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hr.summary())

#calculate effect size
results = no_hr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     6.459
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           9.22e-11
# Time:                        09:43:12   Log-Likelihood:                -18406.
# No. Observations:                5452   AIC:                         3.684e+04
# Df Residuals:                    5440   BIC:                         3.692e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0511      1.635      0.031      0.975      -3.155       3.257
# HG            -0.0239      0.021     -1.114      0.265      -0.066       0.018
# DBP            0.0444      0.014      3.267      0.001       0.018       0.071
# MPA           -0.0013      0.001     -2.021      0.043      -0.002   -3.82e-05
# BMI            0.0258      0.031      0.821      0.412      -0.036       0.088
# Gender        -0.6447      2.096     -0.308      0.758      -4.754       3.465
# IS             0.1236      0.119      1.038      0.299      -0.110       0.357
# Age           -0.0511      0.013     -3.887      0.000      -0.077      -0.025
# HG:Gender     -0.0031      0.027     -0.114      0.909      -0.056       0.050
# DBP:Gender    -0.0062      0.020     -0.314      0.753      -0.045       0.033
# MPA:Gender    -0.0004      0.001     -0.449      0.654      -0.002       0.001
# BMI:Gender     0.0863      0.051      1.688      0.091      -0.014       0.187
# ==============================================================================
# Omnibus:                       63.600   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.304
# Skew:                           0.210   Prob(JB):                     1.21e-16
# Kurtosis:                       3.382   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.000423
# HG           -0.015088
# DBP           0.044248
# MPA          -0.027377
# BMI           0.011119
# Gender       -0.004165
# IS            0.014057
# Age          -0.052636
# HG:Gender    -0.001542
# DBP:Gender   -0.004256
# MPA:Gender   -0.006078
# BMI:Gender    0.022862
# dtype: float64

# %% [markdown]
# ### 7.2.6 PAF / DBP

# %%
no_dbp = ols('BA ~ HG + MPA + HR + BMI + Gender + IS + Age + HG:Gender + MPA:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_dbp.summary())

#calculate effect size
results = no_dbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.836
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           1.75e-09
# Time:                        09:43:12   Log-Likelihood:                -18410.
# No. Observations:                5452   AIC:                         3.684e+04
# Df Residuals:                    5440   BIC:                         3.692e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7332      1.636      0.448      0.654      -2.473       3.940
# HG            -0.0215      0.021     -1.001      0.317      -0.064       0.021
# MPA           -0.0012      0.001     -1.877      0.061      -0.002    5.21e-05
# HR             0.0292      0.013      2.235      0.025       0.004       0.055
# BMI            0.0445      0.031      1.457      0.145      -0.015       0.104
# Gender        -0.8969      1.994     -0.450      0.653      -4.807       3.013
# IS             0.1365      0.119      1.146      0.252      -0.097       0.370
# Age           -0.0476      0.013     -3.624      0.000      -0.073      -0.022
# HG:Gender      0.0001      0.027      0.005      0.996      -0.053       0.053
# MPA:Gender    -0.0003      0.001     -0.360      0.719      -0.002       0.001
# HR:Gender      0.0006      0.018      0.035      0.972      -0.035       0.036
# BMI:Gender     0.0753      0.050      1.499      0.134      -0.023       0.174
# ==============================================================================
# Omnibus:                       65.203   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.551
# Skew:                           0.212   Prob(JB):                     3.93e-17
# Kurtosis:                       3.391   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.006071
# HG           -0.013557
# MPA          -0.025424
# HR            0.030274
# BMI           0.019726
# Gender       -0.006090
# IS            0.015520
# Age          -0.049076
# HG:Gender     0.000063
# MPA:Gender   -0.004880
# HR:Gender     0.000472
# BMI:Gender    0.020301
# dtype: float64

# %% [markdown]
# ### 7.2.7 PAF / BMI

# %%
no_bmi = ols('BA ~ HG + DBP + HR + MPA + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(no_bmi.summary())

#calculate effect size
results = no_bmi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     6.367
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           1.42e-10
# Time:                        09:43:12   Log-Likelihood:                -18407.
# No. Observations:                5452   AIC:                         3.684e+04
# Df Residuals:                    5440   BIC:                         3.692e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.5432      1.665     -0.326      0.744      -3.807       2.721
# HG            -0.0239      0.021     -1.113      0.266      -0.066       0.018
# DBP            0.0422      0.013      3.161      0.002       0.016       0.068
# HR             0.0224      0.013      1.694      0.090      -0.004       0.048
# MPA           -0.0013      0.001     -2.200      0.028      -0.003      -0.000
# Gender         1.1807      2.033      0.581      0.561      -2.805       5.166
# IS             0.1177      0.119      0.988      0.323      -0.116       0.351
# Age           -0.0522      0.013     -3.975      0.000      -0.078      -0.026
# HG:Gender      0.0008      0.027      0.030      0.976      -0.052       0.054
# DBP:Gender    -0.0036      0.020     -0.182      0.855      -0.042       0.035
# HR:Gender      0.0045      0.018      0.246      0.806      -0.031       0.040
# MPA:Gender    -0.0006      0.001     -0.719      0.472      -0.002       0.001
# ==============================================================================
# Omnibus:                       65.317   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.252
# Skew:                           0.214   Prob(JB):                     4.56e-17
# Kurtosis:                       3.384   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.004419
# HG           -0.015078
# DBP           0.042811
# HR            0.022943
# MPA          -0.029801
# Gender        0.007866
# IS            0.013379
# Age          -0.053833
# HG:Gender     0.000405
# DBP:Gender   -0.002468
# HR:Gender     0.003334
# MPA:Gender   -0.009744
# dtype: float64

# %% [markdown]
# # 8 Model comparisons

# %% [markdown]
# ## 8.1 Cov vs. PA

# %%
model_comparison = anova_lm(cov_model, lpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  275903.594080      0.0        NaN       NaN       NaN
# 1    5446.0  275875.323325      2.0  28.270755  0.279044  0.756518

# %%
model_comparison = anova_lm(cov_model, mpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F   Pr(>F)
# 0    5448.0  275903.594080      0.0         NaN       NaN      NaN
# 1    5446.0  275012.617953      2.0  890.976127  8.821879  0.00015

# %%
model_comparison = anova_lm(cov_model, vpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F   Pr(>F)
# 0    5448.0  275903.594080      0.0         NaN       NaN      NaN
# 1    5446.0  275752.216321      2.0  151.377759  1.494826  0.22438

# %% [markdown]
# ## 8.2 Cov vs. SRPA

# %%
model_comparison = anova_lm(cov_model, srlpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff   ss_diff         F    Pr(>F)
# 0    5448.0  275903.594080      0.0       NaN       NaN       NaN
# 1    5446.0  275894.469017      2.0  9.125063  0.090062  0.913876

# %%
model_comparison = anova_lm(cov_model, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  275903.594080      0.0        NaN       NaN       NaN
# 1    5446.0  275878.394615      2.0  25.199465  0.248726  0.779802

# %%
model_comparison = anova_lm(cov_model, srvpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  275903.594080      0.0        NaN       NaN       NaN
# 1    5446.0  275883.063167      2.0  20.530913  0.202643  0.816576

# %% [markdown]
# # 9 PAF Type-III ANOVA

# %% [markdown]
# ## 9.1 PAF / MPA

# %%
model_comparison = anova_lm(no_mpa, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  273341.017010      0.0         NaN       NaN       NaN
# 1    5438.0  272902.256243      2.0  438.760768  4.371494  0.012677

# %% [markdown]
# ## 9.2 SR PAF / SRMPA

# %%
model_comparison = anova_lm(no_mpa, srpaf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff   ss_diff         F    Pr(>F)
# 0    5440.0  273341.017010      0.0       NaN       NaN       NaN
# 1    5438.0  273335.990815      2.0  5.026195  0.049998  0.951232

# %% [markdown]
# ## 9.3 PAF / HG

# %%
model_comparison = anova_lm(no_hg, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  273064.323768      0.0         NaN       NaN       NaN
# 1    5438.0  272902.256243      2.0  162.067525  1.614723  0.199041

# %% [markdown]
# ## 9.4 PAF / DBP

# %%
model_comparison = anova_lm(no_dbp, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  273533.342481      0.0         NaN       NaN       NaN
# 1    5438.0  272902.256243      2.0  631.086238  6.287685  0.001873

# %% [markdown]
# ## 9.5 PAF / HR

# %%
model_comparison = anova_lm(no_hr, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  273193.572216      0.0         NaN       NaN       NaN
# 1    5438.0  272902.256243      2.0  291.315973  2.902461  0.054973

# %% [markdown]
# ## 9.6 PAF / BMI

# %%
model_comparison = anova_lm(no_bmi, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  273243.344132      0.0         NaN       NaN       NaN
# 1    5438.0  272902.256243      2.0  341.087889  3.398352  0.033499

# %% [markdown]
# # 10 Standardization of all variables

# %%
main_test = pd.DataFrame(main_test)
main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Gender","IS"]] = stats.zscore(main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Gender","IS"]], nan_policy='omit')

# %% [markdown]
# # 11 Mediation analysis

# %% [markdown]
# ## 11.1 BMI

# %%
# outcome_model = sm.OLS.from_formula("BA ~ BMI + LPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("BMI ~ LPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "MPA").fit()
print(res.summary())

modelm = ols("BMI ~ MPA + Age + Gender", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ BMI + Age + Gender", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.099093       -0.155499       -0.045815    0.000
# ACME (treated)           -0.099093       -0.155499       -0.045815    0.000
# ADE (control)            -0.302362       -0.518127       -0.095729    0.004
# ADE (treated)            -0.302362       -0.518127       -0.095729    0.004
# Total effect             -0.401454       -0.604669       -0.201047    0.000
# Prop. mediated (control)  0.247333        0.104265        0.534961    0.000
# Prop. mediated (treated)  0.247333        0.104265        0.534961    0.000
# ACME (average)           -0.099093       -0.155499       -0.045815    0.000
# ADE (average)            -0.302362       -0.518127       -0.095729    0.004
# Prop. mediated (average)  0.247333        0.104265        0.534961    0.000
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BMI   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     160.6
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           1.00e-99
# Time:                        09:44:03   Log-Likelihood:                -7505.1
# No. Observations:                5452   AIC:                         1.502e+04
# Df Residuals:                    5448   BIC:                         1.504e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.711e-16      0.013  -2.09e-14      1.000      -0.025       0.025
# MPA           -0.2693      0.013    -20.312      0.000      -0.295      -0.243
# Age           -0.0417      0.013     -3.127      0.002      -0.068      -0.016
# Gender         0.0980      0.013      7.495      0.000       0.072       0.124
# ==============================================================================
# Omnibus:                      982.075   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2194.667
# Skew:                           1.036   Prob(JB):                         0.00
# Kurtosis:                       5.317   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     12.26
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           5.45e-08
# Time:                        09:44:03   Log-Likelihood:                -18423.
# No. Observations:                5452   AIC:                         3.685e+04
# Df Residuals:                    5448   BIC:                         3.688e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0877      0.096      0.912      0.362      -0.101       0.276
# BMI            0.4397      0.097      4.544      0.000       0.250       0.629
# Age           -0.2589      0.097     -2.673      0.008      -0.449      -0.069
# Gender         0.2753      0.097      2.827      0.005       0.084       0.466
# ==============================================================================
# Omnibus:                       61.112   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.513
# Skew:                           0.204   Prob(JB):                     4.88e-16
# Kurtosis:                       3.379   Cond. No.                         1.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ BMI + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("BMI ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.2 DBP

# %%
# outcome_model = sm.OLS.from_formula("BA ~ DBP + LPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("DBP ~ LPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "MPA").fit()
print(res.summary())

modelm = ols("DBP ~ MPA + Age + Gender", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ DBP + Age + Gender", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.027369       -0.055219       -0.005407     0.01
# ACME (treated)           -0.027369       -0.055219       -0.005407     0.01
# ADE (control)            -0.377435       -0.573077       -0.193490     0.00
# ADE (treated)            -0.377435       -0.573077       -0.193490     0.00
# Total effect             -0.404804       -0.602880       -0.220025     0.00
# Prop. mediated (control)  0.066016        0.014773        0.170615     0.01
# Prop. mediated (treated)  0.066016        0.014773        0.170615     0.01
# ACME (average)           -0.027369       -0.055219       -0.005407     0.01
# ADE (average)            -0.377435       -0.573077       -0.193490     0.00
# Prop. mediated (average)  0.066016        0.014773        0.170615     0.01
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DBP   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     86.64
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           9.21e-55
# Time:                        09:44:52   Log-Likelihood:                -7609.0
# No. Observations:                5452   AIC:                         1.523e+04
# Df Residuals:                    5448   BIC:                         1.525e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.108e-16      0.013   1.59e-14      1.000      -0.026       0.026
# MPA           -0.0556      0.014     -4.112      0.000      -0.082      -0.029
# Age            0.0480      0.014      3.534      0.000       0.021       0.075
# Gender         0.1894      0.013     14.206      0.000       0.163       0.216
# ==============================================================================
# Omnibus:                       88.226   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.573
# Skew:                           0.281   Prob(JB):                     1.07e-21
# Kurtosis:                       3.330   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     14.29
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           2.84e-09
# Time:                        09:44:52   Log-Likelihood:                -18420.
# No. Observations:                5452   AIC:                         3.685e+04
# Df Residuals:                    5448   BIC:                         3.687e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0877      0.096      0.913      0.362      -0.101       0.276
# DBP            0.5080      0.098      5.169      0.000       0.315       0.701
# Age           -0.2839      0.097     -2.928      0.003      -0.474      -0.094
# Gender         0.2249      0.099      2.281      0.023       0.032       0.418
# ==============================================================================
# Omnibus:                       61.371   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.232
# Skew:                           0.208   Prob(JB):                     5.61e-16
# Kurtosis:                       3.370   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ DBP + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("DBP ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.3 Heart rate

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HR + LPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("HR ~ LPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("HR ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "MPA").fit()
print(res.summary())

modelm = ols("HR ~ MPA + Age + Gender", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ HR + Age + Gender", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.042447       -0.072880       -0.018200      0.0
# ACME (treated)           -0.042447       -0.072880       -0.018200      0.0
# ADE (control)            -0.349756       -0.545583       -0.145753      0.0
# ADE (treated)            -0.349756       -0.545583       -0.145753      0.0
# Total effect             -0.392204       -0.589410       -0.195415      0.0
# Prop. mediated (control)  0.106645        0.044311        0.272491      0.0
# Prop. mediated (treated)  0.106645        0.044311        0.272491      0.0
# ACME (average)           -0.042447       -0.072880       -0.018200      0.0
# ADE (average)            -0.349756       -0.545583       -0.145753      0.0
# Prop. mediated (average)  0.106645        0.044311        0.272491      0.0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     HR   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     38.93
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           6.93e-25
# Time:                        09:45:42   Log-Likelihood:                -7678.2
# No. Observations:                5452   AIC:                         1.536e+04
# Df Residuals:                    5448   BIC:                         1.539e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.621e-16      0.013   4.19e-14      1.000      -0.026       0.026
# MPA           -0.1082      0.014     -7.909      0.000      -0.135      -0.081
# Age            0.0040      0.014      0.292      0.770      -0.023       0.031
# Gender        -0.1017      0.014     -7.529      0.000      -0.128      -0.075
# ==============================================================================
# Omnibus:                      528.749   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              841.759
# Skew:                           0.712   Prob(JB):                    1.64e-183
# Kurtosis:                       4.295   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     11.97
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           8.28e-08
# Time:                        09:45:42   Log-Likelihood:                -18424.
# No. Observations:                5452   AIC:                         3.686e+04
# Df Residuals:                    5448   BIC:                         3.688e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0877      0.096      0.912      0.362      -0.101       0.276
# HR             0.4300      0.097      4.448      0.000       0.240       0.620
# Age           -0.2648      0.097     -2.733      0.006      -0.455      -0.075
# Gender         0.3643      0.097      3.743      0.000       0.173       0.555
# ==============================================================================
# Omnibus:                       63.447   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.003
# Skew:                           0.210   Prob(JB):                     1.40e-16
# Kurtosis:                       3.380   Cond. No.                         1.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HR + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("HR ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.4 Hand grip

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HG + LPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("HG ~ LPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + MPA + Gender + Age", main_test)
mediator_model = sm.OLS.from_formula("HG ~ MPA + Gender + Age", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "MPA").fit()
print(res.summary())

modelm = ols("HG ~ MPA + Age + Gender", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ HG + Age + Gender", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.002114       -0.012114        0.005476    0.602
# ACME (treated)           -0.002114       -0.012114        0.005476    0.602
# ADE (control)            -0.401482       -0.595872       -0.202954    0.000
# ADE (treated)            -0.401482       -0.595872       -0.202954    0.000
# Total effect             -0.403596       -0.599541       -0.208223    0.000
# Prop. mediated (control)  0.003526       -0.016780        0.031149    0.602
# Prop. mediated (treated)  0.003526       -0.016780        0.031149    0.602
# ACME (average)           -0.002114       -0.012114        0.005476    0.602
# ADE (average)            -0.401482       -0.595872       -0.202954    0.000
# Prop. mediated (average)  0.003526       -0.016780        0.031149    0.602
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     HG   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     2337.
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):               0.00
# Time:                        09:46:31   Log-Likelihood:                -5481.3
# No. Observations:                5452   AIC:                         1.097e+04
# Df Residuals:                    5448   BIC:                         1.100e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.056e-16      0.009   2.29e-14      1.000      -0.018       0.018
# MPA            0.0095      0.009      1.034      0.301      -0.008       0.027
# Age           -0.1601      0.009    -17.413      0.000      -0.178      -0.142
# Gender         0.7516      0.009     83.292      0.000       0.734       0.769
# ==============================================================================
# Omnibus:                       83.560   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.278
# Skew:                          -0.038   Prob(JB):                     4.27e-35
# Kurtosis:                       3.831   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     6.216
# Date:                Wed, 06 Sep 2023   Prob (F-statistic):           0.000328
# Time:                        09:46:31   Log-Likelihood:                -18432.
# No. Observations:                5452   AIC:                         3.687e+04
# Df Residuals:                    5448   BIC:                         3.690e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0877      0.096      0.911      0.363      -0.101       0.277
# HG            -0.2337      0.146     -1.604      0.109      -0.519       0.052
# Age           -0.2918      0.100     -2.923      0.003      -0.488      -0.096
# Gender         0.4975      0.146      3.401      0.001       0.211       0.784
# ==============================================================================
# Omnibus:                       62.240   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               71.311
# Skew:                           0.209   Prob(JB):                     3.27e-16
# Kurtosis:                       3.373   Cond. No.                         2.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HG + VPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("HG ~ VPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# # 12 LASSO Regression

# %% [markdown]
# ## 12.1 Accelerometer PA

# %%
df = main_test[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

# lasso with cross validated alpha

lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.xlim(0.001, 100)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, bbox_to_anchor=(1.01, 1.02), loc='upper left')
plt.show()



# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.0030538555088334154
# [-0.38933661  0.42500664  0.09582674 -0.29696762  0.24897039  0.36503405
#  -0.23890764  0.20943402]
# 0.01332394151059002

# %% [markdown]
# ## 12.2 Self-report PA

# %%
df = main_test[["Age", "Gender", "IS", "LPA", "MPA", "VPA",  "SRLPA", "SRMPA", "SRVPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

# lasso with cross validated alpha

lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.xlim(0.001, 100)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, bbox_to_anchor=(1.01, 1.02), loc='upper left')
plt.show()



# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.021544346900318846
# [-0.29302185  0.35225991  0.06028556 -0.          0.25343516  0.34317325
#  -0.16268654  0.27389108]
# 0.011626082849691022

# %% [markdown]
# # 13 Pickle

# %%
main_test.to_pickle("3_validate.pkl")
