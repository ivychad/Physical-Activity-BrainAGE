# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from random import seed
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, Lasso
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm
from statsmodels.formula.api import ols
from statsmodels.regression import linear_model
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from statsmodels.stats.mediation import Mediation
from sklearn.svm import SVR
from pingouin import ancova
import matplotlib.cm as cm
from scipy.stats import pearsonr
# %matplotlib inline

seed(888)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1 Load validation set

# %%
# load data from pickle and convert to dataframe
brain_test = pd.read_pickle("brain_test_validate.pkl")
main_test = pd.read_pickle("main_test_validate.pkl")
brain_train = pd.read_pickle("1_brain_train.pkl")
brain_test = pd.DataFrame(brain_test)
main_test = pd.DataFrame(main_test)
brain_train = pd.DataFrame(brain_train)

# %% [markdown]
# # 2 BrainAGE prediction Destrieux

# %%
# select variables belonging to A2009s segmentation
X_train = brain_train.iloc[:,1657:2544:2]
Y_train = brain_train.iloc[:,-1]
X_test = brain_test.iloc[:,1657:2544:2]
Y_test = brain_test.iloc[:,-1]

# standardize x-data
X_train = stats.zscore(X_train)
X_test = stats.zscore(X_test)

# set of alphas to try (=penalization)
alpha_parameters = np.power(10,np.linspace(start=-3, stop=5, num=100))

# %% [markdown]
# ## 2.1 Cross-validation

# %%
X_CV = X_train
Y_CV = Y_train

# randomly split data (only training no PA) into training and testing set
X_train_cv, X_test_cv, Y_train_cv, Y_test_cv = train_test_split(X_CV,Y_CV)

#define the model
model_ridge = RidgeCV(alphas = alpha_parameters)

#perform 10-fold cross validation
scores_ridge = cross_val_score(model_ridge, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')

#calculate the mean-absolute error
mae_ridge = -1 * scores_ridge.mean()

print("The MAE for cross-validation (Ridge):", mae_ridge)

# for correction
model_ridge.fit(X_train_cv,Y_train_cv)
y_pred_cv = model_ridge.predict(X_test_cv)
# Out:
# The MAE for cross-validation (Ridge): 4.192981026915527

# %% [markdown]
# ## 2.2 Prediction

# %%
# initialize models
model_Ridge = RidgeCV(alphas = alpha_parameters)

# train model 
model_Ridge.fit(X_train,Y_train)

# get predicted values for test set
y_pred_Ridge = model_Ridge.predict(X_test)

# calculate brain age gap
brain_age_delta_Ridge = y_pred_Ridge-Y_test

# get mean absolute error (MAE)
print("The MAE for testing set using Ridge:", mean_absolute_error(Y_test,y_pred_Ridge))

# top x coefficients and their names
coeff = np.asarray(model_Ridge.coef_)
coeffabs = np.asarray(abs(model_Ridge.coef_))
top_coefficients = np.argsort(coeffabs)[-20:]
print(X_train.iloc[:,top_coefficients].columns)
print(coeff[top_coefficients])

# plot figure with x: actual age Y: predicted age, and a line with slope 1 for reference
plt.figure()
plt.scatter(Y_test, y_pred_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((60,60), slope=1, color='r')
plt.xticks(range(40,90,5))
plt.yticks(range(40,90,5))
plt.ylabel('Predicted Age', fontsize = 16)
plt.xlabel('Age', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()

plt.figure()
plt.scatter(Y_test,brain_age_delta_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((65,0), slope=-0.69, color="blue")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# The MAE for testing set using Ridge: 4.262589702409484
# Index(['volume_of_gtemporalinf_left_hemisphere_f27513_2_0',
#        'volume_of_scentral_right_hemisphere_f27743_2_0',
#        'volume_of_gpostcentral_right_hemisphere_f27726_2_0',
#        'area_of_gtemporalinf_left_hemisphere_f27365_2_0',
#        'mean_thickness_of_gfrontsup_left_hemisphere_f27418_2_0',
#        'area_of_latfispost_right_hemisphere_f27591_2_0',
#        'volume_of_stemporalsup_left_hemisphere_f27549_2_0',
#        'area_of_stemporalsup_left_hemisphere_f27401_2_0',
#        'area_of_sparietooccipital_right_hemisphere_f27615_2_0',
#        'area_of_gscingulant_right_hemisphere_f27556_2_0',
#        'area_of_scalcarine_left_hemisphere_f27372_2_0',
#        'volume_of_scalcarine_left_hemisphere_f27520_2_0',
#        'volume_of_gfrontsup_left_hemisphere_f27492_2_0',
#        'volume_of_gscingulant_right_hemisphere_f27704_2_0',
#        'area_of_gfrontsup_left_hemisphere_f27344_2_0',
#        'volume_of_sparietooccipital_right_hemisphere_f27763_2_0',
#        'volume_of_scentral_left_hemisphere_f27521_2_0',
#        'volume_of_latfispost_right_hemisphere_f27739_2_0',
#        'area_of_scalcarine_right_hemisphere_f27594_2_0',
#        'volume_of_scalcarine_right_hemisphere_f27742_2_0'],
#       dtype='object')
# [ 1.33500311  1.35589929 -1.40956036 -1.41335742 -1.4290742  -1.49188128
#  -1.49429486  1.5138274  -1.53084042  1.55013063 -1.58490537  1.58906398
#   1.60619697 -1.67635603 -1.749753    1.75977046  1.86033162  2.16152389
#  -2.37541509  2.37603676]

# %% [markdown]
# ## 2.3 Correction

# %%
# reformat cross validation data for regression model
y_pred_cv = np.asarray(y_pred_cv)
y_pred_cv = np.reshape(y_pred_cv, (-1,1))
Y_test_cv = np.asarray(Y_test_cv)
Y_test_cv = np.reshape(Y_test_cv, (-1,1))

# now using correction from the R code that's online from Cole
reg = LinearRegression().fit(Y_test_cv, y_pred_cv)
coef = float(reg.coef_)
intercept = float(reg.intercept_)
print("Coefficient and Intercept:", coef, intercept)

# correction by cole
function = lambda t: (t-intercept)/coef
vfunc = np.vectorize(function)
corr_brainage_1 = vfunc(y_pred_Ridge)
corr_brainage_delta_1 = corr_brainage_1-Y_test

# plots corrected
plt.figure()
plt.scatter(Y_test, corr_brainage_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((65,65), slope=coef, color="blue")
plt.ylabel("Predicted Age Corrected", fontsize = 16)
plt.axline((60,60), slope=1, color='r')
plt.xlabel("Age", fontsize = 16)
plt.xticks(range(40,90,5))
plt.yticks(range(30,115,10))
plt.show()

plt.figure()
plt.scatter(Y_test, corr_brainage_delta_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE Corrected", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# Coefficient and Intercept: 0.5313010645298789 30.19680221894273

# %% [markdown]
# ## 2.4 Add BrainAge Delta to Dataframe

# %%
main_test["BA"] = corr_brainage_delta_1

# %% [markdown]
# # 3 Preprocessing

# %% [markdown]
# ## 3.1 Recoding

# %%
# recoding imaging site and gender
# 1 = Cheadle;  2 = Reading;  3 = Newcastle;  4 = Bristol
main_test['IS'] = main_test['IS'].map({'11025': 0, '11026': 1,'11027': 2, '11028': 3})
main_test["Gender"] = main_test["Gender"].map({"Female":0, "Male":1})
main_test["Gender"] = main_test["Gender"].astype("int")

# delete unnecessary variables
del main_test["ID"]
del main_test["MVPA"]
del main_test["TPA"]

# %% [markdown]
# ## 3.2 Remove outliers on SRPA

# %%
# remove outliers on self-reported physical activity data for each intensity seperately
before = main_test.shape[0]
outlier = np.mean(main_test["SRLPA"]) + np.std(main_test["SRLPA"])*3
main_test = main_test[main_test["SRLPA"]<outlier]
outlier = np.mean(main_test["SRMPA"]) + np.std(main_test["SRMPA"])*3
main_test = main_test[main_test["SRMPA"]<outlier]
outlier = np.mean(main_test["SRVPA"]) + np.std(main_test["SRVPA"])*3
main_test = main_test[main_test["SRVPA"]<outlier]
after = main_test.shape[0]
print("Outliers on self-reported PA:", before-after)
print(after)
# Out:
# Outliers on self-reported PA: 532
# 5452

# %% [markdown]
# ## 3.3 Convert SRPA from MET min/week to min/week

# %%
main_test["SRLPA"] = main_test["SRLPA"]/3.3
main_test["SRMPA"] = main_test["SRMPA"]/4
main_test["SRVPA"] = main_test["SRVPA"]/8

# %% [markdown]
# ## 3.4 Remove people with Gender other than Male or Female

# %%
before = main_test.shape[0]
main_test = main_test[(main_test["Gender"] == 0) | (main_test["Gender"] == 1)]
after = main_test.shape[0]
print("Gender not Male or Female:", before-after)
print(after)
# Out:
# Gender not Male or Female: 0
# 5452

# %% [markdown]
# # 4 Basic distributions of validation set

# %% [markdown]
# ## 4.1 Data and Descriptives

# %%
main_test.head()
# Out:
#         Age  Gender  IS      VPA       MPA        LPA  SRLPA  SRMPA  SRVPA  \
# 4723   73.0       0   0  59.2704  661.8528  2400.4512  315.0   90.0    0.0
# 25494  55.0       1   0  70.0560  970.7760  1991.5920  120.0   30.0    0.0
# 34463  65.0       0   1  48.6720  506.1888  2813.2416  420.0  840.0  160.0
# 26337  67.0       0   2   0.0000   60.4800  1653.1200   40.0   60.0    0.0
# 29224  70.0       0   1   9.2736  361.6704  1873.2672   30.0    0.0   45.0
#
#          HG    HR      BMI   DBP    SBP         BA
# 4723   20.0  52.0  25.1338  74.0  137.0   3.791895
# 25494  26.0  55.0  22.9630  80.0  148.0   2.336620
# 34463  22.0  45.0  23.8325  63.0  108.0  -7.002282
# 26337  38.0  68.0  33.6473  84.0  139.0  15.941449
# 29224  24.0  69.0  32.8906  87.0  132.0   3.082344

# %%
# get mean and std for all variables for males and females seperately for the test set
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("Number of females:", female.shape[0])
print("NUmber of males:", male.shape[0])

print("Age")
mean = main_test["Age"].mean()
print("Mean", mean)
std = main_test["Age"].std()
print("Std",std)

print("LPA")
mean = main_test["LPA"].mean()
print("Mean", mean)
std = main_test["LPA"].std()
print("Std",std)

print("MPA")
mean = main_test["MPA"].mean()
print("Mean", mean)
std = main_test["MPA"].std()
print("Std",std)

print("VPA")
mean = main_test["VPA"].mean()
print("Mean", mean)
std = main_test["VPA"].std()
print("Std",std)

print("SRLPA")
mean = main_test["SRLPA"].mean()
print("Mean", mean)
std = main_test["SRLPA"].std()
print("Std",std)

print("SRMPA")
mean = main_test["SRMPA"].mean()
print("Mean", mean)
std = main_test["SRMPA"].std()
print("Std",std)

print("SRVPA")
mean = main_test["SRVPA"].mean()
print("Mean", mean)
std = main_test["SRVPA"].std()
print("Std",std)

print("DBP")
mean = main_test["DBP"].mean()
print("Mean", mean)
std = main_test["DBP"].std()
print("Std",std)

print("SBP")
mean = main_test["SBP"].mean()
print("Mean", mean)
std = main_test["SBP"].std()
print("Std",std)

print("BMI")
mean = main_test["BMI"].mean()
print("Mean", mean)
std = main_test["BMI"].std()
print("Std",std)

print("HG")
mean = main_test["HG"].mean()
print("Mean", mean)
std = main_test["HG"].std()
print("Std",std)

print("HR")
mean = main_test["HR"].mean()
print("Mean", mean)
std = main_test["HR"].std()
print("Std",std)

print("IS")
print(main_test["IS"].value_counts())
# Out:
# Number of females: 2970
# NUmber of males: 2482
# Age
# Mean 64.1907556859868
# Std 7.814225465582799
# LPA
# Mean 1981.0712548789434
# Std 417.08409539087546
# MPA
# Mean 482.57679882611893
# Std 216.85915554816543
# VPA
# Mean 34.27631577402791
# Std 43.2553234105916
# SRLPA
# Mean 235.25458547322083
# Std 219.09399284018272
# SRMPA
# Mean 159.23734409391048
# Std 192.24815076490748
# SRVPA
# Mean 66.45377842993398
# Std 83.83425453246974
# DBP
# Mean 81.11812179016874
# Std 10.361578350786544
# SBP
# Mean 136.32758620689654
# Std 18.24128891718472
# BMI
# Mean 26.36214115920763
# Std 4.213687095706291
# HG
# Mean 33.49486426999266
# Std 10.80830496808681
# HR
# Mean 67.96460014673514
# Std 11.043817664608612
# IS
# 0    3423
# 2    1109
# 1     909
# 3      11
# Name: IS, dtype: int64

# %% [markdown]
# ## 4.2 Age and BrainAge

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'Gender', fill=True, palette = "crest")
plt.title("Age x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'Gender', fill=True, palette = "crest")
plt.title("BrainAge x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'IS', fill=True, palette = "crest")
plt.title("BrainAge x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'IS', fill=True, palette = "crest")
plt.title("Age x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'MPA', hue = 'IS', fill=True, palette = "crest")
plt.title("Moderate PA x Imaging site")
plt.show()


plt.figure()
sns.kdeplot(data = main_test, x= 'BA', fill=True, label="A2009")
plt.title("BrainAge Segmentations")
plt.legend()
plt.show()

# %% [markdown]
# ## 4.3 Physical activity

# %%
# plot physical activity intensity categories for self-report and accelerometer together and seperately

plt.figure()
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,5000,1000),fontsize = 14)
plt.ylim(0,0.01)
plt.ylabel("Density",fontsize = 16)
plt.yticks(fontsize = 14)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA")
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA")
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2000,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA", color="#6baed6")
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA", color="#08519c")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,4500,1000),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA", color="#fd8d3c")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA", color="#a63603")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2500,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA", color="#74c476")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA", color="#006d2c")
plt.ylim(0,0.01)
plt.xticks(range(0,1500,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.legend()
plt.show()

plt.figure()
plt.scatter("MPA", "SRMPA", data = main_test, label = "Moderate PA", alpha=0.3, s=10, color = "darkcyan")
plt.scatter("VPA", "SRVPA", data = main_test, label = "Vigorous PA", alpha=0.3, s=10, color = "mediumvioletred")
plt.ylabel("Self-reported (min/week)", fontsize = 16)
plt.xlabel("Accelerometer (min/week)", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## 4.4 Health and Fitness

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'HG', hue = 'Gender', fill=True, palette = "crest")
plt.title("Hand grip")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'HR', hue = 'Gender', fill=True, palette = "crest")
plt.title("Heart rate")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Systolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'DBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Distolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BMI', hue = 'Gender', fill=True, palette = "crest")
plt.title("BMI")
plt.show()

# %% [markdown]
# # 5 Reorder Dataframe

# %%
# reorder dataframe
main_test = main_test[['Age', 'Gender', 'IS' , 'LPA', 'MPA', 'VPA', 'SRLPA', 'SRMPA', 'SRVPA', 'HG', 'HR', 'BMI', 'DBP', 'SBP', 'BA']]

# %% [markdown]
# # 6 Correlation Heatmap

# %%
def calculate_pvalues(df):
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            tmp = df[df[r].notnull() & df[c].notnull()]
            pvalues[r][c] = round(pearsonr(tmp[r], tmp[c])[1], 4)
    return pvalues

# %%
corr_test = main_test
corr_test = corr_test[:]
del corr_test["BA"]
del corr_test["SBP"]
del corr_test["IS"]
corr = corr_test.corr()
corr = round(corr,3)

fig, ax = plt.subplots(figsize=(13,10)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)


p_values = np.asarray(calculate_pvalues(corr_test))

threshold = 0.0007575  # Define your significance threshold

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if i != j:
            correlation = corr.iloc[i, j]
            p_value = p_values[i,j]  # Calculate or provide the p-value for the correlation

            if p_value < threshold:
                ax.text(j + 0.9, i + 0.2, "*", ha='right', va='top', color='black', fontsize=12)

# %% [markdown]
# # 7 Models with OLS

# %% [markdown]
# ## 7.1 PA BrainAGE Regression

# %% [markdown]
# ### 7.1.1 Baseline Covariates

# %%
cov_model = ols('BA ~ Gender + Age + IS', missing='drop', data = main_test).fit()
print(cov_model.summary())

#calculate effect size
results = cov_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     4.105
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):            0.00641
# Time:                        16:46:26   Log-Likelihood:                -18541.
# No. Observations:                5452   AIC:                         3.709e+04
# Df Residuals:                    5448   BIC:                         3.712e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5896      0.814      0.724      0.469      -1.006       2.185
# Gender         0.6660      0.199      3.349      0.001       0.276       1.056
# Age           -0.0146      0.013     -1.145      0.252      -0.040       0.010
# IS             0.1134      0.122      0.932      0.351      -0.125       0.352
# ==============================================================================
# Omnibus:                       60.694   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.316
# Skew:                           0.207   Prob(JB):                     8.87e-16
# Kurtosis:                       3.366   Cond. No.                         536.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.009810
# Gender       0.045356
# Age         -0.015509
# IS           0.012621
# dtype: float64

# %% [markdown]
# ### 7.1.2 Accelerometer PA

# %%
lpa = ols('BA ~ LPA + Age + Gender + IS + Gender:LPA', missing='drop', data = main_test).fit()
print(lpa.summary())

#calculate effect size
results = lpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.574
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):             0.0247
# Time:                        16:46:26   Log-Likelihood:                -18541.
# No. Observations:                5452   AIC:                         3.709e+04
# Df Residuals:                    5446   BIC:                         3.713e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8124      1.039      0.782      0.434      -1.224       2.849
# LPA           -0.0001      0.000     -0.350      0.727      -0.001       0.001
# Age           -0.0144      0.013     -1.125      0.261      -0.039       0.011
# Gender         0.8721      0.974      0.896      0.370      -1.036       2.781
# IS             0.1106      0.122      0.908      0.364      -0.128       0.349
# Gender:LPA    -0.0001      0.000     -0.249      0.804      -0.001       0.001
# ==============================================================================
# Omnibus:                       60.568   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.090
# Skew:                           0.207   Prob(JB):                     9.94e-16
# Kurtosis:                       3.364   Cond. No.                     2.74e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.010591
# LPA          -0.004735
# Age          -0.015237
# Gender        0.012133
# IS            0.012300
# Gender:LPA   -0.003367
# dtype: float64

# %%
mpa = ols('BA ~ MPA + Gender + Age + IS + Gender:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     5.999
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):           1.53e-05
# Time:                        16:46:26   Log-Likelihood:                -18532.
# No. Observations:                5452   AIC:                         3.708e+04
# Df Residuals:                    5446   BIC:                         3.712e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0627      0.922      2.237      0.025       0.255       3.870
# MPA           -0.0016      0.001     -2.660      0.008      -0.003      -0.000
# Gender         0.9529      0.481      1.979      0.048       0.009       1.897
# Age           -0.0254      0.013     -1.954      0.051      -0.051    8.65e-05
# IS             0.1392      0.122      1.144      0.253      -0.099       0.378
# Gender:MPA    -0.0006      0.001     -0.708      0.479      -0.002       0.001
# ==============================================================================
# Omnibus:                       60.270   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               68.585
# Skew:                           0.207   Prob(JB):                     1.28e-15
# Kurtosis:                       3.361   Cond. No.                     5.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.030294
# MPA          -0.036023
# Gender        0.026807
# Age          -0.026460
# IS            0.015487
# Gender:MPA   -0.009586
# dtype: float64

# %%
vpa = ols('BA ~ VPA + Age + Gender + IS + Gender:VPA', missing='drop', data = main_test).fit()
print(vpa.summary())

#calculate effect size
results = vpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     3.061
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):            0.00919
# Time:                        16:46:27   Log-Likelihood:                -18539.
# No. Observations:                5452   AIC:                         3.709e+04
# Df Residuals:                    5446   BIC:                         3.713e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9533      0.860      1.109      0.267      -0.732       2.638
# VPA           -0.0022      0.003     -0.656      0.512      -0.009       0.004
# Age           -0.0194      0.013     -1.477      0.140      -0.045       0.006
# Gender         0.8009      0.254      3.151      0.002       0.303       1.299
# IS             0.1246      0.122      1.022      0.307      -0.114       0.363
# Gender:VPA    -0.0029      0.005     -0.632      0.527      -0.012       0.006
# ==============================================================================
# Omnibus:                       60.770   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.283
# Skew:                           0.208   Prob(JB):                     9.02e-16
# Kurtosis:                       3.364   Cond. No.                         708.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept     0.015021
# VPA          -0.008888
# Age          -0.019999
# Gender        0.042669
# IS            0.013845
# Gender:VPA   -0.008558
# dtype: float64

# %% [markdown]
# ### 7.1.3 Self-report PA

# %%
srlpa = ols('BA ~ SRLPA + Age + Gender + IS + Gender:SRLPA', missing='drop', data = main_test).fit()
print(srlpa.summary())

#calculate effect size
results = srlpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.498
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):             0.0288
# Time:                        16:46:27   Log-Likelihood:                -18541.
# No. Observations:                5452   AIC:                         3.709e+04
# Df Residuals:                    5446   BIC:                         3.713e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.6441      0.826      0.780      0.435      -0.975       2.263
# SRLPA           -0.0002      0.001     -0.327      0.744      -0.001       0.001
# Age             -0.0147      0.013     -1.151      0.250      -0.040       0.010
# Gender           0.5770      0.290      1.992      0.046       0.009       1.145
# IS               0.1137      0.122      0.934      0.350      -0.125       0.352
# Gender:SRLPA     0.0004      0.001      0.422      0.673      -0.001       0.002
# ==============================================================================
# Omnibus:                       60.465   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.015
# Skew:                           0.207   Prob(JB):                     1.03e-15
# Kurtosis:                       3.365   Cond. No.                     3.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.010562
# SRLPA          -0.004425
# Age            -0.015593
# Gender          0.026978
# IS              0.012652
# Gender:SRLPA    0.005711
# dtype: float64

# %%
srmpa = ols('BA ~ SRMPA + Gender + Age + IS + Gender:SRMPA', missing='drop', data = main_test).fit()
print(srmpa.summary())

#calculate effect size
results = srmpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.562
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):             0.0253
# Time:                        16:46:27   Log-Likelihood:                -18541.
# No. Observations:                5452   AIC:                         3.709e+04
# Df Residuals:                    5446   BIC:                         3.713e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.5317      0.819      0.649      0.516      -1.073       2.137
# SRMPA        -2.895e-06      0.001     -0.004      0.997      -0.001       0.001
# Gender           0.7475      0.257      2.907      0.004       0.243       1.252
# Age             -0.0137      0.013     -1.060      0.289      -0.039       0.012
# IS               0.1112      0.122      0.913      0.361      -0.128       0.350
# Gender:SRMPA    -0.0005      0.001     -0.516      0.606      -0.003       0.001
# ==============================================================================
# Omnibus:                       60.402   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.012
# Skew:                           0.206   Prob(JB):                     1.03e-15
# Kurtosis:                       3.366   Cond. No.                     2.36e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.36e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.008794
# SRMPA          -0.000056
# Gender          0.039371
# Age            -0.014350
# IS              0.012370
# Gender:SRMPA   -0.006989
# dtype: float64

# %%
srvpa = ols('BA ~ SRVPA + Age + Gender + IS + Gender:SRVPA', missing='drop', data = main_test).fit()
print(srvpa.summary())

#calculate effect size
results = srvpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.543
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):             0.0263
# Time:                        16:46:27   Log-Likelihood:                -18541.
# No. Observations:                5452   AIC:                         3.709e+04
# Df Residuals:                    5446   BIC:                         3.713e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.6587      0.825      0.799      0.424      -0.958       2.275
# SRVPA           -0.0007      0.002     -0.397      0.691      -0.004       0.003
# Age             -0.0151      0.013     -1.179      0.239      -0.040       0.010
# Gender           0.6875      0.255      2.699      0.007       0.188       1.187
# IS               0.1135      0.122      0.932      0.351      -0.125       0.352
# Gender:SRVPA    -0.0001      0.002     -0.059      0.953      -0.005       0.004
# ==============================================================================
# Omnibus:                       60.578   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.193
# Skew:                           0.207   Prob(JB):                     9.44e-16
# Kurtosis:                       3.366   Cond. No.                     1.10e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.010819
# SRVPA          -0.005380
# Age            -0.015965
# Gender          0.036560
# IS              0.012623
# Gender:SRVPA   -0.000805
# dtype: float64

# %% [markdown]
# ## 7.2 PA+Fitness models

# %% [markdown]
# ### 7.2.1 PAF

# %%
paf = ols('BA ~ MPA + HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(paf.summary())

#calculate effect size
results = paf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     5.556
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):           3.69e-10
# Time:                        16:46:27   Log-Likelihood:                -18511.
# No. Observations:                5452   AIC:                         3.705e+04
# Df Residuals:                    5438   BIC:                         3.714e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.3093      1.778     -1.298      0.194      -5.796       1.177
# MPA           -0.0013      0.001     -1.959      0.050      -0.003    9.38e-07
# HG            -0.0239      0.022     -1.093      0.275      -0.067       0.019
# DBP            0.0406      0.014      2.867      0.004       0.013       0.068
# HR             0.0218      0.014      1.602      0.109      -0.005       0.048
# BMI            0.0197      0.032      0.608      0.543      -0.044       0.083
# Gender        -0.5485      2.277     -0.241      0.810      -5.012       3.915
# IS             0.1237      0.122      1.018      0.309      -0.115       0.362
# Age           -0.0318      0.013     -2.371      0.018      -0.058      -0.006
# HG:Gender     -0.0013      0.028     -0.045      0.964      -0.055       0.053
# DBP:Gender    -0.0087      0.021     -0.419      0.675      -0.049       0.032
# HR:Gender      0.0016      0.019      0.085      0.932      -0.035       0.038
# BMI:Gender     0.0855      0.053      1.627      0.104      -0.018       0.189
# MPA:Gender    -0.0004      0.001     -0.372      0.710      -0.002       0.002
# ==============================================================================
# Omnibus:                       65.241   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.437
# Skew:                           0.213   Prob(JB):                     4.16e-17
# Kurtosis:                       3.389   Cond. No.                     1.58e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.017585
# MPA          -0.026530
# HG           -0.014799
# DBP           0.038825
# HR            0.021696
# BMI           0.008234
# Gender       -0.003263
# IS            0.013786
# Age          -0.032116
# HG:Gender    -0.000616
# DBP:Gender   -0.005674
# HR:Gender     0.001149
# BMI:Gender    0.022029
# MPA:Gender   -0.005034
# dtype: float64

# %% [markdown]
# ### 7.2.2 SRPAF

# %%
srpaf = ols('BA ~ SRMPA + HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + SRMPA:Gender', missing='drop', data = main_test).fit()
print(srpaf.summary())

#calculate effect size
results = srpaf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     4.884
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):           1.40e-08
# Time:                        16:46:27   Log-Likelihood:                -18515.
# No. Observations:                5452   AIC:                         3.706e+04
# Df Residuals:                    5438   BIC:                         3.715e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -3.8232      1.676     -2.281      0.023      -7.108      -0.538
# SRMPA            0.0002      0.001      0.241      0.809      -0.001       0.002
# HG              -0.0255      0.022     -1.167      0.243      -0.068       0.017
# DBP              0.0396      0.014      2.797      0.005       0.012       0.067
# HR               0.0229      0.014      1.684      0.092      -0.004       0.050
# BMI              0.0365      0.031      1.166      0.244      -0.025       0.098
# Gender          -0.9004      2.161     -0.417      0.677      -5.137       3.336
# IS               0.1075      0.122      0.885      0.376      -0.131       0.346
# Age             -0.0242      0.013     -1.817      0.069      -0.050       0.002
# HG:Gender        0.0009      0.027      0.033      0.974      -0.053       0.055
# DBP:Gender      -0.0090      0.021     -0.432      0.666      -0.050       0.032
# HR:Gender        0.0028      0.019      0.150      0.880      -0.034       0.040
# BMI:Gender       0.0899      0.051      1.758      0.079      -0.010       0.190
# SRMPA:Gender    -0.0003      0.001     -0.314      0.754      -0.002       0.002
# ==============================================================================
# Omnibus:                       66.000   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.781
# Skew:                           0.212   Prob(JB):                     2.12e-17
# Kurtosis:                       3.397   Cond. No.                     7.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept      -0.030898
# SRMPA           0.003265
# HG             -0.015799
# DBP             0.037876
# HR              0.022813
# BMI             0.015796
# Gender         -0.005643
# IS              0.011982
# Age            -0.024606
# HG:Gender       0.000443
# DBP:Gender     -0.005848
# HR:Gender       0.002037
# BMI:Gender      0.023816
# SRMPA:Gender   -0.004250
# dtype: float64

# %% [markdown]
# ### 7.2.3 PAF / MPA

# %%
no_mpa = ols('BA ~ HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_mpa.summary())

#calculate effect size
results = no_mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.765
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):           2.45e-09
# Time:                        16:46:27   Log-Likelihood:                -18516.
# No. Observations:                5452   AIC:                         3.706e+04
# Df Residuals:                    5440   BIC:                         3.713e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.7758      1.669     -2.263      0.024      -7.047      -0.504
# HG            -0.0257      0.022     -1.176      0.239      -0.069       0.017
# DBP            0.0396      0.014      2.799      0.005       0.012       0.067
# HR             0.0228      0.014      1.676      0.094      -0.004       0.049
# BMI            0.0362      0.031      1.156      0.248      -0.025       0.097
# Gender        -0.9924      2.141     -0.464      0.643      -5.189       3.204
# IS             0.1075      0.121      0.885      0.376      -0.131       0.346
# Age           -0.0242      0.013     -1.837      0.066      -0.050       0.002
# HG:Gender      0.0010      0.027      0.038      0.970      -0.053       0.055
# DBP:Gender    -0.0089      0.021     -0.428      0.668      -0.050       0.032
# HR:Gender      0.0031      0.019      0.165      0.869      -0.034       0.040
# BMI:Gender     0.0904      0.051      1.770      0.077      -0.010       0.191
# ==============================================================================
# Omnibus:                       65.863   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.548
# Skew:                           0.212   Prob(JB):                     2.39e-17
# Kurtosis:                       3.396   Cond. No.                     3.57e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.030643
# HG           -0.015933
# DBP           0.037913
# HR            0.022703
# BMI           0.015660
# Gender       -0.006278
# IS            0.011991
# Age          -0.024872
# HG:Gender     0.000509
# DBP:Gender   -0.005801
# HR:Gender     0.002230
# BMI:Gender    0.023974
# dtype: float64

# %% [markdown]
# ### 7.2.4 PAF / HG

# %%
no_hg = ols('BA ~ MPA + DBP + HR + BMI + Gender + IS + Age + MPA:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hg.summary())

#calculate effect size
results = no_hg
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     6.272
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):           2.24e-10
# Time:                        16:46:27   Log-Likelihood:                -18513.
# No. Observations:                5452   AIC:                         3.705e+04
# Df Residuals:                    5440   BIC:                         3.713e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.2441      1.625     -1.997      0.046      -6.429      -0.059
# MPA           -0.0013      0.001     -2.022      0.043      -0.003   -3.93e-05
# DBP            0.0400      0.014      2.827      0.005       0.012       0.068
# HR             0.0220      0.014      1.614      0.107      -0.005       0.049
# BMI            0.0201      0.032      0.621      0.535      -0.043       0.084
# Gender        -0.9286      2.125     -0.437      0.662      -5.094       3.237
# IS             0.1213      0.121      0.999      0.318      -0.117       0.360
# Age           -0.0263      0.013     -2.024      0.043      -0.052      -0.001
# MPA:Gender    -0.0003      0.001     -0.311      0.756      -0.002       0.002
# DBP:Gender    -0.0100      0.021     -0.483      0.629      -0.051       0.031
# HR:Gender      0.0029      0.019      0.152      0.879      -0.034       0.040
# BMI:Gender     0.0831      0.053      1.582      0.114      -0.020       0.186
# ==============================================================================
# Omnibus:                       63.310   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.901
# Skew:                           0.210   Prob(JB):                     1.48e-16
# Kurtosis:                       3.380   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.027039
# MPA          -0.027386
# DBP           0.038290
# HR            0.021858
# BMI           0.008408
# Gender       -0.005918
# IS            0.013525
# Age          -0.027409
# MPA:Gender   -0.004213
# DBP:Gender   -0.006546
# HR:Gender     0.002061
# BMI:Gender    0.021430
# dtype: float64

# %% [markdown]
# ### 7.2.5 PAF / HR

# %%
no_hr = ols('BA ~ HG + DBP + MPA + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + MPA:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hr.summary())

#calculate effect size
results = no_hr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     6.035
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):           6.88e-10
# Time:                        16:46:27   Log-Likelihood:                -18514.
# No. Observations:                5452   AIC:                         3.705e+04
# Df Residuals:                    5440   BIC:                         3.713e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.2999      1.668     -0.779      0.436      -4.570       1.970
# HG            -0.0244      0.022     -1.114      0.265      -0.067       0.019
# DBP            0.0453      0.014      3.267      0.001       0.018       0.072
# MPA           -0.0013      0.001     -2.021      0.043      -0.003    -3.9e-05
# BMI            0.0264      0.032      0.821      0.412      -0.037       0.089
# Gender        -0.6576      2.138     -0.308      0.758      -4.849       3.534
# IS             0.1261      0.121      1.038      0.299      -0.112       0.364
# Age           -0.0322      0.013     -2.397      0.017      -0.058      -0.006
# HG:Gender     -0.0031      0.028     -0.114      0.909      -0.057       0.051
# DBP:Gender    -0.0063      0.020     -0.314      0.753      -0.046       0.033
# MPA:Gender    -0.0004      0.001     -0.449      0.654      -0.002       0.001
# BMI:Gender     0.0880      0.052      1.688      0.091      -0.014       0.190
# ==============================================================================
# Omnibus:                       63.600   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.304
# Skew:                           0.210   Prob(JB):                     1.21e-16
# Kurtosis:                       3.382   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.010555
# HG           -0.015088
# DBP           0.044248
# MPA          -0.027377
# BMI           0.011119
# Gender       -0.004165
# IS            0.014057
# Age          -0.032464
# HG:Gender    -0.001542
# DBP:Gender   -0.004256
# MPA:Gender   -0.006078
# BMI:Gender    0.022862
# dtype: float64

# %% [markdown]
# ### 7.2.6 PAF / DBP

# %%
no_dbp = ols('BA ~ HG + MPA + HR + BMI + Gender + IS + Age + HG:Gender + MPA:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_dbp.summary())

#calculate effect size
results = no_dbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     5.413
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):           1.27e-08
# Time:                        16:46:27   Log-Likelihood:                -18517.
# No. Observations:                5452   AIC:                         3.706e+04
# Df Residuals:                    5440   BIC:                         3.714e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.6042      1.668     -0.362      0.717      -3.875       2.666
# HG            -0.0219      0.022     -1.001      0.317      -0.065       0.021
# MPA           -0.0012      0.001     -1.877      0.061      -0.002    5.31e-05
# HR             0.0298      0.013      2.235      0.025       0.004       0.056
# BMI            0.0453      0.031      1.457      0.145      -0.016       0.106
# Gender        -0.9148      2.034     -0.450      0.653      -4.903       3.073
# IS             0.1393      0.122      1.146      0.252      -0.099       0.378
# Age           -0.0286      0.013     -2.132      0.033      -0.055      -0.002
# HG:Gender      0.0001      0.028      0.005      0.996      -0.054       0.054
# MPA:Gender    -0.0003      0.001     -0.360      0.719      -0.002       0.002
# HR:Gender      0.0006      0.018      0.035      0.972      -0.035       0.037
# BMI:Gender     0.0768      0.051      1.499      0.134      -0.024       0.177
# ==============================================================================
# Omnibus:                       65.203   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.551
# Skew:                           0.212   Prob(JB):                     3.93e-17
# Kurtosis:                       3.391   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.004905
# HG           -0.013557
# MPA          -0.025424
# HR            0.030274
# BMI           0.019726
# Gender       -0.006090
# IS            0.015520
# Age          -0.028869
# HG:Gender     0.000063
# MPA:Gender   -0.004880
# HR:Gender     0.000472
# BMI:Gender    0.020301
# dtype: float64

# %% [markdown]
# ### 7.2.7 PAF / BMI

# %%
no_bmi = ols('BA ~ HG + DBP + HR + MPA + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(no_bmi.summary())

#calculate effect size
results = no_bmi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     5.944
# Date:                Tue, 08 Aug 2023   Prob (F-statistic):           1.06e-09
# Time:                        16:46:27   Log-Likelihood:                -18515.
# No. Observations:                5452   AIC:                         3.705e+04
# Df Residuals:                    5440   BIC:                         3.713e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.9061      1.698     -1.122      0.262      -5.235       1.423
# HG            -0.0244      0.022     -1.113      0.266      -0.067       0.019
# DBP            0.0430      0.014      3.161      0.002       0.016       0.070
# HR             0.0229      0.013      1.694      0.090      -0.004       0.049
# MPA           -0.0014      0.001     -2.200      0.028      -0.003      -0.000
# Gender         1.2043      2.073      0.581      0.561      -2.861       5.269
# IS             0.1200      0.122      0.988      0.323      -0.118       0.358
# Age           -0.0333      0.013     -2.484      0.013      -0.060      -0.007
# HG:Gender      0.0008      0.028      0.030      0.976      -0.053       0.055
# DBP:Gender    -0.0037      0.020     -0.182      0.855      -0.043       0.036
# HR:Gender      0.0046      0.019      0.246      0.806      -0.032       0.041
# MPA:Gender    -0.0007      0.001     -0.719      0.472      -0.002       0.001
# ==============================================================================
# Omnibus:                       65.317   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.252
# Skew:                           0.214   Prob(JB):                     4.56e-17
# Kurtosis:                       3.384   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.015201
# HG           -0.015078
# DBP           0.042811
# HR            0.022943
# MPA          -0.029801
# Gender        0.007866
# IS            0.013379
# Age          -0.033635
# HG:Gender     0.000405
# DBP:Gender   -0.002468
# HR:Gender     0.003334
# MPA:Gender   -0.009744
# dtype: float64

# %% [markdown]
# # 8 Model comparisons

# %% [markdown]
# ## 8.1 Cov vs. PA

# %%
model_comparison = anova_lm(cov_model, lpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  287043.202068      0.0        NaN       NaN       NaN
# 1    5446.0  287013.789881      2.0  29.412187  0.279044  0.756518

# %%
model_comparison = anova_lm(cov_model, mpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F   Pr(>F)
# 0    5448.0  287043.202068      0.0        NaN       NaN      NaN
# 1    5446.0  286116.252778      2.0  926.94929  8.821879  0.00015

# %%
model_comparison = anova_lm(cov_model, vpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F   Pr(>F)
# 0    5448.0  287043.202068      0.0         NaN       NaN      NaN
# 1    5446.0  286885.712431      2.0  157.489636  1.494826  0.22438

# %% [markdown]
# ## 8.2 Cov vs. SRPA

# %%
model_comparison = anova_lm(cov_model, srlpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff   ss_diff         F    Pr(>F)
# 0    5448.0  287043.202068      0.0       NaN       NaN       NaN
# 1    5446.0  287033.708580      2.0  9.493487  0.090062  0.913876

# %%
model_comparison = anova_lm(cov_model, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  287043.202068      0.0        NaN       NaN       NaN
# 1    5446.0  287016.985174      2.0  26.216893  0.248726  0.779802

# %%
model_comparison = anova_lm(cov_model, srvpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  287043.202068      0.0        NaN       NaN       NaN
# 1    5446.0  287021.842219      2.0  21.359849  0.202643  0.816576

# %% [markdown]
# # 9 PAF Type-III ANOVA

# %% [markdown]
# ## 9.1 PAF / MPA

# %%
model_comparison = anova_lm(no_mpa, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  284377.160945      0.0         NaN       NaN       NaN
# 1    5438.0  283920.685211      2.0  456.475734  4.371494  0.012677

# %% [markdown]
# ## 9.2 SR PAF / SRMPA

# %%
model_comparison = anova_lm(no_mpa, srpaf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff   ss_diff         F    Pr(>F)
# 0    5440.0  284377.160945      0.0       NaN       NaN       NaN
# 1    5438.0  284371.931818      2.0  5.229128  0.049998  0.951232

# %% [markdown]
# ## 9.3 PAF / HG

# %%
model_comparison = anova_lm(no_hg, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  284089.296213      0.0         NaN       NaN       NaN
# 1    5438.0  283920.685211      2.0  168.611002  1.614723  0.199041

# %% [markdown]
# ## 9.4 PAF / DBP

# %%
model_comparison = anova_lm(no_dbp, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  284577.251557      0.0         NaN       NaN       NaN
# 1    5438.0  283920.685211      2.0  656.566346  6.287685  0.001873

# %% [markdown]
# ## 9.5 PAF / HR

# %%
model_comparison = anova_lm(no_hr, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  284223.763067      0.0         NaN       NaN       NaN
# 1    5438.0  283920.685211      2.0  303.077856  2.902461  0.054973

# %% [markdown]
# ## 9.6 PAF / BMI

# %%
model_comparison = anova_lm(no_bmi, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  284275.544525      0.0         NaN       NaN       NaN
# 1    5438.0  283920.685211      2.0  354.859313  3.398352  0.033499

# %% [markdown]
# # 10 Standardization of all variables

# %%
main_test = pd.DataFrame(main_test)
main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Gender","IS"]] = stats.zscore(main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Gender","IS"]], nan_policy='omit')

# %% [markdown]
# # 11 Mediation analysis

# %% [markdown]
# ## 11.1 BMI

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + LPA + Gender + Age", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ LPA + Gender + Age", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.074714       -0.119017       -0.038095    0.000
# ACME (treated)           -0.074714       -0.119017       -0.038095    0.000
# ADE (control)             0.006648       -0.200289        0.203359    0.954
# ADE (treated)             0.006648       -0.200289        0.203359    0.954
# Total effect             -0.068066       -0.267680        0.129164    0.514
# Prop. mediated (control)  0.535991       -7.541899        8.802521    0.514
# Prop. mediated (treated)  0.535991       -7.541899        8.802521    0.514
# ACME (average)           -0.074714       -0.119017       -0.038095    0.000
# ADE (average)             0.006648       -0.200289        0.203359    0.954
# Prop. mediated (average)  0.535991       -7.541899        8.802521    0.514

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.098737       -0.156404       -0.047589    0.000
# ACME (treated)           -0.098737       -0.156404       -0.047589    0.000
# ADE (control)            -0.305451       -0.508199       -0.106897    0.002
# ADE (treated)            -0.305451       -0.508199       -0.106897    0.002
# Total effect             -0.404188       -0.603165       -0.216589    0.000
# Prop. mediated (control)  0.241599        0.099143        0.534555    0.000
# Prop. mediated (treated)  0.241599        0.099143        0.534555    0.000
# ACME (average)           -0.098737       -0.156404       -0.047589    0.000
# ADE (average)            -0.305451       -0.508199       -0.106897    0.002
# Prop. mediated (average)  0.241599        0.099143        0.534555    0.000

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + VPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ VPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.090642       -0.138966       -0.046650    0.000
# ACME (treated)           -0.090642       -0.138966       -0.046650    0.000
# ADE (control)            -0.068646       -0.275188        0.139718    0.534
# ADE (treated)            -0.068646       -0.275188        0.139718    0.534
# Total effect             -0.159288       -0.357962        0.049191    0.116
# Prop. mediated (control)  0.520305       -2.381767        5.468879    0.116
# Prop. mediated (treated)  0.520305       -2.381767        5.468879    0.116
# ACME (average)           -0.090642       -0.138966       -0.046650    0.000
# ADE (average)            -0.068646       -0.275188        0.139718    0.534
# Prop. mediated (average)  0.520305       -2.381767        5.468879    0.116

# %% [markdown]
# ## 11.2 DBP

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + LPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ LPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.036812       -0.067549       -0.012942    0.000
# ACME (treated)           -0.036812       -0.067549       -0.012942    0.000
# ADE (control)            -0.036082       -0.232194        0.150731    0.726
# ADE (treated)            -0.036082       -0.232194        0.150731    0.726
# Total effect             -0.072894       -0.271876        0.120303    0.448
# Prop. mediated (control)  0.268302       -2.545100        3.955034    0.448
# Prop. mediated (treated)  0.268302       -2.545100        3.955034    0.448
# ACME (average)           -0.036812       -0.067549       -0.012942    0.000
# ADE (average)            -0.036082       -0.232194        0.150731    0.726
# Prop. mediated (average)  0.268302       -2.545100        3.955034    0.448

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.027687       -0.056841       -0.005930    0.016
# ACME (treated)           -0.027687       -0.056841       -0.005930    0.016
# ADE (control)            -0.381673       -0.588729       -0.180786    0.000
# ADE (treated)            -0.381673       -0.588729       -0.180786    0.000
# Total effect             -0.409360       -0.618554       -0.201919    0.000
# Prop. mediated (control)  0.066070        0.013394        0.161050    0.016
# Prop. mediated (treated)  0.066070        0.013394        0.161050    0.016
# ACME (average)           -0.027687       -0.056841       -0.005930    0.016
# ADE (average)            -0.381673       -0.588729       -0.180786    0.000
# Prop. mediated (average)  0.066070        0.013394        0.161050    0.016

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + VPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ VPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.041868       -0.071425       -0.017644    0.000
# ACME (treated)           -0.041868       -0.071425       -0.017644    0.000
# ADE (control)            -0.115964       -0.319089        0.081631    0.266
# ADE (treated)            -0.115964       -0.319089        0.081631    0.266
# Total effect             -0.157832       -0.356683        0.044889    0.118
# Prop. mediated (control)  0.235321       -1.023475        3.159387    0.118
# Prop. mediated (treated)  0.235321       -1.023475        3.159387    0.118
# ACME (average)           -0.041868       -0.071425       -0.017644    0.000
# ADE (average)            -0.115964       -0.319089        0.081631    0.266
# Prop. mediated (average)  0.235321       -1.023475        3.159387    0.118

# %% [markdown]
# ## 11.3 Heart rate

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + LPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("HR ~ LPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.028229       -0.052829       -0.007031    0.002
# ACME (treated)           -0.028229       -0.052829       -0.007031    0.002
# ADE (control)            -0.046983       -0.241823        0.141830    0.632
# ADE (treated)            -0.046983       -0.241823        0.141830    0.632
# Total effect             -0.075212       -0.270747        0.113249    0.456
# Prop. mediated (control)  0.195839       -3.335386        3.042206    0.458
# Prop. mediated (treated)  0.195839       -3.335386        3.042206    0.458
# ACME (average)           -0.028229       -0.052829       -0.007031    0.002
# ADE (average)            -0.046983       -0.241823        0.141830    0.632
# Prop. mediated (average)  0.195839       -3.335386        3.042206    0.458

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("HR ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.043277       -0.074509       -0.018770      0.0
# ACME (treated)           -0.043277       -0.074509       -0.018770      0.0
# ADE (control)            -0.364942       -0.562835       -0.152401      0.0
# ADE (treated)            -0.364942       -0.562835       -0.152401      0.0
# Total effect             -0.408219       -0.604190       -0.196314      0.0
# Prop. mediated (control)  0.104569        0.042583        0.248785      0.0
# Prop. mediated (treated)  0.104569        0.042583        0.248785      0.0
# ACME (average)           -0.043277       -0.074509       -0.018770      0.0
# ADE (average)            -0.364942       -0.562835       -0.152401      0.0
# Prop. mediated (average)  0.104569        0.042583        0.248785      0.0

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + VPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("HR ~ VPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.073636       -0.114799       -0.039272     0.00
# ACME (treated)           -0.073636       -0.114799       -0.039272     0.00
# ADE (control)            -0.087993       -0.285185        0.110852     0.39
# ADE (treated)            -0.087993       -0.285185        0.110852     0.39
# Total effect             -0.161629       -0.358946        0.036920     0.11
# Prop. mediated (control)  0.416931       -2.452798        4.358764     0.11
# Prop. mediated (treated)  0.416931       -2.452798        4.358764     0.11
# ACME (average)           -0.073636       -0.114799       -0.039272     0.00
# ADE (average)            -0.087993       -0.285185        0.110852     0.39
# Prop. mediated (average)  0.416931       -2.452798        4.358764     0.11

# %% [markdown]
# ## 11.4 Hand grip

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + LPA + Gender + Age", main_test)
mediator_model = sm.OLS.from_formula("HG ~ LPA + Gender + Age", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "LPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.004166       -0.003815        0.017019    0.376
# ACME (treated)            0.004166       -0.003815        0.017019    0.376
# ADE (control)            -0.078057       -0.260271        0.113016    0.404
# ADE (treated)            -0.078057       -0.260271        0.113016    0.404
# Total effect             -0.073891       -0.255320        0.114863    0.416
# Prop. mediated (control) -0.018689       -0.566499        0.391738    0.644
# Prop. mediated (treated) -0.018689       -0.566499        0.391738    0.644
# ACME (average)            0.004166       -0.003815        0.017019    0.376
# ADE (average)            -0.078057       -0.260271        0.113016    0.404
# Prop. mediated (average) -0.018689       -0.566499        0.391738    0.644

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + MPA + Gender + Age", main_test)
mediator_model = sm.OLS.from_formula("HG ~ MPA + Gender + Age", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "MPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.002024       -0.011774        0.006118    0.586
# ACME (treated)           -0.002024       -0.011774        0.006118    0.586
# ADE (control)            -0.405783       -0.603023       -0.209343    0.000
# ADE (treated)            -0.405783       -0.603023       -0.209343    0.000
# Total effect             -0.407806       -0.602950       -0.211511    0.000
# Prop. mediated (control)  0.003593       -0.015822        0.030342    0.586
# Prop. mediated (treated)  0.003593       -0.015822        0.030342    0.586
# ACME (average)           -0.002024       -0.011774        0.006118    0.586
# ADE (average)            -0.405783       -0.603023       -0.209343    0.000
# Prop. mediated (average)  0.003593       -0.015822        0.030342    0.586

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + VPA + Gender + Age", main_test)
mediator_model = sm.OLS.from_formula("HG ~ VPA + Gender + Age", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "VPA").fit()
print(res.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.005965       -0.019400        0.002426    0.214
# ACME (treated)           -0.005965       -0.019400        0.002426    0.214
# ADE (control)            -0.151574       -0.353271        0.054117    0.158
# ADE (treated)            -0.151574       -0.353271        0.054117    0.158
# Total effect             -0.157539       -0.364997        0.048563    0.144
# Prop. mediated (control)  0.026838       -0.203682        0.290029    0.326
# Prop. mediated (treated)  0.026838       -0.203682        0.290029    0.326
# ACME (average)           -0.005965       -0.019400        0.002426    0.214
# ADE (average)            -0.151574       -0.353271        0.054117    0.158
# Prop. mediated (average)  0.026838       -0.203682        0.290029    0.326

# %% [markdown]
# # 12 LASSO Regression

# %% [markdown]
# ## 12.1 Accelerometer PA

# %%
df = main_test[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# lasso with cross validated alpha

lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.0030538555088334154
# [-0.24108213  0.43376731  0.09781845 -0.30296597  0.25398764  0.37237165
#  -0.24395214  0.21364354]
# 0.012488666106534985

# %% [markdown]
# ## 12.2 Self-report PA

# %%
df = main_test[["Age", "Gender", "IS", "LPA", "MPA", "VPA",  "SRLPA", "SRMPA", "SRVPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('viridis')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, loc="upper right")
plt.show()

# lasso with cross validated alpha

lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.021544346900318846
# [-0.14359105  0.36118782  0.06200946 -0.          0.25881605  0.35030971
#  -0.16784644  0.27964444]
# 0.010794271576496484

# %% [markdown]
# # 13 Pickle

# %%
main_test.to_pickle("3_validate.pkl")
