# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from random import seed
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, Lasso
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm
from statsmodels.formula.api import ols
from statsmodels.regression import linear_model
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from statsmodels.stats.mediation import Mediation
from sklearn.svm import SVR
from pingouin import ancova
import matplotlib.cm as cm
from scipy.stats import pearsonr
# %matplotlib inline

seed(888)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1 Load validation set

# %%
# load data from pickle and convert to dataframe
brain_test = pd.read_pickle("brain_test_validate.pkl")
main_test = pd.read_pickle("main_test_validate.pkl")
brain_train = pd.read_pickle("1_brain_train.pkl")
brain_test = pd.DataFrame(brain_test)
main_test = pd.DataFrame(main_test)
brain_train = pd.DataFrame(brain_train)

# %% [markdown]
# # 2 BrainAGE prediction Destrieux

# %%
# select variables belonging to A2009s segmentation
X_train = brain_train.iloc[:,1657:2544:2]
Y_train = brain_train.iloc[:,-1]
X_test = brain_test.iloc[:,1657:2544:2]
Y_test = brain_test.iloc[:,-1]

# standardize x-data
X_train = stats.zscore(X_train)
X_test = stats.zscore(X_test)

# set of alphas to try (=penalization)
alpha_parameters = np.power(10,np.linspace(start=-3, stop=5, num=100))

# %% [markdown]
# ## 2.1 Cross-validation

# %%
X_CV = X_train
Y_CV = Y_train

# randomly split data (only training no PA) into training and testing set
X_train_cv, X_test_cv, Y_train_cv, Y_test_cv = train_test_split(X_CV,Y_CV)

#define the model
model_ridge = RidgeCV(alphas = alpha_parameters)

#perform 10-fold cross validation
scores_ridge = cross_val_score(model_ridge, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')

#calculate the mean-absolute error
mae_ridge = -1 * scores_ridge.mean()

print("The MAE for cross-validation (Ridge):", mae_ridge)

# for correction
model_ridge.fit(X_train_cv,Y_train_cv)
y_pred_cv = model_ridge.predict(X_test_cv)
# Out:
# The MAE for cross-validation (Ridge): 4.192981026915527

# %% [markdown]
# ## 2.2 Prediction

# %%
# initialize models
model_Ridge = RidgeCV(alphas = alpha_parameters)

# train model 
model_Ridge.fit(X_train,Y_train)

# get predicted values for test set
y_pred_Ridge = model_Ridge.predict(X_test)

# calculate brain age gap
brain_age_delta_Ridge = y_pred_Ridge-Y_test

# get mean absolute error (MAE)
print("The MAE for testing set using Ridge:", mean_absolute_error(Y_test,y_pred_Ridge))

# top x coefficients and their names
coeff = np.asarray(model_Ridge.coef_)
coeffabs = np.asarray(abs(model_Ridge.coef_))
top_coefficients = np.argsort(coeffabs)[-20:]
print(X_train.iloc[:,top_coefficients].columns)
print(coeff[top_coefficients])

# plot figure with x: actual age Y: predicted age, and a line with slope 1 for reference
plt.figure()
plt.scatter(Y_test, y_pred_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((60,60), slope=1, color='r')
plt.xticks(range(40,90,5))
plt.yticks(range(40,90,5))
plt.ylabel('Predicted Age', fontsize = 16)
plt.xlabel('Age', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()

plt.figure()
plt.scatter(Y_test,brain_age_delta_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((65,0), slope=-0.69, color="blue")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# The MAE for testing set using Ridge: 4.262589702409484
# Index(['volume_of_gtemporalinf_left_hemisphere_f27513_2_0',
#        'volume_of_scentral_right_hemisphere_f27743_2_0',
#        'volume_of_gpostcentral_right_hemisphere_f27726_2_0',
#        'area_of_gtemporalinf_left_hemisphere_f27365_2_0',
#        'mean_thickness_of_gfrontsup_left_hemisphere_f27418_2_0',
#        'area_of_latfispost_right_hemisphere_f27591_2_0',
#        'volume_of_stemporalsup_left_hemisphere_f27549_2_0',
#        'area_of_stemporalsup_left_hemisphere_f27401_2_0',
#        'area_of_sparietooccipital_right_hemisphere_f27615_2_0',
#        'area_of_gscingulant_right_hemisphere_f27556_2_0',
#        'area_of_scalcarine_left_hemisphere_f27372_2_0',
#        'volume_of_scalcarine_left_hemisphere_f27520_2_0',
#        'volume_of_gfrontsup_left_hemisphere_f27492_2_0',
#        'volume_of_gscingulant_right_hemisphere_f27704_2_0',
#        'area_of_gfrontsup_left_hemisphere_f27344_2_0',
#        'volume_of_sparietooccipital_right_hemisphere_f27763_2_0',
#        'volume_of_scentral_left_hemisphere_f27521_2_0',
#        'volume_of_latfispost_right_hemisphere_f27739_2_0',
#        'area_of_scalcarine_right_hemisphere_f27594_2_0',
#        'volume_of_scalcarine_right_hemisphere_f27742_2_0'],
#       dtype='object')
# [ 1.33500311  1.35589929 -1.40956036 -1.41335742 -1.4290742  -1.49188128
#  -1.49429486  1.5138274  -1.53084042  1.55013063 -1.58490537  1.58906398
#   1.60619697 -1.67635603 -1.749753    1.75977046  1.86033162  2.16152389
#  -2.37541509  2.37603676]

# %% [markdown]
# ## 2.3 Correction

# %%
# reformat cross validation data for regression model
y_pred_cv = np.asarray(y_pred_cv)
y_pred_cv = np.reshape(y_pred_cv, (-1,1))
Y_test_cv = np.asarray(Y_test_cv)
Y_test_cv = np.reshape(Y_test_cv, (-1,1))

# now using correction from the R code that's online from Cole
reg = LinearRegression().fit(Y_test_cv, y_pred_cv)
coef = float(reg.coef_)
intercept = float(reg.intercept_)
print("Coefficient and Intercept:", coef, intercept)

# correction by cole
function = lambda t: (t-intercept)/coef
vfunc = np.vectorize(function)
corr_brainage_1 = vfunc(y_pred_Ridge)
corr_brainage_delta_1 = corr_brainage_1-Y_test

# plots corrected
plt.figure()
plt.scatter(Y_test, corr_brainage_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((65,65), slope=coef, color="blue")
plt.ylabel("Predicted Age Corrected", fontsize = 16)
plt.axline((60,60), slope=1, color='r')
plt.xlabel("Age", fontsize = 16)
plt.xticks(range(40,90,5))
plt.yticks(range(30,115,10))
plt.show()

plt.figure()
plt.scatter(Y_test, corr_brainage_delta_1, alpha=0.5, s=10, color="darkcyan")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE Corrected", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# Coefficient and Intercept: 0.5322831480071359 30.056471148163197

# %% [markdown]
# ## 2.4 Add BrainAge Delta to Dataframe

# %%
#main_test["BA"] = corr_brainage_delta_1

# %% [markdown]
# ## 2.5 Combined BA Delta

# %%
# select Freesurfer ASEG for training data
whole_brain = brain_train.iloc[:,27:70:2]
left_hemi = brain_train.iloc[:,103:134:2]
right_hemi = brain_train.iloc[:,165:196:2]
age = brain_train["Age"]
ASEG_train = pd.DataFrame(pd.concat([whole_brain,left_hemi, right_hemi,age],axis = 1))

# select Freesurfer ASEG for testing data
whole_brain = brain_test.iloc[:,27:70:2]
left_hemi = brain_test.iloc[:,103:134:2]
right_hemi = brain_test.iloc[:,165:196:2]
age = brain_test["Age"]
ASEG_test = pd.DataFrame(pd.concat([whole_brain,left_hemi, right_hemi,age],axis = 1))

ASEG_X_train = ASEG_train.iloc[:,:-1]
ASEG_X_test = ASEG_test.iloc[:,:-1]


# select variables belonging to the A2009s segmentation
Des_X_train = brain_train.iloc[:,1657:2544:2]
Des_X_test = brain_test.iloc[:,1657:2544:2]


# select age
Y_train = brain_train.iloc[:,-1]
Y_test = brain_test.iloc[:,-1]

# Combine ASEG and A2009s for training data
X_train = pd.concat([ASEG_X_train, Des_X_train], axis=1)
Y_train = Y_train

# Combine ASEG and A2009s for testing data
X_test = pd.concat([ASEG_X_test, Des_X_test], axis=1)
Y_test = Y_test

# standardize x-data
X_train = stats.zscore(X_train)
X_test = stats.zscore(X_test)

# set of alphas to try (=penalization)
alpha_parameters = np.power(10,np.linspace(start=-3, stop=5, num=100))

# %%
X_CV = X_train
Y_CV = Y_train

# randomly split data (only training no PA) into training and testing set
X_train_cv, X_test_cv, Y_train_cv, Y_test_cv = train_test_split(X_CV,Y_CV)

# define the model
model_ridge = RidgeCV(alphas = alpha_parameters)

# perform 10-fold cross validation
scores_ridge = cross_val_score(model_ridge, X_CV, Y_CV, cv=10, scoring='neg_mean_absolute_error')

# calculate the mean-absolute error
mae_ridge = -1 * scores_ridge.mean()

print("The MAE for cross-validation (Ridge):", mae_ridge)

# for correction
model_ridge.fit(X_train_cv,Y_train_cv)
y_pred_cv = model_ridge.predict(X_test_cv)
# Out:
# The MAE for cross-validation (Ridge): 3.73656425547509

# %%
model_Ridge = RidgeCV(alphas = alpha_parameters)

# train model 
model_Ridge.fit(X_train,Y_train)

# get predicted values for test set
y_pred_Ridge = model_Ridge.predict(X_test)

# calculate brain age gap
brain_age_delta_Ridge = y_pred_Ridge-Y_test

# get mean absolute error (MAE)
print("The MAE for testing set using Ridge:", mean_absolute_error(Y_test,y_pred_Ridge))

# top x coefficients and their names
coeff = np.asarray(model_Ridge.coef_)
coeffabs = np.asarray(abs(model_Ridge.coef_))
top_coefficients = np.argsort(coeffabs)[-20:]
print(X_train.iloc[:,top_coefficients].columns)
print(coeff[top_coefficients])

# plot figure with x: actual age Y: predicted age, and a line with slope 1 for reference
plt.figure()
plt.scatter(Y_test, y_pred_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((60,60), slope=1, color='r')
plt.xticks(range(40,90,5))
plt.yticks(range(40,95,5))
plt.ylabel('Predicted Age', fontsize = 16)
plt.xlabel('Age', fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()

# plot the brainAGE and a line with the correlation between brainAGE and age 
plt.figure()
plt.scatter(Y_test,brain_age_delta_Ridge, alpha=0.5, s=10, color = "darkcyan")
plt.axline((65,0), slope=-0.69, color="blue")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# The MAE for testing set using Ridge: 3.8495727593131943
# Index(['volume_of_putamen_left_hemisphere_f26560_2_0',
#        'volume_of_brainstem_whole_brain_f26526_2_0',
#        'volume_of_putamen_right_hemisphere_f26591_2_0',
#        'volume_of_ventraldc_right_hemisphere_f26596_2_0',
#        'volume_of_supratentorialnotvent_whole_brain_f26520_2_0',
#        'volume_of_thalamusproper_left_hemisphere_f26558_2_0',
#        'volume_of_thalamusproper_right_hemisphere_f26589_2_0',
#        'volume_of_supratentorial_whole_brain_f26519_2_0',
#        'volume_of_cortex_right_hemisphere_f26583_2_0',
#        'volume_of_cortex_left_hemisphere_f26552_2_0',
#        'volume_of_totalgray_whole_brain_f26518_2_0',
#        'volume_of_brainsegnotvent_whole_brain_f26515_2_0',
#        'volume_of_cerebralwhitematter_left_hemisphere_f26553_2_0',
#        'volume_of_brainseg_whole_brain_f26514_2_0',
#        'volume_of_cerebralwhitematter_right_hemisphere_f26584_2_0',
#        'volume_of_subcortgray_whole_brain_f26517_2_0',
#        'volume_of_lateralventricle_right_hemisphere_f26585_2_0',
#        'volume_of_lateralventricle_left_hemisphere_f26554_2_0',
#        'volume_of_ventriclechoroid_whole_brain_f26522_2_0',
#        'volume_of_brainsegnotventsurf_whole_brain_f26516_2_0'],
#       dtype='object')
# [ -2.26860126   2.39696434  -2.50775638  -2.73702095  -2.79581218
#   -3.18768567  -3.46072034   4.47572726   5.88380517  -7.24909472
#   -9.94656768 -10.80662041 -11.75101437  12.15655364 -13.17155378
#   17.63982205 -19.89223201 -23.21030878  42.26283551  48.04208732]

# %%
# reformat cross validation data for regression model
y_pred_cv = np.asarray(y_pred_cv)
y_pred_cv = np.reshape(y_pred_cv, (-1,1))
Y_test_cv = np.asarray(Y_test_cv)
Y_test_cv = np.reshape(Y_test_cv, (-1,1))

# now using correction from the R code that's online from Cole
reg = LinearRegression().fit(Y_test_cv, y_pred_cv)
coef = float(reg.coef_)
intercept = float(reg.intercept_)
print("Coefficient and Intercept:", coef, intercept)

# correction by cole
function = lambda t: (t-intercept)/coef
vfunc = np.vectorize(function)
corr_brainage_4 = vfunc(y_pred_Ridge)
corr_brainage_delta_4 = corr_brainage_4-Y_test

# plots corrected
plt.figure()
plt.scatter(Y_test, corr_brainage_4, alpha=0.5, s=10, color="darkcyan")
plt.axline((65,65), slope=coef, color="blue")
plt.ylabel("Predicted Age Corrected", fontsize = 16)
plt.axline((60,60), slope=1, color='r')
plt.xlabel("Age", fontsize = 16)
plt.xticks(range(40,90,5), fontsize = 14)
plt.yticks(range(30,115,10), fontsize = 14)
plt.show()

plt.figure()
plt.scatter(Y_test, corr_brainage_delta_4, alpha=0.5, s=10, color="darkcyan")
plt.axline((60,0),slope=0, color = "black")
plt.ylabel("BrainAGE Corrected", fontsize = 16)
plt.xlabel("Age", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# Coefficient and Intercept: 0.6342162045915982 23.676656722126673

# %%
main_test["BA"] = corr_brainage_delta_4

# %% [markdown]
# # 3 Preprocessing

# %% [markdown]
# ## 3.1 Recoding

# %%
# recoding imaging site and gender
# 1 = Cheadle;  2 = Reading;  3 = Newcastle;  4 = Bristol
main_test['IS'] = main_test['IS'].map({'11025': 0, '11026': 1,'11027': 2, '11028': 3})
main_test["Gender"] = main_test["Gender"].map({"Female":0, "Male":1})
main_test["Gender"] = main_test["Gender"].astype("int")

# delete unnecessary variables
del main_test["ID"]
del main_test["MVPA"]
del main_test["TPA"]

# %% [markdown]
# ## 3.2 Remove outliers on SRPA

# %%
# remove outliers on self-reported physical activity data for each intensity seperately
before = main_test.shape[0]
outlier = np.mean(main_test["SRLPA"]) + np.std(main_test["SRLPA"])*3
main_test = main_test[main_test["SRLPA"]<outlier]
outlier = np.mean(main_test["SRMPA"]) + np.std(main_test["SRMPA"])*3
main_test = main_test[main_test["SRMPA"]<outlier]
outlier = np.mean(main_test["SRVPA"]) + np.std(main_test["SRVPA"])*3
main_test = main_test[main_test["SRVPA"]<outlier]
after = main_test.shape[0]
print("Outliers on self-reported PA:", before-after)
print(after)
# Out:
# Outliers on self-reported PA: 532
# 5452

# %% [markdown]
# ## 3.3 Convert SRPA from MET min/week to min/week

# %%
main_test["SRLPA"] = main_test["SRLPA"]/3.3
main_test["SRMPA"] = main_test["SRMPA"]/4
main_test["SRVPA"] = main_test["SRVPA"]/8

# %% [markdown]
# ## 3.4 Remove people with Gender other than Male or Female

# %%
before = main_test.shape[0]
main_test = main_test[(main_test["Gender"] == 0) | (main_test["Gender"] == 1)]
after = main_test.shape[0]
print("Gender not Male or Female:", before-after)
print(after)
# Out:
# Gender not Male or Female: 0
# 5452

# %% [markdown]
# # 4 Basic distributions of validation set

# %% [markdown]
# ## 4.1 Data and Descriptives

# %%
main_test.head()
# Out:
#         Age  Gender  IS      VPA       MPA        LPA  SRLPA  SRMPA  SRVPA  \
# 4723   73.0       0   0  59.2704  661.8528  2400.4512  315.0   90.0    0.0
# 25494  55.0       1   0  70.0560  970.7760  1991.5920  120.0   30.0    0.0
# 34463  65.0       0   1  48.6720  506.1888  2813.2416  420.0  840.0  160.0
# 26337  67.0       0   2   0.0000   60.4800  1653.1200   40.0   60.0    0.0
# 29224  70.0       0   1   9.2736  361.6704  1873.2672   30.0    0.0   45.0
#
#          HG    HR      BMI   DBP    SBP        BA
# 4723   20.0  52.0  25.1338  74.0  137.0  0.116661
# 25494  26.0  55.0  22.9630  80.0  148.0 -1.268852
# 34463  22.0  45.0  23.8325  63.0  108.0 -7.702843
# 26337  38.0  68.0  33.6473  84.0  139.0  6.932214
# 29224  24.0  69.0  32.8906  87.0  132.0  3.364124

# %%
# get mean and std for all variables for males and females seperately for the test set
female = main_test[main_test["Gender"] == 0]
male = main_test[main_test["Gender"]== 1]

print("Number of females:", female.shape[0])
print("NUmber of males:", male.shape[0])

print("Age")
mean = main_test["Age"].mean()
print("Mean", mean)
std = main_test["Age"].std()
print("Std",std)

print("LPA")
mean = main_test["LPA"].mean()
print("Mean", mean)
std = main_test["LPA"].std()
print("Std",std)

print("MPA")
mean = main_test["MPA"].mean()
print("Mean", mean)
std = main_test["MPA"].std()
print("Std",std)

print("VPA")
mean = main_test["VPA"].mean()
print("Mean", mean)
std = main_test["VPA"].std()
print("Std",std)

print("SRLPA")
mean = main_test["SRLPA"].mean()
print("Mean", mean)
std = main_test["SRLPA"].std()
print("Std",std)

print("SRMPA")
mean = main_test["SRMPA"].mean()
print("Mean", mean)
std = main_test["SRMPA"].std()
print("Std",std)

print("SRVPA")
mean = main_test["SRVPA"].mean()
print("Mean", mean)
std = main_test["SRVPA"].std()
print("Std",std)

print("DBP")
mean = main_test["DBP"].mean()
print("Mean", mean)
std = main_test["DBP"].std()
print("Std",std)

print("SBP")
mean = main_test["SBP"].mean()
print("Mean", mean)
std = main_test["SBP"].std()
print("Std",std)

print("BMI")
mean = main_test["BMI"].mean()
print("Mean", mean)
std = main_test["BMI"].std()
print("Std",std)

print("HG")
mean = main_test["HG"].mean()
print("Mean", mean)
std = main_test["HG"].std()
print("Std",std)

print("HR")
mean = main_test["HR"].mean()
print("Mean", mean)
std = main_test["HR"].std()
print("Std",std)

print("IS")
print(main_test["IS"].value_counts())
# Out:
# Number of females: 2970
# NUmber of males: 2482
# Age
# Mean 64.1907556859868
# Std 7.814225465582799
# LPA
# Mean 1981.0712548789434
# Std 417.08409539087546
# MPA
# Mean 482.57679882611893
# Std 216.85915554816543
# VPA
# Mean 34.27631577402791
# Std 43.2553234105916
# SRLPA
# Mean 235.25458547322083
# Std 219.09399284018272
# SRMPA
# Mean 159.23734409391048
# Std 192.24815076490748
# SRVPA
# Mean 66.45377842993398
# Std 83.83425453246974
# DBP
# Mean 81.11812179016874
# Std 10.361578350786544
# SBP
# Mean 136.32758620689654
# Std 18.24128891718472
# BMI
# Mean 26.36214115920763
# Std 4.213687095706291
# HG
# Mean 33.49486426999266
# Std 10.80830496808681
# HR
# Mean 67.96460014673514
# Std 11.043817664608612
# IS
# 0    3423
# 2    1109
# 1     909
# 3      11
# Name: IS, dtype: int64

# %% [markdown]
# ## 4.2 Age and BrainAge

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'Gender', fill=True, palette = "crest")
plt.title("Age x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'Gender', fill=True, palette = "crest")
plt.title("BrainAge x Gender")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BA', hue = 'IS', fill=True, palette = "crest")
plt.title("BrainAge x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'Age', hue = 'IS', fill=True, palette = "crest")
plt.title("Age x Imaging site")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'MPA', hue = 'IS', fill=True, palette = "crest")
plt.title("Moderate PA x Imaging site")
plt.show()


plt.figure()
sns.kdeplot(data = main_test, x= 'BA', fill=True, label="A2009")
plt.title("BrainAge Segmentations")
plt.legend()
plt.show()

# %% [markdown]
# ## 4.3 Physical activity

# %%
# plot physical activity intensity categories for self-report and accelerometer together and seperately

plt.figure()
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,5000,1000),fontsize = 14)
plt.ylim(0,0.01)
plt.ylabel("Density",fontsize = 16)
plt.yticks(fontsize = 14)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA")
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA")
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2000,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA", color="#6baed6")
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA", color="#08519c")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,4500,1000),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA", color="#fd8d3c")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA", color="#a63603")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2500,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA", color="#74c476")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA", color="#006d2c")
plt.ylim(0,0.01)
plt.xticks(range(0,1500,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.legend()
plt.show()

plt.figure()
plt.scatter("MPA", "SRMPA", data = main_test, label = "Moderate PA", alpha=0.3, s=10, color = "darkcyan")
plt.scatter("VPA", "SRVPA", data = main_test, label = "Vigorous PA", alpha=0.3, s=10, color = "mediumvioletred")
plt.ylabel("Self-reported (min/week)", fontsize = 16)
plt.xlabel("Accelerometer (min/week)", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## 4.4 Health and Fitness

# %%
plt.figure()
sns.kdeplot(data = main_test, x= 'HG', hue = 'Gender', fill=True, palette = "crest")
plt.title("Hand grip")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'HR', hue = 'Gender', fill=True, palette = "crest")
plt.title("Heart rate")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Systolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'DBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Distolic BP")
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'BMI', hue = 'Gender', fill=True, palette = "crest")
plt.title("BMI")
plt.show()

# %% [markdown]
# # 5 Reorder Dataframe

# %%
# reorder dataframe
main_test = main_test[['Age', 'Gender', 'IS' , 'LPA', 'MPA', 'VPA', 'SRLPA', 'SRMPA', 'SRVPA', 'HG', 'HR', 'BMI', 'DBP', 'SBP', 'BA']]

# %% [markdown]
# # 6 Correlation Heatmap

# %%
def calculate_pvalues(df):
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            tmp = df[df[r].notnull() & df[c].notnull()]
            pvalues[r][c] = round(pearsonr(tmp[r], tmp[c])[1], 4)
    return pvalues

# %%
corr_test = main_test
corr_test = corr_test[:]
del corr_test["BA"]
del corr_test["SBP"]
del corr_test["IS"]
corr = corr_test.corr()
corr = round(corr,3)

fig, ax = plt.subplots(figsize=(13,10)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)


p_values = np.asarray(calculate_pvalues(corr_test))

threshold = 0.0007575  # Define your significance threshold

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if i != j:
            correlation = corr.iloc[i, j]
            p_value = p_values[i,j]  # Calculate or provide the p-value for the correlation

            if p_value < threshold:
                ax.text(j + 0.9, i + 0.2, "*", ha='right', va='top', color='black', fontsize=12)

# %% [markdown]
# # 7 Models with OLS

# %% [markdown]
# ## 7.1 PA BrainAGE Regression

# %% [markdown]
# ### 7.1.1 Baseline Covariates

# %%
cov_model = ols('BA ~ Gender + Age + IS', missing='drop', data = main_test).fit()
print(cov_model.summary())

#calculate effect size
results = cov_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     14.71
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.55e-09
# Time:                        18:31:27   Log-Likelihood:                -17516.
# No. Observations:                5452   AIC:                         3.504e+04
# Df Residuals:                    5448   BIC:                         3.507e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8002      0.674      1.186      0.236      -0.522       2.122
# Gender         1.0633      0.165      6.453      0.000       0.740       1.386
# Age           -0.0230      0.011     -2.179      0.029      -0.044      -0.002
# IS             0.1078      0.101      1.069      0.285      -0.090       0.306
# ==============================================================================
# Omnibus:                       74.328   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.215
# Skew:                           0.231   Prob(JB):                     1.90e-19
# Kurtosis:                       3.408   Cond. No.                         536.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.016067
# Gender       0.087391
# Age         -0.029504
# IS           0.014481
# dtype: float64

# %% [markdown]
# ### 7.1.2 Accelerometer PA

# %%
lpa = ols('BA ~ LPA + Age + Gender + IS + Gender:LPA', missing='drop', data = main_test).fit()
print(lpa.summary())

#calculate effect size
results = lpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     9.003
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.56e-08
# Time:                        18:31:27   Log-Likelihood:                -17516.
# No. Observations:                5452   AIC:                         3.504e+04
# Df Residuals:                    5446   BIC:                         3.508e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3998      0.861      0.464      0.642      -1.288       2.087
# LPA            0.0002      0.000      0.753      0.452      -0.000       0.001
# Age           -0.0234      0.011     -2.211      0.027      -0.044      -0.003
# Gender         1.1622      0.807      1.441      0.150      -0.419       2.744
# IS             0.1104      0.101      1.094      0.274      -0.087       0.308
# Gender:LPA -3.302e-05      0.000     -0.082      0.934      -0.001       0.001
# ==============================================================================
# Omnibus:                       74.440   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.402
# Skew:                           0.231   Prob(JB):                     1.73e-19
# Kurtosis:                       3.409   Cond. No.                     2.74e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.006290
# LPA           0.010195
# Age          -0.029942
# Gender        0.019512
# IS            0.014813
# Gender:LPA   -0.001115
# dtype: float64

# %%
mpa = ols('BA ~ MPA + Gender + Age + IS + Gender:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     11.97
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.51e-11
# Time:                        18:31:28   Log-Likelihood:                -17508.
# No. Observations:                5452   AIC:                         3.503e+04
# Df Residuals:                    5446   BIC:                         3.507e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3523      0.764      1.769      0.077      -0.146       2.851
# MPA           -0.0003      0.001     -0.579      0.563      -0.001       0.001
# Gender         1.9832      0.399      4.971      0.000       1.201       2.765
# Age           -0.0296      0.011     -2.746      0.006      -0.051      -0.008
# IS             0.1224      0.101      1.214      0.225      -0.075       0.320
# Gender:MPA    -0.0019      0.001     -2.570      0.010      -0.003      -0.000
# ==============================================================================
# Omnibus:                       74.888   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.993
# Skew:                           0.232   Prob(JB):                     1.29e-19
# Kurtosis:                       3.410   Cond. No.                     5.59e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.59e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.023964
# MPA          -0.007844
# Gender        0.067319
# Age          -0.037187
# IS            0.016436
# Gender:MPA   -0.034807
# dtype: float64

# %%
vpa = ols('BA ~ VPA + Age + Gender + IS + Gender:VPA', missing='drop', data = main_test).fit()
print(vpa.summary())

#calculate effect size
results = vpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     10.15
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.07e-09
# Time:                        18:31:28   Log-Likelihood:                -17513.
# No. Observations:                5452   AIC:                         3.504e+04
# Df Residuals:                    5446   BIC:                         3.508e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.8409      0.712      1.181      0.238      -0.555       2.237
# VPA            0.0029      0.003      1.017      0.309      -0.003       0.008
# Age           -0.0252      0.011     -2.317      0.021      -0.046      -0.004
# Gender         1.3892      0.211      6.597      0.000       0.976       1.802
# IS             0.1182      0.101      1.171      0.242      -0.080       0.316
# Gender:VPA    -0.0090      0.004     -2.367      0.018      -0.016      -0.002
# ==============================================================================
# Omnibus:                       75.287   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.339
# Skew:                           0.233   Prob(JB):                     1.08e-19
# Kurtosis:                       3.409   Cond. No.                         708.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept     0.015995
# VPA           0.013773
# Age          -0.031383
# Gender        0.089351
# IS            0.015864
# Gender:VPA   -0.032059
# dtype: float64

# %% [markdown]
# ### 7.1.3 Self-report PA

# %%
srlpa = ols('BA ~ SRLPA + Age + Gender + IS + Gender:SRLPA', missing='drop', data = main_test).fit()
print(srlpa.summary())

#calculate effect size
results = srlpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.966
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.70e-08
# Time:                        18:31:28   Log-Likelihood:                -17516.
# No. Observations:                5452   AIC:                         3.504e+04
# Df Residuals:                    5446   BIC:                         3.508e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.8926      0.684      1.304      0.192      -0.449       2.234
# SRLPA           -0.0004      0.001     -0.683      0.494      -0.001       0.001
# Age             -0.0232      0.011     -2.189      0.029      -0.044      -0.002
# Gender           0.9169      0.240      3.820      0.000       0.446       1.387
# IS               0.1084      0.101      1.075      0.282      -0.089       0.306
# Gender:SRLPA     0.0006      0.001      0.837      0.403      -0.001       0.002
# ==============================================================================
# Omnibus:                       74.404   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.292
# Skew:                           0.231   Prob(JB):                     1.83e-19
# Kurtosis:                       3.408   Cond. No.                     3.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.017664
# SRLPA          -0.009256
# Age            -0.029645
# Gender          0.051736
# IS              0.014559
# Gender:SRLPA    0.011335
# dtype: float64

# %%
srmpa = ols('BA ~ SRMPA + Gender + Age + IS + Gender:SRMPA', missing='drop', data = main_test).fit()
print(srmpa.summary())

#calculate effect size
results = srmpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.971
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.68e-08
# Time:                        18:31:28   Log-Likelihood:                -17516.
# No. Observations:                5452   AIC:                         3.504e+04
# Df Residuals:                    5446   BIC:                         3.508e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.8353      0.678      1.231      0.218      -0.495       2.165
# SRMPA            0.0003      0.001      0.512      0.609      -0.001       0.001
# Gender           1.0446      0.213      4.903      0.000       0.627       1.462
# Age             -0.0244      0.011     -2.280      0.023      -0.045      -0.003
# IS               0.1108      0.101      1.098      0.272      -0.087       0.309
# Gender:SRMPA     0.0001      0.001      0.165      0.869      -0.002       0.002
# ==============================================================================
# Omnibus:                       74.923   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.083
# Skew:                           0.232   Prob(JB):                     1.23e-19
# Kurtosis:                       3.411   Cond. No.                     2.36e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.36e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.016674
# SRMPA           0.006932
# Gender          0.066398
# Age            -0.030876
# IS              0.014866
# Gender:SRMPA    0.002240
# dtype: float64

# %%
srvpa = ols('BA ~ SRVPA + Age + Gender + IS + Gender:SRVPA', missing='drop', data = main_test).fit()
print(srvpa.summary())

#calculate effect size
results = srvpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.932
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.84e-08
# Time:                        18:31:28   Log-Likelihood:                -17516.
# No. Observations:                5452   AIC:                         3.504e+04
# Df Residuals:                    5446   BIC:                         3.508e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.7344      0.683      1.075      0.282      -0.605       2.074
# SRVPA            0.0010      0.001      0.707      0.480      -0.002       0.004
# Age             -0.0229      0.011     -2.165      0.030      -0.044      -0.002
# Gender           1.1457      0.211      5.430      0.000       0.732       1.559
# IS               0.1083      0.101      1.074      0.283      -0.089       0.306
# Gender:SRVPA    -0.0013      0.002     -0.670      0.503      -0.005       0.003
# ==============================================================================
# Omnibus:                       74.303   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.061
# Skew:                           0.231   Prob(JB):                     2.05e-19
# Kurtosis:                       3.406   Cond. No.                     1.10e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.014557
# SRVPA           0.009573
# Age            -0.029328
# Gender          0.073535
# IS              0.014539
# Gender:SRVPA   -0.009068
# dtype: float64

# %% [markdown]
# ## 7.2 PA+Fitness models

# %% [markdown]
# ### 7.2.1 PAF

# %%
paf = ols('BA ~ MPA + HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(paf.summary())

#calculate effect size
results = paf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     8.805
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           4.03e-18
# Time:                        18:31:28   Log-Likelihood:                -17481.
# No. Observations:                5452   AIC:                         3.499e+04
# Df Residuals:                    5438   BIC:                         3.508e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.9228      1.472     -1.306      0.192      -4.809       0.964
# MPA        -2.748e-05      0.001     -0.052      0.959      -0.001       0.001
# HG            -0.0220      0.018     -1.213      0.225      -0.058       0.014
# DBP            0.0428      0.012      3.650      0.000       0.020       0.066
# HR             0.0075      0.011      0.665      0.506      -0.015       0.030
# BMI            0.0114      0.027      0.427      0.670      -0.041       0.064
# Gender         0.0497      1.885      0.026      0.979      -3.645       3.745
# IS             0.1080      0.101      1.074      0.283      -0.089       0.305
# Age           -0.0371      0.011     -3.337      0.001      -0.059      -0.015
# HG:Gender     -0.0096      0.023     -0.420      0.674      -0.054       0.035
# DBP:Gender     0.0019      0.017      0.111      0.911      -0.032       0.036
# HR:Gender      0.0104      0.016      0.666      0.505      -0.020       0.041
# BMI:Gender     0.0584      0.044      1.342      0.180      -0.027       0.144
# MPA:Gender    -0.0017      0.001     -2.168      0.030      -0.003      -0.000
# ==============================================================================
# Omnibus:                       78.453   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.676
# Skew:                           0.233   Prob(JB):                     7.51e-21
# Kurtosis:                       3.436   Cond. No.                     1.58e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.017687
# MPA          -0.000704
# HG           -0.016431
# DBP           0.049435
# HR            0.009012
# BMI           0.005781
# Gender        0.000357
# IS            0.014548
# Age          -0.045193
# HG:Gender    -0.005695
# DBP:Gender    0.001507
# HR:Gender     0.009027
# BMI:Gender    0.018176
# MPA:Gender   -0.029360
# dtype: float64

# %% [markdown]
# ### 7.2.2 SRPAF

# %%
srpaf = ols('BA ~ SRMPA + HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + SRMPA:Gender', missing='drop', data = main_test).fit()
print(srpaf.summary())

#calculate effect size
results = srpaf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     8.304
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           7.22e-17
# Time:                        18:31:28   Log-Likelihood:                -17484.
# No. Observations:                5452   AIC:                         3.500e+04
# Df Residuals:                    5438   BIC:                         3.509e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -2.2137      1.387     -1.596      0.111      -4.933       0.505
# SRMPA            0.0004      0.001      0.700      0.484      -0.001       0.002
# HG              -0.0208      0.018     -1.148      0.251      -0.056       0.015
# DBP              0.0426      0.012      3.630      0.000       0.020       0.066
# HR               0.0078      0.011      0.696      0.487      -0.014       0.030
# BMI              0.0127      0.026      0.490      0.624      -0.038       0.064
# Gender          -1.5462      1.789     -0.864      0.387      -5.053       1.961
# IS               0.1048      0.101      1.042      0.297      -0.092       0.302
# Age             -0.0348      0.011     -3.156      0.002      -0.056      -0.013
# HG:Gender       -0.0116      0.023     -0.512      0.609      -0.056       0.033
# DBP:Gender       0.0017      0.017      0.097      0.923      -0.032       0.035
# HR:Gender        0.0135      0.016      0.865      0.387      -0.017       0.044
# BMI:Gender       0.0811      0.042      1.918      0.055      -0.002       0.164
# SRMPA:Gender     0.0004      0.001      0.487      0.626      -0.001       0.002
# ==============================================================================
# Omnibus:                       78.870   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.301
# Skew:                           0.234   Prob(JB):                     5.49e-21
# Kurtosis:                       3.439   Cond. No.                     7.40e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept      -0.021615
# SRMPA           0.009477
# HG             -0.015546
# DBP             0.049164
# HR              0.009419
# BMI             0.006635
# Gender         -0.011706
# IS              0.014113
# Age            -0.042739
# HG:Gender      -0.006928
# DBP:Gender      0.001311
# HR:Gender       0.011716
# BMI:Gender      0.025979
# SRMPA:Gender    0.006598
# dtype: float64

# %% [markdown]
# ### 7.2.3 PAF / MPA

# %%
no_mpa = ols('BA ~ HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_mpa.summary())

#calculate effect size
results = no_mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     9.614
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.97e-17
# Time:                        18:31:28   Log-Likelihood:                -17486.
# No. Observations:                5452   AIC:                         3.500e+04
# Df Residuals:                    5440   BIC:                         3.507e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.2580      1.381     -1.634      0.102      -4.966       0.450
# HG            -0.0204      0.018     -1.127      0.260      -0.056       0.015
# DBP            0.0425      0.012      3.625      0.000       0.020       0.065
# HR             0.0075      0.011      0.669      0.504      -0.015       0.030
# BMI            0.0119      0.026      0.458      0.647      -0.039       0.063
# Gender        -1.4309      1.772     -0.807      0.420      -4.905       2.044
# IS             0.0998      0.101      0.993      0.321      -0.097       0.297
# Age           -0.0324      0.011     -2.974      0.003      -0.054      -0.011
# HG:Gender     -0.0112      0.023     -0.494      0.621      -0.056       0.033
# DBP:Gender     0.0011      0.017      0.062      0.950      -0.033       0.035
# HR:Gender      0.0131      0.016      0.840      0.401      -0.017       0.044
# BMI:Gender     0.0811      0.042      1.917      0.055      -0.002       0.164
# ==============================================================================
# Omnibus:                       77.754   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.719
# Skew:                           0.232   Prob(JB):                     1.21e-20
# Kurtosis:                       3.433   Cond. No.                     3.57e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.022136
# HG           -0.015269
# DBP           0.049097
# HR            0.009054
# BMI           0.006199
# Gender       -0.010934
# IS            0.013442
# Age          -0.040275
# HG:Gender    -0.006691
# DBP:Gender    0.000843
# HR:Gender     0.011378
# BMI:Gender    0.025967
# dtype: float64

# %% [markdown]
# ### 7.2.4 PAF / HG

# %%
no_hg = ols('BA ~ MPA + DBP + HR + BMI + Gender + IS + Age + MPA:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hg.summary())

#calculate effect size
results = no_hg
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     9.836
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           6.57e-18
# Time:                        18:31:28   Log-Likelihood:                -17484.
# No. Observations:                5452   AIC:                         3.499e+04
# Df Residuals:                    5440   BIC:                         3.507e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.8343      1.346     -2.106      0.035      -5.472      -0.197
# MPA        -5.508e-05      0.001     -0.104      0.917      -0.001       0.001
# DBP            0.0422      0.012      3.601      0.000       0.019       0.065
# HR             0.0076      0.011      0.679      0.497      -0.014       0.030
# BMI            0.0119      0.027      0.444      0.657      -0.041       0.064
# Gender        -0.6160      1.760     -0.350      0.726      -4.066       2.834
# IS             0.1058      0.101      1.052      0.293      -0.091       0.303
# Age           -0.0312      0.011     -2.897      0.004      -0.052      -0.010
# MPA:Gender    -0.0017      0.001     -2.113      0.035      -0.003      -0.000
# DBP:Gender     0.0001      0.017      0.008      0.993      -0.034       0.034
# HR:Gender      0.0120      0.016      0.772      0.440      -0.018       0.043
# BMI:Gender     0.0553      0.043      1.272      0.203      -0.030       0.141
# ==============================================================================
# Omnibus:                       76.401   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.932
# Skew:                           0.230   Prob(JB):                     2.96e-20
# Kurtosis:                       3.429   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.028528
# MPA          -0.001415
# DBP           0.048768
# HR            0.009191
# BMI           0.006018
# Gender       -0.004741
# IS            0.014248
# Age          -0.039241
# MPA:Gender   -0.028619
# DBP:Gender    0.000114
# HR:Gender     0.010461
# BMI:Gender    0.017233
# dtype: float64

# %% [markdown]
# ### 7.2.5 PAF / HR

# %%
no_hr = ols('BA ~ HG + DBP + MPA + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + MPA:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hr.summary())

#calculate effect size
results = no_hr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     10.11
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.66e-18
# Time:                        18:31:28   Log-Likelihood:                -17483.
# No. Observations:                5452   AIC:                         3.499e+04
# Df Residuals:                    5440   BIC:                         3.507e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.5682      1.380     -1.136      0.256      -4.274       1.138
# HG            -0.0222      0.018     -1.224      0.221      -0.058       0.013
# DBP            0.0444      0.011      3.871      0.000       0.022       0.067
# MPA        -4.154e-05      0.001     -0.079      0.937      -0.001       0.001
# BMI            0.0137      0.027      0.516      0.606      -0.038       0.066
# Gender         0.3806      1.770      0.215      0.830      -3.089       3.850
# IS             0.1077      0.101      1.071      0.284      -0.089       0.305
# Age           -0.0373      0.011     -3.357      0.001      -0.059      -0.016
# HG:Gender     -0.0112      0.023     -0.491      0.623      -0.056       0.033
# DBP:Gender     0.0057      0.017      0.340      0.734      -0.027       0.038
# MPA:Gender    -0.0018      0.001     -2.263      0.024      -0.003      -0.000
# BMI:Gender     0.0632      0.043      1.463      0.143      -0.021       0.148
# ==============================================================================
# Omnibus:                       76.628   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.157
# Skew:                           0.231   Prob(JB):                     2.65e-20
# Kurtosis:                       3.429   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.015385
# HG           -0.016579
# DBP           0.052432
# MPA          -0.001065
# BMI           0.006991
# Gender        0.002913
# IS            0.014505
# Age          -0.045459
# HG:Gender    -0.006649
# DBP:Gender    0.004600
# MPA:Gender   -0.030651
# BMI:Gender    0.019819
# dtype: float64

# %% [markdown]
# ### 7.2.6 PAF / DBP

# %%
no_dbp = ols('BA ~ HG + MPA + HR + BMI + Gender + IS + Age + HG:Gender + MPA:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_dbp.summary())

#calculate effect size
results = no_dbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     8.023
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           4.89e-14
# Time:                        18:31:28   Log-Likelihood:                -17494.
# No. Observations:                5452   AIC:                         3.501e+04
# Df Residuals:                    5440   BIC:                         3.509e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1504      1.383     -0.109      0.913      -2.861       2.560
# HG            -0.0198      0.018     -1.089      0.276      -0.055       0.016
# MPA          2.85e-05      0.001      0.054      0.957      -0.001       0.001
# HR             0.0159      0.011      1.441      0.150      -0.006       0.038
# BMI            0.0385      0.026      1.493      0.136      -0.012       0.089
# Gender         0.2202      1.686      0.131      0.896      -3.085       3.526
# IS             0.1256      0.101      1.247      0.212      -0.072       0.323
# Age           -0.0333      0.011     -3.000      0.003      -0.055      -0.012
# HG:Gender     -0.0072      0.023     -0.316      0.752      -0.052       0.038
# MPA:Gender    -0.0017      0.001     -2.132      0.033      -0.003      -0.000
# HR:Gender      0.0118      0.015      0.778      0.436      -0.018       0.042
# BMI:Gender     0.0550      0.042      1.296      0.195      -0.028       0.138
# ==============================================================================
# Omnibus:                       80.463   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.348
# Skew:                           0.236   Prob(JB):                     1.97e-21
# Kurtosis:                       3.443   Cond. No.                     1.40e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.001473
# HG           -0.014748
# MPA           0.000729
# HR            0.019513
# BMI           0.020218
# Gender        0.001769
# IS            0.016891
# Age          -0.040625
# HG:Gender    -0.004282
# MPA:Gender   -0.028872
# HR:Gender     0.010540
# BMI:Gender    0.017554
# dtype: float64

# %% [markdown]
# ### 7.2.7 PAF / BMI

# %%
no_bmi = ols('BA ~ HG + DBP + HR + MPA + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(no_bmi.summary())

#calculate effect size
results = no_bmi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5452))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     10.01
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           2.77e-18
# Time:                        18:31:28   Log-Likelihood:                -17483.
# No. Observations:                5452   AIC:                         3.499e+04
# Df Residuals:                    5440   BIC:                         3.507e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.6818      1.406     -1.196      0.232      -4.437       1.074
# HG            -0.0223      0.018     -1.230      0.219      -0.058       0.013
# DBP            0.0442      0.011      3.924      0.000       0.022       0.066
# HR             0.0081      0.011      0.727      0.468      -0.014       0.030
# MPA        -9.005e-05      0.001     -0.176      0.860      -0.001       0.001
# Gender         1.2380      1.716      0.721      0.471      -2.126       4.602
# IS             0.1058      0.101      1.052      0.293      -0.091       0.303
# Age           -0.0380      0.011     -3.427      0.001      -0.060      -0.016
# HG:Gender     -0.0082      0.023     -0.360      0.719      -0.053       0.036
# DBP:Gender     0.0054      0.017      0.325      0.745      -0.027       0.038
# HR:Gender      0.0125      0.015      0.806      0.420      -0.018       0.043
# MPA:Gender    -0.0019      0.001     -2.514      0.012      -0.003      -0.000
# ==============================================================================
# Omnibus:                       78.668   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.792
# Skew:                           0.234   Prob(JB):                     7.09e-21
# Kurtosis:                       3.435   Cond. No.                     1.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.016204
# HG           -0.016653
# DBP           0.053139
# HR            0.009839
# MPA          -0.002388
# Gender        0.009770
# IS            0.014243
# Age          -0.046407
# HG:Gender    -0.004876
# DBP:Gender    0.004407
# HR:Gender     0.010923
# MPA:Gender   -0.034045
# dtype: float64

# %% [markdown]
# # 8 Model comparisons

# %% [markdown]
# ## 8.1 Cov vs. PA

# %%
model_comparison = anova_lm(cov_model, lpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  197092.091692      0.0        NaN       NaN       NaN
# 1    5446.0  197059.343894      2.0  32.747797  0.452515  0.636051

# %%
model_comparison = anova_lm(cov_model, mpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F   Pr(>F)
# 0    5448.0  197092.091692      0.0         NaN       NaN      NaN
# 1    5446.0  196528.415037      2.0  563.676655  7.810023  0.00041

# %%
model_comparison = anova_lm(cov_model, vpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  197092.091692      0.0        NaN       NaN       NaN
# 1    5446.0  196853.209261      2.0  238.88243  3.304375  0.036796

# %% [markdown]
# ## 8.2 Cov vs. SRPA

# %%
model_comparison = anova_lm(cov_model, srlpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  197092.091692      0.0        NaN       NaN       NaN
# 1    5446.0  197065.992843      2.0  26.098848  0.360626  0.697256

# %%
model_comparison = anova_lm(cov_model, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  197092.091692      0.0        NaN       NaN       NaN
# 1    5446.0  197065.082228      2.0  27.009464  0.373211  0.688538

# %%
model_comparison = anova_lm(cov_model, srvpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5448.0  197092.091692      0.0        NaN       NaN       NaN
# 1    5446.0  197072.070941      2.0  20.020751  0.276632  0.758344

# %% [markdown]
# # 9 PAF Type-III ANOVA

# %% [markdown]
# ## 9.1 PAF / MPA

# %%
model_comparison = anova_lm(no_mpa, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  194899.445067      0.0         NaN       NaN       NaN
# 1    5438.0  194592.007132      2.0  307.437935  4.295776  0.013672

# %% [markdown]
# ## 9.2 SR PAF / SRMPA

# %%
model_comparison = anova_lm(no_mpa, srpaf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5440.0  194899.445067      0.0        NaN       NaN       NaN
# 1    5438.0  194820.949076      2.0  78.495991  1.095522  0.334439

# %% [markdown]
# ## 9.3 PAF / HG

# %%
model_comparison = anova_lm(no_hg, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff   ss_diff         F    Pr(>F)
# 0    5440.0  194813.665432      0.0       NaN       NaN       NaN
# 1    5438.0  194592.007132      2.0  221.6583  3.097193  0.045256

# %% [markdown]
# ## 9.4 PAF / DBP

# %%
model_comparison = anova_lm(no_dbp, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff          F    Pr(>F)
# 0    5440.0  195516.486067      0.0         NaN        NaN       NaN
# 1    5438.0  194592.007132      2.0  924.478935  12.917582  0.000003

# %% [markdown]
# ## 9.5 PAF / HR

# %%
model_comparison = anova_lm(no_hr, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  194706.616358      0.0         NaN       NaN       NaN
# 1    5438.0  194592.007132      2.0  114.609227  1.601415  0.201706

# %% [markdown]
# ## 9.6 PAF / BMI

# %%
model_comparison = anova_lm(no_bmi, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5440.0  194746.501855      0.0         NaN       NaN       NaN
# 1    5438.0  194592.007132      2.0  154.494723  2.158728  0.115571

# %% [markdown]
# # 10 Standardization of all variables

# %%
main_test = pd.DataFrame(main_test)
main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Gender","IS"]] = stats.zscore(main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Gender","IS"]], nan_policy='omit')

# %% [markdown]
# # 11 Mediation analysis

# %% [markdown]
# ## 11.1 BMI

# %%
# outcome_model = sm.OLS.from_formula("BA ~ BMI + LPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("BMI ~ LPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "MPA").fit()
print(res.summary())

modelm = ols("BMI ~ MPA + Age + Gender", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ BMI + Age + Gender", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.075745       -0.121355       -0.031800    0.002
# ACME (treated)           -0.075745       -0.121355       -0.031800    0.002
# ADE (control)            -0.167914       -0.330474       -0.006948    0.048
# ADE (treated)            -0.167914       -0.330474       -0.006948    0.048
# Total effect             -0.243659       -0.404154       -0.087191    0.006
# Prop. mediated (control)  0.311222        0.108933        0.883202    0.008
# Prop. mediated (treated)  0.311222        0.108933        0.883202    0.008
# ACME (average)           -0.075745       -0.121355       -0.031800    0.002
# ADE (average)            -0.167914       -0.330474       -0.006948    0.048
# Prop. mediated (average)  0.311222        0.108933        0.883202    0.008
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BMI   R-squared:                       0.081
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     160.6
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.00e-99
# Time:                        18:32:18   Log-Likelihood:                -7505.1
# No. Observations:                5452   AIC:                         1.502e+04
# Df Residuals:                    5448   BIC:                         1.504e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.711e-16      0.013  -2.09e-14      1.000      -0.025       0.025
# MPA           -0.2693      0.013    -20.312      0.000      -0.295      -0.243
# Age           -0.0417      0.013     -3.127      0.002      -0.068      -0.016
# Gender         0.0980      0.013      7.495      0.000       0.072       0.124
# ==============================================================================
# Omnibus:                      982.075   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2194.667
# Skew:                           1.036   Prob(JB):                         0.00
# Kurtosis:                       5.317   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     19.58
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.28e-12
# Time:                        18:32:18   Log-Likelihood:                -17509.
# No. Observations:                5452   AIC:                         3.503e+04
# Df Residuals:                    5448   BIC:                         3.505e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1320      0.081     -1.622      0.105      -0.291       0.028
# BMI            0.3236      0.082      3.955      0.000       0.163       0.484
# Age           -0.1729      0.082     -2.111      0.035      -0.333      -0.012
# Gender         0.4921      0.082      5.975      0.000       0.331       0.654
# ==============================================================================
# Omnibus:                       74.934   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.749
# Skew:                           0.229   Prob(JB):                     8.82e-20
# Kurtosis:                       3.420   Cond. No.                         1.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ BMI + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("BMI ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.2 DBP

# %%
# outcome_model = sm.OLS.from_formula("BA ~ DBP + LPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("DBP ~ LPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "MPA").fit()
print(res.summary())

modelm = ols("DBP ~ MPA + Age + Gender", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ DBP + Age + Gender", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.028698       -0.054440       -0.005491    0.022
# ACME (treated)           -0.028698       -0.054440       -0.005491    0.022
# ADE (control)            -0.219078       -0.377283       -0.067724    0.010
# ADE (treated)            -0.219078       -0.377283       -0.067724    0.010
# Total effect             -0.247776       -0.405129       -0.099026    0.004
# Prop. mediated (control)  0.114470        0.024185        0.331693    0.022
# Prop. mediated (treated)  0.114470        0.024185        0.331693    0.022
# ACME (average)           -0.028698       -0.054440       -0.005491    0.022
# ADE (average)            -0.219078       -0.377283       -0.067724    0.010
# Prop. mediated (average)  0.114470        0.024185        0.331693    0.022
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DBP   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     86.64
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           9.21e-55
# Time:                        18:33:07   Log-Likelihood:                -7609.0
# No. Observations:                5452   AIC:                         1.523e+04
# Df Residuals:                    5448   BIC:                         1.525e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.108e-16      0.013   1.59e-14      1.000      -0.026       0.026
# MPA           -0.0556      0.014     -4.112      0.000      -0.082      -0.029
# Age            0.0480      0.014      3.534      0.000       0.021       0.075
# Gender         0.1894      0.013     14.206      0.000       0.163       0.216
# ==============================================================================
# Omnibus:                       88.226   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.573
# Skew:                           0.281   Prob(JB):                     1.07e-21
# Kurtosis:                       3.330   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     27.97
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           6.07e-18
# Time:                        18:33:07   Log-Likelihood:                -17496.
# No. Observations:                5452   AIC:                         3.500e+04
# Df Residuals:                    5448   BIC:                         3.503e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1320      0.081     -1.626      0.104      -0.291       0.027
# DBP            0.5287      0.083      6.374      0.000       0.366       0.691
# Age           -0.2004      0.082     -2.448      0.014      -0.361      -0.040
# Gender         0.4254      0.083      5.111      0.000       0.262       0.589
# ==============================================================================
# Omnibus:                       73.306   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.380
# Skew:                           0.227   Prob(JB):                     2.88e-19
# Kurtosis:                       3.411   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ DBP + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("DBP ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.3 Heart rate

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HR + LPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("HR ~ LPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + MPA + Age + Gender", main_test)
mediator_model = sm.OLS.from_formula("HR ~ MPA + Age + Gender", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "MPA").fit()
print(res.summary())

modelm = ols("HR ~ MPA + Age + Gender", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ HR + Age + Gender", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.033139       -0.057331       -0.013157    0.000
# ACME (treated)           -0.033139       -0.057331       -0.013157    0.000
# ADE (control)            -0.209463       -0.381139       -0.043770    0.012
# ADE (treated)            -0.209463       -0.381139       -0.043770    0.012
# Total effect             -0.242602       -0.411393       -0.078676    0.002
# Prop. mediated (control)  0.136169        0.047659        0.460685    0.002
# Prop. mediated (treated)  0.136169        0.047659        0.460685    0.002
# ACME (average)           -0.033139       -0.057331       -0.013157    0.000
# ADE (average)            -0.209463       -0.381139       -0.043770    0.012
# Prop. mediated (average)  0.136169        0.047659        0.460685    0.002
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     HR   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     38.93
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           6.93e-25
# Time:                        18:33:56   Log-Likelihood:                -7678.2
# No. Observations:                5452   AIC:                         1.536e+04
# Df Residuals:                    5448   BIC:                         1.539e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.621e-16      0.013   4.19e-14      1.000      -0.026       0.026
# MPA           -0.1082      0.014     -7.909      0.000      -0.135      -0.081
# Age            0.0040      0.014      0.292      0.770      -0.023       0.031
# Gender        -0.1017      0.014     -7.529      0.000      -0.128      -0.075
# ==============================================================================
# Omnibus:                      528.749   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              841.759
# Skew:                           0.712   Prob(JB):                    1.64e-183
# Kurtosis:                       4.295   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     19.70
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           1.07e-12
# Time:                        18:33:56   Log-Likelihood:                -17509.
# No. Observations:                5452   AIC:                         3.503e+04
# Df Residuals:                    5448   BIC:                         3.505e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1320      0.081     -1.622      0.105      -0.291       0.028
# HR             0.3271      0.082      4.001      0.000       0.167       0.487
# Age           -0.1775      0.082     -2.167      0.030      -0.338      -0.017
# Gender         0.5586      0.082      6.788      0.000       0.397       0.720
# ==============================================================================
# Omnibus:                       77.403   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               90.822
# Skew:                           0.233   Prob(JB):                     1.90e-20
# Kurtosis:                       3.427   Cond. No.                         1.16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HR + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("HR ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 11.4 Hand grip

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HG + LPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("HG ~ LPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + MPA + Gender + Age", main_test)
mediator_model = sm.OLS.from_formula("HG ~ MPA + Gender + Age", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "MPA").fit()
print(res.summary())

modelm = ols("HG ~ MPA + Age + Gender", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ HG + Age + Gender", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.002247       -0.011781        0.005691    0.578
# ACME (treated)           -0.002247       -0.011781        0.005691    0.578
# ADE (control)            -0.245817       -0.415451       -0.079087    0.002
# ADE (treated)            -0.245817       -0.415451       -0.079087    0.002
# Total effect             -0.248064       -0.418864       -0.082348    0.000
# Prop. mediated (control)  0.007415       -0.029030        0.056392    0.578
# Prop. mediated (treated)  0.007415       -0.029030        0.056392    0.578
# ACME (average)           -0.002247       -0.011781        0.005691    0.578
# ADE (average)            -0.245817       -0.415451       -0.079087    0.002
# Prop. mediated (average)  0.007415       -0.029030        0.056392    0.578
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     HG   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     2337.
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):               0.00
# Time:                        18:34:45   Log-Likelihood:                -5481.3
# No. Observations:                5452   AIC:                         1.097e+04
# Df Residuals:                    5448   BIC:                         1.100e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.056e-16      0.009   2.29e-14      1.000      -0.018       0.018
# MPA            0.0095      0.009      1.034      0.301      -0.008       0.027
# Age           -0.1601      0.009    -17.413      0.000      -0.178      -0.142
# Gender         0.7516      0.009     83.292      0.000       0.734       0.769
# ==============================================================================
# Omnibus:                       83.560   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.278
# Skew:                          -0.038   Prob(JB):                     4.27e-35
# Kurtosis:                       3.831   Cond. No.                         1.26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     15.76
# Date:                Wed, 17 Jul 2024   Prob (F-statistic):           3.35e-10
# Time:                        18:34:45   Log-Likelihood:                -17515.
# No. Observations:                5452   AIC:                         3.504e+04
# Df Residuals:                    5448   BIC:                         3.506e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1320      0.081     -1.620      0.105      -0.292       0.028
# HG            -0.2546      0.123     -2.067      0.039      -0.496      -0.013
# Age           -0.2105      0.084     -2.495      0.013      -0.376      -0.045
# Gender         0.7177      0.124      5.806      0.000       0.475       0.960
# ==============================================================================
# Omnibus:                       76.273   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.688
# Skew:                           0.234   Prob(JB):                     5.51e-20
# Kurtosis:                       3.414   Cond. No.                         2.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HG + VPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("HG ~ VPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# # 12 LASSO Regression

# %% [markdown]
# ## 12.1 Accelerometer PA

# %%
df = main_test[["Age", "Gender", "IS", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('turbo')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)

# lasso with cross validated alpha
lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

for i, column in enumerate(columns):
    y_pos = coefficients[i]
    color = cmap(i / 7.0)
    if i == 0:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(100, -7),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 1:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(60, 6),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 4:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(60, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 6:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(60, -13),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 2:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(60, 0),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 3:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(60, -5),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 7:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(100, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i ==5:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(60, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white',edgecolor="white", pad=0))

plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.xlim(0.001, 100)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend().set_visible(False)
plt.show()

# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.0093260334688322
# [-0.27013533  0.61433872  0.07540069 -0.16114501  0.15105065  0.44094544
#  -0.24352392  0.1217052 ]
# 0.01867413704614662

# %% [markdown]
# ## 12.2 Self-report PA

# %%
df = main_test[["Age", "Gender", "IS", "LPA", "MPA", "VPA",  "SRLPA", "SRMPA", "SRVPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "SRMPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('turbo')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

# lasso with cross validated alpha
lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)


# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

for i, column in enumerate(columns):
    y_pos = coefficients[i]
    color = cmap(i / 7.0)
    if i == 0:
        plt.annotate(column, (1e-1, y_pos), textcoords="offset points", xytext=(0, -4),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 1:
        plt.annotate(column, (1e-1, y_pos), textcoords="offset points", xytext=(0, 5),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 2:
        plt.annotate(column, (1e-1, y_pos), textcoords="offset points", xytext=(40, 0),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 3:
        plt.annotate(column, (1e-1, y_pos), textcoords="offset points", xytext=(0, 0),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 4:
        plt.annotate(column, (1e-1, y_pos), textcoords="offset points", xytext=(40, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 5:
        plt.annotate(column, (1e-1, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 6:
        plt.annotate(column, (1e-1, y_pos), textcoords="offset points", xytext=(40, -13),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 7:
        plt.annotate(column, (1e-1, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))


plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.xlim(0.001, 100)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend().set_visible(False)
plt.show()


# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.008111308307896872
# [-0.25729693  0.62980597  0.07315142  0.10264778  0.16668406  0.43851175
#  -0.25636811  0.16766901]
# 0.018320862462250398

# %% [markdown]
# # 13 Pickle

# %%
main_test.to_pickle("3_validate.pkl")
