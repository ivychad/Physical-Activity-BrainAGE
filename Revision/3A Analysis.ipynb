# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import *
from random import seed
from scipy import stats
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV
import statsmodels.api as sm
from statsmodels.stats.api import anova_lm
from statsmodels.formula.api import ols
from statsmodels.regression import linear_model
from sklearn.metrics import explained_variance_score
from statsmodels.stats.mediation import Mediation
from sklearn.linear_model import LassoCV, RidgeCV, Lasso
from pingouin import ancova
import matplotlib.cm as cm
from scipy.stats.stats import pearsonr


# %matplotlib inline

seed(888)
pd.set_option('display.max_columns', None)
# Out:
# /tmp/ipykernel_760239/3379509306.py:18: DeprecationWarning: Please use `pearsonr` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   from scipy.stats.stats import pearsonr

# %% [markdown]
# # 1 Load data from "2 BrainAge"

# %%
# load data from pickle and convert to dataframe
main_test = pd.read_pickle("2_main_test.pkl")
main_train = pd.read_pickle("2_main_train.pkl")
main_test = pd.DataFrame(main_test)
main_train = pd.DataFrame(main_train)

# %%
edu = main_test[main_test["EDUL"]=="Prefer not to answer"].index
main_test = main_test.drop(edu)
print(edu)
# Out:
# Int64Index([  842,  4607,  6841,  7321, 11768, 13776, 17616, 18380, 26831,
#             29780, 32069, 33693, 34924, 38820, 40126],
#            dtype='int64')

# %% [markdown]
# # 2 Preprocessing and descriptives

# %% [markdown]
# ## 2.1 Data

# %%
main_test.head()
# Out:
#          ID   Age  Gender     IS        TPA       VPA       MPA       MVPA  \
# 10  1001365  71.0  Female  11025  3396.9600   20.1600  514.0800   554.4000
# 17  1001748  48.0  Female  11025  3126.8160  265.3056  596.9376  1127.5488
# 20  1001984  69.0  Female  11026  2468.4192    9.9936  579.6288   599.6160
# 21  1002138  56.0  Female  11025  2465.2224   29.1168  427.0464   485.2800
# 23  1002288  63.0  Female  11025  2559.7728  109.1376  704.4336   922.7088
#
#           LPA   SRLPA  SRMPA   SRVPA    HG    HR      BMI   DBP    SBP  EDUA  \
# 10  2862.7200   594.0  240.0   240.0  20.0  73.0  28.2030  70.0  106.0  16.0
# 17  2264.5728   462.0    0.0  2400.0  34.0  52.0  25.7857  75.0  124.0  18.0
# 20  1878.7968   693.0  960.0     0.0  26.0  76.0  25.7422  79.0  120.0  16.0
# 21  2009.0592  2970.0  720.0   240.0  18.0  56.0  33.5680  75.0  134.0  20.0
# 23  1746.2016   264.0  960.0     0.0  30.0  85.0  27.4762  84.0  146.0   NaN
#
#                             EDUL  BADA2009    BADASEG  BADDesikan  BADCombined
# 10  O levels/GCSEs or equivalent -3.272061  -5.762153   -0.972775    -4.348802
# 17  O levels/GCSEs or equivalent  4.175501  -2.619043    5.079592    -0.122651
# 20  O levels/GCSEs or equivalent  1.744594  -3.907803   -7.487591    -0.339589
# 21  O levels/GCSEs or equivalent -4.797479 -11.749959    1.942913    -4.609280
# 23  College or University degree -5.003056  -4.366149   -4.328995    -3.523589

# %% [markdown]
# ## 2.2 Remove outliers on SR PA

# %%
# remove outliers on self-reported physical activity data for each intensity seperately
before = main_test.shape[0]
outlier = np.mean(main_test["SRLPA"]) + np.std(main_test["SRLPA"])*3
main_test = main_test[main_test["SRLPA"]<outlier]
outlier = np.mean(main_test["SRMPA"]) + np.std(main_test["SRMPA"])*3
main_test = main_test[main_test["SRMPA"]<outlier]
outlier = np.mean(main_test["SRVPA"]) + np.std(main_test["SRVPA"])*3
main_test = main_test[main_test["SRVPA"]<outlier]
after = main_test.shape[0]
print("Outliers on self-reported PA:", before-after)
print(after)
# Out:
# Outliers on self-reported PA: 560
# 5410

# %% [markdown]
# ## 2.3 Convert SRPA from MET min/week to min/week

# %%
main_test["SRLPA"] = main_test["SRLPA"]/3.3
main_test["SRMPA"] = main_test["SRMPA"]/4
main_test["SRVPA"] = main_test["SRVPA"]/8

main_train["SRLPA"] = main_train["SRLPA"]/3.3
main_train["SRMPA"] = main_train["SRMPA"]/4
main_train["SRVPA"] = main_train["SRVPA"]/8

# %% [markdown]
# ## 2.4 Remove people with Gender other than Male or Female

# %%
before = main_test.shape[0]
main_test = main_test[(main_test["Gender"] == "Female") | (main_test["Gender"] == "Male")]
after = main_test.shape[0]
print("Gender not Male or Female:", before-after)
print(after)
# Out:
# Gender not Male or Female: 0
# 5410

# %% [markdown]
# ## 2.5 Test set descriptives

# %%
# get mean and std for all variables for males and females seperately for the test set
female = main_test[main_test["Gender"] == "Female"]
male = main_test[main_test["Gender"]== "Male"]

print("Number of females:", female.shape[0])
print("NUmber of males:", male.shape[0])

print("Age")
mean = main_test["Age"].mean()
print("Mean", mean)
std = main_test["Age"].std()
print("Std",std)

print("LPA")
mean = main_test["LPA"].mean()
print("Mean", mean)
std = main_test["LPA"].std()
print("Std",std)

print("MPA")
mean = main_test["MPA"].mean()
print("Mean", mean)
std = main_test["MPA"].std()
print("Std",std)

print("VPA")
mean = main_test["VPA"].mean()
print("Mean", mean)
std = main_test["VPA"].std()
print("Std",std)

print("SRLPA")
mean = main_test["SRLPA"].mean()
print("Mean", mean)
std = main_test["SRLPA"].std()
print("Std",std)

print("SRMPA")
mean = main_test["SRMPA"].mean()
print("Mean", mean)
std = main_test["SRMPA"].std()
print("Std",std)

print("SRVPA")
mean = main_test["SRVPA"].mean()
print("Mean", mean)
std = main_test["SRVPA"].std()
print("Std",std)

print("DBP")
mean = main_test["DBP"].mean()
print("Mean", mean)
std = main_test["DBP"].std()
print("Std",std)

print("SBP")
mean = main_test["SBP"].mean()
print("Mean", mean)
std = main_test["SBP"].std()
print("Std",std)

print("BMI")
mean = main_test["BMI"].mean()
print("Mean", mean)
std = main_test["BMI"].std()
print("Std",std)

print("HG")
mean = main_test["HG"].mean()
print("Mean", mean)
std = main_test["HG"].std()
print("Std",std)

print("HR")
mean = main_test["HR"].mean()
print("Mean", mean)
std = main_test["HR"].std()
print("Std",std)

print("IS")
print(main_test["IS"].value_counts())

print("EDUA")
print(main_test["EDUA"].value_counts())

print("EDUL")
print(main_test["EDUL"].value_counts())
# Out:
# Number of females: 2893
# NUmber of males: 2517
# Age
# Mean 64.4166358595194
# Std 7.743423223084423
# LPA
# Mean 1976.9216845841036
# Std 414.8292137777303
# MPA
# Mean 484.4173548243994
# Std 223.4087277242472
# VPA
# Mean 33.87367896487988
# Std 44.57648961925181
# SRLPA
# Mean 233.96783733826248
# Std 216.21816560690934
# SRMPA
# Mean 158.59907578558224
# Std 191.4536434159878
# SRVPA
# Mean 64.17744916820702
# Std 82.65668678330978
# DBP
# Mean 81.12421441774492
# Std 10.413972722407959
# SBP
# Mean 136.5894639556377
# Std 18.799893004289288
# BMI
# Mean 26.334092033271716
# Std 4.2281519593890495
# HG
# Mean 33.6090573012939
# Std 10.95014801623315
# HR
# Mean 67.98040665434381
# Std 10.696072914887235
# IS
# 11025    3322
# 11027    1150
# 11026     933
# 11028       5
# Name: IS, dtype: int64
# EDUA
#  16.0    817
#  18.0    455
#  15.0    450
#  17.0    342
#  21.0    139
#  19.0    112
#  20.0     91
#  22.0     55
#  23.0     30
#  24.0     18
#  14.0     15
#  25.0      8
# -1.0       7
#  27.0      7
#  5.0       5
#  30.0      3
#  35.0      2
# -3.0       2
#  28.0      2
#  11.0      1
#  33.0      1
#  10.0      1
#  13.0      1
# Name: EDUA, dtype: int64
# EDUL
# College or University degree                               2833
# O levels/GCSEs or equivalent                                975
# A levels/AS levels or equivalent                            713
# NVQ or HND or HNC or equivalent                             248
# None of the above                                           244
# Other professional qualifications eg: nursing, teaching     228
# CSEs or equivalent                                          169
# Prefer not to answer                                          0
# Name: EDUL, dtype: int64

# %% [markdown]
# ## 2.6 Train set descriptives

# %%
# get mean and std for all variables for males and females seperately for the test set
female = main_train[main_train["Gender"] == "Female"]
male = main_train[main_train["Gender"]== "Male"]

print("Number of females:", female.shape[0])
print("NUmber of males:", male.shape[0])

print("Age")
mean = main_train["Age"].mean()
print("Mean", mean)
std = main_train["Age"].std()
print("Std",std)

print("SRLPA")
mean = main_train["SRLPA"].mean()
print("Mean", mean)
std = main_train["SRLPA"].std()
print("Std",std)

print("SRMPA")
mean = main_train["SRMPA"].mean()
print("Mean", mean)
std = main_train["SRMPA"].std()
print("Std",std)

print("SRVPA")
mean = main_train["SRVPA"].mean()
print("Mean", mean)
std = main_train["SRVPA"].std()
print("Std",std)

print("DBP")
mean = main_train["DBP"].mean()
print("Mean", mean)
std = main_train["DBP"].std()
print("Std",std)

print("SBP")
mean = main_train["SBP"].mean()
print("Mean", mean)
std = main_train["SBP"].std()
print("Std",std)

print("BMI")
mean = main_train["BMI"].mean()
print("Mean", mean)
std = main_train["BMI"].std()
print("Std",std)

print("HG")
mean = main_train["HG"].mean()
print("Mean", mean)
std = main_train["HG"].std()
print("Std",std)

print("HR")
mean = main_train["HR"].mean()
print("Mean", mean)
std = main_train["HR"].std()
print("Std",std)

print("IS")
print(main_train["IS"].value_counts())

print("EDUA")
print(main_train["EDUA"].value_counts())

print("EDUL")
print(main_train["EDUL"].value_counts())
# Out:
# Number of females: 11117
# NUmber of males: 10325
# Age
# Mean 64.39889002891522
# Std 7.649732872523935
# SRLPA
# Mean 289.784948011223
# Std 309.29411344455514
# SRMPA
# Mean 206.94867139792044
# Std 280.6411674181547
# SRVPA
# Mean 82.22308411729108
# Std 130.49491812800625
# DBP
# Mean 81.29120713856025
# Std 10.363904029343296
# SBP
# Mean 136.45067174654102
# Std 18.67013239738352
# BMI
# Mean 26.645524985989166
# Std 4.237943939447412
# HG
# Mean 33.90108039848464
# Std 11.262323642066619
# HR
# Mean 68.077150591538
# Std 10.972897755270589
# IS
# 11025    12729
# 11027     5651
# 11026     3034
# 11028       28
# Name: IS, dtype: int64
# EDUA
#  16.0    3996
#  15.0    2165
#  18.0    1779
#  17.0    1479
#  21.0     662
#  19.0     442
#  20.0     312
#  22.0     236
#  23.0     122
#  14.0      76
#  24.0      69
#  25.0      55
# -1.0       37
# -3.0       32
#  26.0      26
#  27.0      15
#  35.0      14
#  28.0      12
#  30.0      12
#  32.0      10
#  31.0       9
#  29.0       6
#  34.0       6
#  33.0       5
#  5.0        3
#  13.0       2
#  12.0       1
# -2.0        1
#  10.0       1
#  11.0       1
#  6.0        1
# Name: EDUA, dtype: int64
# EDUL
# College or University degree                               9621
# O levels/GCSEs or equivalent                               4155
# A levels/AS levels or equivalent                           2718
# None of the above                                          1458
# NVQ or HND or HNC or equivalent                            1184
# Other professional qualifications eg: nursing, teaching    1046
# CSEs or equivalent                                          904
# Prefer not to answer                                         67
# Name: EDUL, dtype: int64

# %% [markdown]
# ## 2.7 Age and BrainAge

# %%
# # plot Age by Gender
# plt.figure()
# sns.kdeplot(data = main_test, x= 'Age', hue = 'Gender', fill=True, palette = "crest")
# plt.title("Age x Gender")
# plt.show()

# # plot BrainAGE by Gender
# plt.figure()
# sns.kdeplot(data = main_test, x= 'BADA2009', hue = 'Gender', fill=True, palette = "crest")
# plt.title("BrainAge x Gender")
# plt.show()

# # plot BrainAGE by Imaging Site
# plt.figure()
# sns.kdeplot(data = main_test, x= 'BADA2009', hue = 'IS', fill=True, palette = "crest")
# plt.title("BrainAge x Imaging site")
# plt.show()

# # plot Age by Imaging Site
# plt.figure()
# sns.kdeplot(data = main_test, x= 'Age', hue = 'IS', fill=True, palette = "crest")
# plt.title("Age x Imaging site")
# plt.show()

# # plot Moderate PA by Imaging Site
# plt.figure()
# sns.kdeplot(data = main_test, x= 'MPA', hue = 'IS', fill=True, palette = "crest")
# plt.title("Moderate PA x Imaging site")
# plt.show()

# # plot BrainAGE Segmentations
# plt.figure()
# sns.kdeplot(data = main_test, x= 'BADA2009', fill=True, label="Destrieux")
# sns.kdeplot(data = main_test, x= 'BADASEG', fill=True, label="ASEG")
# sns.kdeplot(data = main_test, x= 'BADDesikan', fill=True, label="Desikan")
# plt.xlabel("BrainAGE", fontsize=14)
# plt.ylabel("Density", fontsize=14)
# plt.xticks(fontsize=14)
# plt.yticks(fontsize=14)
# plt.legend(fontsize=14)
# plt.show()

# %% [markdown]
# ## 2.8 Physical activity

# %%
# plot physical activity intensity categories for self-report and accelerometer together and seperately

plt.figure()
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,5000,1000),fontsize = 14)
#plt.ylim(0,0.01)
plt.ylabel("Density",fontsize = 16)
plt.yticks(fontsize = 14)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA")
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA")
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2000,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRLPA', fill=True, label = "SR Light PA", color="#6baed6")
sns.kdeplot(data = main_test, x= 'LPA', fill=True, label = "Light PA", color="#08519c")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,4500,1000),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRMPA', fill=True, label = "SR Moderate PA", color="#fd8d3c")
sns.kdeplot(data = main_test, x= 'MPA', fill=True, label = "Moderate PA", color="#a63603")
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.xticks(range(0,2500,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.legend()
plt.show()

plt.figure()
sns.kdeplot(data = main_test, x= 'SRVPA', fill=True, label = "SR Vigorous PA", color="#74c476")
sns.kdeplot(data = main_test, x= 'VPA', fill=True, label = "Vigorous PA", color="#006d2c")
plt.ylim(0,0.01)
plt.xticks(range(0,1500,500),fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Density",fontsize = 16)
plt.xlabel("Min/week of physical activity", fontsize = 16)
plt.legend()
plt.show()

plt.figure()
plt.scatter("MPA", "SRMPA", data = main_test, label = "Moderate PA", alpha=0.3, s=10, color = "darkcyan")
plt.scatter("VPA", "SRVPA", data = main_test, label = "Vigorous PA", alpha=0.3, s=10, color = "mediumvioletred")
plt.ylabel("Self-reported (min/week)", fontsize = 16)
plt.xlabel("Accelerometer (min/week)", fontsize = 16)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## 2.9 Fitness

# %%
# plot dominant hand grip strength
plt.figure()
sns.kdeplot(data = main_test, x= 'HG', hue = 'Gender', fill=True, palette = "crest")
plt.title("Hand grip")
plt.show()

# %% [markdown]
# ## 2.10 Health

# %%
# plot Heart rate
plt.figure()
sns.kdeplot(data = main_test, x= 'HR', hue = 'Gender', fill=True, palette = "crest")
plt.title("Heart rate")
plt.show()

# plot systolic blood pressure
plt.figure()
sns.kdeplot(data = main_test, x= 'SBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Systolic BP")
plt.show()

# plot diastolic blood pressure
plt.figure()
sns.kdeplot(data = main_test, x= 'DBP', hue = 'Gender', fill=True, palette = "crest")
plt.title("Diastolic BP")
plt.show()

# plot BMI
plt.figure()
sns.kdeplot(data = main_test, x= 'BMI', hue = 'Gender', fill=True, palette = "crest")
plt.title("BMI")
plt.show()

# %% [markdown]
# # 3 Recode variables

# %%
# recode Imaging site and Gender
# 1 = Cheadle;  2 = Reading;  3 = Newcastle;  4 = Bristol
main_test['IS'] = main_test['IS'].map({'11025': 0, '11026': 1,'11027': 2, '11028': 3})
# fix this
main_test['EDUL'] = main_test['EDUL'].map({'None of the above': 0, 'Other professional qualifications eg: nursing, teaching': 5,'NVQ or HND or HNC or equivalent': 4, 'CSEs or equivalent': 1, 'O levels/GCSEs or equivalent':2, 'A levels/AS levels or equivalent':3,'College or University degree':6})
main_test["Gender"] = main_test["Gender"].map({"Female":0, "Male":1})
main_test["Gender"] = main_test["Gender"].astype("int")
main_test = main_test.rename(columns={"BADCombined": "BA"})

print("EDU")
print(main_test["EDUL"].value_counts())
# Out:
# EDU
# 6.0    2833
# 2.0     975
# 3.0     713
# 4.0     248
# 0.0     244
# 5.0     228
# 1.0     169
# Name: EDUL, dtype: int64

# %% [markdown]
# # 4 Reorder dataframe and delete unused variables

# %%
main_test = main_test[['Age', 'Gender', 'IS' , 'LPA', 'MPA', 'VPA', 'SRLPA', 'SRMPA', 'SRVPA', 'HG', 'HR', 'BMI', 'DBP', 'SBP', "EDUL", "EDUA", 'BA']]

# %% [markdown]
# # 5 Correlation heatmap

# %%
def calculate_pvalues(df):
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            tmp = df[df[r].notnull() & df[c].notnull()]
            pvalues[r][c] = round(pearsonr(tmp[r], tmp[c])[1], 4)
    return pvalues

# %%
corr_test = main_test
corr_test = corr_test[:]
#del corr_test["BA"]
del corr_test["SBP"]
del corr_test["IS"]
#del corr_test["EDU"]
corr = corr_test.corr()
corr = round(corr,3)

fig, ax = plt.subplots(figsize=(13,10)) 
sns.heatmap(corr, annot=True, cmap = "coolwarm", vmin=-1, vmax=1)
plt.xticks(size=10)
plt.yticks(size=10)


p_values = np.asarray(calculate_pvalues(corr_test))

threshold = 0.0007575  # Define your significance threshold

for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        if i != j:
            correlation = corr.iloc[i, j]
            p_value = p_values[i,j]  # Calculate or provide the p-value for the correlation

            if p_value < threshold:
                ax.text(j + 0.9, i + 0.2, "*", ha='right', va='top', color='black', fontsize=12)

# %% [markdown]
# # 6 Models OLS

# %% [markdown]
# ## 6.1 PA BrainAGE Regression

# %% [markdown]
# ### 6.1.1 Baseline Covariates

# %%
cov_model = ols('BA ~ Gender + Age + IS + EDUL', missing='drop', data = main_test).fit()
print(cov_model.summary())

#calculate effect size
results = cov_model
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     9.803
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           6.72e-08
# Time:                        15:17:06   Log-Likelihood:                -17153.
# No. Observations:                5410   AIC:                         3.432e+04
# Df Residuals:                    5405   BIC:                         3.435e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0399      0.686      2.974      0.003       0.695       3.384
# Gender         0.6447      0.159      4.063      0.000       0.334       0.956
# Age           -0.0282      0.010     -2.744      0.006      -0.048      -0.008
# IS             0.2082      0.096      2.162      0.031       0.019       0.397
# EDUL          -0.1631      0.040     -4.091      0.000      -0.241      -0.085
# ==============================================================================
# Omnibus:                       37.659   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.158
# Skew:                           0.174   Prob(JB):                     1.90e-09
# Kurtosis:                       3.238   Cond. No.                         569.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept    0.040391
# Gender       0.055180
# Age         -0.037263
# IS           0.029364
# EDUL        -0.055555
# dtype: float64

# %% [markdown]
# ### 6.1.2 Accelerometer PA

# %%
lpa = ols('BA ~ LPA + Age + Gender + IS + EDUL + Gender:LPA + EDUL:LPA', missing='drop', data = main_test).fit()
print(lpa.summary())

#calculate effect size
results = lpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     5.934
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           6.78e-07
# Time:                        15:17:06   Log-Likelihood:                -17152.
# No. Observations:                5410   AIC:                         3.432e+04
# Df Residuals:                    5402   BIC:                         3.437e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7844      1.207      0.650      0.516      -1.581       3.150
# LPA            0.0006      0.000      1.262      0.207      -0.000       0.002
# Age           -0.0280      0.010     -2.718      0.007      -0.048      -0.008
# Gender         0.5759      0.780      0.739      0.460      -0.952       2.104
# IS             0.2113      0.096      2.193      0.028       0.022       0.400
# EDUL           0.0329      0.194      0.169      0.865      -0.348       0.414
# Gender:LPA  5.139e-05      0.000      0.133      0.895      -0.001       0.001
# EDUL:LPA   -9.826e-05   9.57e-05     -1.026      0.305      -0.000    8.94e-05
# ==============================================================================
# Omnibus:                       37.964   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.478
# Skew:                           0.175   Prob(JB):                     1.62e-09
# Kurtosis:                       3.239   Cond. No.                     1.55e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.55e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.008829
# LPA           0.017137
# Age          -0.036914
# Gender        0.010034
# IS            0.029777
# EDUL          0.002302
# Gender:LPA    0.001801
# EDUL:LPA     -0.013940
# dtype: float64

# %%
mpa = ols('BA ~ MPA + Age + Gender + IS + EDUL + Gender:MPA + EDUL:MPA', missing='drop', data = main_test).fit()
print(mpa.summary())

#calculate effect size
results = mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     8.021
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           9.95e-10
# Time:                        15:17:06   Log-Likelihood:                -17145.
# No. Observations:                5410   AIC:                         3.431e+04
# Df Residuals:                    5402   BIC:                         3.436e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.6150      0.845      1.912      0.056      -0.041       3.271
# MPA            0.0016      0.001      1.811      0.070      -0.000       0.003
# Age           -0.0334      0.010     -3.180      0.001      -0.054      -0.013
# Gender         1.7454      0.377      4.633      0.000       1.007       2.484
# IS             0.2180      0.096      2.264      0.024       0.029       0.407
# EDUL          -0.0222      0.094     -0.237      0.813      -0.206       0.161
# Gender:MPA    -0.0023      0.001     -3.288      0.001      -0.004      -0.001
# EDUL:MPA      -0.0003      0.000     -1.710      0.087      -0.001    4.39e-05
# ==============================================================================
# Omnibus:                       35.482   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.966
# Skew:                           0.167   Prob(JB):                     5.70e-09
# Kurtosis:                       3.240   Cond. No.                     2.79e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.79e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.025962
# MPA           0.024598
# Age          -0.043181
# Gender        0.062918
# IS            0.030751
# EDUL         -0.003221
# Gender:MPA   -0.044649
# EDUL:MPA     -0.023229
# dtype: float64

# %%
vpa = ols('BA ~ VPA + Age + Gender + IS + EDUL + Gender:VPA + EDUL:VPA', missing='drop', data = main_test).fit()
print(vpa.summary())

#calculate effect size
results = vpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     6.570
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           9.49e-08
# Time:                        15:17:06   Log-Likelihood:                -17150.
# No. Observations:                5410   AIC:                         3.432e+04
# Df Residuals:                    5402   BIC:                         3.437e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.1800      0.729      2.991      0.003       0.751       3.609
# VPA           -0.0011      0.005     -0.207      0.836      -0.011       0.009
# Age           -0.0299      0.010     -2.847      0.004      -0.050      -0.009
# Gender         0.9356      0.199      4.698      0.000       0.545       1.326
# IS             0.2073      0.096      2.152      0.031       0.018       0.396
# EDUL          -0.1907      0.051     -3.761      0.000      -0.290      -0.091
# Gender:VPA    -0.0082      0.004     -2.332      0.020      -0.015      -0.001
# EDUL:VPA       0.0009      0.001      0.903      0.367      -0.001       0.003
# ==============================================================================
# Omnibus:                       37.831   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.446
# Skew:                           0.174   Prob(JB):                     1.65e-09
# Kurtosis:                       3.242   Cond. No.                     2.64e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.64e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept     0.040618
# VPA          -0.002816
# Age          -0.038670
# Gender        0.063801
# IS            0.029222
# EDUL         -0.051082
# Gender:VPA   -0.031664
# EDUL:VPA      0.012258
# dtype: float64

# %% [markdown]
# ### 6.1.3 Self-report PA

# %%
srlpa = ols('BA ~ SRLPA + Age + Gender + IS + EDUL + Gender:SRLPA + EDUL:SRLPA', missing='drop', data = main_test).fit()
print(srlpa.summary())

#calculate effect size
results = srlpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     6.022
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           5.18e-07
# Time:                        15:17:06   Log-Likelihood:                -17152.
# No. Observations:                5410   AIC:                         3.432e+04
# Df Residuals:                    5402   BIC:                         3.437e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.8543      0.722      2.569      0.010       0.439       3.269
# SRLPA            0.0008      0.001      0.886      0.375      -0.001       0.003
# Age             -0.0283      0.010     -2.750      0.006      -0.048      -0.008
# Gender           0.8819      0.232      3.801      0.000       0.427       1.337
# IS               0.2025      0.096      2.099      0.036       0.013       0.392
# EDUL            -0.1636      0.059     -2.754      0.006      -0.280      -0.047
# Gender:SRLPA    -0.0010      0.001     -1.372      0.170      -0.002       0.000
# EDUL:SRLPA    8.967e-06      0.000      0.050      0.960      -0.000       0.000
# ==============================================================================
# Omnibus:                       38.046   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.692
# Skew:                           0.174   Prob(JB):                     1.46e-09
# Kurtosis:                       3.243   Cond. No.                     1.38e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.034890
# SRLPA           0.012037
# Age            -0.037345
# Gender          0.051616
# IS              0.028510
# EDUL           -0.037397
# Gender:SRLPA   -0.018630
# EDUL:SRLPA      0.000678
# dtype: float64

# %%
srmpa = ols('BA ~ SRMPA + Age + Gender + IS + EDUL + Gender:SRMPA + EDUL:SRMPA', missing='drop', data = main_test).fit()
print(srmpa.summary())

#calculate effect size
results = srmpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     6.897
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           3.43e-08
# Time:                        15:17:06   Log-Likelihood:                -17149.
# No. Observations:                5410   AIC:                         3.431e+04
# Df Residuals:                    5402   BIC:                         3.437e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        2.2262      0.704      3.162      0.002       0.846       3.606
# SRMPA           -0.0008      0.001     -0.749      0.454      -0.003       0.001
# Age             -0.0290      0.010     -2.803      0.005      -0.049      -0.009
# Gender           0.9234      0.205      4.504      0.000       0.521       1.325
# IS               0.2155      0.096      2.238      0.025       0.027       0.404
# EDUL            -0.2358      0.052     -4.519      0.000      -0.338      -0.133
# Gender:SRMPA    -0.0017      0.001     -2.006      0.045      -0.003   -3.75e-05
# EDUL:SRMPA       0.0004      0.000      2.102      0.036     2.9e-05       0.001
# ==============================================================================
# Omnibus:                       37.469   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.996
# Skew:                           0.173   Prob(JB):                     2.07e-09
# Kurtosis:                       3.240   Cond. No.                     1.05e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.042943
# SRMPA          -0.010172
# Age            -0.038065
# Gender          0.061172
# IS              0.030395
# EDUL           -0.061374
# Gender:SRMPA   -0.027242
# EDUL:SRMPA      0.028549
# dtype: float64

# %%
srvpa = ols('BA ~ SRVPA + Age + Gender + IS + EDUL + Gender:SRVPA + EDUL:SRVPA', missing='drop', data = main_test).fit()
print(srvpa.summary())

#calculate effect size
results = srvpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     6.764
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           5.19e-08
# Time:                        15:17:06   Log-Likelihood:                -17149.
# No. Observations:                5410   AIC:                         3.431e+04
# Df Residuals:                    5402   BIC:                         3.437e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        2.0858      0.701      2.976      0.003       0.712       3.460
# SRVPA           -0.0008      0.002     -0.321      0.748      -0.006       0.004
# Age             -0.0280      0.010     -2.723      0.006      -0.048      -0.008
# Gender           0.8762      0.201      4.357      0.000       0.482       1.270
# IS               0.2102      0.096      2.183      0.029       0.021       0.399
# EDUL            -0.2184      0.050     -4.384      0.000      -0.316      -0.121
# Gender:SRVPA    -0.0038      0.002     -1.992      0.046      -0.008   -6.07e-05
# EDUL:SRVPA       0.0009      0.000      1.825      0.068   -6.45e-05       0.002
# ==============================================================================
# Omnibus:                       38.578   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.331
# Skew:                           0.175   Prob(JB):                     1.06e-09
# Kurtosis:                       3.247   Cond. No.                     4.61e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.61e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept       0.040418
# SRVPA          -0.004357
# Age            -0.036977
# Gender          0.059170
# IS              0.029643
# EDUL           -0.059537
# Gender:SRVPA   -0.027057
# EDUL:SRVPA      0.024783
# dtype: float64

# %% [markdown]
# ## 6.2 PA+Fitness models

# %% [markdown]
# ### 6.2.1 PAF

# %%
paf = ols('BA ~ MPA + HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(paf.summary())

#calculate effect size
results = paf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     7.894
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           7.57e-16
# Time:                        15:17:06   Log-Likelihood:                -17122.
# No. Observations:                5410   AIC:                         3.427e+04
# Df Residuals:                    5396   BIC:                         3.436e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.1231      1.427     -0.787      0.431      -3.920       1.674
# MPA            0.0005      0.000      0.951      0.341      -0.000       0.001
# HG            -0.0138      0.017     -0.816      0.415      -0.047       0.019
# DBP            0.0284      0.011      2.504      0.012       0.006       0.051
# HR             0.0180      0.011      1.616      0.106      -0.004       0.040
# BMI           -0.0004      0.026     -0.014      0.989      -0.051       0.050
# Gender         0.6300      1.803      0.349      0.727      -2.905       4.165
# IS             0.1768      0.096      1.842      0.066      -0.011       0.365
# Age           -0.0419      0.011     -3.858      0.000      -0.063      -0.021
# HG:Gender     -0.0506      0.021     -2.380      0.017      -0.092      -0.009
# DBP:Gender     0.0157      0.016      0.954      0.340      -0.017       0.048
# HR:Gender      0.0130      0.015      0.843      0.399      -0.017       0.043
# BMI:Gender     0.0390      0.041      0.951      0.342      -0.041       0.119
# MPA:Gender    -0.0019      0.001     -2.674      0.008      -0.003      -0.001
# ==============================================================================
# Omnibus:                       38.047   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.320
# Skew:                           0.168   Prob(JB):                     1.07e-09
# Kurtosis:                       3.264   Cond. No.                     1.58e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.010689
# MPA           0.012921
# HG           -0.011082
# DBP           0.034011
# HR            0.021950
# BMI          -0.000194
# Gender        0.004745
# IS            0.025015
# Age          -0.052396
# HG:Gender    -0.032317
# DBP:Gender    0.012961
# HR:Gender     0.011450
# BMI:Gender    0.012911
# MPA:Gender   -0.036309
# dtype: float64

# %% [markdown]
# ### 6.2.2 SRPAF

# %%
srpaf = ols('BA ~ SRMPA + HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender + SRMPA:Gender', missing='drop', data = main_test).fit()
print(srpaf.summary())

#calculate effect size
results = srpaf
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     7.573
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           4.71e-15
# Time:                        15:17:06   Log-Likelihood:                -17124.
# No. Observations:                5410   AIC:                         3.428e+04
# Df Residuals:                    5396   BIC:                         3.437e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -1.1581      1.338     -0.866      0.387      -3.781       1.465
# SRMPA            0.0011      0.001      2.058      0.040    5.44e-05       0.002
# HG              -0.0114      0.017     -0.675      0.500      -0.044       0.022
# DBP              0.0277      0.011      2.440      0.015       0.005       0.050
# HR               0.0181      0.011      1.631      0.103      -0.004       0.040
# BMI             -0.0026      0.025     -0.105      0.917      -0.052       0.047
# Gender          -0.7304      1.711     -0.427      0.670      -4.085       2.625
# IS               0.1702      0.096      1.775      0.076      -0.018       0.358
# Age             -0.0399      0.011     -3.717      0.000      -0.061      -0.019
# HG:Gender       -0.0536      0.021     -2.528      0.012      -0.095      -0.012
# DBP:Gender       0.0170      0.016      1.031      0.303      -0.015       0.049
# HR:Gender        0.0146      0.015      0.948      0.343      -0.016       0.045
# BMI:Gender       0.0580      0.040      1.442      0.149      -0.021       0.137
# SRMPA:Gender    -0.0012      0.001     -1.455      0.146      -0.003       0.000
# ==============================================================================
# Omnibus:                       39.579   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.035
# Skew:                           0.172   Prob(JB):                     4.52e-10
# Kurtosis:                       3.269   Cond. No.                     7.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept      -0.011755
# SRMPA           0.027948
# HG             -0.009167
# DBP             0.033130
# HR              0.022151
# BMI            -0.001420
# Gender         -0.005796
# IS              0.024106
# Age            -0.050473
# HG:Gender      -0.034326
# DBP:Gender      0.013998
# HR:Gender       0.012871
# BMI:Gender      0.019582
# SRMPA:Gender   -0.019765
# dtype: float64

# %% [markdown]
# ### 6.2.3 PAF / MPA

# %%
no_mpa = ols('BA ~ HG + DBP + HR + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_mpa.summary())

#calculate effect size
results = no_mpa
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     8.560
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           3.54e-15
# Time:                        15:17:06   Log-Likelihood:                -17126.
# No. Observations:                5410   AIC:                         3.428e+04
# Df Residuals:                    5398   BIC:                         3.436e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9979      1.334     -0.748      0.454      -3.613       1.617
# HG            -0.0110      0.017     -0.653      0.514      -0.044       0.022
# DBP            0.0282      0.011      2.478      0.013       0.006       0.050
# HR             0.0172      0.011      1.551      0.121      -0.005       0.039
# BMI           -0.0057      0.025     -0.226      0.821      -0.055       0.044
# Gender        -1.0504      1.695     -0.620      0.535      -4.373       2.272
# IS             0.1682      0.096      1.753      0.080      -0.020       0.356
# Age           -0.0380      0.011     -3.569      0.000      -0.059      -0.017
# HG:Gender     -0.0536      0.021     -2.525      0.012      -0.095      -0.012
# DBP:Gender     0.0165      0.016      1.001      0.317      -0.016       0.049
# HR:Gender      0.0155      0.015      1.012      0.312      -0.015       0.046
# BMI:Gender     0.0613      0.040      1.525      0.127      -0.018       0.140
# ==============================================================================
# Omnibus:                       39.033   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.366
# Skew:                           0.171   Prob(JB):                     6.31e-10
# Kurtosis:                       3.265   Cond. No.                     3.56e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.010161
# HG           -0.008866
# DBP           0.033655
# HR            0.021062
# BMI          -0.003065
# Gender       -0.008417
# IS            0.023808
# Age          -0.048469
# HG:Gender    -0.034294
# DBP:Gender    0.013597
# HR:Gender     0.013742
# BMI:Gender    0.020707
# dtype: float64

# %% [markdown]
# ### 6.2.4 PAF / HG

# %%
no_hg = ols('BA ~ MPA + DBP + HR + BMI + Gender + IS + Age + MPA:Gender + DBP:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hg.summary())

#calculate effect size
results = no_hg
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     7.203
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           2.61e-12
# Time:                        15:17:06   Log-Likelihood:                -17133.
# No. Observations:                5410   AIC:                         3.429e+04
# Df Residuals:                    5398   BIC:                         3.437e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.1136      1.311     -1.612      0.107      -4.684       0.457
# MPA            0.0005      0.000      1.005      0.315      -0.000       0.001
# DBP            0.0275      0.011      2.421      0.016       0.005       0.050
# HR             0.0183      0.011      1.644      0.100      -0.004       0.040
# BMI            0.0003      0.026      0.010      0.992      -0.050       0.051
# Gender        -1.2449      1.707     -0.729      0.466      -4.591       2.101
# IS             0.1742      0.096      1.812      0.070      -0.014       0.363
# Age           -0.0317      0.010     -3.019      0.003      -0.052      -0.011
# MPA:Gender    -0.0020      0.001     -2.688      0.007      -0.003      -0.001
# DBP:Gender     0.0107      0.016      0.652      0.515      -0.022       0.043
# HR:Gender      0.0150      0.015      0.974      0.330      -0.015       0.045
# BMI:Gender     0.0314      0.041      0.766      0.444      -0.049       0.112
# ==============================================================================
# Omnibus:                       37.803   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.546
# Skew:                           0.172   Prob(JB):                     1.57e-09
# Kurtosis:                       3.247   Cond. No.                     1.48e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.48e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.021891
# MPA           0.013645
# DBP           0.032878
# HR            0.022333
# BMI           0.000137
# Gender       -0.009906
# IS            0.024602
# Age          -0.040994
# MPA:Gender   -0.036510
# DBP:Gender    0.008850
# HR:Gender     0.013223
# BMI:Gender    0.010402
# dtype: float64

# %% [markdown]
# ### 6.2.5 PAF / HR

# %%
no_hr = ols('BA ~ HG + DBP + MPA + BMI + Gender + IS + Age + HG:Gender + DBP:Gender + MPA:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_hr.summary())

#calculate effect size
results = no_hr
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     8.306
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           1.23e-14
# Time:                        15:17:06   Log-Likelihood:                -17127.
# No. Observations:                5410   AIC:                         3.428e+04
# Df Residuals:                    5398   BIC:                         3.436e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.2072      1.319     -0.157      0.875      -2.792       2.378
# HG            -0.0147      0.017     -0.871      0.384      -0.048       0.018
# DBP            0.0331      0.011      3.003      0.003       0.011       0.055
# MPA            0.0004      0.000      0.823      0.411      -0.001       0.001
# BMI            0.0020      0.026      0.078      0.938      -0.048       0.052
# Gender         1.0670      1.665      0.641      0.522      -2.197       4.331
# IS             0.1887      0.096      1.966      0.049       0.001       0.377
# Age           -0.0427      0.011     -3.930      0.000      -0.064      -0.021
# HG:Gender     -0.0515      0.021     -2.424      0.015      -0.093      -0.010
# DBP:Gender     0.0188      0.016      1.170      0.242      -0.013       0.050
# MPA:Gender    -0.0020      0.001     -2.730      0.006      -0.003      -0.001
# BMI:Gender     0.0458      0.041      1.120      0.263      -0.034       0.126
# ==============================================================================
# Omnibus:                       37.360   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.561
# Skew:                           0.167   Prob(JB):                     1.56e-09
# Kurtosis:                       3.263   Cond. No.                     1.44e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.002134
# HG           -0.011832
# DBP           0.040787
# MPA           0.011171
# BMI           0.001062
# Gender        0.008703
# IS            0.026705
# Age          -0.053367
# HG:Gender    -0.032918
# DBP:Gender    0.015888
# MPA:Gender   -0.037075
# BMI:Gender    0.015209
# dtype: float64

# %% [markdown]
# ### 6.2.6 PAF / DBP

# %%
no_dbp = ols('BA ~ HG + MPA + HR + BMI + Gender + IS + Age + HG:Gender + MPA:Gender + HR:Gender + BMI:Gender', missing='drop', data = main_test).fit()
print(no_dbp.summary())

#calculate effect size
results = no_dbp
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     7.497
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           6.30e-13
# Time:                        15:17:07   Log-Likelihood:                -17132.
# No. Observations:                5410   AIC:                         3.429e+04
# Df Residuals:                    5398   BIC:                         3.437e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0709      1.354     -0.052      0.958      -2.725       2.584
# HG            -0.0113      0.017     -0.670      0.503      -0.044       0.022
# MPA            0.0005      0.000      0.973      0.330      -0.000       0.001
# HR             0.0249      0.011      2.310      0.021       0.004       0.046
# BMI            0.0179      0.025      0.724      0.469      -0.030       0.066
# Gender         1.5989      1.622      0.986      0.324      -1.580       4.778
# IS             0.1844      0.096      1.919      0.055      -0.004       0.373
# Age           -0.0391      0.011     -3.602      0.000      -0.060      -0.018
# HG:Gender     -0.0475      0.021     -2.237      0.025      -0.089      -0.006
# MPA:Gender    -0.0020      0.001     -2.704      0.007      -0.003      -0.001
# HR:Gender      0.0146      0.015      0.978      0.328      -0.015       0.044
# BMI:Gender     0.0455      0.040      1.141      0.254      -0.033       0.124
# ==============================================================================
# Omnibus:                       37.382   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.698
# Skew:                           0.166   Prob(JB):                     1.45e-09
# Kurtosis:                       3.266   Cond. No.                     1.42e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.42e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.000711
# HG           -0.009101
# MPA           0.013221
# HR            0.031373
# BMI           0.009834
# Gender        0.013391
# IS            0.026057
# Age          -0.048923
# HG:Gender    -0.030377
# MPA:Gender   -0.036718
# HR:Gender     0.013286
# BMI:Gender    0.015491
# dtype: float64

# %% [markdown]
# ### 6.2.7 PAF / BMI

# %%
no_bmi = ols('BA ~ HG + DBP + HR + MPA + Gender + IS + Age + HG:Gender + DBP:Gender + HR:Gender + MPA:Gender', missing='drop', data = main_test).fit()
print(no_bmi.summary())

#calculate effect size
results = no_bmi
coefficients = results.params
stderr = results.bse
effect_size = coefficients / (stderr* np.sqrt(5422))
print(effect_size)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     9.197
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           1.54e-16
# Time:                        15:17:07   Log-Likelihood:                -17123.
# No. Observations:                5410   AIC:                         3.427e+04
# Df Residuals:                    5398   BIC:                         3.435e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0843      1.358     -0.798      0.425      -3.747       1.578
# HG            -0.0140      0.017     -0.828      0.408      -0.047       0.019
# DBP            0.0284      0.011      2.610      0.009       0.007       0.050
# HR             0.0180      0.011      1.617      0.106      -0.004       0.040
# MPA            0.0005      0.000      0.970      0.332      -0.000       0.001
# Gender         1.3665      1.646      0.830      0.407      -1.861       4.594
# IS             0.1768      0.096      1.842      0.065      -0.011       0.365
# Age           -0.0426      0.011     -3.922      0.000      -0.064      -0.021
# HG:Gender     -0.0496      0.021     -2.336      0.020      -0.091      -0.008
# DBP:Gender     0.0187      0.016      1.172      0.241      -0.013       0.050
# HR:Gender      0.0143      0.015      0.930      0.353      -0.016       0.044
# MPA:Gender    -0.0021      0.001     -2.909      0.004      -0.003      -0.001
# ==============================================================================
# Omnibus:                       37.860   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.988
# Skew:                           0.169   Prob(JB):                     1.26e-09
# Kurtosis:                       3.260   Cond. No.                     1.47e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Intercept    -0.010843
# HG           -0.011249
# DBP           0.035447
# HR            0.021963
# MPA           0.013180
# Gender        0.011272
# IS            0.025022
# Age          -0.053259
# HG:Gender    -0.031720
# DBP:Gender    0.015921
# HR:Gender     0.012628
# MPA:Gender   -0.039511
# dtype: float64

# %% [markdown]
# # 7 Model comparisons

# %% [markdown]
# ## 7.1 Cov vs. PA

# %%
model_comparison = anova_lm(cov_model, lpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5405.0  179769.738094      0.0        NaN       NaN       NaN
# 1    5402.0  179692.070910      3.0  77.667185  0.778291  0.505928

# %%
model_comparison = anova_lm(cov_model, mpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5405.0  179769.738094      0.0        NaN       NaN       NaN
# 1    5402.0  179211.123145      3.0  558.61495  5.612817  0.000772

# %%
model_comparison = anova_lm(cov_model, vpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5405.0  179769.738094      0.0         NaN       NaN       NaN
# 1    5402.0  179545.312691      3.0  224.425404  2.250771  0.080353

# %% [markdown]
# ## 7.2 Cov vs. SRPA

# %%
model_comparison = anova_lm(cov_model, srlpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5405.0  179769.738094      0.0        NaN       NaN       NaN
# 1    5402.0  179671.932894      3.0  97.805201  0.980201  0.400957

# %%
model_comparison = anova_lm(cov_model, srmpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F   Pr(>F)
# 0    5405.0  179769.738094      0.0         NaN       NaN      NaN
# 1    5402.0  179469.956234      3.0  299.781861  3.007786  0.02907

# %%
model_comparison = anova_lm(cov_model, srvpa)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5405.0  179769.738094      0.0         NaN       NaN       NaN
# 1    5402.0  179500.684896      3.0  269.053198  2.699015  0.044153

# %% [markdown]
# # 8 PAF Type-III ANOVA

# %% [markdown]
# ## 8.1 PAF / MPA

# %%
model_comparison = anova_lm(no_mpa, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5398.0  177969.505829      0.0         NaN       NaN       NaN
# 1    5396.0  177694.631033      2.0  274.874796  4.173521  0.015448

# %% [markdown]
# ## 8.2 SR PAF / SRMPA

# %%
model_comparison = anova_lm(no_mpa, srpaf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F  Pr(>F)
# 0    5398.0  177969.505829      0.0         NaN       NaN     NaN
# 1    5396.0  177829.590660      2.0  139.915169  2.122769  0.1198

# %% [markdown]
# ## 8.3 PAF / HG

# %%
model_comparison = anova_lm(no_hg, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff   ss_diff          F   Pr(>F)
# 0    5398.0  178454.649433      0.0       NaN        NaN      NaN
# 1    5396.0  177694.631033      2.0  760.0184  11.539626  0.00001

# %% [markdown]
# ## 8.4 PAF / DBP

# %%
model_comparison = anova_lm(no_dbp, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff        F    Pr(>F)
# 0    5398.0  178349.327703      0.0         NaN      NaN       NaN
# 1    5396.0  177694.631033      2.0  654.696671  9.94049  0.000049

# %% [markdown]
# ## 8.5 PAF / HR

# %%
model_comparison = anova_lm(no_hr, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff     ss_diff         F    Pr(>F)
# 0    5398.0  178059.961818      0.0         NaN       NaN       NaN
# 1    5396.0  177694.631033      2.0  365.330786  5.546946  0.003922

# %% [markdown]
# ## 8.6 PAF / BMI

# %%
model_comparison = anova_lm(no_bmi, paf)
print(model_comparison)
# Out:
#    df_resid            ssr  df_diff    ss_diff         F    Pr(>F)
# 0    5398.0  177742.573768      0.0        NaN       NaN       NaN
# 1    5396.0  177694.631033      2.0  47.942736  0.727931  0.482954

# %% [markdown]
# # 9 Standardization of all variables

# %%
main_test = pd.DataFrame(main_test)
main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Gender","IS", "EDUL"]] = stats.zscore(main_test[["LPA", "MPA","VPA","SRLPA","SRMPA","SRVPA","HR", "DBP", "SBP", "HG","BMI","Age","Gender","IS","EDUL"]], nan_policy='omit')

# %% [markdown]
# # 10 Mediation analysis

# %% [markdown]
# ## 10.1 BMI

# %%
# outcome_model = sm.OLS.from_formula("BA ~ BMI + LPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("BMI ~ LPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ BMI + MPA + Age + Gender + IS + EDUL", main_test)
mediator_model = sm.OLS.from_formula("BMI ~ MPA + Age + Gender + IS + EDUL", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "MPA").fit()
print(res.summary())

modelm = ols("BMI ~ MPA + Age + Gender + IS + EDUL", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ BMI + Age + Gender + IS + EDUL", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.033692       -0.071965        0.004357    0.078
# ACME (treated)           -0.033692       -0.071965        0.004357    0.078
# ADE (control)            -0.120297       -0.279398        0.042300    0.146
# ADE (treated)            -0.120297       -0.279398        0.042300    0.146
# Total effect             -0.153989       -0.305755        0.007155    0.074
# Prop. mediated (control)  0.206204       -0.755768        1.299767    0.152
# Prop. mediated (treated)  0.206204       -0.755768        1.299767    0.152
# ACME (average)           -0.033692       -0.071965        0.004357    0.078
# ADE (average)            -0.120297       -0.279398        0.042300    0.146
# Prop. mediated (average)  0.206204       -0.755768        1.299767    0.152
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    BMI   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     92.64
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           7.38e-94
# Time:                        15:18:08   Log-Likelihood:                -7454.0
# No. Observations:                5410   AIC:                         1.492e+04
# Df Residuals:                    5404   BIC:                         1.496e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.004e-16      0.013   5.36e-14      1.000      -0.026       0.026
# MPA           -0.2319      0.013    -17.324      0.000      -0.258      -0.206
# Age           -0.0437      0.014     -3.230      0.001      -0.070      -0.017
# Gender         0.1249      0.013      9.472      0.000       0.099       0.151
# IS            -0.0001      0.013     -0.009      0.993      -0.026       0.026
# EDUL          -0.0997      0.013     -7.618      0.000      -0.125      -0.074
# ==============================================================================
# Omnibus:                     1257.910   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4008.859
# Skew:                           1.174   Prob(JB):                         0.00
# Kurtosis:                       6.502   Cond. No.                         1.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     8.782
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           2.61e-08
# Time:                        15:18:08   Log-Likelihood:                -17151.
# No. Observations:                5410   AIC:                         3.431e+04
# Df Residuals:                    5404   BIC:                         3.435e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0549      0.078     -0.701      0.483      -0.209       0.099
# BMI            0.1718      0.079      2.161      0.031       0.016       0.328
# Age           -0.2190      0.079     -2.756      0.006      -0.375      -0.063
# Gender         0.2984      0.080      3.738      0.000       0.142       0.455
# IS             0.1722      0.079      2.184      0.029       0.018       0.327
# EDUL          -0.3043      0.079     -3.853      0.000      -0.459      -0.149
# ==============================================================================
# Omnibus:                       36.944   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.482
# Skew:                           0.171   Prob(JB):                     2.67e-09
# Kurtosis:                       3.241   Cond. No.                         1.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ BMI + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("BMI ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "BMI", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 10.2 DBP

# %%
# outcome_model = sm.OLS.from_formula("BA ~ DBP + LPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("DBP ~ LPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ DBP + MPA + Age + Gender + IS + EDUL", main_test)
mediator_model = sm.OLS.from_formula("DBP ~ MPA + Age + Gender + IS + EDUL", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "MPA").fit()
print(res.summary())

modelm = ols("DBP ~ MPA + Age + Gender + IS + EDUL", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ DBP + Age + Gender + IS + EDUL", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.033094       -0.059394       -0.012172    0.000
# ACME (treated)           -0.033094       -0.059394       -0.012172    0.000
# ADE (control)            -0.120113       -0.282383        0.038147    0.156
# ADE (treated)            -0.120113       -0.282383        0.038147    0.156
# Total effect             -0.153206       -0.310738        0.009259    0.066
# Prop. mediated (control)  0.205499       -0.745310        1.496829    0.066
# Prop. mediated (treated)  0.205499       -0.745310        1.496829    0.066
# ACME (average)           -0.033094       -0.059394       -0.012172    0.000
# ADE (average)            -0.120113       -0.282383        0.038147    0.156
# Prop. mediated (average)  0.205499       -0.745310        1.496829    0.066
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DBP   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     51.79
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           1.25e-52
# Time:                        15:19:08   Log-Likelihood:                -7549.9
# No. Observations:                5410   AIC:                         1.511e+04
# Df Residuals:                    5404   BIC:                         1.515e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.377e-16      0.013   -4.8e-14      1.000      -0.026       0.026
# MPA           -0.0802      0.014     -5.888      0.000      -0.107      -0.054
# Age            0.0299      0.014      2.171      0.030       0.003       0.057
# Gender         0.1812      0.013     13.496      0.000       0.155       0.207
# IS             0.0206      0.013      1.540      0.124      -0.006       0.047
# EDUL          -0.0328      0.013     -2.463      0.014      -0.059      -0.007
# ==============================================================================
# Omnibus:                       98.936   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              106.194
# Skew:                           0.314   Prob(JB):                     8.72e-24
# Kurtosis:                       3.277   Cond. No.                         1.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     13.44
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           4.78e-13
# Time:                        15:19:08   Log-Likelihood:                -17139.
# No. Observations:                5410   AIC:                         3.429e+04
# Df Residuals:                    5404   BIC:                         3.433e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0549      0.078     -0.702      0.482      -0.208       0.098
# DBP            0.4206      0.080      5.270      0.000       0.264       0.577
# Age           -0.2379      0.079     -2.996      0.003      -0.393      -0.082
# Gender         0.2440      0.080      3.038      0.002       0.087       0.401
# IS             0.1632      0.079      2.075      0.038       0.009       0.317
# EDUL          -0.3076      0.078     -3.921      0.000      -0.461      -0.154
# ==============================================================================
# Omnibus:                       38.220   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.699
# Skew:                           0.176   Prob(JB):                     1.45e-09
# Kurtosis:                       3.237   Cond. No.                         1.28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ DBP + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("DBP ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "DBP", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 10.3 Heart rate

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HR + LPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("HR ~ LPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ HR + MPA + Age + Gender + EDUL", main_test)
mediator_model = sm.OLS.from_formula("HR ~ MPA + Age + Gender + EDUL", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "MPA").fit()
print(res.summary())

modelm = ols("HR ~ MPA + Age + Gender + EDUL", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ HR + Age + Gender + EDUL", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)           -0.040671       -0.066331       -0.019417    0.000
# ACME (treated)           -0.040671       -0.066331       -0.019417    0.000
# ADE (control)            -0.101961       -0.251167        0.053165    0.190
# ADE (treated)            -0.101961       -0.251167        0.053165    0.190
# Total effect             -0.142632       -0.291743        0.010258    0.074
# Prop. mediated (control)  0.270566       -0.887964        2.127062    0.074
# Prop. mediated (treated)  0.270566       -0.887964        2.127062    0.074
# ACME (average)           -0.040671       -0.066331       -0.019417    0.000
# ADE (average)            -0.101961       -0.251167        0.053165    0.190
# Prop. mediated (average)  0.270566       -0.887964        2.127062    0.074
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     HR   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     33.62
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           9.60e-28
# Time:                        15:20:02   Log-Likelihood:                -7610.0
# No. Observations:                5410   AIC:                         1.523e+04
# Df Residuals:                    5405   BIC:                         1.526e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.486e-16      0.013  -1.11e-14      1.000      -0.026       0.026
# MPA           -0.1078      0.014     -7.831      0.000      -0.135      -0.081
# Age           -0.0058      0.014     -0.421      0.674      -0.033       0.021
# Gender        -0.1194      0.014     -8.797      0.000      -0.146      -0.093
# EDUL          -0.0115      0.013     -0.855      0.393      -0.038       0.015
# ==============================================================================
# Omnibus:                      434.135   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              609.894
# Skew:                           0.663   Prob(JB):                    3.66e-133
# Kurtosis:                       3.974   Cond. No.                         1.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     14.73
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           5.62e-12
# Time:                        15:20:02   Log-Likelihood:                -17143.
# No. Observations:                5410   AIC:                         3.430e+04
# Df Residuals:                    5405   BIC:                         3.433e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0549      0.078     -0.702      0.483      -0.208       0.098
# HR             0.3882      0.079      4.927      0.000       0.234       0.543
# Age           -0.2079      0.079     -2.631      0.009      -0.363      -0.053
# Gender         0.3616      0.079      4.549      0.000       0.206       0.517
# EDUL          -0.3090      0.078     -3.943      0.000      -0.463      -0.155
# ==============================================================================
# Omnibus:                       38.200   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.825
# Skew:                           0.175   Prob(JB):                     1.36e-09
# Kurtosis:                       3.242   Cond. No.                         1.19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HR + VPA + Age + Gender", main_test)
# mediator_model = sm.OLS.from_formula("HR ~ VPA + Age + Gender", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HR", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# ## 10.4 Hand grip

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HG + LPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("HG ~ LPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "LPA").fit()
# print(res.summary())

# %%
outcome_model = sm.OLS.from_formula("BA ~ HG + MPA + Gender + Age + EDUL", main_test)
mediator_model = sm.OLS.from_formula("HG ~ MPA + Gender + Age + EDUL", main_test)
res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "MPA").fit()
print(res.summary())

modelm = ols("HG ~ MPA + Age + Gender + EDUL", missing='drop', data = main_test).fit()
print(modelm.summary())
modely = ols("BA ~ HG + Age + Gender + EDUL", missing='drop', data = main_test).fit()
print(modely.summary())
# Out:
#                           Estimate  Lower CI bound  Upper CI bound  P-value
# ACME (control)            0.001281       -0.012204        0.014650    0.812
# ACME (treated)            0.001281       -0.012204        0.014650    0.812
# ADE (control)            -0.147251       -0.302332       -0.002827    0.046
# ADE (treated)            -0.147251       -0.302332       -0.002827    0.046
# Total effect             -0.145970       -0.303034       -0.001098    0.048
# Prop. mediated (control) -0.007035       -0.241155        0.157602    0.828
# Prop. mediated (treated) -0.007035       -0.241155        0.157602    0.828
# ACME (average)            0.001281       -0.012204        0.014650    0.812
# ADE (average)            -0.147251       -0.302332       -0.002827    0.046
# Prop. mediated (average) -0.007035       -0.241155        0.157602    0.828
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     HG   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     1688.
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):               0.00
# Time:                        15:20:58   Log-Likelihood:                -5483.4
# No. Observations:                5410   AIC:                         1.098e+04
# Df Residuals:                    5405   BIC:                         1.101e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.025e-16      0.009  -2.23e-14      1.000      -0.018       0.018
# MPA           -0.0031      0.009     -0.335      0.738      -0.021       0.015
# Age           -0.1826      0.009    -19.520      0.000      -0.201      -0.164
# Gender         0.7440      0.009     81.228      0.000       0.726       0.762
# EDUL           0.0355      0.009      3.905      0.000       0.018       0.053
# ==============================================================================
# Omnibus:                       55.813   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.518
# Skew:                           0.013   Prob(JB):                     4.93e-21
# Kurtosis:                       3.644   Cond. No.                         1.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     BA   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     11.52
# Date:                Sat, 23 Nov 2024   Prob (F-statistic):           2.59e-09
# Time:                        15:20:58   Log-Likelihood:                -17150.
# No. Observations:                5410   AIC:                         3.431e+04
# Df Residuals:                    5405   BIC:                         3.434e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0549      0.078     -0.701      0.483      -0.209       0.099
# HG            -0.3986      0.118     -3.391      0.001      -0.629      -0.168
# Age           -0.2739      0.082     -3.344      0.001      -0.435      -0.113
# Gender         0.6136      0.118      5.205      0.000       0.382       0.845
# EDUL          -0.2996      0.079     -3.813      0.000      -0.454      -0.146
# ==============================================================================
# Omnibus:                       37.943   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.795
# Skew:                           0.172   Prob(JB):                     1.39e-09
# Kurtosis:                       3.251   Cond. No.                         2.65
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# outcome_model = sm.OLS.from_formula("BA ~ HG + VPA + Gender + Age", main_test)
# mediator_model = sm.OLS.from_formula("HG ~ VPA + Gender + Age", main_test)
# res = Mediation(outcome_model, mediator_model, mediator = "HG", exposure = "VPA").fit()
# print(res.summary())

# %% [markdown]
# # 11 LASSO Regression

# %% [markdown]
# ## 11.1 Accelerometer PA

# %%
df = main_test[["Age","Gender","IS", "EDUL", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age","Gender","IS", "EDUL", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age","Gender","IS", "EDUL", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


# lasso with cross validated alpha
lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)



cmap = cm.get_cmap('turbo')
plt.figure(figsize=(20,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

for i, column in enumerate(columns):
    y_pos = coefficients[i]
    color = cmap(i / 7.0)

    if i == 1:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, 0),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 5:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='square', facecolor='white', edgecolor="white", pad=0))
    elif i == 3:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='square', facecolor='white', edgecolor="white", pad=0))
    elif i == 6:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -4),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    else:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='square', facecolor='white',edgecolor="white", pad=0))
        
        
plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.xlim(0.001, 100)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, bbox_to_anchor=(1.01, 1.02), loc='upper left')
plt.legend().set_visible(False)
plt.show()




# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.005336699231206312
# [-0.3261213   0.58560178  0.15559303 -0.28388016 -0.08629898  0.26796201
#   0.35768876 -0.41812818  0.01157014]
# 0.01743374224450167

# %%
df = main_test[["Age","Gender","IS", "EDUA", "MPA", "SRMPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age","Gender","IS", "EDUA", "MPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age","Gender","IS", "EDUA", "MPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


# lasso with cross validated alpha
lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)

# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)



cmap = cm.get_cmap('turbo')
plt.figure(figsize=(20,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

for i, column in enumerate(columns):
    y_pos = coefficients[i]
    color = cmap(i / 7.0)

    if i == 1:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, 0),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 5:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='square', facecolor='white', edgecolor="white", pad=0))
    elif i == 3:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='square', facecolor='white', edgecolor="white", pad=0))
    elif i == 6:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -4),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    else:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='square', facecolor='white',edgecolor="white", pad=0))
        
        
plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.xlim(0.001, 100)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
plt.legend(columns, bbox_to_anchor=(1.01, 1.02), loc='upper left')
plt.legend().set_visible(False)
plt.show()




# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.03274549162877728
# [-0.25174431  0.63641102  0.01581887  0.00439087  0.          0.27731354
#   0.30261316 -0.31930773 -0.        ]
# 0.016634327112978298

# %% [markdown]
# ## 11.2 Self-report PA

# %%
df = main_test[["Age", "Gender", "IS", "EDUL", "LPA", "MPA", "VPA",  "SRLPA", "SRMPA", "SRVPA", "HR", "DBP", "HG", "BMI", "BA"]]
df = df.dropna()
df = pd.DataFrame(df)
X = df[["Age", "Gender", "IS", "EDUL", "SRMPA", "HR", "DBP", "HG", "BMI"]]
Y = df["BA"]
columns = ["Age", "Gender", "IS", "EDUL", "SRMPA", "HR", "DBP", "HG", "BMI"]

coefs = []
alphas = np.power(10,np.linspace(start=-3, stop=3, num=100))

for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X,Y)
    coefs.append(lasso.coef_)

coefs = pd.DataFrame(coefs)
coefs.columns = columns
coefs = pd.DataFrame(coefs)


cmap = cm.get_cmap('turbo')
plt.figure(figsize=(12,9))
coefs.plot(kind='line', colormap=cmap)
#plt.plot(coefs, color=cm.plasma([np.linspace(0,1,12)]))

# lasso with cross validated alpha
lassocv = LassoCV(alphas = alphas).fit(X,Y)
best_alpha = lassocv.alpha_
print("Optimal alpha:", best_alpha)


# Get the coefficients of the Lasso model at the best lambda value
lasso = Lasso(alpha=best_alpha)
lasso.fit(X, Y)
coefficients = lasso.coef_
r_squared = lasso.score(X,Y)

for i, column in enumerate(columns):
    y_pos = coefficients[i]
    color = cmap(i / 7.0)
    
    if i == 3:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(40, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    elif i == 7:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -3),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white', edgecolor="white", pad=0))
    else:
        plt.annotate(column, (1e-2, y_pos), textcoords="offset points", xytext=(0, -2),
                     ha='center', fontsize=10, color=color, bbox=dict(boxstyle='round', facecolor='white',edgecolor="white", pad=0))


plt.xticks(alphas, fontsize = 14)
plt.yticks(fontsize = 14)
plt.xscale("log")
plt.axis('tight')
plt.xlabel('Lambda', fontsize = 16)
plt.axvline(x = best_alpha, color = 'gray', linestyle='dashed')
plt.xlim(0.001, 100)
plt.ylabel('Coefficients', fontsize = 16)
#plt.title('Lasso coefficients as a function of alpha')
#plt.legend(columns, bbox_to_anchor=(1.01, 1.02), loc='upper left')
plt.legend().set_visible(False)
plt.show()


# Print the coefficients
print(coefficients)
print(r_squared)
# Out:
# Optimal alpha: 0.003511191734215131
# [-0.32590796  0.60428358  0.15454082 -0.2795276   0.09276633  0.28042118
#   0.35942291 -0.43230391  0.03697564]
# 0.017491353080682948
